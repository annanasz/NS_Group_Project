# %%
import os
import networkx as nx
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from networkx.algorithms.community import greedy_modularity_communities, label_propagation_communities, modularity
from collections import Counter, defaultdict, Counter
from scipy.stats import pearsonr, spearmanr, kendalltau, poisson, expon
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import factorial
import powerlaw


recipes_graph = nx.read_gml("final_recipe_graph_min_common_5.gml")

# %%
for node in recipes_graph.nodes(data=True):
    print(node)
# Out:
# ('522861', {'name': 'lplermagrone', 'num_ingredients': 8, 'ingredients': ['Milk', 'salt', 'macaroni', 'cheese', 'pepper', 'butter', 'onion', 'garlic']})
# ('523359', {'name': 'der wiener schnitzel style chili dog sauce', 'num_ingredients': 14, 'ingredients': ['beef', 'pork', 'water', 'cornstarch', 'flour', 'tomato', 'chili', 'Paprika', 'vinegar', 'salt', 'onion', 'sugar', 'garlic', 'pepper']})
# ('513531', {'name': 'better than a can  homemade sloppy joes', 'num_ingredients': 18, 'ingredients': ['olive oil', 'onion', 'pepper', 'pepper', 'celery', 'garlic', 'tomato', 'tomato', 'ketchup', 'vinegar', 'Molasses', 'Worcestershire', 'mushroom', 'tomato', 'oregano', 'beef', 'pepper', 'buns']})
# ('535020', {'name': 'buffalo wing  mushrooms', 'num_ingredients': 8, 'ingredients': ['mushroom', 'cornstarch', 'flour', 'salt', 'pepper', 'seltzer', 'panko', 'oil']})
# ('519068', {'name': 'dorito  popcorn seasoning', 'num_ingredients': 8, 'ingredients': ['yeast', 'garlic', 'onion', 'cumin', 'Paprika', 'chili', 'pepper', 'salt']})
# ('535431', {'name': 'ham  solo savory cake', 'num_ingredients': 12, 'ingredients': ['cheddar', 'spray', 'Bisquick', 'Milk', 'sugar', 'egg', 'salt', 'Gruyere', 'onion', 'ham', 'chives', 'butter']})
# ('532472', {'name': 'west african s finest  mafe', 'num_ingredients': 16, 'ingredients': ['peanut oil', 'carrot', 'garlic', 'potato', 'potato', 'onion', 'tomato', 'Paprika', 'pepper', 'cumin', 'thyme', 'chickpea', 'salt', 'stock', 'peanut butter', 'rice']})
# ('533190', {'name': '1 minute breakfast sandwich', 'num_ingredients': 12, 'ingredients': ['egg', 'Milk', 'salt', 'pepper', 'spray', 'English muffin', 'cheese', 'bacon', 'tomatoes', 'basil', 'avocado', 'pepper']})
# ('531143', {'name': '10 minute shrimp pad thai', 'num_ingredients': 13, 'ingredients': ['rice noodles', 'Peanut butter', 'sambal oelek', 'lime', 'fish', 'sugar', 'oil', 'shrimp', 'tomatoes', 'bean', 'cilantro', 'peanut', 'lime']})
# ('525649', {'name': '15 bean soup in the instant pot', 'num_ingredients': 17, 'ingredients': ['bean', 'water', 'onion', 'carrot', 'garlic', 'olive oil', 'ham', 'lemon', 'tomato soup', 'Paprika', 'paprika', 'chili', 'pepper', 'pepper', 'oregano', 'thyme', 'salt']})
# ('531148', {'name': '15 minute shrimp stir fry', 'num_ingredients': 11, 'ingredients': ['olive oil', 'shrimp', 'salt', 'onion', 'corn', 'tomatoes', 'zucchini', 'pea', 'Lemon', 'butter', 'herb']})
# ('517511', {'name': '2 minute microwave brownie in a mug', 'num_ingredients': 7, 'ingredients': ['oil', 'water', 'flour', 'salt', 'sugar', 'cocoa', 'extract']})
# ('513216', {'name': '2 minute eggless microwave chocolate cake', 'num_ingredients': 8, 'ingredients': ['flour', 'cocoa', 'oil', 'Milk', 'sugar', 'sugar', 'baking', 'salt']})
# ('516214', {'name': '2014 memorial day buttermilk french toast', 'num_ingredients': 9, 'ingredients': ['bread', 'eggs', 'sugar', 'buttermilk', 'Milk', 'vanilla', 'nutmeg', 'cinnamon', 'butter']})
# ('520809', {'name': '3 layer chocolate cake with chocolate mousse filling  gluten fre', 'num_ingredients': 19, 'ingredients': ['flour', 'tapioca', 'flour', 'cocoa', 'chocolate', 'baking soda', 'cream', 'gum', 'butter', 'salt', 'sugar', 'sugar', 'eggs', 'egg', 'vanilla', 'coconut', 'butter', 'cream', 'extract']})
# ('531161', {'name': '3 ingredient carnitas', 'num_ingredients': 13, 'ingredients': ['pork', 'water', 'salt', 'cumin', 'cloves', 'cayenne', 'tortilla', 'cabbage', 'sour cream', 'onion', 'cilantro', 'avocado', 'chili']})
# ('513291', {'name': '4 delicious french fry toppers', 'num_ingredients': 16, 'ingredients': ['Salsa', 'cheddar', 'onion', 'parsley', 'parmesan', 'caper', 'lemon', 'salt', 'garlic', 'mayonnaise', 'lemon', 'paprika', 'chili', 'onion', 'sour cream', 'cheese']})
# ('531144', {'name': '5 minute general tsos chicken', 'num_ingredients': 14, 'ingredients': ['chicken', 'broccoli', 'salt', 'cornstarch', 'vinegar', 'soy', 'Honey', 'chili', 'sesame oil', 'garlic', 'ginger', 'rice', 'scallion', 'sesame']})
# ('514206', {'name': '5 minute healthy sauted red cabbage', 'num_ingredients': 12, 'ingredients': ['cabbage', 'lemon', 'stock', 'olive oil', 'garlic', 'salt', 'pepper', 'ginger', 'seed', 'soy', 'cilantro', 'vinegar']})
# ('535021', {'name': '7 layer elote dip', 'num_ingredients': 15, 'ingredients': ['avocado', 'olive oil', 'lime', 'salt', 'corn', 'sour cream', 'corn', 'cilantro', 'cheese', 'onion', 'salt', 'chili', 'garlic', 'seasoning', 'tortilla']})
# ('516267', {'name': 'a yummy chicken noodle soup  8 qt  pressure cooker', 'num_ingredients': 16, 'ingredients': ['salt', 'pepper', 'carrot', 'celery', 'onion', 'bay', 'thyme', 'parsley', 'ginger', 'garlic', 'chicken', 'water', 'noodles', 'butter', 'mushroom', 'sherry']})
# ('518146', {'name': 'a 1 black cherry brie   chocolate walnut tartlet  a1', 'num_ingredients': 11, 'ingredients': ['cherries', 'sugar', 'zest', 'sauce', 'cornstarch', 'walnut', 'chocolate', 'cheese', 'pastry', 'orange', 'cherry']})
# ('517683', {'name': 'a 1 butter deconstructed pinwheel steak with avocado sauce  a1', 'num_ingredients': 13, 'ingredients': ['steak', 'salt', 'pepper', 'butter', 'cilantro', 'sauce', 'olive oil', 'garlic', 'salt', 'spinach', 'avocado', 'tomato', 'lime']})
# ('518176', {'name': 'a 1 steak puffs with corn and avocado salsa  a1', 'num_ingredients': 14, 'ingredients': ['steak', 'oil', 'onion', 'flour', 'pastry', 'egg', 'beef broth', 'sauce', 'cheese', 'avocado', 'corn', 'lime', 'salt', 'pepper']})
# ('518068', {'name': 'a 1  cherry cobbler tart   a1', 'num_ingredients': 10, 'ingredients': ['cherry', 'mascarpone', 'sugar', 'extract', 'pastry', 'flour', 'butter', 'chocolate', 'sauce', 'cream']})
# ('517702', {'name': 'a 1  chinese pasta  a1', 'num_ingredients': 12, 'ingredients': ['garlic', 'scallion', 'mushroom', 'pasta', 'sauce', 'hoisin', 'soy', 'sugar', 'pepper', 'sesame', 'mayonnaise', 'turkey']})
# ('518151', {'name': 'a 1  pot stickers with chili pineapple dipping sauce  a1', 'num_ingredients': 15, 'ingredients': ['wrapper', 'olive oil', 'spinach', 'onion', 'salt', 'pepper', 'turkey', 'garlic', 'ginger', 'sauce', 'pepper', 'sugar', 'water', 'cilantro', 'onion']})
# ('518145', {'name': 'a 1  slow roasted shredded steak with polenta  a1', 'num_ingredients': 18, 'ingredients': ['oil', 'steak', 'salt', 'pepper', 'sauce', 'jam', 'water', 'garlic', 'mustard', 'sugar', 'lemon', 'lemon', 'potato', 'Milk', 'garlic', 'polenta', 'parmesan', 'butter']})
# ('518143', {'name': 'a1 cowboy up tart  a1', 'num_ingredients': 11, 'ingredients': ['pastry', 'cream cheese', 'sour cream', 'sauce', 'steak', 'potato', 'tomatoes', 'corn', 'pepper', 'cheddar', 'salt']})
# ('518234', {'name': 'a1 marinated top round with bacon parmesan polenta  a1', 'num_ingredients': 19, 'ingredients': ['tomato', 'shallot', 'scallion', 'olive oil', 'salt', 'pepper', 'Milk', 'water', 'cornmeal', 'parmesan', 'butter', 'bacon', 'sauce', 'sugar', 'agave', 'scallion', 'tarragon', 'hot sauce', 'steak']})
# ('518192', {'name': 'a1 zesty potatoes  a1', 'num_ingredients': 9, 'ingredients': ['bacon', 'potato', 'onion', 'walnut', 'mayonnaise', 'cheese', 'sauce', 'mustard', 'salt']})
# ('518230', {'name': 'a1 derful grilled chicken  a1', 'num_ingredients': 8, 'ingredients': ['sauce', 'chicken', 'pineapple', 'cheese', 'spinach', 'salt', 'pepper', 'pineapple']})
# ('517863', {'name': 'a1b bacon burger bites on white polenta cakes  a1', 'num_ingredients': 13, 'ingredients': ['Milk', 'water', 'pepper', 'salt', 'polenta', 'cheese', 'olive oil', 'bacon', 'sugar', 'turkey', 'sauce', 'pepper', 'cheddar']})
# ('532656', {'name': 'acili biskuvi  spicy biscuits', 'num_ingredients': 8, 'ingredients': ['flour', 'butter', 'cheese', 'egg', 'salt', 'pepper', 'egg', 'seed']})
# ('526265', {'name': 'afghan kabuli pulao', 'num_ingredients': 10, 'ingredients': ['rice', 'onion', 'pistachio', 'almond', 'carrot', 'raisin', 'sugar', 'oil', 'olive oil', 'salt']})
# ('512943', {'name': 'aha herb mix', 'num_ingredients': 10, 'ingredients': ['pepper', 'garlic', 'basil', 'thyme', 'Parsley', 'marjoram', 'Mace', 'onion', 'pepper', 'sage']})
# ('524790', {'name': 'aip bbq sauce', 'num_ingredients': 10, 'ingredients': ['pumpkin', 'cider', 'vinegar', 'coconut oil', 'Molasses', 'syrup', 'garlic', 'salt', 'aminos', 'ginger']})
# ('530305', {'name': 'air fried onion rings', 'num_ingredients': 7, 'ingredients': ['breadcrumb', 'salt', 'pepper', 'parmesan', 'onion', 'egg', 'spray']})
# ('517847', {'name': 'aji criollo   green aji salsa', 'num_ingredients': 7, 'ingredients': ['cilantro', 'onion', 'lime', 'Vinegar', 'pepper', 'olive oil', 'salt']})
# ('522117', {'name': 'alan s vegetarian vegan bean and rice burger mashup', 'num_ingredients': 12, 'ingredients': ['bean', 'bean', 'rice', 'breadcrumb', 'picante', 'chili', 'cumin', 'oregano', 'salt', 'pepper', 'garlic', 'pepper']})
# ('516687', {'name': 'alea s corned beef and cabbage soup', 'num_ingredients': 6, 'ingredients': ['beef broth', 'potato', 'onion', 'garlic', 'beef', 'cabbage']})
# ('535371', {'name': 'almond flour blueberry muffins best ever', 'num_ingredients': 11, 'ingredients': ['flour', 'baking soda', 'salt', 'nutmeg', 'sugar', 'eggs', 'oil', 'Honey', 'almond', 'extract', 'blueberries']})
# ('519547', {'name': 'almond flour stevia cookies', 'num_ingredients': 6, 'ingredients': ['butter', 'flour', 'Stevia', 'salt', 'extract', 'egg']})
# ('511753', {'name': 'almond milk hot chocolate   martha stewart', 'num_ingredients': 6, 'ingredients': ['milk', 'cinnamon', 'sugar', 'cocoa', 'chocolate', 'salt']})
# ('526984', {'name': 'almond milk pancakes', 'num_ingredients': 8, 'ingredients': ['flour', 'baking', 'sugar', 'salt', 'almond milk', 'oil', 'vanilla', 'eggs']})
# ('515787', {'name': 'almond pancakes', 'num_ingredients': 6, 'ingredients': ['almond', 'milk', 'baking', 'salt', 'flax', 'cinnamon']})
# ('512375', {'name': 'almond chive salmon', 'num_ingredients': 10, 'ingredients': ['almond', 'chives', 'parsley', 'lemon', 'bread', 'salt', 'salmon', 'pepper', 'spray', 'Lemon']})
# ('522989', {'name': 'alton brown s stove top mac n cheese', 'num_ingredients': 9, 'ingredients': ['macaroni', 'butter', 'eggs', 'milk', 'hot sauce', 'salt', 'pepper', 'mustard', 'cheddar']})
# ('521731', {'name': 'amazing baked chicken breasts    you must try   easy to make', 'num_ingredients': 10, 'ingredients': ['chicken', 'Feta', 'tomatoes', 'garlic', 'basil', 'parsley', 'chives', 'olive', 'cheddar', 'salt']})
# ('512051', {'name': 'amazing beef stew', 'num_ingredients': 13, 'ingredients': ['beef', 'flour', 'salt', 'pepper', 'olive oil', 'onion', 'celery', 'Parsley', 'thyme', 'beef broth', 'carrot', 'potato', 'peas']})
# ('534722', {'name': 'amazing buttermilk biscuits', 'num_ingredients': 6, 'ingredients': ['flour', 'buttermilk', 'butter', 'baking', 'salt', 'baking soda']})
# ('515019', {'name': 'amazingly easy grain free biscuits rolls', 'num_ingredients': 7, 'ingredients': ['flour', 'starch', 'baking', 'salt', 'sugar', 'milk', 'olive oil']})
# ('512939', {'name': 'american sandwich bread   abm or oven', 'num_ingredients': 8, 'ingredients': ['water', 'milk', 'butter', 'Honey', 'flour', 'flour', 'salt', 'yeast']})
# ('526764', {'name': 'amish funeral cookies', 'num_ingredients': 8, 'ingredients': ['butter', 'Milk', 'sugar', 'cocoa', 'peanut butter', 'vanilla', 'salt', 'oats']})
# ('536322', {'name': 'amish peanut butter', 'num_ingredients': 6, 'ingredients': ['sugar', 'water', 'corn', 'syrup', 'peanut', 'marshmallow']})
# ('518120', {'name': 'amish sourdough bread starter', 'num_ingredients': 11, 'ingredients': ['Yeast', 'water', 'flour', 'sugar', 'Milk', 'Honey', 'salt', 'oil', 'eggs', 'flour', 'egg']})
# ('536384', {'name': 'amish triple butter biscuits', 'num_ingredients': 8, 'ingredients': ['flour', 'salt', 'cream', 'sugar', 'baking', 'butter', 'egg', 'Milk']})
# ('521585', {'name': 'amy truong zucchini low carb lasagna', 'num_ingredients': 19, 'ingredients': ['ground', 'onion', 'tomatoes', 'tomato', 'garlic', 'oregano', 'basil', 'thyme', 'water', 'pepper', 'eggs', 'cheese', 'red pepper', 'sriracha', 'mozzarella', 'flour', 'zucchini', 'parmesan', 'olive oil']})
# ('512771', {'name': 'andouille and chicken gumbo with black eyed peas and greens', 'num_ingredients': 23, 'ingredients': ['sausage', 'chicken', 'salt', 'pepper', 'Paprika', 'pepper', 'olive oil', 'flour', 'onion', 'onion', 'celery', 'garlic', 'pepper', 'pepper', 'chicken', 'leaf', 'thyme', 'pea', 'greens', 'okra', 'gumbo', 'rice', 'hot pepper sauce']})
# ('517082', {'name': 'angel biscuits', 'num_ingredients': 11, 'ingredients': ['flour', 'baking', 'salt', 'baking soda', 'sugar', 'yeast', 'water', 'buttermilk', 'shortening', 'biscuit', 'flour']})
# ('517983', {'name': 'angelo azzurro  blue angel  cocktail', 'num_ingredients': 6, 'ingredients': ['Cointreau', 'limoncello', 'gin', 'Vermouth', 'fruit', 'ice']})
# ('513805', {'name': 'apple bok choy salad', 'num_ingredients': 9, 'ingredients': ['bok choy', 'cashews', 'milk', 'vinegar', 'raisin', 'mustard', 'apple', 'carrot', 'onion']})
# ('512207', {'name': 'apple bread abm', 'num_ingredients': 9, 'ingredients': ['sugar', 'cinnamon', 'apple', 'juice', 'flour', 'yeast', 'salt', 'butter', 'egg']})
# ('512016', {'name': 'apple mango chutney', 'num_ingredients': 14, 'ingredients': ['apple', 'Mango', 'onion', 'ginger', 'juice', 'lemon', 'cider', 'sugar', 'raisin', 'cayenne', 'cinnamon', 'nutmeg', 'salt', 'thyme']})
# ('528546', {'name': 'apple pie breakfast quinoa', 'num_ingredients': 12, 'ingredients': ['quinoa', 'milk', 'apple', 'sugar', 'cinnamon', 'allspice', 'clove', 'nutmeg', 'extract', 'salt', 'pecan', 'syrup']})
# ('512109', {'name': 'apple pie egg roll', 'num_ingredients': 7, 'ingredients': ['apple', 'sugar', 'flour', 'cinnamon', 'lemon', 'wraps', 'oil']})
# ('534000', {'name': 'apple pie with cheddar crust', 'num_ingredients': 15, 'ingredients': ['flour', 'salt', 'butter', 'cheddar', 'water', 'apple', 'lemon', 'sugar', 'cornstarch', 'cinnamon', 'salt', 'egg', 'cream', 'sugar', 'cream']})
# ('517371', {'name': 'apple sharlotka', 'num_ingredients': 9, 'ingredients': ['apples', 'eggs', 'sugar', 'extract', 'flour', 'cinnamon', 'sugar', 'cream', 'sour cream']})
# ('528058', {'name': 'apple slab pie', 'num_ingredients': 14, 'ingredients': ['flour', 'sugar', 'salt', 'butter', 'water', 'apple', 'cornstarch', 'cinnamon', 'nutmeg', 'allspice', 'cream', 'glaze', 'sugar', 'Milk']})
# ('518669', {'name': 'apple  honey   caramelized onion flatbread pizza', 'num_ingredients': 13, 'ingredients': ['crust', 'olive oil', 'onion', 'rosemary', 'salt', 'pepper', 'cornmeal', 'apple', 'brie', 'mozzarella', 'parmesan', 'Honey', 'parsley']})
# ('521251', {'name': 'apple cinnamon mug cake', 'num_ingredients': 7, 'ingredients': ['oatmeal', 'sugar', 'cinnamon', 'baking', 'apple', 'Milk', 'oil']})
# ('524289', {'name': 'apple glazed stuffed pork chops', 'num_ingredients': 9, 'ingredients': ['bacon', 'leek', 'wine', 'thyme', 'salt', 'pepper', 'jelly', 'mustard', 'pork']})
# ('512773', {'name': 'applebee s chicken wonton', 'num_ingredients': 12, 'ingredients': ['chicken breast', 'olive oil', 'stir-fry', 'sesame', 'soy', 'teriyaki', 'slaw', 'wrapper', 'oil', 'onion', 'cilantro', 'onion']})
# ('532924', {'name': 'apricot almond cake with rosewater   cardamom', 'num_ingredients': 13, 'ingredients': ['apricot', 'water', 'cardamom', 'almonds', 'polenta', 'baking', 'sugar', 'eggs', 'lemon', 'rose water', 'spray', 'rose', 'pistachio']})
# ('520120', {'name': 'apricot cranberry kugel', 'num_ingredients': 11, 'ingredients': ['noodles', 'sour cream', 'cream cheese', 'apricot', 'salt', 'extract', 'cinnamon', 'cranberries', 'eggs', 'butter', 'cereal']})
# ('529216', {'name': 'arancini  italian rice balls', 'num_ingredients': 8, 'ingredients': ['rice', 'chicken', 'butter', 'eggs', 'parmesan', 'mozzarella', 'breadcrumb', 'oil']})
# ('514145', {'name': 'arby s oven baked curly fries', 'num_ingredients': 9, 'ingredients': ['potato', 'Paprika', 'salt', 'garlic', 'onion', 'pepper', 'flour', 'egg', 'milk']})
# ('536318', {'name': 'argentine chili', 'num_ingredients': 12, 'ingredients': ['olive oil', 'ground sirloin', 'chorizo', 'onion', 'garlic', 'pepper', 'salt', 'oregano', 'paprika', 'chile', 'tomato', 'beef']})
# ('517347', {'name': 'argentine grilled flank steak', 'num_ingredients': 6, 'ingredients': ['steak', 'pepper', 'olive oil', 'lime', 'soy', 'garlic']})
# ('536401', {'name': 'argentinian steak sandwiches', 'num_ingredients': 15, 'ingredients': ['beef', 'olive oil', 'salt', 'Baguette', 'mayonnaise', 'lettuce', 'avocado', 'vinegar', 'shallot', 'tomatoes', 'garlic', 'parsley', 'oregano', 'pepper', 'salt']})
# ('536044', {'name': 'argentinian tropical tincho', 'num_ingredients': 6, 'ingredients': ['mint', 'lime', 'ice', 'Vodka', 'wine', 'soda']})
# ('512720', {'name': 'artichoke heart frittata', 'num_ingredients': 13, 'ingredients': ['artichoke', 'zucchini', 'onion', 'pepper', 'garlic', 'oil', 'eggs', 'Milk', 'salt', 'pepper', 'bread', 'cream cheese', 'cheddar']})
# ('528358', {'name': 'artichoke pad thai', 'num_ingredients': 19, 'ingredients': ['rice', 'onion', 'garlic', 'ginger', 'tamarind', 'Honey', 'peanut', 'vinegar', 'fish', 'vinegar', 'sesame oil', 'olive oil', 'pepper', 'pepper', 'artichoke', 'bean', 'egg', 'cilantro', 'lime']})
# ('520016', {'name': 'asian chicken meatball   rice noodle soup', 'num_ingredients': 20, 'ingredients': ['scallion', 'garlic', 'ginger', 'egg', 'soy', 'oil', 'spice', 'salt', 'pepper', 'chicken', 'pork', 'breadcrumb', 'stock', 'garlic', 'Ginger', 'anise', 'mushroom', 'carrot', 'bok choy', 'rice']})
# ('515833', {'name': 'asian inspired pulled pork shoulder  for tacos or sliders', 'num_ingredients': 15, 'ingredients': ['pork', 'pepper', 'salt', 'onion', 'water', 'hoisin', 'Honey', 'soy', 'sesame oil', 'mirin', 'wine', 'lemongrass', 'ginger', 'garlic', 'spice']})
# ('516981', {'name': 'asian inspired zucchini', 'num_ingredients': 8, 'ingredients': ['zucchini', 'onion', 'garlic', 'sesame oil', 'olive oil', 'soy', 'ginger', 'seed']})
# ('518223', {'name': 'asian marinated pork chops', 'num_ingredients': 6, 'ingredients': ['soy', 'lemon', 'Ginger', 'garlic', 'pork', 'butter']})
# ('512372', {'name': 'asian noodle bowl with sesame salmon', 'num_ingredients': 11, 'ingredients': ['salmon', 'teriyaki', 'seed', 'Vermicelli', 'vinegar', 'onion', 'onion', 'tomatoes', 'cucumber', 'carrot', 'cilantro']})
# ('520940', {'name': 'asian vegetable soup with shrimp', 'num_ingredients': 15, 'ingredients': ['coconut oil', 'leek', 'celery', 'ginger', 'garlic', 'pepper', 'pepper', 'carrot', 'cabbage', 'vinegar', 'soy', 'stock', 'water', 'shrimp', 'salt']})
# ('512747', {'name': 'aunt carrie s indian pudding', 'num_ingredients': 11, 'ingredients': ['Milk', 'water', 'cornmeal', 'butter', 'Molasses', 'flour', 'cinnamon', 'Ginger', 'salt', 'egg', 'ice cream']})
# ('516015', {'name': 'austin chicken fajitas', 'num_ingredients': 10, 'ingredients': ['chicken', 'oil', 'juice', 'sauce', 'onion', 'garlic', 'pepper', 'celery', 'jalapeno', 'zest']})
# ('513298', {'name': 'australian crash hot potatoes', 'num_ingredients': 7, 'ingredients': ['potato', 'olive oil', 'garlic', 'salt', 'pepper', 'herb', 'parmesan']})
# ('532422', {'name': 'austrian kaesespaetzle  cheese spaetzle', 'num_ingredients': 10, 'ingredients': ['flour', 'eggs', 'Milk', 'Gruyere', 'edam', 'onion', 'olive oil', 'salt', 'pepper', 'parsley']})
# ('523334', {'name': 'authentic eggplant parmesan', 'num_ingredients': 13, 'ingredients': ['olive oil', 'garlic', 'onion', 'tomato', 'tomato', 'wine', 'seasoning', 'eggplant', 'eggs', 'Milk', 'breadcrumbs', 'mozzarella', 'cheese']})
# ('512041', {'name': 'authentic thai red curry with chicken', 'num_ingredients': 17, 'ingredients': ['chicken', 'curry', 'coconut', 'oil', 'stock', 'bouillon', 'onion', 'pepper', 'carrot', 'eggplant', 'sugar', 'lemon', 'fish', 'basil', 'basil', 'tomatoes', 'rice']})
# ('530683', {'name': 'avocado cream cheese toast', 'num_ingredients': 7, 'ingredients': ['bread', 'cream cheese', 'olive oil', 'avocado', 'salt', 'pepper', 'hot sauce']})
# ('529506', {'name': 'avocado lime and coconut no bake cheesecake', 'num_ingredients': 9, 'ingredients': ['raspberry', 'lime', 'avocado', 'cream cheese', 'lime', 'sugar', 'butter', 'graham cracker', 'coconut']})
# ('515352', {'name': 'avocado white bean hummus', 'num_ingredients': 7, 'ingredients': ['bean', 'avocado', 'lemon', 'tahini', 'garlic', 'salt', 'olive oil']})
# ('517715', {'name': 'avocado tomatillo taco truck sauce', 'num_ingredients': 8, 'ingredients': ['tomatillo', 'chili', 'cilantro', 'onion', 'water', 'avocado', 'lime', 'salt']})
# ('525001', {'name': 'babette s colossal crockpot chili  ragu', 'num_ingredients': 11, 'ingredients': ['pasta', 'tomato', 'sausage', 'onion', 'garlic', 'pasta', 'bean', 'pepper', 'water', 'chili', 'Feta']})
# ('536583', {'name': 'bacon and egg breakfast stromboli', 'num_ingredients': 7, 'ingredients': ['bacon', 'pastry', 'eggs', 'cheddar', 'egg', 'water', 'salt']})
# ('533950', {'name': 'bacon lattice turkey', 'num_ingredients': 6, 'ingredients': ['butter', 'bacon', 'thyme', 'sage', 'turkey', 'onion']})
# ('527202', {'name': 'bacon peanut caramel corn', 'num_ingredients': 7, 'ingredients': ['bacon', 'popcorn', 'bacon', 'Peanuts', 'sugar', 'corn', 'water']})
# ('523538', {'name': 'bacon potato cheddar tart', 'num_ingredients': 7, 'ingredients': ['bacon', 'potato', 'cheddar', 'paper', 'pepper', 'onion', 'garlic']})
# ('512716', {'name': 'bacon ranch wedge salad', 'num_ingredients': 6, 'ingredients': ['lettuce', 'onion', 'cucumber', 'bacon', 'Provolone', 'ranch']})
# ('536564', {'name': 'bacon wrapped coconut quiche and coconut popcorn shrimp', 'num_ingredients': 17, 'ingredients': ['coconut', 'eggs', 'corn', 'parmesan', 'bacon', 'shrimp', 'flour', 'egg', 'cornmeal', 'panko', 'coconut oil', 'Coconut', 'ketchup', 'Worcestershire', 'lemon', 'soy', 'tabasco']})
# ('513221', {'name': 'bacon wrapped steak', 'num_ingredients': 7, 'ingredients': ['beef', 'bacon', 'butter', 'rosemary', 'garlic', 'olive oil', 'wine']})
# ('516718', {'name': 'bacon  egg and cheese ring', 'num_ingredients': 8, 'ingredients': ['bacon', 'eggs', 'salt', 'pepper', 'crescent', 'cheese', 'cilantro', 'Salsa']})
# ('524716', {'name': 'bacon kissed cauliflower dip w  crispy corn tortillas  ragu', 'num_ingredients': 12, 'ingredients': ['oil', 'tortillas', 'salt', 'bacon', 'butter', 'onion', 'cauliflower', 'garlic', 'pepper', 'cheese', 'pasta', 'panko']})
# ('513094', {'name': 'bacon wrapped sonoran hot dogs', 'num_ingredients': 15, 'ingredients': ['bun', 'bacon', 'hot dog', 'bean', 'onion', 'tomato', 'mayonnaise', 'mustard', 'Salsa', 'garlic', 'olive oil', 'peppers', 'lime', 'oregano', 'salt']})
# ('530386', {'name': 'baconfredo', 'num_ingredients': 8, 'ingredients': ['bacon', 'onion', 'butter', 'cream', 'parmesan', 'pepper', 'salt', 'pasta']})
# ('514211', {'name': 'baileys irish cream pancakes', 'num_ingredients': 10, 'ingredients': ['butter', 'sugar', 'salt', 'egg', 'Milk', 'cream', 'flour', 'baking', 'butter', 'syrup']})
# ('516897', {'name': 'baja citrus marinade  chicken or pork chops', 'num_ingredients': 10, 'ingredients': ['chicken', 'beverage', 'juice', 'Vinegar', 'soy', 'oil', 'onion', 'garlic', 'salt', 'cayenne']})
# ('535581', {'name': 'baja fish taco', 'num_ingredients': 12, 'ingredients': ['salt', 'pepper', 'chicken', 'oregano', 'mustard', 'water', 'flour', 'tomato', 'onion', 'jalapeno', 'lemon', 'cilantro']})
# ('520110', {'name': 'bake a chocolate cake', 'num_ingredients': 13, 'ingredients': ['cocoa', 'sugar', 'baking soda', 'flour', 'salt', 'eggs', 'butter', 'water', 'vanilla', 'butter', 'Milk', 'cocoa', 'sugar']})
# ('533718', {'name': 'baked apple cider donuts', 'num_ingredients': 15, 'ingredients': ['cider', 'oil', 'applesauce', 'sugar', 'eggs', 'extract', 'flour', 'cinnamon', 'baking', 'salt', 'sugar', 'food', 'doughnut', 'licorice', 'apple']})
# ('513817', {'name': 'baked barley with mushrooms', 'num_ingredients': 11, 'ingredients': ['tomato', 'olive oil', 'carrot', 'shallot', 'mushroom', 'thyme', 'broth', 'barley', 'salt', 'pepper', 'mozzarella']})
# ('533649', {'name': 'baked brie with maple apples and pecans', 'num_ingredients': 6, 'ingredients': ['pecan', 'apple', 'butter', 'sugar', 'brie', 'maple syrup']})
# ('518070', {'name': 'baked chicken parmigiano', 'num_ingredients': 10, 'ingredients': ['yogurt', 'garlic', 'oregano', 'salt', 'pepper', 'chicken', 'parmesan', 'tomatoes', 'basil', 'bocconcini']})
# ('513941', {'name': 'baked mango sriracha cauliflower wings', 'num_ingredients': 16, 'ingredients': ['cauliflower', 'water', 'flour', 'salt', 'garlic', 'onion', 'paprika', 'chili', 'cayenne', 'pepper', 'oil', 'Mango', 'sriracha', 'hot sauce', 'juice', 'ginger']})
# ('515852', {'name': 'baked mexican pie', 'num_ingredients': 13, 'ingredients': ['beef', 'taco', 'beef broth', 'butter', 'onion', 'garlic', 'onion', 'chili', 'soup', 'enchilada', 'bean', 'flour', 'cheese']})
# ('530364', {'name': 'baked penne', 'num_ingredients': 13, 'ingredients': ['beef', 'sausage', 'pasta', 'pasta', 'onion', 'pepper', 'pepper', 'mushroom', 'carrot', 'spinach', 'tomatoes', 'cheddar', 'parmesan']})
# ('528861', {'name': 'baked potato volcano', 'num_ingredients': 10, 'ingredients': ['potato', 'bacon', 'cream cheese', 'cheddar', 'mozzarella', 'onion', 'chili', 'salt', 'cheddar', 'parsley']})
# ('522710', {'name': 'baked rice with cheese and tomatoes', 'num_ingredients': 11, 'ingredients': ['butter', 'onion', 'garlic', 'tomatoes', 'rice', 'salt', 'thyme', 'leaf', 'chicken', 'cheese', 'parmesan']})
# ('529772', {'name': 'baked salmon with garlic and dijon', 'num_ingredients': 9, 'ingredients': ['salmon', 'parsley', 'garlic', 'mustard', 'salt', 'pepper', 'olive oil', 'lemon', 'lemon']})
# ('512106', {'name': 'baked salmon with lemon and capers', 'num_ingredients': 10, 'ingredients': ['salmon', 'olive oil', 'salt', 'pepper', 'garlic', 'lemon', 'lemon', 'wine', 'caper', 'foil']})
# ('524817', {'name': 'baked sausage and garbanzo bean rollups  ragu', 'num_ingredients': 12, 'ingredients': ['flour', 'water', 'lemon', 'salt', 'oil', 'sausage', 'bean', 'pasta', 'breadcrumb', 'cilantro', 'pine', 'olive oil']})
# ('532486', {'name': 'baked sea bass with vegetables', 'num_ingredients': 12, 'ingredients': ['sea bass', 'onion', 'garlic', 'tomatoes', 'potato', 'lemon', 'water', 'olive oil', 'pepper', 'salt', 'parsley', 'Lemon']})
# ('537076', {'name': 'baked shrimp and orzo with chickpeas  lemon  and dill', 'num_ingredients': 15, 'ingredients': ['shrimp', 'salt', 'olive oil', 'fennel', 'garlic', 'red pepper', 'orzo', 'chickpea', 'tomatoes', 'olive', 'dill', 'Lemon', 'wine', 'broth', 'feta']})
# ('520337', {'name': 'baked turkey meatballs', 'num_ingredients': 9, 'ingredients': ['turkey', 'breadcrumbs', 'cheese', 'parsley', 'egg', 'garlic', 'salt', 'pepper', 'pepper']})
# ('515814', {'name': 'baked turkey quinoa meatballs', 'num_ingredients': 11, 'ingredients': ['turkey', 'quinoa', 'garlic', 'egg', 'onion', 'pepper', 'parsley', 'basil', 'oregano', 'tomato', 'salt']})
# ('517798', {'name': 'baked zucchini balls  gluten free', 'num_ingredients': 8, 'ingredients': ['zucchini', 'parmesan', 'breadcrumb', 'basil', 'egg', 'salt', 'flour', 'olive oil']})
# ('536474', {'name': 'baklava salmon with asparagus', 'num_ingredients': 14, 'ingredients': ['butter', 'mustard', 'Honey', 'pistachio', 'panko', 'parsley', 'olive oil', 'salmon', 'asparagus', 'tomatoes', 'thyme', 'lemon', 'salt', 'pepper']})
# ('532338', {'name': 'balsamic chicken wings', 'num_ingredients': 9, 'ingredients': ['chicken', 'Honey', 'sugar', 'vinegar', 'ginger', 'garlic', 'Lemon', 'salt', 'lemon']})
# ('529948', {'name': 'banana bomb', 'num_ingredients': 9, 'ingredients': ['banana', 'raisin', 'currant', 'coconut', 'dates', 'peanut', 'walnut', 'carob', 'Stevia']})
# ('536568', {'name': 'banana coffee cake', 'num_ingredients': 12, 'ingredients': ['butter', 'sugar', 'flour', 'cinnamon', 'salt', 'vanilla', 'cake', 'baking', 'banana', 'eggs', 'yogurt', 'sugar']})
# ('519167', {'name': 'banana date bread', 'num_ingredients': 12, 'ingredients': ['oil', 'sugar', 'egg', 'flour', 'baking', 'baking soda', 'salt', 'banana', 'water', 'extract', 'date', 'nut']})
# ('517744', {'name': 'banana muffins', 'num_ingredients': 10, 'ingredients': ['sugar', 'margarine', 'eggs', 'banana', 'water', 'flour', 'baking soda', 'salt', 'baking', 'chocolate']})
# ('525729', {'name': 'banana mug cake', 'num_ingredients': 8, 'ingredients': ['banana', 'syrup', 'oil', 'extract', 'flour', 'salt', 'cinnamon', 'sugar']})
# ('513434', {'name': 'banana pecan buttermilk pancakes', 'num_ingredients': 13, 'ingredients': ['pecan', 'flour', 'flour', 'sugar', 'baking', 'salt', 'flax', 'eggs', 'butter', 'milk', 'buttermilk', 'vanilla', 'banana']})
# ('535830', {'name': 'banana pudding beach icebox cake', 'num_ingredients': 10, 'ingredients': ['cream cheese', 'sugar', 'Milk', 'extract', 'cream', 'pudding', 'sugar', 'wafer', 'banana', 'cream']})
# ('522498', {'name': 'banana walnut pancake  paleo compliant', 'num_ingredients': 11, 'ingredients': ['banana', 'walnut', 'eggs', 'flour', 'baking', 'extract', 'baking soda', 'cinnamon', 'coconut', 'butter', 'Honey']})
# ('521481', {'name': 'bang bang shrimp pasta', 'num_ingredients': 11, 'ingredients': ['spaghetti', 'shrimp', 'coconut oil', 'garlic', 'Paprika', 'Parsley', 'pepper', 'mayonnaise', 'chili', 'lime', 'red pepper']})
# ('527864', {'name': 'barberton hot sauce', 'num_ingredients': 11, 'ingredients': ['Crisco', 'onion', 'celery', 'pepper', 'tomatoes', 'tomato', 'pepper', 'sugar', 'salt', 'pepper', 'rice']})
# ('514038', {'name': 'basic bechamel  white sauce', 'num_ingredients': 7, 'ingredients': ['butter', 'flour', 'Paprika', 'nutmeg', 'leaf', 'Milk', 'pepper']})
# ('516838', {'name': 'basil   mint orzo salad', 'num_ingredients': 12, 'ingredients': ['chicken', 'orzo', 'vinegar', 'lemon', 'Honey', 'salt', 'pepper', 'olive oil', 'tomatoes', 'onion', 'basil', 'mint']})
# ('520864', {'name': 'battered chicken tenders', 'num_ingredients': 11, 'ingredients': ['chicken', 'flour', 'baking', 'salt', 'pepper', 'egg', 'water', 'oil', 'mayonnaise', 'mustard', 'Honey']})
# ('519260', {'name': 'bbq chicken tenders', 'num_ingredients': 10, 'ingredients': ['barbecue', 'mustard', 'Honey', 'chicken', 'flour', 'salt', 'pepper', 'eggs', 'breadcrumb', 'olive oil']})
# ('512390', {'name': 'bean and bell pepper salad', 'num_ingredients': 12, 'ingredients': ['bean', 'bean', 'pepper', 'pepper', 'bell pepper', 'pepper', 'onion', 'garlic', 'parsley', 'lemon', 'olive oil', 'salt']})
# ('517603', {'name': 'beecher s kale and brown rice gratin with smoked cheese', 'num_ingredients': 13, 'ingredients': ['chicken', 'rice', 'olive oil', 'onion', 'garlic', 'kale', 'salt', 'pepper', 'butter', 'flour', 'Milk', 'fontina', 'gouda']})
# ('516391', {'name': 'beef   bean    oven tacos', 'num_ingredients': 8, 'ingredients': ['beef', 'onion', 'bean', 'taco', 'tomatoes', 'shell', 'cheese', 'corn']})
# ('513565', {'name': 'beef   chickpea paprikash', 'num_ingredients': 16, 'ingredients': ['beef', 'flour', 'salt', 'pepper', 'butter', 'onion', 'garlic', 'stock', 'Paprika', 'sugar', 'pepper', 'mustard', 'ketchup', 'Worcestershire', 'chickpea', 'yogurt']})
# ('518912', {'name': 'beef and barley soup with wils mushrooms', 'num_ingredients': 16, 'ingredients': ['beef', 'water', 'mushroom', 'barley', 'onion', 'celery', 'carrot', 'salt', 'pepper', 'thyme', 'leaf', 'garlic', 'parsley', 'mushroom', 'tomatoes', 'beef broth']})
# ('512873', {'name': 'beef and black bean taco dip', 'num_ingredients': 7, 'ingredients': ['ground beef', 'taco', 'garlic', 'tomatoes', 'bean', 'cheese', 'scallion']})
# ('518104', {'name': 'beef and quinoa stuffed bell peppers', 'num_ingredients': 11, 'ingredients': ['quinoa', 'water', 'beef', 'pepper', 'olive oil', 'onion', 'oregano', 'basil', 'salt', 'pepper', 'tomato']})
# ('515568', {'name': 'beef skewers with cilantro chimichurri', 'num_ingredients': 12, 'ingredients': ['cider', 'sugar', 'salt', 'onion', 'cilantro', 'steak', 'garlic', 'vinegar', 'lemon', 'pepper', 'olive oil', 'pepper']})
# ('512458', {'name': 'beefy chipotle cocoa chili', 'num_ingredients': 23, 'ingredients': ['olive oil', 'ground beef', 'chili', 'Paprika', 'garlic', 'onion', 'oregano', 'cumin', 'cocoa', 'sugar', 'salt', 'pepper', 'pepper', 'tomato', 'bean', 'corn', 'tomatoes', 'onion', 'peppers', 'water', 'squash', 'cilantro', 'epazote']})
# ('535570', {'name': 'beer bacon mac and cheese', 'num_ingredients': 15, 'ingredients': ['macaroni', 'bacon', 'butter', 'flour', 'garlic', 'chile', 'paprika', 'salt', 'pepper', 'beer', 'chicken', 'milk', 'Worcestershire', 'cheddar', 'chives']})
# ('511925', {'name': 'beer battered fish tacos with pickled onion and cucumber', 'num_ingredients': 18, 'ingredients': ['oil', 'flour', 'cumin', 'pepper', 'salt', 'beer', 'tilapia', 'flour', 'cucumber', 'cider', 'sugar', 'water', 'onion', 'onion', 'cucumber', 'pepper', 'tomato', 'cilantro']})
# ('534898', {'name': 'beer cheese stuffed pretzels', 'num_ingredients': 18, 'ingredients': ['water', 'sugar', 'yeast', 'beer', 'butter', 'salt', 'flour', 'pretzels', 'pretzel', 'egg', 'salt', 'cheddar', 'cheese', 'garlic', 'mustard', 'Worcestershire', 'cream', 'scallion']})
# ('527535', {'name': 'beery chorizo queso fundido', 'num_ingredients': 13, 'ingredients': ['butter', 'onion', 'jalapeno', 'garlic', 'chorizo', 'flour', 'chili', 'cumin', 'beer', 'milk', 'cheese', 'cilantro', 'chip']})
# ('532442', {'name': 'belizean meat pies', 'num_ingredients': 14, 'ingredients': ['beef', 'pepper', 'onion', 'pepper', 'thyme', 'tomato', 'cumin', 'Worcestershire', 'pepper', 'flour', 'baking', 'salt', 'shortening', 'water']})
# ('512898', {'name': 'belt salad', 'num_ingredients': 9, 'ingredients': ['eggs', 'bacon', 'lettuce', 'tomatoes', 'crouton', 'sour cream', 'buttermilk', 'mustard', 'onion']})
# ('532427', {'name': 'berbere spice mix', 'num_ingredients': 12, 'ingredients': ['chili', 'Paprika', 'Ginger', 'cardamom', 'turmeric', 'coriander', 'fenugreek', 'cinnamon', 'nutmeg', 'allspice', 'cloves', 'pepper']})
# ('514982', {'name': 'best copycat benihana japanese chicken rice', 'num_ingredients': 14, 'ingredients': ['rice', 'butter', 'garlic', 'sesame oil', 'eggs', 'chicken', 'peas', 'carrot', 'onion', 'onion', 'salt', 'pepper', 'soy', 'sesame']})
# ('529697', {'name': 'best ever cornbread', 'num_ingredients': 8, 'ingredients': ['butter', 'eggs', 'Milk', 'sugar', 'baking', 'salt', 'flour', 'cornmeal']})
# ('511622', {'name': 'best ever green bean casserole  no canned soup', 'num_ingredients': 9, 'ingredients': ['butter', 'flour', 'salt', 'sugar', 'onion', 'sour cream', 'bean', 'onion', 'cheddar']})
# ('532179', {'name': 'best ever pecan pie bars', 'num_ingredients': 11, 'ingredients': ['butter', 'sugar', 'eggs', 'vanilla', 'flour', 'baking', 'salt', 'corn syrup', 'sugar', 'cream', 'pecan']})
# ('515446', {'name': 'best general tso s chicken from serious eats', 'num_ingredients': 20, 'ingredients': ['egg', 'soy', 'wine', 'Vodka', 'baking soda', 'cornstarch', 'chicken', 'flour', 'baking', 'salt', 'vinegar', 'broth', 'sugar', 'sesame oil', 'peanut oil', 'garlic', 'ginger', 'scallion', 'pepper', 'rice']})
# ('511837', {'name': 'best paleo pancakes', 'num_ingredients': 10, 'ingredients': ['eggs', 'Milk', 'flour', 'almond', 'banana', 'baking soda', 'gelatin', 'vanilla', 'cider', 'salt']})
# ('512954', {'name': 'best vegan blueberry muffins ever', 'num_ingredients': 10, 'ingredients': ['flour', 'sugar', 'sugar', 'sugar', 'salt', 'baking', 'banana', 'oil', 'coconut', 'blueberries']})
# ('522478', {'name': 'best ever chewy chocolate chip cookies', 'num_ingredients': 10, 'ingredients': ['butter', 'sugar', 'sugar', 'egg', 'extract', 'flour', 'cornstarch', 'baking soda', 'salt', 'chocolate']})
# ('536834', {'name': 'better than del taco chicken soft tacos', 'num_ingredients': 15, 'ingredients': ['chicken', 'lime', 'garlic', 'taco', 'oil', 'sugar', 'ranch', 'sour cream', 'lime', 'garlic', 'salt', 'lettuce', 'tomatoes', 'cheddar', 'flour']})
# ('521101', {'name': 'better than takeout chicken fried rice from rachel schultz', 'num_ingredients': 8, 'ingredients': ['rice', 'chicken breast', 'peas', 'onion', 'garlic', 'eggs', 'sesame oil', 'soy']})
# ('519383', {'name': 'betty crocker s baking powder biscuits  light  flaky and tender', 'num_ingredients': 6, 'ingredients': ['flour', 'sugar', 'baking', 'salt', 'shortening', 'Milk']})
# ('520030', {'name': 'betty crocker s salmon loaf', 'num_ingredients': 11, 'ingredients': ['salmon', 'margarine', 'flour', 'salt', 'pepper', 'Milk', 'bread', 'eggs', 'lemon', 'soup', 'water']})
# ('513249', {'name': 'betty fords buttermilk pancakes', 'num_ingredients': 7, 'ingredients': ['flour', 'baking', 'baking soda', 'salt', 'sugar', 'eggs', 'buttermilk']})
# ('522745', {'name': 'big bend texas style chili', 'num_ingredients': 17, 'ingredients': ['olive oil', 'garlic', 'onion', 'beef', 'salt', 'pepper', 'chili', 'tomatoes', 'tomato', 'beef', 'beer', 'vinegar', 'cumin', 'oregano', 'parsley', 'bean', 'cheese']})
# ('529766', {'name': 'birthday cake babka', 'num_ingredients': 12, 'ingredients': ['milk', 'yeast', 'sugar', 'flour', 'salt', 'eggs', 'vanilla', 'butter', 'sprinkles', 'extract', 'butter', 'chocolate']})
# ('530370', {'name': 'birthday cake cookies', 'num_ingredients': 7, 'ingredients': ['cake', 'baking', 'eggs', 'oil', 'chocolate', 'chocolate', 'sprinkles']})
# ('524062', {'name': 'bisquick crepes', 'num_ingredients': 7, 'ingredients': ['eggs', 'Bisquick', 'Milk', 'butter', 'cream cheese', 'sugar', 'extract']})
# ('513680', {'name': 'bistec argentino al chimichurri  steak with chimichurri sauce', 'num_ingredients': 11, 'ingredients': ['cilantro', 'vinegar', 'olive oil', 'garlic', 'adobo', 'oregano', 'pepper', 'chili', 'steak', 'herb', 'butter']})
# ('515641', {'name': 'black bean and sweet potato burritos light', 'num_ingredients': 8, 'ingredients': ['bean', 'onion', 'potato', 'peppers', 'garlic', 'cumin', 'oil', 'flour']})
# ('516662', {'name': 'black bean chocolate cake', 'num_ingredients': 9, 'ingredients': ['bean', 'eggs', 'vanilla', 'salt', 'coconut oil', 'Honey', 'cocoa', 'baking', 'baking soda']})
# ('527442', {'name': 'black bean donuts', 'num_ingredients': 15, 'ingredients': ['bean', 'milk', 'baking', 'baking soda', 'cider', 'vanilla', 'cocoa', 'salt', 'sweetener', 'oat', 'egg', 'applesauce', 'peanut', 'sugar', 'Milk']})
# ('516952', {'name': 'black bean quinoa soup', 'num_ingredients': 14, 'ingredients': ['onion', 'pepper', 'garlic', 'carrot', 'tomatoes', 'cumin', 'chili', 'cilantro', 'red pepper', 'bean', 'quinoa', 'broth', 'spinach', 'lime']})
# ('516447', {'name': 'blackberry mini muffins or mini cupcakes   you decide', 'num_ingredients': 11, 'ingredients': ['butter', 'sugar', 'eggs', 'extract', 'Milk', 'flour', 'baking soda', 'salt', 'blackberry', 'lemon', 'sugar']})
# ('514889', {'name': 'blackened cod with mango salsa', 'num_ingredients': 15, 'ingredients': ['chili', 'Paprika', 'cumin', 'garlic', 'salt', 'sugar', 'oil', 'Mango', 'onion', 'pepper', 'jalapeno', 'lime', 'salt', 'cilantro', 'cod']})
# ('520307', {'name': 'blackened pork ribs', 'num_ingredients': 11, 'ingredients': ['pork', 'salt', 'cumin', 'fennel', 'Paprika', 'clove', 'garlic', 'lime', 'ketchup', 'tabasco', 'vinegar']})
# ('531172', {'name': 'blender chocolate mousse', 'num_ingredients': 7, 'ingredients': ['chocolate', 'cream', 'butter', 'eggs', 'extract', 'salt', 'raspberries']})
# ('515629', {'name': 'bloody marys by ree drummond', 'num_ingredients': 9, 'ingredients': ['Vodka', 'lime', 'steak', 'Worcestershire', 'pepper', 'tomato', 'salt', 'pepper', 'celery']})
# ('514370', {'name': 'blue ribbon chicken pasta with prosciutto', 'num_ingredients': 13, 'ingredients': ['steak', 'pepper', 'chicken', 'olive oil', 'garlic', 'tomatoes', 'prosciutto', 'butter', 'basil', 'linguine', 'Parmesan', 'chiles', 'peppers']})
# ('522349', {'name': 'blue ribbon coleslaw', 'num_ingredients': 13, 'ingredients': ['slaw', 'onion', 'carrot', 'pepper', 'apple', 'mayonnaise', 'cream', 'vinegar', 'lemon', 'sugar', 'garlic', 'salt', 'pepper']})
# ('512753', {'name': 'blueberry and lemon ricotta cheesecake  gluten free', 'num_ingredients': 9, 'ingredients': ['oats', 'almond', 'sugar', 'butter', 'eggs', 'almond', 'ricotta', 'lemon', 'blueberries']})
# ('535644', {'name': 'blueberry cheesecake crumb cake', 'num_ingredients': 16, 'ingredients': ['flour', 'baking', 'salt', 'butter', 'lemon', 'sugar', 'sugar', 'eggs', 'vanilla', 'Mascarpone', 'cream cheese', 'sugar', 'cornstarch', 'blueberries', 'sugar', 'Milk']})
# ('519945', {'name': 'blueberry coffee cake', 'num_ingredients': 13, 'ingredients': ['butter', 'sugar', 'eggs', 'sour cream', 'extract', 'flour', 'baking', 'salt', 'blueberries', 'sugar', 'cinnamon', 'pecan', 'sugar']})
# ('536305', {'name': 'blueberry lemon oreo cheesecake bars', 'num_ingredients': 11, 'ingredients': ['butter', 'Oreo', 'blueberries', 'sugar', 'water', 'lemon', 'cornstarch', 'cream cheese', 'sour cream', 'extract', 'egg']})
# ('527141', {'name': 'bob s sloppy joes for 6', 'num_ingredients': 10, 'ingredients': ['ground beef', 'onion', 'pepper', 'pepper', 'garlic', 'mustard', 'ketchup', 'sugar', 'salt', 'pepper']})
# ('524301', {'name': 'bob s taco soup with pasta', 'num_ingredients': 11, 'ingredients': ['beef', 'onion', 'tomatoes', 'bean', 'taco', 'corn', 'chili', 'jalapeno', 'ranch', 'pasta', 'sour cream']})
# ('513973', {'name': 'bobotie  south african curry meat loaf', 'num_ingredients': 17, 'ingredients': ['tea', 'raisin', 'apricot', 'oil', 'garlic', 'onion', 'turmeric', 'coriander', 'pepper', 'cumin', 'fenugreek', 'pepper', 'fennel', 'salt', 'cider', 'ground beef', 'almond']})
# ('520015', {'name': 'boiled pig feet', 'num_ingredients': 10, 'ingredients': ['salt', 'onion', 'garlic', 'pepper', 'onion', 'cider', 'bay', 'parsley', 'seasoning', 'pepper']})
# ('518243', {'name': 'bok choy in cream sauce', 'num_ingredients': 9, 'ingredients': ['cabbage', 'oil', 'salt', 'sugar', 'stock', 'cornstarch', 'water', 'Milk', 'pepper']})
# ('533432', {'name': 'booyah the soup', 'num_ingredients': 21, 'ingredients': ['chicken', 'beef', 'flour', 'kielbasa', 'olive oil', 'onion', 'pepper', 'celery', 'carrot', 'turnip', 'potato', 'barley', 'corn', 'pea', 'seasoning', 'pepper', 'salt', 'pepper', 'tomatoes', 'chicken', 'beer']})
# ('513641', {'name': 'border quiche   low carb', 'num_ingredients': 11, 'ingredients': ['butter', 'eggs', 'cream', 'hot pepper sauce', 'salt', 'pepper', 'chili', 'chorizo', 'Muenster', 'cilantro', 'scallion']})
# ('520055', {'name': 'bourbon chicken   jasmine rice', 'num_ingredients': 13, 'ingredients': ['sesame oil', 'chicken', 'garlic', 'ginger', 'pepper', 'apple', 'sugar', 'ketchup', 'vinegar', 'bourbon', 'soy', 'rice', 'scallion']})
# ('534558', {'name': 'braciole', 'num_ingredients': 12, 'ingredients': ['beef', 'garlic', 'cheese', 'parsley', 'salt', 'prosciutto', 'olive oil', 'garlic', 'wine', 'tomato', 'basil', 'ziti']})
# ('535724', {'name': 'braised brisket tacos', 'num_ingredients': 29, 'ingredients': ['beef', 'salt', 'olive oil', 'carrot', 'onion', 'celery', 'pepper', 'garlic', 'coriander', 'cumin', 'Paprika', 'pepper', 'oregano', 'tomato', 'tomato', 'beef broth', 'avocado', 'Lemon', 'basil', 'cheese', 'apple', 'pear', 'cabbage', 'cider', 'tortilla', 'cilantro', 'Lime', 'Yogurt', 'hot sauce']})
# ('534393', {'name': 'braised cauliflower with bacon', 'num_ingredients': 8, 'ingredients': ['cauliflower', 'olive oil', 'garlic', 'Bacon', 'onion', 'tomatoes', 'red pepper', 'salt']})
# ('513820', {'name': 'bratwurst wraps with onion sauerkraut filling', 'num_ingredients': 11, 'ingredients': ['bratwurst', 'beer', 'onion', 'oil', 'sauerkraut', 'sugar', 'salt', 'red pepper', 'flour', 'mustard', 'cheese']})
# ('513812', {'name': 'brazilian chicken and rice with olives', 'num_ingredients': 10, 'ingredients': ['chicken', 'olive oil', 'garlic', 'zest', 'water', 'juice', 'rice', 'olive', 'cilantro', 'orange']})
# ('517907', {'name': 'brazilian shrimp stew', 'num_ingredients': 13, 'ingredients': ['shrimp', 'salt', 'pepper', 'garlic', 'lemon', 'tomatoes', 'onion', 'pepper', 'oil', 'cayenne', 'cilantro', 'coconut', 'oil']})
# ('517531', {'name': 'breaded fried steak   milanesa', 'num_ingredients': 9, 'ingredients': ['beef', 'breadcrumb', 'oregano', 'flour', 'salt', 'pepper', 'eggs', 'oil', 'salt']})
# ('529787', {'name': 'breakfast egg muffins', 'num_ingredients': 11, 'ingredients': ['olive oil', 'ground beef', 'salt', 'thyme', 'garlic', 'paprika', 'pepper', 'pepper', 'pepper', 'eggs', 'parsley']})
# ('513821', {'name': 'breakfast grilled cheese mexican style', 'num_ingredients': 6, 'ingredients': ['cheese', 'eggs', 'bacon', 'onion', 'bread', 'butter']})
# ('532077', {'name': 'breakfast muffins to go', 'num_ingredients': 15, 'ingredients': ['olive oil', 'garlic', 'onion', 'zucchini', 'chives', 'cheese', 'flour', 'baking', 'salt', 'eggs', 'avocado', 'chip', 'Honey', 'lemon', 'sriracha']})
# ('533171', {'name': 'breakfast taquitos', 'num_ingredients': 11, 'ingredients': ['sausage', 'eggs', 'salt', 'pepper', 'spray', 'cheddar', 'cilantro', 'tortillas', 'Salsa', 'hot sauce', 'sour cream']})
# ('516279', {'name': 'bright and fresh thai beef salad', 'num_ingredients': 15, 'ingredients': ['Anaheim', 'tomatoes', 'lemongrass', 'fish', 'lime', 'mint', 'Honey', 'garlic', 'chili', 'olive oil', 'beef', 'pepper', 'Lettuce', 'radicchio', 'arugula']})
# ('511612', {'name': 'broccoli and bean soup', 'num_ingredients': 6, 'ingredients': ['onion', 'garlic', 'broth', 'broccoli', 'bean', 'pepper']})
# ('534509', {'name': 'broccoli cauliflower mac and cheese', 'num_ingredients': 10, 'ingredients': ['pasta', 'butter', 'flour', 'shallot', 'Milk', 'salt', 'cheddar', 'cheese', 'broccoli', 'cauliflower']})
# ('520442', {'name': 'broccoli cheddar latkes', 'num_ingredients': 12, 'ingredients': ['broccoli', 'potato', 'onion', 'panko', 'eggs', 'pepper', 'salt', 'pepper', 'flour', 'cheddar', 'oil', 'oil']})
# ('513724', {'name': 'broiled halibut steaks with cranberry compote', 'num_ingredients': 11, 'ingredients': ['halibut', 'oil', 'onion', 'cranberries', 'pear', 'sugar', 'water', 'cloves', 'salt', 'pepper', 'walnut']})
# ('520577', {'name': 'broiled honey lime salmon', 'num_ingredients': 8, 'ingredients': ['salmon', 'pepper', 'olive oil', 'Honey', 'lime', 'lime', 'soy', 'cilantro']})
# ('514825', {'name': 'brown sugar carmel pound cake', 'num_ingredients': 13, 'ingredients': ['butter', 'sugar', 'sugar', 'eggs', 'flour', 'baking', 'salt', 'milk', 'toffee', 'pecan', 'milk', 'sugar', 'extract']})
# ('534954', {'name': 'brownie baklava', 'num_ingredients': 11, 'ingredients': ['butter', 'chocolate', 'sugar', 'eggs', 'vanilla', 'flour', 'cinnamon', 'walnut', 'pistachio', 'phyllo', 'Honey']})
# ('535690', {'name': 'brownie terrarium', 'num_ingredients': 19, 'ingredients': ['mix', 'candy', 'Graham', 'brownie', 'egg', 'sugar', 'salt', 'cream', 'chocolate', 'extract', 'coconut oil', 'chocolate', 'flour', 'baking powder', 'salt', 'cocoa', 'eggs', 'Coconut', 'food']})
# ('532637', {'name': 'bruschetta grilled chicken zoodle bowl', 'num_ingredients': 13, 'ingredients': ['olive oil', 'vinegar', 'salt', 'pepper', 'garlic', 'basil', 'chicken', 'tomatoes', 'onion', 'olive oil', 'salt', 'parmesan', 'zucchini']})
# ('513874', {'name': 'budget bytes  italian wonderpot', 'num_ingredients': 12, 'ingredients': ['broth', 'olive oil', 'Fettuccine', 'spinach', 'tomatoes', 'onion', 'garlic', 'basil', 'oregano', 'pepper', 'pepper', 'Feta']})
# ('512719', {'name': 'buffalo cauliflower chili   crock pot', 'num_ingredients': 15, 'ingredients': ['cauliflower', 'onion', 'bean', 'tomatoes', 'chili', 'hot sauce', 'sugar', 'chili', 'cumin', 'pepper', 'salt', 'blue cheese', 'celery', 'onion', 'sour cream']})
# ('522824', {'name': 'buffalo cauliflower sandwich', 'num_ingredients': 18, 'ingredients': ['cauliflower', 'Milk', 'water', 'flour', 'garlic', 'onion', 'cumin', 'Paprika', 'salt', 'pepper', 'butter', 'hot sauce', 'mayonnaise', 'cider', 'dill', 'parsley', 'chives', 'salt']})
# ('530729', {'name': 'buffalo cauliflower tots', 'num_ingredients': 10, 'ingredients': ['olive oil', 'onion', 'cauliflower', 'flour', 'eggs', 'hot sauce', 'salt', 'pepper', 'rice', 'ranch']})
# ('523551', {'name': 'buffalo chicken fritos pie', 'num_ingredients': 11, 'ingredients': ['chicken', 'chicken', 'salt', 'hot sauce', 'cream', 'butter', 'cheese', 'Fritos', 'ranch', 'tomatoes', 'onion']})
# ...
# ('537089', {'name': 'vampire s kiss cake', 'num_ingredients': 18, 'ingredients': ['egg', 'eggs', 'milk', 'vanilla', 'flour', 'sugar', 'baking', 'salt', 'butter', 'frosting', 'lemon', 'almond', 'corn', 'cornstarch', 'food coloring', 'food', 'food coloring', 'sprinkles']})
# ('515188', {'name': 'vanilla cornmeal griddle cakes with pears', 'num_ingredients': 15, 'ingredients': ['butter', 'flour', 'cornflour', 'sugar', 'baking', 'salt', 'nutmeg', 'buttermilk', 'grits', 'egg', 'juice', 'extract', 'pear', 'butter', 'syrup']})
# ('517394', {'name': 'vanilla custards with roasted berries', 'num_ingredients': 8, 'ingredients': ['milk', 'vanilla', 'egg', 'sugar', 'flour', 'butter', 'blueberries', 'lemon']})
# ('529309', {'name': 'veal ribs with fontina cheese', 'num_ingredients': 8, 'ingredients': ['veal', 'rib', 'eggs', 'olive oil', 'butter', 'garlic', 'fontina', 'truffle']})
# ('516828', {'name': 'vegan banana chocolate cake', 'num_ingredients': 12, 'ingredients': ['oil', 'chocolate', 'sugar', 'banana', 'flour', 'baking', 'salt', 'cinnamon', 'nutmeg', 'cloves', 'nuts', 'raisin']})
# ('524458', {'name': 'vegan collard greens', 'num_ingredients': 10, 'ingredients': ['greens', 'bouillon', 'onion', 'garlic', 'tomatoes', 'jalapeno', 'vinegar', 'water', 'olive oil', 'salt']})
# ('528506', {'name': 'vegan fried cauliflower', 'num_ingredients': 9, 'ingredients': ['flour', 'paprika', 'garlic', 'seasoning', 'salt', 'water', 'oil', 'coconut oil', 'cauliflower']})
# ('511625', {'name': 'vegan graham crackers', 'num_ingredients': 9, 'ingredients': ['flour', 'sugar', 'baking soda', 'cinnamon', 'salt', 'oil', 'syrup', 'extract', 'water']})
# ('530722', {'name': 'vegan oatmeal pancakes with banana', 'num_ingredients': 9, 'ingredients': ['oat', 'water', 'baking', 'flax', 'cinnamon', 'vanilla', 'Honey', 'banana', 'salt']})
# ('530409', {'name': 'vegan pizza margherita', 'num_ingredients': 12, 'ingredients': ['sugar', 'yeast', 'water', 'flour', 'salt', 'olive oil', 'cornmeal', 'tomato', 'garlic', 'basil', 'chili', 'cheese']})
# ('513113', {'name': 'vegan spelt buns or rolls', 'num_ingredients': 9, 'ingredients': ['water', 'coconut oil', 'Yeast', 'sugar', 'water', 'flax', 'salt', 'flour', 'poppy']})
# ('519882', {'name': 'vegetable broth base', 'num_ingredients': 8, 'ingredients': ['leek', 'carrot', 'root', 'parsley', 'onion', 'salt', 'tomato', 'soy']})
# ('519394', {'name': 'vegetarian african peanut soup', 'num_ingredients': 11, 'ingredients': ['broth', 'onion', 'ginger', 'garlic', 'salt', 'greens', 'peanut', 'tomato', 'hot sauce', 'peanut', 'rice']})
# ('529568', {'name': 'vegetarian french dip sandwiches', 'num_ingredients': 12, 'ingredients': ['onion', 'mushroom', 'butter', 'salt', 'thyme', 'oregano', 'broth', 'soy', 'sugar', 'garlic', 'bread', 'Provolone']})
# ('517857', {'name': 'vegetarian lomo saltado', 'num_ingredients': 14, 'ingredients': ['mushroom', 'tofu', 'oil', 'onion', 'garlic', 'pepper', 'tomatoes', 'soy', 'oregano', 'cumin', 'vinegar', 'salt', 'fries', 'rice']})
# ('517530', {'name': 'venezuelan pepito sandwich   pepito venezolano', 'num_ingredients': 7, 'ingredients': ['roll', 'steak', 'oil', 'garlic', 'soy', 'Worcestershire', 'salt']})
# ('514024', {'name': 'venezuelan spiced hot chocolate', 'num_ingredients': 8, 'ingredients': ['Milk', 'anise', 'cinnamon', 'orange', 'allspice', 'sugar', 'chocolate', 'rum']})
# ('513187', {'name': 'vermont whole wheat oatmeal honey bread', 'num_ingredients': 10, 'ingredients': ['water', 'oats', 'sugar', 'Honey', 'butter', 'salt', 'cinnamon', 'yeast', 'flour', 'flour']})
# ('514161', {'name': 'vietnamese beef marinade', 'num_ingredients': 11, 'ingredients': ['onion', 'ginger', 'garlic', 'pepper', 'pear', 'soy', 'sugar', 'sugar', 'sesame oil', 'oil', 'onion']})
# ('520663', {'name': 'vietnamese bun cha gio', 'num_ingredients': 19, 'ingredients': ['pork', 'ginger', 'garlic', 'fish', 'soy', 'sugar', 'peanut oil', 'water', 'vinegar', 'chili-garlic', 'salt', 'carrot', 'Vermicelli', 'mung', 'cucumber', 'cilantro', 'peanut', 'onion', 'roll']})
# ('535341', {'name': 'vietnamese caramelized pork  thit ko    instant pot version', 'num_ingredients': 13, 'ingredients': ['pork', 'eggs', 'sugar', 'garlic', 'shallot', 'anise', 'pepper', 'salt', 'soy', 'msg', 'coconut', 'water', 'fish']})
# ('535389', {'name': 'vietnamese chicken', 'num_ingredients': 11, 'ingredients': ['chicken', 'onion', 'garlic', 'Ginger', 'salt', 'pepper', 'chili', 'olive oil', 'sugar', 'water', 'Soya']})
# ('516702', {'name': 'vietnamese chicken liver pate', 'num_ingredients': 9, 'ingredients': ['liver', 'Milk', 'wine', 'onion', 'garlic', 'fish', 'salt', 'pepper', 'butter']})
# ('514721', {'name': 'vietnamese lemongrass pork', 'num_ingredients': 9, 'ingredients': ['pork', 'sugar', 'garlic', 'shallot', 'lemongrass', 'pepper', 'soy sauce', 'fish', 'oil']})
# ('523426', {'name': 'vietnamese style caramel chicken with broccoli', 'num_ingredients': 9, 'ingredients': ['baking soda', 'chicken', 'sugar', 'fish', 'ginger', 'broccoli', 'cornstarch', 'pepper', 'cilantro']})
# ('511623', {'name': 'vinegar air and salty crispy potatoes   british larder', 'num_ingredients': 6, 'ingredients': ['vinegar', 'water', 'gelatin', 'potato', 'salt', 'oil']})
# ('523306', {'name': 'vinegar dill coleslaw', 'num_ingredients': 11, 'ingredients': ['cabbage', 'carrot', 'cabbage', 'onion', 'sugar', 'oil', 'vinegar', 'mustard', 'dill', 'celery', 'salt']})
# ('518198', {'name': 'walnut crusted cherry chicken  a1', 'num_ingredients': 17, 'ingredients': ['walnut', 'pepper', 'sugar', 'paprika', 'salt', 'rosemary', 'sage', 'chicken', 'olive oil', 'cherry', 'sugar', 'sauce', 'mustard', 'agave', 'jelly', 'jelly', 'mint']})
# ('527823', {'name': 'walnut rolls', 'num_ingredients': 8, 'ingredients': ['walnut', 'cinnamon', 'cloves', 'sugar', 'phyllo', 'butter', 'water', 'lemon']})
# ('526150', {'name': 'warm roasted vegetable farro salad', 'num_ingredients': 14, 'ingredients': ['eggplant', 'salt', 'tomatoes', 'zucchini', 'mushroom', 'garlic', 'onion', 'olive oil', 'farro', 'milk', 'vinegar', 'cilantro', 'salt', 'pepper']})
# ('524868', {'name': 'warm shrimp nest salad  ragu', 'num_ingredients': 12, 'ingredients': ['pasta', 'squash', 'parmesan', 'eggs', 'shrimp', 'garlic', 'arugula', 'vinegar', 'cheese', 'butter', 'salt', 'pepper']})
# ('513395', {'name': 'warm sweet potato salad with chorizo', 'num_ingredients': 10, 'ingredients': ['potato', 'olive oil', 'juice', 'sugar', 'salt', 'pepper', 'chorizo', 'pepper', 'onion', 'cilantro']})
# ('520788', {'name': 'warren ohio hot dog shoppe sauce', 'num_ingredients': 10, 'ingredients': ['beef', 'salt', 'sugar', 'chili', 'clove', 'nutmeg', 'Paprika', 'ketchup', 'water', 'flour']})
# ('522871', {'name': 'wasabi ae  broccoli with wasabi sauce', 'num_ingredients': 6, 'ingredients': ['broccoli', 'water', 'wasabi', 'soy', 'sake', 'sugar']})
# ('516296', {'name': 'watermelon sangria with sriracha', 'num_ingredients': 8, 'ingredients': ['watermelon', 'wine', 'rum', 'sugar', 'chili', 'lime', 'ginger', 'mint']})
# ('520322', {'name': 'weight watchers classic lasagna', 'num_ingredients': 20, 'ingredients': ['olive oil', 'onion', 'carrot', 'celery', 'garlic', 'ground beef', 'wine', 'tomatoes', 'tomato', 'oregano', 'salt', 'pepper', 'pepper', 'basil', 'Ricotta', 'egg', 'parmesan', 'parsley', 'lasagna', 'mozzarella']})
# ('519141', {'name': 'weight watchers italian sausage and pepper pasta', 'num_ingredients': 10, 'ingredients': ['sausage', 'olive oil', 'pepper', 'wine', 'garlic', 'tomato', 'red pepper', 'salt', 'fusilli', 'basil']})
# ('512242', {'name': 'weight watchers parmesan crusted chicken schnitzels', 'num_ingredients': 7, 'ingredients': ['chicken', 'breadcrumb', 'parmesan', 'garlic', 'oregano', 'salt', 'oil']})
# ('533134', {'name': 'welsh dragon pie', 'num_ingredients': 12, 'ingredients': ['pork', 'leek', 'butter', 'cumin', 'pepper', 'salt', 'flour', 'Lard', 'water', 'salt', 'stock', 'gelatin']})
# ('521673', {'name': 'west african chili', 'num_ingredients': 18, 'ingredients': ['ham', 'bay', 'chilies', 'pepper', 'garlic', 'cumin', 'salt', 'water', 'olive oil', 'onion', 'tomatoes', 'curry', 'cumin', 'paprika', 'chili', 'cauliflower', 'carrot', 'chard']})
# ('511737', {'name': 'whiskey pretzels', 'num_ingredients': 6, 'ingredients': ['pretzel', 'butter', 'whiskey', 'sugar', 'garlic', 'pepper']})
# ('534786', {'name': 'white bean and chicken chili', 'num_ingredients': 11, 'ingredients': ['chicken', 'onion', 'garlic', 'bean', 'chicken', 'chili', 'soup', 'cumin', 'pepper', 'olive oil', 'cheese']})
# ('513918', {'name': 'white bean green chili with ground pork', 'num_ingredients': 12, 'ingredients': ['bean', 'pork', 'chili', 'garlic', 'onion', 'chicken', 'cumin', 'garlic', 'chili', 'Paprika', 'pepper', 'salt']})
# ('516610', {'name': 'white castle turkey stuffing', 'num_ingredients': 6, 'ingredients': ['hamburger', 'celery', 'thyme', 'sage', 'pepper', 'chicken']})
# ('535874', {'name': 'white chocolate grasshopper pie', 'num_ingredients': 18, 'ingredients': ['flour', 'baking soda', 'baking', 'shortening', 'sugar', 'egg', 'food', 'chocolate', 'gelatin', 'water', 'marshmallow', 'half-and-half', 'creme de menthe', 'cream', 'water', 'gelatin', 'white chocolate', 'corn']})
# ('534956', {'name': 'white chocolate mousse mirror cake', 'num_ingredients': 10, 'ingredients': ['strawberry', 'gelatin', 'sugar', 'chocolate', 'water', 'cream', 'cake', 'sugar', 'glucose', 'milk']})
# ('534266', {'name': 'white chocolate peppermint candies', 'num_ingredients': 6, 'ingredients': ['spray', 'chocolate', 'cream', 'peppermint', 'food coloring', 'candy']})
# ('516142', {'name': 'white chocolate raspberry pancakes', 'num_ingredients': 8, 'ingredients': ['flour', 'baking soda', 'salt', 'egg', 'sour cream', 'Milk', 'raspberries', 'white chocolate']})
# ('518114', {'name': 'white chocolate rose pudding', 'num_ingredients': 6, 'ingredients': ['Milk', 'cream', 'cornstarch', 'white chocolate', 'essence', 'salt']})
# ('517641', {'name': 'white russian sorbet', 'num_ingredients': 8, 'ingredients': ['water', 'sugar', 'espresso', 'syrup', 'cream', 'Vodka', 'coffee', 'coffee']})
# ('530037', {'name': 'whole 30 hibachi chicken', 'num_ingredients': 8, 'ingredients': ['aminos', 'garlic', 'pineapple', 'ginger', 'onion', 'cilantro', 'pepper', 'chicken']})
# ('520769', {'name': 'whole lemon roasted chicken', 'num_ingredients': 7, 'ingredients': ['lemon', 'butter', 'thyme', 'salt', 'chicken', 'pepper', 'garlic']})
# ('531446', {'name': 'whole wheat spaghetti bolognese', 'num_ingredients': 16, 'ingredients': ['carrot', 'root', 'parsley', 'onion', 'garlic', 'olive oil', 'beef', 'bacon', 'tomato', 'wine', 'beef', 'bay', 'thyme', 'pepper', 'spaghetti', 'Grana Padano']})
# ('520313', {'name': 'wholly huli pulled pork', 'num_ingredients': 12, 'ingredients': ['pork', 'oil', 'sesame oil', 'soy', 'pineapple', 'sugar', 'ginger', 'sake', 'onion', 'garlic', 'pepper', 'onion']})
# ('536066', {'name': 'widow s soup', 'num_ingredients': 16, 'ingredients': ['butter', 'olive oil', 'onion', 'garlic', 'parsley', 'potato', 'carrot', 'kohlrabi', 'celery', 'bean', 'pea', 'cauliflower', 'tomato', 'stock', 'salt', 'cheese']})
# ('511932', {'name': 'wild rice and ham soup   lower fat', 'num_ingredients': 11, 'ingredients': ['butter', 'onion', 'flour', 'broth', 'rice', 'mushroom', 'carrot', 'ham', 'almond', 'milk', 'wine']})
# ('512536', {'name': 'wings peanut butter and jelly wings', 'num_ingredients': 7, 'ingredients': ['jelly', 'peanut butter', 'vinegar', 'hot pepper sauce', 'salt', 'chicken', 'cilantro']})
# ('521748', {'name': 'world s best pasta sauce', 'num_ingredients': 14, 'ingredients': ['sausage', 'ground beef', 'onion', 'garlic', 'tomato', 'tomato', 'tomato', 'water', 'sugar', 'basil', 'fennel', 'seasoning', 'salt', 'pepper']})
# ('514626', {'name': 'ww broccoli with spicy honey sesame sauce', 'num_ingredients': 6, 'ingredients': ['broccoli', 'soy sauce', 'Honey', 'seed', 'sesame oil', 'pepper']})
# ('513171', {'name': 'ww brussels sprouts with dried canberries and lemon   3 pts', 'num_ingredients': 6, 'ingredients': ['Brussels', 'cranberries', 'lemon', 'olive oil', 'salt', 'pepper']})
# ('514750', {'name': 'ww soba chicken noodle bowl', 'num_ingredients': 11, 'ingredients': ['soba', 'chicken broth', 'water', 'chicken', 'mushroom', 'ginger', 'soy sauce', 'pea', 'peas', 'spinach', 'scallion']})
# ('527467', {'name': 'yakitori chicken', 'num_ingredients': 12, 'ingredients': ['sake', 'mirin', 'garlic', 'ginger', 'red pepper', 'sugar', 'soy sauce', 'soy', 'chicken', 'scallion', 'pepper', 'pear']})
# ('527351', {'name': 'yellow butter cake', 'num_ingredients': 12, 'ingredients': ['cake mix', 'butter', 'eggs', 'cream cheese', 'sugar', 'extract', 'chocolate', 'white chocolate', 'flour', 'Milk', 'sugar', 'vanilla']})
# ('523043', {'name': 'yellow squash and corn saute', 'num_ingredients': 7, 'ingredients': ['corn', 'squash', 'water', 'butter', 'parsley', 'salt', 'pepper']})
# ('512528', {'name': 'yemeni lentil soup', 'num_ingredients': 13, 'ingredients': ['lentils', 'oil', 'tomatoes', 'onion', 'garlic', 'cumin', 'coriander', 'turmeric', 'salt', 'water', 'pepper', 'pepper', 'pepper']})
# ('517455', {'name': 'yogurt and dill  crack  sauce', 'num_ingredients': 6, 'ingredients': ['yogurt', 'mayonnaise', 'lemon', 'dill', 'garlic', 'salt']})
# ('533161', {'name': 'yogurt fruit bark', 'num_ingredients': 6, 'ingredients': ['yogurt', 'syrup', 'peach', 'blueberries', 'strawberry', 'granola']})
# ('516278', {'name': 'yummy corn cakes', 'num_ingredients': 13, 'ingredients': ['cornmeal', 'flour', 'salt', 'baking soda', 'pepper', 'sugar', 'butter', 'egg', 'buttermilk', 'corn', 'onion', 'pepper', 'cheese']})
# ('522942', {'name': 'yuzu cocktail', 'num_ingredients': 6, 'ingredients': ['rum', 'vodka', 'sec', 'syrup', 'yuzu', 'soda']})
# ('532829', {'name': 'zaatar pita bread', 'num_ingredients': 11, 'ingredients': ["Za'atar", 'olive oil', 'bread', 'labneh', 'tomato', 'olive', 'flour', 'yeast', 'salt', 'sugar', 'water']})
# ('516905', {'name': 'zero carb bread', 'num_ingredients': 8, 'ingredients': ['flax', 'egg', 'eggs', 'flax seed', 'baking', 'salt', 'water', 'Stevia']})
# ('524487', {'name': 'zesty chicken and black bean salad   starbucks copycat', 'num_ingredients': 15, 'ingredients': ['tomato', 'vinegar', 'olive oil', 'mustard', 'garlic', 'basil', 'salt', 'quinoa', 'salad', 'tomatoes', 'bean', 'corn', 'jicama', 'Feta', 'chicken']})
# ('517517', {'name': 'zharenaya kartoshka fried potatoes russian style', 'num_ingredients': 7, 'ingredients': ['potato', 'onion', 'garlic', 'mushroom', 'water', 'oil', 'onion']})
# ('511888', {'name': 'zippy meatloaf   2 5 qt  pressure cooker', 'num_ingredients': 14, 'ingredients': ['salt', 'pepper', 'oatmeal', 'Worcestershire', 'parsley', 'onion', 'celery', 'garlic', 'pepper', 'sirloin', 'pork', 'oil', 'ketchup', 'tomato sauce']})
# ('531003', {'name': 'zucchini and sweet corn chowder', 'num_ingredients': 13, 'ingredients': ['zucchini', 'zucchini', 'onion', 'garlic', 'celery', 'corn', 'epazote', 'half-and-half', 'pepper', 'turmeric', 'water', 'oil', 'salt']})
# ('522243', {'name': 'zucchini fritters  low carb', 'num_ingredients': 12, 'ingredients': ['zucchini', 'scallion', 'eggs', 'cream cheese', 'parmesan', 'garlic', 'basil', 'salt', 'pepper', 'powder', 'butter', 'olive oil']})
# ('517690', {'name': 'zucchini lemon poppyseed bread', 'num_ingredients': 14, 'ingredients': ['sugar', 'eggs', 'vanilla', 'oil', 'Milk', 'lemon', 'salt', 'baking soda', 'baking', 'flour', 'flour', 'cinnamon', 'poppy', 'zucchini']})
# ('528086', {'name': 'zucchini tater tots', 'num_ingredients': 11, 'ingredients': ['zucchini', 'shallot', 'mozzarella', 'parmesan', 'panko', 'egg', 'seasoning', 'garlic', 'salt', 'olive oil', 'marinara']})
# ('515473', {'name': 'zucchini  kale  and tomato saute', 'num_ingredients': 10, 'ingredients': ['olive oil', 'onion', 'garlic', 'zucchini', 'tomatoes', 'basil', 'oregano', 'red pepper', 'salt', 'kale']})
# ('529308', {'name': 'zuppa di cipolla al vino rosso', 'num_ingredients': 10, 'ingredients': ['beef broth', 'butter', 'onion', 'flour', 'oil', 'pepper', 'salt', 'sugar', 'Gruyere', 'baguette']})

# %% [markdown]
# ## Do recipes from the same cuisine form distinct communities within the graph?

# %%
def randomize_graph(graph):
    randomized_graph = nx.algorithms.smallworld.random_reference(graph, connectivity=False)
    return randomized_graph

# %%
def print_total_communities_and_modularity(G, method, communities):
    total_communities = len(communities)
    modularity_value = modularity(G, communities)
    print(f"{method} - Total Communities: {total_communities}, Modularity: {modularity_value:.4f}")

def communities_greedy_label_summary(G, dataset_name):
    greedy_communities = list(greedy_modularity_communities(G))
    print_total_communities_and_modularity(G, "Greedy Modularity", greedy_communities)

    label_communities = list(label_propagation_communities(G))
    print_total_communities_and_modularity(G, "Label Propagation", label_communities)

print("\n=== Greedy and Label ===")
communities_greedy_label_summary(recipes_graph, 'Graph 5 Common Ingredients')

print("\n=== Randomized ===")
recipes_randomized = randomize_graph(recipes_graph)
communities_greedy_label_summary(recipes_randomized, 'Graph 5 Common Ingredients Randomized')
# Out:
# === Greedy and Label ===
# Greedy Modularity - Total Communities: 205, Modularity: 0.3608
# Label Propagation - Total Communities: 203, Modularity: 0.3546
#
# === Randomized ===
# Greedy Modularity - Total Communities: 201, Modularity: 0.0512
# Label Propagation - Total Communities: 195, Modularity: 0.0000

# %%
def print_communities_by_name(G, method, communities):
    print(f"\n{method}:")
    for i, community in enumerate(communities):
        node_names = [G.nodes[node]['name'] for node in community]
        print(f"\nCommunity {i+1} ({len(node_names)} recipes):")
        for idx, name in enumerate(node_names, start=1):
            print(f"  {idx}. {name}")
    print(f"\nTotal number of communities: {len(communities)}")
    print(f"Modularity: {modularity(G, communities):.4f}")

def communities_greedy_label(G, dataset_name):
    greedy_communities = list(greedy_modularity_communities(G))
    print_communities_by_name(G, "Greedy Modularity", greedy_communities)

    label_communities = list(label_propagation_communities(G))
    print_communities_by_name(G, "Label Propagation", label_communities)

# %%
communities_greedy_label(recipes_graph, 'Graph 5 Common Ingredients')
# Out:
# Greedy Modularity:
#
# Community 1 (1032 recipes):
#   1. chicken and vegetable borscht
#   2. sweet and spicy short ribs
#   3. rainbow rose veggie tart
#   4. sunrabbit s vegan creamy corn chowder
#   5. rice con queso
#   6. lithuanian potato pudding
#   7. barberton hot sauce
#   8. vietnamese caramelized pork  thit ko    instant pot version
#   9. mexican street corn casserole
#   10. roasted pork tenderloin with cajun cornbread stuffing
#   11. slow cooker honey pork roast
#   12. open pit bbq sauce
#   13. alan s vegetarian vegan bean and rice burger mashup
#   14. world s best pasta sauce
#   15. slow cooker whole cauliflower
#   16. border quiche   low carb
#   17. lump crabmeat and avocado crostini
#   18. babette s colossal crockpot chili  ragu
#   19. turkish spice mix
#   20. copycat hamburger helper rice oriental
#   21. pretzel beer cheese stuffing
#   22. pan roasted chicken with harissa chickpeas
#   23. taco squares
#   24. warm sweet potato salad with chorizo
#   25. crock pot beans in molasses
#   26. baja fish taco
#   27. bright and fresh thai beef salad
#   28. esquites  mexican corn salad
#   29. grilled roadside chicken with knob onions
#   30. kfc copycat chicken
#   31. happy humus  ragu
#   32. limpin susan
#   33. a 1  chinese pasta  a1
#   34. cajun shrimp and mashed cauliflower
#   35. spicy red pepper jelly
#   36. old el paso baked spicy chicken tacos
#   37. vietnamese bun cha gio
#   38. mel s black bean and sweet potato burritos
#   39. chili rubbed rib eye steaks with cilantro butter
#   40. honey lemon glazed cauliflower
#   41. dee s italian green bean salad
#   42. taco bell xxl copycat beef nachos
#   43. panda express eggplant tofu
#   44. fear the reaper bbq sauce
#   45. scottish meat pie
#   46. baked chicken parmigiano
#   47. cauliflower mac   cheese
#   48. sehriye pasta dish  turkish
#   49. texas pete warm buffalo potato salad
#   50. lentil soup with italian sausage
#   51. one pot spicy turkey rice taco bowl
#   52. pork carnitas
#   53. ham and cheese frittata
#   54. a1 zesty potatoes  a1
#   55. a 1 steak puffs with corn and avocado salsa  a1
#   56. mini vegetable frittatas
#   57. doritos taco casserole
#   58. fat free italian dressing
#   59. crusty parmesan herb zucchini bites
#   60. caprese stuffed avocado
#   61. solar starninja s twisted green bean casserole
#   62. russian borsch
#   63. vietnamese lemongrass pork
#   64. dried cherry and goat cheese salad with dijon vinaigrette
#   65. zharenaya kartoshka fried potatoes russian style
#   66. turkish green bean salad
#   67. philly cheesesteak sliders
#   68. korean style vinaigrette
#   69. zesty chicken and black bean salad   starbucks copycat
#   70. yemeni lentil soup
#   71. katel s tweaked world s best lasagna
#   72. burrito bowl mason jar salad
#   73. sweet   saucy chicken
#   74. hawaiian poke bowl
#   75. mel s brown pizza sauce
#   76. mexican tabbouleh
#   77. creamed curly kale
#   78. breakfast muffins to go
#   79. kosher hamburger helper
#   80. thai noodles
#   81. touchdown turkey chili
#   82. calamari salad with red chicory   herby lime dressing
#   83. beef and black bean taco dip
#   84. quick cheeseburger pie  gold medal
#   85. whole lemon roasted chicken
#   86. nif s instant pot macaroni and cheese
#   87. loaded baked potato soup lactose free
#   88. belizean meat pies
#   89. serious eats chicken tikka masala   maybe the best
#   90. pina colada shrimp
#   91. don pablo s copycat chili con queso
#   92. dr  oz s 2 week rapid weight loss plan  vegetable broth
#   93. mini buffalo chicken cheesesteaks
#   94. instant pot chicken pot pie casserole
#   95. beecher s kale and brown rice gratin with smoked cheese
#   96. skillet linguica with pasta
#   97. olive rice
#   98. vinegar dill coleslaw
#   99. warm shrimp nest salad  ragu
#   100. thanksgiving turkey meatloaf
#   101. spicy italian mexican chili  ragu
#   102. harira soup
#   103. mario batali s baked pasta with mushrooms and mozzarella
#   104. vietnamese chicken
#   105. ultimate black bean soup stew with chorizo and braised chicken
#   106. vietnamese chicken liver pate
#   107. creamy vegan potato soup
#   108. hot spicey tomato oil for dipping
#   109. roasted chicken thighs with lemon and oregano
#   110. instant pot vegetarian stew
#   111. sweet and savory chicken rice bowl
#   112. roasted mushroom  onion  and garlic soup
#   113. whole 30 hibachi chicken
#   114. mac   cheese stuffed crust pizza
#   115. wholly huli pulled pork
#   116. white bean green chili with ground pork
#   117. holy yum chicken
#   118. ragu shuka  ragu
#   119. collard greens mac   cheese
#   120. a 1  slow roasted shredded steak with polenta  a1
#   121. ragu ratatouille hummus plate  ragu
#   122. tasty stir fry szechuan prawns shrimps
#   123. spinach ricotta pizza with fresh tomato puree
#   124. a 1  pot stickers with chili pineapple dipping sauce  a1
#   125. cream cheese stuffed pork chops wrapped in bacon
#   126. randy s hybrid alfredo sauce
#   127. pizza skulls
#   128. chicken pot pie for two  cook s country
#   129. bob s sloppy joes for 6
#   130. pan fried chicken with garlic and lemon
#   131. panko crusted salmon
#   132. tony diramio s official ham bone soup
#   133. baked penne
#   134. breaded fried steak   milanesa
#   135. cheesy pulled pork nachos
#   136. paleo party pork carnitas
#   137. light chicken nuggets
#   138. smokey black bean   the bandit soup
#   139. stuffing butter
#   140. baked salmon with lemon and capers
#   141. parmesan french toast
#   142. zippy meatloaf   2 5 qt  pressure cooker
#   143. almond chive salmon
#   144. chicken and broccoli alfredo stuffed shells
#   145. lemon pepper chicken with creamy garlic lemon sauce
#   146. lentil vegetable coconut curry soup
#   147. d arabian s roasted garlic clove chicken thighs
#   148. brazilian chicken and rice with olives
#   149. portuguese chicken and rice
#   150. pork chop with sweet potato and pineapple
#   151. tuna melts with horseradish mayonnaise
#   152. pickled jalapeo peppers
#   153. oriental chicken salad with honey sesame dressing
#   154. incredible cheesy broccoli soup   weight watchers
#   155. francos sea scallops in white wine sauce
#   156. garbanzo chipotle soup  chowder
#   157. tender beef kabobs  shashlik
#   158. taqueria green salsa  salsa verde
#   159. a 1 butter deconstructed pinwheel steak with avocado sauce  a1
#   160. ginger soy salmon   asian noodles
#   161. montreal style poutine
#   162. 4 delicious french fry toppers
#   163. boiled pig feet
#   164. ginger peanut dressing
#   165. caesar dressing
#   166. honey jalapeno dressing
#   167. pan fry garlic butter branzino
#   168. whole wheat spaghetti bolognese
#   169. ww broccoli with spicy honey sesame sauce
#   170. one pan mongolian beef zoodles
#   171. cheats crock pot indian pakistani chicken curry   semi authentic
#   172. easy cheesy fondue  ragu
#   173. dijon cream sauce
#   174. chicken breasts with tomatoes and capers
#   175. shrimp ceylon
#   176. gheyme
#   177. thanksgiving panzanella
#   178. beef skewers with cilantro chimichurri
#   179. keto   low carb cream of broccoli soup
#   180. sriracha roasted chicken
#   181. kfc kentucky fried chicken with 11 special seasonings
#   182. sweet and spicy dry rub
#   183. iowa girl cheeseburger pizza with secret sauce
#   184. soma sengupta easter recipes  spicy roast lamb with classic indi
#   185. hainanese chicken and rice  instant pot
#   186. saucy steak pocket pies  a1
#   187. slow cooker tomato sauce  with fresh tomatoes
#   188. roasted pork shoulder  pernil al horno
#   189. spicy szechuan orange chicken   ww
#   190. moroccan turkey tagine
#   191. layered ragu taco salad with crispy tortilla triangles ragu
#   192. garlic and herb mashed potatoes
#   193. shrimp scampi potstickers
#   194. skinny beef and broccoli
#   195. dhaba style aloo paratha
#   196. klotski  potato dumplings in chicken broth
#   197. buffalo turkey burgers with blue cheese
#   198. parmesan baked pork chops
#   199. wild rice and ham soup   lower fat
#   200. buffalo chicken monkey bread
#   201. green chile spinach dip
#   202. hawaiian shoyu chicken
#   203. curried thunder thighs  a1
#   204. paleo ginger chicken breasts over green spinach
#   205. kate s loaded fried rice
#   206. widow s soup
#   207. sweet tea baby back ribs
#   208. hard fried chicken
#   209. mock outback steakhouse green beans
#   210. mustard and brown sugar rubbed salmon
#   211. kai wot  ethiopian beef stew
#   212. gastric sleeve white bean soup with extra protein and bone broth
#   213. braciole
#   214. salmon poke bowl
#   215. neiman marcus chicken salad
#   216. truffle hummus
#   217. dijon mustard pork marinade
#   218. captain chris  honey n hickr y bar b q sauce
#   219. weight watchers parmesan crusted chicken schnitzels
#   220. shortcut lasagna
#   221. hyderabadi chicken biryani
#   222. chimichurri rojo for brazilian styled steak and other meats
#   223. broccoli and bean soup
#   224. mushroom bhaji
#   225. shrimp in chili sauce  ebi no chili sauce
#   226. chicken adobo   steamy kitchen
#   227. caramelized onion loco moco
#   228. hearty heatlthy lentil soup
#   229. tasty green bean casserole cups
#   230. avocado white bean hummus
#   231. new york breakfast casserole
#   232. cauliflower alfredo
#   233. baconfredo
#   234. creamy spaghetti with beef and veggies
#   235. zucchini tater tots
#   236. tom kha kai point 2
#   237. chicken and kale stew  crock pot  paleo
#   238. yellow squash and corn saute
#   239. creamy sriracha dressing
#   240. irish meat pie
#   241. thai peanut coconut chicken
#   242. kemp s vegetarian black beans   6 qt pressure cooker
#   243. salsa queens copycat  creamy horseradish sauce
#   244. hearty italian sausage and meatball stew  ragu
#   245. chicken frangelico
#   246. a yummy chicken noodle soup  8 qt  pressure cooker
#   247. chicken zurbian rice from yemen
#   248. burnt garlic whole wheat or gluten free noodles
#   249. pei wei asian diner caramel chicken
#   250. better than del taco chicken soft tacos
#   251. white bean and chicken chili
#   252. charge me up a1 steak   egg veggie breakfast wrap  a1
#   253. instant pot beef shawarma
#   254. chicken  spinach and cannellini bean quesadillas
#   255. chinese stir fried curried shrimp
#   256. butternut squash  spinach   goat cheese pie
#   257. spicy thai coconut shrimp with rice noodles
#   258. sweet dry rub baby back ribs   6 qt electric pressure cooker
#   259. vietnamese beef marinade
#   260. dorito  popcorn seasoning
#   261. homemade spaghetti sauce with ground beef
#   262. budget bytes  italian wonderpot
#   263. chicken cabbage stir fry
#   264. memphis spice rub
#   265. stuffed baby bell peppers
#   266. risotto with peas and green onions
#   267. home style sushi over rice  chirashizushi
#   268. turkey meatballs and peanut sauce
#   269. chicken and pepper
#   270. quick easy sicilian pasta sauce
#   271. saucy tortellini and meatball soup  a1
#   272. ground turkey tacos
#   273. carne estufada  azorean beef casserole
#   274. tuscan marinated steaks
#   275. spicy fried ginger beef
#   276. slow cooker chana masala
#   277. insalata florentine romano s macaroni grill copycat
#   278. reser s potato salad  copycat
#   279. spicy lamb meatballs
#   280. onion bibb salad
#   281. taco bell style crunch wrap supreme
#   282. sausage  potato  and spinach soup
#   283. old rag pie
#   284. easy salisbury steak and mushroom gravy
#   285. creamy italian dressing  cook s country
#   286. fresh cucumber condiment   tang kwah ah jad
#   287. west african chili
#   288. kale slaw with curried almond dressing
#   289. vegetarian lomo saltado
#   290. taco meat   restaurant style
#   291. quinoa with winter squash and carrot stew
#   292. tsizzles sloppy joes
#   293. hawaiian slaw
#   294. mediterranean tortellini  ragu
#   295. kiwicats gourmet salad with chicken
#   296. mac n cheese
#   297. korean bbq chicken thighs  a1
#   298. portuguese macaroni   bean soup
#   299. dees bell pepper salad
#   300. i forgot about the broccoli soup
#   301. laarb gai
#   302. shortcut smoky indoor ribs
#   303. chicken roast garlic pasta
#   304. sicilian eggplant caponata
#   305. eggplant tomato pie
#   306. lumpia  filipino spring rolls
#   307. stove top pot roast with gravy  potatoes and carrots
#   308. black bean quinoa soup
#   309. puff pastry chicken pot pie
#   310. spice rub for steaks
#   311. grilled chicken wings   japanese style
#   312. zucchini and sweet corn chowder
#   313. chilean pistou with cilantro pesto
#   314. lemongrass chicken bnh m bowls
#   315. sheet pan turkey caprese meatballs with rosemary smashed potatoe
#   316. impossibly easy mini cheeseburger pies
#   317. stromboli ring
#   318. a1 cowboy up tart  a1
#   319. ty s thai salad
#   320. unstuffed cabbage rolls
#   321. thai basil beef
#   322. vegetable broth base
#   323. beefy chipotle cocoa chili
#   324. griby marinovannye  russian marinated mushrooms
#   325. chicpea salad sandwiches
#   326. sarmale
#   327. bruschetta grilled chicken zoodle bowl
#   328. one pot tomato basil pasta
#   329. tasty crockpot cheese baked rigatoni  you will be using a pan to
#   330. beef and quinoa stuffed bell peppers
#   331. one pot chicken bacon spinach parmesan pasta
#   332. no butter shrimp scampi
#   333. baja citrus marinade  chicken or pork chops
#   334. pecorino crusted chicken with mushroom salad
#   335. chicken vol au vent with tomato mango relish  a1
#   336. lasagna soup with sausage
#   337. spice rubbed pork with quinoa
#   338. fiesta caliente bean salad
#   339. spicy tofu and coconut curry soup
#   340. portobello pizzas
#   341. saffron roasted cauliflower
#   342. copycat campbell s bean with bacon soup
#   343. baked turkey meatballs
#   344. simply delightful and easy lima beans
#   345. paleo pork chili verde
#   346. creme de volaille  french cream of chicken soup
#   347. beef   chickpea paprikash
#   348. pasta maldonado
#   349. kfc inspired chicken  slow cooker
#   350. coconut curried butternut squash soup
#   351. easy green chile chicken rice casserole
#   352. slow cooker lentil beef stew
#   353. tasty summer beet salad
#   354. simply wonderful low carb sloppy joes
#   355. crockpot brazilian chicken curry  paleo
#   356. prime rib with garlic herb butter
#   357. sheet pan shrimp scampi
#   358. 10 minute shrimp pad thai
#   359. the real deal authentic homemade enchilidas
#   360. cucumber raita salad
#   361. pasta with tomatoes  capers  olives and breadcrumbs
#   362. quick coconut chicken curry
#   363. cast iron skillet fillet mignon
#   364. buffalo wing  mushrooms
#   365. buffalo cauliflower chili   crock pot
#   366. chinese rice salad with snow peas
#   367. mini pepperoni calzones
#   368. mix   match chicken soup
#   369. bunny chow
#   370. indian chicken drumsticks
#   371. spaghetti kabob  ragu
#   372. janet s kfc seasoned fried chicken
#   373. instant pot italian meatballs
#   374. quick chicken and dumplings
#   375. persian rice with cinnamon  pistachios and golden raisins
#   376. honey ginger chicken wings
#   377. cauliflower ceviche
#   378. ci shrimp fra diavolo
#   379. chorizo   black bean breakfast burritos  oamc
#   380. instant pot pork chops and potatoes
#   381. pan fried quinoa cakes
#   382. lemon butter scallops
#   383. turkish eggs
#   384. dill tastic pizza  ragu
#   385. the best slow cooker carnitas  great for tacos
#   386. orzo artichoke pasta salad
#   387. tuna poke
#   388. pasta in pink sauce with sausage  ragu
#   389. slow cooker cheesy bacon ranch potatoes
#   390. mint chimichurri
#   391. baked zucchini balls  gluten free
#   392. pineapple habanero pepper jelly
#   393. greek with envy
#   394. nif s cajun macaroni and cheese
#   395. blackened pork ribs
#   396. light thai coconut soup
#   397. carolina chicken bog
#   398. the best ever slow cooker carnitas
#   399. tuna melt sliders
#   400. mock baccalla salad
#   401. fried chicken sandwich with hot honey
#   402. crazy good casserole
#   403. navy bean  ham and potato soup
#   404. loaded buffalo oven fries
#   405. fish house panko cod fillets
#   406. cornbread squash casserole
#   407. 15 minute shrimp stir fry
#   408. slow cooker overnight breakfast casserole
#   409. bacon wrapped sonoran hot dogs
#   410. cajun guacamole shrimp cups
#   411. broiled halibut steaks with cranberry compote
#   412. sweet and sour cabbage
#   413. authentic eggplant parmesan
#   414. middle eastern rice   lentils
#   415. pan seared shrimp and bacon 3 cheese truffles  ragu
#   416. smooth smoking spicy salsa
#   417. basil   mint orzo salad
#   418. chicken meatball tikka masala
#   419. garlic baked brie spider
#   420. artichoke pad thai
#   421. carol p s six can chicken tortilla soup
#   422. eggplant involtini
#   423. french onion soup ii
#   424. crab cake stuffed mushrooms
#   425. spice rubbed tilapia with tomatillo  black bean and mango salad
#   426. no carb   chicken stuffed green peppers
#   427. extra crispy fried chicken
#   428. philly cheesesteak stuffed peppers
#   429. orzo and shrimp salad recipe
#   430. spaghetti with mint   parsley pesto
#   431. chile jam chicken
#   432. big bend texas style chili
#   433. jk wasabi dip  public
#   434. oven fried chicken sliders
#   435. shrimp and crab meat with rice
#   436. rainbow salad
#   437. swedish  ikea  meatballs
#   438. ellen s potato soup
#   439. filet mignon
#   440. jalapeno and beer baked short ribs
#   441. jose s shrimp ceviche
#   442. slow cooker lamb shanks
#   443. butternut squash penne with chicken  bacon and spinach
#   444. hungarian chicken breasts
#   445. paprika pork chops
#   446. argentine grilled flank steak
#   447. slow cooker san francisco pork chops
#   448. tilapia picata or chicken picata with capers
#   449. bacon kissed cauliflower dip w  crispy corn tortillas  ragu
#   450. beer battered fish tacos with pickled onion and cucumber
#   451. spicy beef flatbread with yogurt   cucumbers
#   452. egg and spinach pot
#   453. argentine chili
#   454. charquican   chilean beef stew
#   455. crustless spainch and mushroom quiche
#   456. choc chilli sauce
#   457. cajun remoulade
#   458. fermented giardiniera
#   459. roasted tomato   feta penne with arugula pesto
#   460. rich sour cream gravy
#   461. lplermagrone
#   462. lemon butter brussels sprouts
#   463. bacon potato cheddar tart
#   464. japanese salad with ginger soy dressing
#   465. chicken helper   chicken enchilada copycat
#   466. pulled pork sandwiches  ww and crock pot
#   467. walnut crusted cherry chicken  a1
#   468. cast party salad  arugula
#   469. zucchini fritters  low carb
#   470. rainbow veggie pizza
#   471. the best basic hummus recipe
#   472. slow cooker beer chicken
#   473. linguine with honey sauced prawns
#   474. black bean and sweet potato burritos light
#   475. honduran chicken   rice
#   476. garlic pepper sausage linguine pasta
#   477. crock pot white chicken chili
#   478. sweet   sour spam
#   479. shrimp scampi mac   cheese
#   480. tomato basil pasta sauce
#   481. ground turkey   noodle paprikash
#   482. purple gnocchi with shiitake mushrooms
#   483. spanish quinoa
#   484. instant pot beef tips
#   485. mexican ground turkey tostada  a1
#   486. broccoli cheddar latkes
#   487. beef   bean    oven tacos
#   488. st  louis style chicken salad
#   489. p f chang s lo mein
#   490. blue ribbon coleslaw
#   491. arby s oven baked curly fries
#   492. gorky s chicken
#   493. country beef   cabbage soup  good carbs
#   494. spicy whole roasted cauliflower
#   495. guasacaca   guacamole from venezuela
#   496. bobotie  south african curry meat loaf
#   497. phena s beef delight  a1
#   498. slow cooker quinoa chicken chili
#   499. creamy beef   rice casserole
#   500. sheet pan chicken dinner
#   501. goan black eyed peas  slow cooker
#   502. kicking southern style collard greens
#   503. melt in your mouth chicken casserole with biscuit topping
#   504. linda s low carb italian casserole
#   505. egg and kale breakfast wraps
#   506. low carb mozzarella sticks
#   507. polenta   sausage stuffed pepper gondolas  ragu
#   508. pasta puttanesca perfecto
#   509. australian crash hot potatoes
#   510. slow cooker thai pork with peanut sauce
#   511. southern potato salad
#   512. sunday  any day spaghetti  ragu
#   513. mexican tomato soup with toasted pasta
#   514. kartoffelpuffer  german potato pancakes   sp5
#   515. cheesy buffalo chicken skulls
#   516. cheesy steak casserole
#   517. shrimp fettuccine with lemon pesto parmesan  rag
#   518. summer squash stir fry with beef featuring beef bou
#   519. butternut squash soup with bacon and cheddar
#   520. homemade mayonnaise   2 ways
#   521. breakfast taquitos
#   522. chicken cobb salad with avocado dressing
#   523. pork of the gods  paleopot com smokey pulled pork
#   524. gluten free vegan zucchini eggplant lasagna
#   525. instant pot cheesy ham and potato soup
#   526. pan fried rainbow trout
#   527. dungeness   mushroom chowder
#   528. asian chicken meatball   rice noodle soup
#   529. kick n chunky chicken tortilla soup
#   530. mintea couscous  vegan
#   531. dr  oz 2 week rapid weight loss diet detox broth recipe
#   532. asian vegetable soup with shrimp
#   533. vegetarian french dip sandwiches
#   534. 1 minute breakfast sandwich
#   535. green bean and carrot soup  vegan  gluten free
#   536. cheesy chicken parm volcanos
#   537. 5 minute healthy sauted red cabbage
#   538. instant pot lemon chicken orzo soup
#   539. warm roasted vegetable farro salad
#   540. creamy garlic  parmesan  leeks and rice
#   541. pasta alla norma    pasta tossed with fresh tomato sauce  flavor
#   542. flounder  or other white fish  stuffed with shrimp
#   543. smoky salmon spread
#   544. red leaf salad with candied walnuts and grapes
#   545. creamy shrimp fettuccine
#   546. vegan collard greens
#   547. chicken teriyaki meatballs
#   548. amazing beef stew
#   549. cheddar vegetable bake  ragu
#   550. potato salad with pancetta  rosemary  and lemon
#   551. greek quinoa salad
#   552. grilled chicken with spicy brazilian tomato and coconut sauce
#   553. spicy red eye baked beans
#   554. spicy garlic thai shrimp and sauteed kale
#   555. grilled szechuan pork chops
#   556. chicken in red curry and coconut
#   557. sheet pan salmon dinner
#   558. chicken avocado lime soup
#   559. epic egg brunch
#   560. curried chicken moghlai
#   561. baked sea bass with vegetables
#   562. slow cooker chicken burrito bowls
#   563. smoky kentucky chili
#   564. lailani s  pressure cooker   stuffed pepper casserole
#   565. instant pot chicken and dumplings
#   566. fail proof oven baked salmon
#   567. seared ahi tuna
#   568. my mother s better than takeout wonton soup
#   569. paleo mayo
#   570. japanese pan noodles
#   571. stuffed bell peppers   hardcore paleo
#   572. spaghetti squash pitas  ragu
#   573. jim zumbo s unreal stew for gamey meat
#   574. roasted cauliflower potato leek and garlic soup
#   575. saucy chickenaloha  a1
#   576. yakitori chicken
#   577. gulai sayur  collard greens curry indonesian style
#   578. green goddess pizza
#   579. soma sengupta easter recipes  spring pea soup  a great start to
#   580. modern moussaka  a1
#   581. chicken meatballs with spinach and roasted garlic
#   582. stuffed banana peppers
#   583. easy avocado   feta cheese dip
#   584. baked barley with mushrooms
#   585. corned beef hash frittata
#   586. fish kebab
#   587. blue ribbon chicken pasta with prosciutto
#   588. fabulous ham bone and lentil soup
#   589. avocado cream cheese toast
#   590. condensed tomato soup for recipes
#   591. cabbage lasagna
#   592. mediterranean fettuccine with sausage
#   593. spiced lentil  chicken    sausage soup
#   594. creole oven fried chicken and rice
#   595. creamy spinach   mushroom risotto
#   596. prawns in green spice paste  hara masala
#   597. chicken cutlets with mushrooms and pearl onions
#   598. chicken parm
#   599. spaghetti and turkey meatballs
#   600. arancini  italian rice balls
#   601. omelet bites
#   602. umami bomb
#   603. minestrone with italian sausage
#   604. spicy daal
#   605. sheet pan breakfast bake
#   606. baked potato volcano
#   607. super bowl five bean chicken chili
#   608. crunchy lentil walnut salad
#   609. sweet potato and chorizo tacos
#   610. salad olivier   russian potato salad
#   611. balsamic chicken wings
#   612. circle around sausage minestrone  ragu
#   613. karen s easy crockpot potato soup
#   614. bob s taco soup with pasta
#   615. stuffed bell and jalapeno peppers
#   616. chicken and mushroom patties  kotlety or katleti
#   617. mizuna salad with cumin roasted cauliflower
#   618. aji criollo   green aji salsa
#   619. chinese noodle vegetable bowl
#   620. heavenly crock pot honey teriyaki chicken
#   621. broiled honey lime salmon
#   622. sugar snap pea and carrot soup
#   623. one pot taco pasta
#   624. mini stuffed peppers
#   625. 15 bean soup in the instant pot
#   626. moroccan cauliflower couscous salad
#   627. korean inspired popcorn chicken
#   628. crispy chicken thighs in convection oven
#   629. reggie s special mashed potatoes   light
#   630. pull apart pepperoni pizza bread  monkey pizza
#   631. pureed beets with yogurt   zaatar
#   632. cajun boudine
#   633. creamy chicken   black bean enchiladas
#   634. creamy mascarpone polenta with turkey bolognese  a1
#   635. snap pea  corn  and quinoa salad
#   636. saarlndischer dippelappes  or kartoffel charles  po
#   637. chicken pasta salad with fresh mozzarella
#   638. oven roasted potato  fries
#   639. cajun french fries  lowfat
#   640. easy shortcut lasagna
#   641. instant pot thai green curry chicken
#   642. kiwi and tomatillo pico de gallo
#   643. tacos de bistec with lime sauce  mexican street tacos
#   644. maltese stuffed eggplant  brungiel mimli
#   645. baked turkey quinoa meatballs
#   646. lazy days restaurant fish with key lime butter sauce
#   647. alea s corned beef and cabbage soup
#   648. grilled jerk pork tenderloin
#   649. chana punjabi  indian chickpea stew
#   650. pulled pork bbq sandwiches
#   651. weight watchers classic lasagna
#   652. instant pot pork chop
#   653. skillet margarita pizza
#   654. p f chang s beef a la sichuan
#   655. chicken margarita   saffron yellow rice
#   656. instant pot turkey chili
#   657. bloody marys by ree drummond
#   658. one pot spanish chicken and rice
#   659. crawfish or shrimp bisque
#   660. cuban pork roast sandwich
#   661. p f chang s shrimp with lobster sauce
#   662. creamy crockpot tortellini soup
#   663. lemon honey ginger salad dressing
#   664. vegan fried cauliflower
#   665. yogurt and dill  crack  sauce
#   666. italian style huevos rancheros  ragu
#   667. argentinian steak sandwiches
#   668. killer voodoo gumbo
#   669. spicy thai basil chicken   noodle stir fry
#   670. chinese style glazed  loin of pork
#   671. severed hand pies
#   672. vegan pizza margherita
#   673. popeye s popcorn shrimp and chicken
#   674. pork roast crock pot with mushrooms
#   675. best copycat benihana japanese chicken rice
#   676. chorizo   quinoa stuffed poblano peppers with adobo chile  t
#   677. eat until your skinny zucchini pizza pasta
#   678. cilantro lime quinoa
#   679. crock pot chicken and dumplings  spend with pennies version
#   680. the best potato salad
#   681. pasta in almond garlic sauce
#   682. easy mashed potatoes
#   683. braised cauliflower with bacon
#   684. llapingachos ecuatorianos  ecuadorean potato and cheese patties
#   685. der wiener schnitzel style chili dog sauce
#   686. saltgrass style baked potato soup
#   687. avocado tomatillo taco truck sauce
#   688. steak tacos with charred salsa
#   689. dill zucchini dip
#   690. 5 minute general tsos chicken
#   691. spicy shrimp tacos with garlic cilantro lime slaw
#   692. calico slaw with poppyseed dressing
#   693. cayenne cherry chocolate steak sauce  a1
#   694. better than takeout chicken fried rice from rachel schultz
#   695. cranberry bbq turkey or chicken
#   696. chicken tomato soup  mexican style
#   697. orinoco red beans and rice
#   698. chicken khao soi
#   699. grandma mayre s chicken enchilladas
#   700. easy basalmic vinaigrette
#   701. asian noodle bowl with sesame salmon
#   702. apple glazed stuffed pork chops
#   703. mustard potato salad
#   704. baked mexican pie
#   705. chana masala in the slow cooker
#   706. austin chicken fajitas
#   707. orange chicken dino nuggets
#   708. low carb  keto  shrimp and sausage gumbo
#   709. cheesesteak stuffed onion rings
#   710. bang bang shrimp pasta
#   711. corn bread ground beef casserole
#   712. foolproof roast chicken dinner
#   713. the suffed crepes have a mild spice  ragu
#   714. not so swedish meatballs  a1
#   715. sunrabbit s vegan mac n cheese
#   716. satisfying tomato soup
#   717. coffee infused steak
#   718. three pea chicken salad
#   719. shrimp scampi over rice
#   720. chipotle agave chicken wings
#   721. gryby w smetanye  mushrooms with sour cream
#   722. potato   sauerkraut bake
#   723. garlic noodles with vegetables  cheesecake factory style copycat
#   724. ketchup   from fresh garden tomatoes
#   725. rigatoni pasta bake
#   726. savory breakfast tart
#   727. phena s baked turkey flautas  a1
#   728. quick   easy crab dip with a kick
#   729. 7 layer elote dip
#   730. panera bread tuna salad sandwich
#   731. mashup mexican lasagna
#   732. crockpot quinoa  chicken  and kale soup
#   733. lighter 3 bean salad
#   734. rainbow summer rolls with peanut sauce
#   735. latin marinade
#   736. super summer kale salad
#   737. beef and barley soup with wils mushrooms
#   738. my homemade cheeseburger mac hamburger helper
#   739. crisp roasted broccoli
#   740. authentic thai red curry with chicken
#   741. hamburger hash brown casserole
#   742. chips and salsa salad
#   743. egremont inn avocado with celery seed dressing
#   744. austrian kaesespaetzle  cheese spaetzle
#   745. gouda grilled cheese with tahini black bean hummus
#   746. mi casa salsa  from costa mesa restraunt
#   747. qunoa and black bean salad
#   748. rainbow trout  tilapia  baked
#   749. pimiento cheese stuffed celery ribs
#   750. omlet
#   751. creamy chicken and green bean casserole
#   752. cajun jambalaya soup
#   753. hawaiian shrimp truck special  garlic lemon butter shrimp
#   754. the best ground beef tacos on the planet
#   755. neopolitan nachos  ragu
#   756. cranberry walnut chickpea salad sandwich
#   757. filipino lumpia  deep fried pork spring rolls
#   758. spicy mexican chili with chicken nugget dumplings
#   759. ground lamb with orzo
#   760. creamy linquuni stuffed tomato  a1
#   761. a1 derful grilled chicken  a1
#   762. mini mexi meatball bowls   ragu
#   763. sausage and peppers pasta  paula deen
#   764. coffee chipotle pork chops
#   765. bistec argentino al chimichurri  steak with chimichurri sauce
#   766. smothered pork chops and grits
#   767. spinach artichoke dip recipe like houston s
#   768. herb crusted pork loin
#   769. roasted cherry tomatoes with goat cheese
#   770. chicken friand  tourte au poulet et champignons
#   771. joppiesaus my way
#   772. mushrooms in a sour cream sauce
#   773. grilled beet   charred citrus salad
#   774. pork belly ramen
#   775. turkey and vegetable ragout with warm polenta rounds  a1
#   776. ethiopian spiced butter  niter kibbeh
#   777. grilled pork tenderloin with peach barbecue sauce
#   778. healthy garlic shrimp pasta
#   779. mamaw s ham   dumplings
#   780. andouille and chicken gumbo with black eyed peas and greens
#   781. creamy ham and gnocchi bake
#   782. charred thin asian pork chops
#   783. crock pot stuffed peppers
#   784. cheesy pepperoni mushroom flatbread  ww
#   785. sweet potato   kale colcannon
#   786. aha herb mix
#   787. chicken   chorizo spanish enchiladas
#   788. kenji s better big mac
#   789. tamale skillet pie
#   790. spinach   meat stuffed peppers carb free
#   791. firecracker shrimp cups
#   792. shrimp scampi garlic bread
#   793. chickpea pilaf
#   794. bourbon chicken   jasmine rice
#   795. chicken and spinach
#   796. easy  delicious   low carb taco soup
#   797. christmas ham in the slow cooker
#   798. herb garden grilled hamburgers
#   799. lettuce wrap fish tacos
#   800. crock pot lentil   ham soup
#   801. crockpot venison roast
#   802. chicken with caramelized onions and bacon
#   803. caprese mac   cheese
#   804. sausage stuffed ragu mushrooms  ragu
#   805. spanakopita  spinach pie  by ina garten
#   806. easy spaghetti squash casserole
#   807. fasoolya khadra  jordanian beef stew
#   808. spaghetti squash casserole with sweet sausage   peppers
#   809. indonesian malaysian street noodles
#   810. unrolled cabbage rolls
#   811. cornmeal crusted oven fried chicken
#   812. zucchini  kale  and tomato saute
#   813. coconut lime and pork skewers
#   814. hp guinness sauce
#   815. instant pot goulash
#   816. swiss eggs
#   817. breakfast egg muffins
#   818. strawberry mint quinoa salad with lemon vinaigrette featuring ve
#   819. moroccan spiced roast chickpeas
#   820. chicken pot pie  using rotisserie chicken
#   821. meat solyanke
#   822. quinoa spinach patties
#   823. asian inspired zucchini
#   824. grilled salmon with mango salsa
#   825. forevermama s stuffing for fish  shrimp or mushrooms
#   826. pan fried   oven baked steaks
#   827. lets talk turkey  burgers with chipotle mayo   a1
#   828. lighter rotini carbonara
#   829. hiyashi somen   cold noodles with dipping sauce mark bittman
#   830. cabbage rolls with mushroom sauce
#   831. chicken  bacon alfredo bread boat
#   832. clams with chili and basil
#   833. baked salmon with garlic and dijon
#   834. deruny   ukrainian potato pancakes
#   835. sofrito    puerto rican
#   836. creamy parmesan garlic mushroom chicken
#   837. turkey cutlets with barley and swiss chard
#   838. pasta and burnt butter sauce
#   839. schinkenfleckerln    ham noodle casserole
#   840. magic weight loss soup
#   841. fancy pants easy chicken casserole
#   842. cauliflower tacos
#   843. blackened cod with mango salsa
#   844. 3 ingredient carnitas
#   845. scallops marinara with spinach linguine
#   846. better than a can  homemade sloppy joes
#   847. linguini with chicken  sun dried tomatoes  and arugula  ragu
#   848. un stuffed cabbage rolls
#   849. stuffed papaya
#   850. dairy free cream of chicken
#   851. slow cooker jalapeno popper white bean chili
#   852. steak teriyaki
#   853. one hour spanish chickpea soup   6 qt pressure cooker
#   854. hemingway s favorite burger
#   855. roasted potatoes  leeks and cabbage
#   856. herbed turkey london broil
#   857. baklava salmon with asparagus
#   858. baked shrimp and orzo with chickpeas  lemon  and dill
#   859. weight watchers italian sausage and pepper pasta
#   860. steakhouse lover s pasta  a1
#   861. buffalo chicken fritos pie
#   862. crunchy chicken egg rolls with tangy dipping sauce  a1
#   863. curried shrimp and polenta  ragu
#   864. sizzler s malibu chicken
#   865. slow cooker chicken parmigiana meatloaf
#   866. asian inspired pulled pork shoulder  for tacos or sliders
#   867. caldo verde
#   868. slow cooker pho
#   869. shrimp scampi dip
#   870. a1b bacon burger bites on white polenta cakes  a1
#   871. healthy holiday hummus  ragu
#   872. creamy chicken casserole with fingerling potatoes
#   873. apple  honey   caramelized onion flatbread pizza
#   874. margarita shrimp
#   875. roasted red potatoes in the crock pot
#   876. joann s tuna macaroni salad
#   877. dal bhat  red lentils with rice
#   878. paleo chipotle chicken cauliflower bake
#   879. spicy tacos  ragu
#   880. corned beef brisket w  veggies   horseradish pressure cooker
#   881. natasha s tomato  avocado  basil salad
#   882. chicken and broccoli alfredo casserole
#   883. buffalo cauliflower sandwich
#   884. lasagna in the pressure cooker
#   885. cauliflower grilled cheese
#   886. creamy turkey soup with homemade noodles
#   887. slow cooker honey garlic chicken
#   888. french onion baked potato soup
#   889. afghan kabuli pulao
#   890. croatian cabbage soup with pork
#   891. the people s pizza
#   892. chicken poppy seed salad
#   893. couscous with feta  sun dried tomatoes and kalamata olives
#   894. vietnamese style caramel chicken with broccoli
#   895. outback copycat alice springs chicken
#   896. sesame pork balls
#   897. pumpkin and shrimp risotto
#   898. shakshuka with swiss chard
#   899. stuffed chicken breast alfredo with a creamy cheese twist ragu
#   900. red stripe chicken
#   901. one pan crispy chicken legs and brussels sprouts
#   902. chicken bacon mushroom bake
#   903. jason s crab cakes
#   904. slow cooker soy braised chicken
#   905. irish scrambler and irish bangers
#   906. lentil  bean   parsley salad
#   907. lime grilled chicken and polenta with a 1  mole sauce  a1
#   908. creamed spinach from lawrys prime rib  house of prime rib
#   909. a1 marinated top round with bacon parmesan polenta  a1
#   910. vegetarian african peanut soup
#   911. slow cooked cajun pork rib stroganoff
#   912. deep dish taco pizza
#   913. spicy tuna sandwich
#   914. cucumber salad with lemon dill dressing
#   915. cilantro lime pasta salad  with or without chicken
#   916. crispy baked tofu with pineapple  avocado   corn salad  a1
#   917. amazing baked chicken breasts    you must try   easy to make
#   918. cajun glazed mushrooms
#   919. pork ribs perfection
#   920. cheeseboard supper potatoes
#   921. chicken lazone
#   922. mexican style pickled vegetables
#   923. honey dijon chicken from tiphero com
#   924. artichoke heart frittata
#   925. rigatoni pizza pie
#   926. smoked sausage dish
#   927. bacon wrapped steak
#   928. creamy vegan tomato sauce
#   929. food works parmesan roasted broccoli
#   930. nest egg pie
#   931. portobello chicken lomein
#   932. loaded breakfast potatoes
#   933. lemony chicken stir fry
#   934. tilapia and vegetable stir fry
#   935. italian sausage rice balls with marinara sauce  ragu
#   936. mediterranean tomato lentil soup with spinach   kalamata
#   937. one pan no peek chicken and rice
#   938. chipotle popcorn chicken
#   939. shrimp tortellini pasta toss
#   940. low   slow pork shoulder
#   941. spinach  brie   bacon mini quiche
#   942. lemon chicken and spaghetti squash
#   943. bean and bell pepper salad
#   944. p f chang s beef with broccoli
#   945. mrs  g s best caesar dressing
#   946. creamy chicken and kale tortellini soup
#   947. chicken parmesan  low carb  keto
#   948. herbamare substitute
#   949. cast iron steaks with herb butter
#   950. p f chang s pepper steak
#   951. my friend  tony s best pesto
#   952. brazilian shrimp stew
#   953. booyah the soup
#   954. cl sichuan shrimp stir fry with broccoli or asparagus
#   955. firecracker shrimp tacos
#   956. fettuccine with veal  olives   tomatoes
#   957. slow cooker crock pot thai chicken curry
#   958. hungry girl choptastic chicken fiesta salad
#   959. red wine chicken skillet
#   960. homeade avocado  salad dressing
#   961. linguini with mediterranean chicken  ragu
#   962. buffalo chicken meatball subs  slow cooker
#   963. cauliflower tots
#   964. beery chorizo queso fundido
#   965. gorgonzola chicken salad  fred meyer deli copycat
#   966. ensalada criolla
#   967. spicy thai basil beef
#   968. guilt free chicken with mushroom cream sauce   cspi
#   969. baked mango sriracha cauliflower wings
#   970. figged up chicken thighs  a1
#   971. peppered sliders
#   972. portuguese baked eggs with chorizo and ricotta
#   973. corn fritters with black bean salad
#   974. apple bok choy salad
#   975. spinach rice pot
#   976. cajun shrimp linguine
#   977. cheesy jalapeo popper pull apart bread
#   978. baked sausage and garbanzo bean rollups  ragu
#   979. panda express zucchini and mushroom chicken stir fry
#   980. west african s finest  mafe
#   981. buffalo cauliflower tots
#   982. open faced sandwiches with herbed cream cheese and baby cucumber
#   983. spaghetti stuffed meatballs
#   984. ragu alla veneziana  venetian duck ragu
#   985. braised brisket tacos
#   986. tuscan roast chicken with tomatoes  zucchini and olives
#   987. bbq chicken tenders
#   988. true brazilian rice
#   989. peanut noodles with pork
#   990. garlic prawn pasta
#   991. roasted shrimp and tomatoes with roasted garlic parmesan  ragu
#   992. white castle turkey stuffing
#   993. dr  weil s miso soup
#   994. pete s garlic oil  essential when cooking italian
#   995. instant pot asian pork chop
#   996. phena s asian chicken kabobs  a1
#   997. turkey  white bean  spinach stew
#   998. steamed salmon cantonese style
#   999. mediterranean style grilled rib steak
#   1000. beer bacon mac and cheese
#   1001. magic crust blender quiche
#   1002. tuscan ribolitta with garlic parmesan croutons
#   1003. davies  bourbon chili
#   1004. instant pot or slow cooker pork carnitas
#   1005. loaded skillet chicken dinner
#   1006. red wine braised short ribs with fingerlings potatoes
#   1007. open face bacon jam and egg sandwich  a1
#   1008. greek style watermelon salad
#   1009. amy truong zucchini low carb lasagna
#   1010. cheesy potato zucchini casserole
#   1011. easy greek salad
#   1012. tyler forence s extra crispy fried chicken
#   1013. crock pot chicken taco chili
#   1014. deconstructed a1 california turkey burger  a1
#   1015. pioneer woman mexican macaroni salad
#   1016. aip bbq sauce
#   1017. air fried onion rings
#   1018. bok choy in cream sauce
#   1019. outback steakhouse tangy tomato salad dressing
#   1020. minestrone soup with tortellini  pressure cooker
#   1021. spicy mini pork kabobs
#   1022. greek style flounder
#   1023. spicy turkey cutlets
#   1024. grilled zucchini and mushrooms
#   1025. peruvian breakfast sandwich
#   1026. pepperoni pizza lasagna rolls
#   1027. crockpot pinto beans and ham
#   1028. pizza lasagna
#   1029. coconut shrimp pizza
#   1030. slow cooked bacon cheese potatoes
#   1031. nassau peas and rice
#   1032. baked rice with cheese and tomatoes
#
# Community 2 (461 recipes):
#   1. cranberry almond  raincoast  crisps
#   2. taralli pugliesi
#   3. cream of wheat buscuits
#   4. warren ohio hot dog shoppe sauce
#   5. faux laminated maple brioche rolls
#   6. tuna noodle broccoli casserole
#   7. coco oatmeal honey cookies
#   8. best ever chewy chocolate chip cookies
#   9. chocolate chip cookie dough pots
#   10. lemon pom pom cake
#   11. nutella banana brunch bake
#   12. gluten free bananas foster pancakes
#   13. great american cookie double fudge cookies
#   14. classic raisin oatmeal cookies
#   15. miracle home made puff pastry
#   16. flourless hazelnut chocolate cake  gluten free
#   17. gluten free  dairy free  corn free pancakes
#   18. galaxy mirror cake
#   19. german cheesecake  mit quark
#   20. milk tart with a baked crust
#   21. chili cheese croissant corndogs
#   22. flourless peanut butter chocolate chip cookies
#   23. irish bread pudding with whiskey caramel sauce
#   24. forevermama s old time pancakes
#   25. old world yugoslavian coffee cake
#   26. funfetti mug cake
#   27. jumbo chocolate chip cookies
#   28. baked apple cider donuts
#   29. paleo pumpkin spice cookies
#   30. kitchenaid kneaded basic white bread
#   31. pumpkin spice french toast bake
#   32. creamy corn pudding
#   33. pumpkin cream cheese swirl muffins
#   34. beer cheese stuffed pretzels
#   35. ham  solo savory cake
#   36. vegan spelt buns or rolls
#   37. one banana bread muffins
#   38. betty fords buttermilk pancakes
#   39. samoa sheet cake
#   40. moist gingerbread cake
#   41. giant instant pot pancakes
#   42. pumpkin muffins   vegan and gluten free
#   43. moroccan carrots
#   44. pflaumenkuchen  german plum cake
#   45. red  white   blue breakfast buns
#   46. egg waffles 4 or gai daan jai
#   47. onion lover s twist
#   48. unicorn cake truffles
#   49. strawberry blessed snow with custard sauce
#   50. carrot apple zucchini bread
#   51. valentines day recipe
#   52. copycat chick fil a spicy deluxe chicken sandwich
#   53. cheesecake caramel toffee chocolate chip cookie bars
#   54. rosemary and toasted onion bread  bread machine dough
#   55. charred bourbon apple pork chops
#   56. peanuts butter cookies
#   57. lower carb machine bread
#   58. flaky layer biscuits
#   59. chocolate protein balls
#   60. butter meltaways with lemon frosting
#   61. john f kennedy waffles
#   62. mint chip brownies
#   63. panera bread style cobblestone muffins
#   64. onion rye loaf  bread machine
#   65. best ever pecan pie bars
#   66. stout cupcakes with irish cream frosting
#   67. royal crown strawberry pie
#   68. sweet potato pie with gooey pecan topping
#   69. fruit loop waffles
#   70. marvelous macerated cherries  a1
#   71. five minute vegan pancakes
#   72. chocolate peanut butter pinecone cakes
#   73. instant pot rice pudding
#   74. almond milk hot chocolate   martha stewart
#   75. self saucing chocolate pudding  slow cooker
#   76. maggie s banana bread
#   77. mousse de morangos with port wine sauce
#   78. overnight pumpkin pecan waffles
#   79. rapid rise skillet yeast rolls
#   80. blackberry mini muffins or mini cupcakes   you decide
#   81. ghost busted piata cake
#   82. chicago style deep dish sausage pizza   real deep dish
#   83. easy maple pecan monkey bread
#   84. the perfect ginger snap
#   85. brownie terrarium
#   86. old fashioned triple lemon cake
#   87. best ever cornbread
#   88. habanero and orange chocolate chip cookies
#   89. paleo pumpkin bread    elana s pantry
#   90. brown sugar carmel pound cake
#   91. thanksgiving piecaken
#   92. surprise rainbow pi cake
#   93. dorothy s cranberry bread
#   94. fresh cream corn off the cob
#   95. italian christmas cookies
#   96. microwave spiced nuts
#   97. flourless chocolate truffle cake
#   98. nordic  stone age  nut and seed bread
#   99. memes meal
#   100. johnny cakes   journey cakes
#   101. amazing buttermilk biscuits
#   102. chocolate chai coffee mix
#   103. ginger snaps
#   104. chocolate lace sandwich cookies
#   105. pumpkin cookie butter bundt cakes
#   106. dark chocolate cream pie
#   107. cherry buttermilk clafoutis
#   108. jamie oliver s portuguese custard tarts
#   109. amazingly easy grain free biscuits rolls
#   110. ultimate chewy chocolate chip cookies
#   111. zucchini lemon poppyseed bread
#   112. italian dark chocolate   anise cookie
#   113. giant cinnamon roll with blood orange glaze
#   114. frozen edible cookie dough  no eggs
#   115. cheery cherry cream puffs with a 1  ganache drizzle  a1
#   116. lemon rose bundt cake
#   117. best ever green bean casserole  no canned soup
#   118. cake boss sponge cake recipe
#   119. traditional style pastitsio  ragu
#   120. stranger things dodeca demon cookies
#   121. not your grandmothers fruitcake
#   122. one bowl upside down cake
#   123. caballero cookies
#   124. iron skillet blackberry cobbler
#   125. pumpkin pie moonshine
#   126. cider   5 spice bundt cake
#   127. carol s soft and chewy chocolate chippies
#   128. giant heart sunglasses cake
#   129. ligurian lemon cake
#   130. amish funeral cookies
#   131. lemon meringue pie easy deep dish
#   132. zero carb bread
#   133. moist and fluffy banana muffins
#   134. lower sugar carrot cake jam
#   135. chocolate strawberry slab pie
#   136. mac and jack and cheese
#   137. cinnamon belgian waffles
#   138. paleo breakfast muffins
#   139. creamy quinoa with blueberries  vegan
#   140. pusheen macarons
#   141. instant oatmeal packet cookies
#   142. easy cherry pie bars
#   143. jack s bread pudding
#   144. banana mug cake
#   145. country harvest bread  bread machine
#   146. apple cinnamon mug cake
#   147. paleo chocolate cupcake and frosting
#   148. blender chocolate mousse
#   149. churro ice cream cones
#   150. red  white and blueberry trifle
#   151. mashed cauliflower with cream cheese
#   152. luncheonette crumb cake
#   153. cheesy jalapeno corn casserole  slow cooker
#   154. apple slab pie
#   155. almond milk pancakes
#   156. taiwanese pineapple cakes
#   157. truffle carbonara mac and cheese
#   158. fannie farmer sugar cookies
#   159. twice baked jumbo mini cheesecakes
#   160. christmas thumb print cookies
#   161. battered chicken tenders
#   162. swans down orange coconut cake
#   163. lemon velvet cream cake
#   164. peach amaretto bread pudding
#   165. healthy brownie in a mug
#   166. frozen smores pops
#   167. apple pie egg roll
#   168. bacon wrapped coconut quiche and coconut popcorn shrimp
#   169. three cheese cupcakes
#   170. apple pie with cheddar crust
#   171. cappuccino creme brulee
#   172. the skinny girl with fat appetite apple turnovers
#   173. lava cake
#   174. gold medal classic white bread
#   175. good seed bread
#   176. high altitude chocolate cake
#   177. rainbow poke cake
#   178. apricot cranberry kugel
#   179. apricot almond cake with rosewater   cardamom
#   180. homemade thin mint cookies
#   181. super soft snickerdoodle cookies
#   182. lemon cheesecake  pressure cooker
#   183. great whole wheat  freshly milled  pancakes
#   184. milk   cookie cups
#   185. smoked salmon   avocado baked eggs
#   186. caramel macchiato vegan style
#   187. silver palate oatmeal raisin cookies
#   188. mom s best apple cake with caramel frosting
#   189. enchilada burgers
#   190. chocolate chip cookie slab pie
#   191. best paleo pancakes
#   192. pumpkin white chocolate chip blondies
#   193. double peanut butter swirled brownies
#   194. dad s bread pudding
#   195. tunnel of fudge banana cake
#   196. triple chocolate zucchini muffins
#   197. yummy corn cakes
#   198. heath salted caramel cookies
#   199. vegan graham crackers
#   200. baileys irish cream pancakes
#   201. cornbread muffins
#   202. high altitude apple cake
#   203. banana muffins
#   204. french toast forest casserole
#   205. purple sweet potato casserole
#   206. sauted kale with apples and bacon
#   207. no crust blueberry pie with crumble topping
#   208. banana coffee cake
#   209. orange french toast
#   210. pumpkin spice latte cake
#   211. soft sour cream sugar cookies
# ...
#   331. stuffed champagne cupcakes
#   332. dark   sumptuous chocolate cake
#   333. southern caramel cake
#   334. colossal chocolate chip cookies
#   335. banana pecan buttermilk pancakes
#   336. vermont whole wheat oatmeal honey bread
#   337. kaiserschmarrn with peaches
#   338. strawberry shortcake scones
#   339. pecan pie bars  paleo  gluten free
#   340. lazy man s pie peach cobbler
#   341. cream cheese coffee cake with cinnamon streusel
#   342. sweet carrot souffle
#   343. amish triple butter biscuits
#   344. blueberry cheesecake crumb cake
#   345. no butter lactation cookies
#   346. royal purple black panther cake
#   347. marshmallow fluff sponge cake
#   348. old fashion sour cream donuts
#   349. fig and pear crumble
#   350. salvadoran sweet cheese bread
#   351. brownie baklava
#   352. ultimate jiffy southern cornbread   sweet   moist
#   353. betty crocker s baking powder biscuits  light  flaky and tender
#   354. light   fluffy pancakes
#   355. peasant bread
#   356. lemon poppyseed biscotti
#   357. delicious gluten free carrot cake
#   358. pumpkin pancakes  gluten free
#   359. easy apple dump cake   from scratch
#   360. no flour brownies
#   361. 2 minute eggless microwave chocolate cake
#   362. sugared pita with fried apples
#   363. gingerbread castle
#   364. easy mini apple pies
#   365. apple sharlotka
#   366. buscuits
#   367. sunrabbit s vegan pumpkin cupcakes with vegan cream cheese icing
#   368. gooey cinnamon roll cheesecake
#   369. oreo cheesecake cookies
#   370. raspberry swirl cheesecake minis
#   371. hillybilly cornbread
#   372. banana walnut pancake  paleo compliant
#   373. the life changing loaf of bread
#   374. vegan banana chocolate cake
#   375. ma s cornbread re make
#   376. sweet potato and peach casserole with pecan topping
#   377. pumpkin pie overnight oats
#   378. apple bread abm
#   379. stuffed french toast ii
#   380. croissant bread pudding
#   381. granny s banana cream pie  no sugar added version
#   382. bake a chocolate cake
#   383. individual tiramisu cups
#   384. glazed strawberry galette
#   385. the turducken of thanksgiving sides
#   386. russian tea cakes
#   387. healthy coffee cake  vegan
#   388. camaron rebosado filipino fried shrimp
#   389. double fudge banana muffins brownies
#   390. muffin in a minute
#   391. soft hamburger buns
#   392. mimi s date squares  gluten free
#   393. sugar free mug cake
#   394. sweet potato casserole roses
#   395. dees pumpkin pie oatmeal
#   396. almond flour blueberry muffins best ever
#   397. chocolate peanut butter globs
#   398. one egg cake
#   399. cranberry apple ginger compote
#   400. high altitude banana crumb muffins
#   401. american sandwich bread   abm or oven
#   402. almond flour stevia cookies
#   403. cinnamon roll cream pie
#   404. loaded quinoa cookies
#   405. navajo style peach crisp
#   406. soft homemade flour tortillas
#   407. carrot cake with pineapple
#   408. blueberry coffee cake
#   409. pecan pie brittle
#   410. fudgy gluten free chocolate cake
#   411. 3 layer chocolate cake with chocolate mousse filling  gluten fre
#   412. blueberry and lemon ricotta cheesecake  gluten free
#   413. kidney bean brownies
#
# Community 3 (3 recipes):
#   1. a 1 black cherry brie   chocolate walnut tartlet  a1
#   2. cheery cherry cream puffs with a 1  ganache drizzle  a1
#   3. marvelous macerated cherries  a1
#
# Community 4 (1 recipes):
#   1. almond pancakes
#
# Community 5 (1 recipes):
#   1. amish peanut butter
#
# Community 6 (1 recipes):
#   1. angelo azzurro  blue angel  cocktail
#
# Community 7 (1 recipes):
#   1. applebee s chicken wonton
#
# Community 8 (1 recipes):
#   1. argentinian tropical tincho
#
# Community 9 (1 recipes):
#   1. asian marinated pork chops
#
# Community 10 (1 recipes):
#   1. avocado lime and coconut no bake cheesecake
#
# Community 11 (1 recipes):
#   1. bacon and egg breakfast stromboli
#
# Community 12 (1 recipes):
#   1. bacon lattice turkey
#
# Community 13 (1 recipes):
#   1. bacon peanut caramel corn
#
# Community 14 (1 recipes):
#   1. bacon ranch wedge salad
#
# Community 15 (2 recipes):
#   1. huevos rancheros potato waffles
#   2. bacon  egg and cheese ring
#
# Community 16 (1 recipes):
#   1. baked brie with maple apples and pecans
#
# Community 17 (1 recipes):
#   1. banana bomb
#
# Community 18 (2 recipes):
#   1. sand pudding recipe
#   2. banana pudding beach icebox cake
#
# Community 19 (1 recipes):
#   1. belt salad
#
# Community 20 (1 recipes):
#   1. birthday cake cookies
#
# Community 21 (1 recipes):
#   1. breakfast grilled cheese mexican style
#
# Community 22 (1 recipes):
#   1. buffalo chicken mason jar salad
#
# Community 23 (1 recipes):
#   1. campbell s mini green bean casseroles
#
# Community 24 (1 recipes):
#   1. caramel apple dump cake
#
# Community 25 (1 recipes):
#   1. caramelized sweet potatoes and peaches
#
# Community 26 (1 recipes):
#   1. cauliflower and tofu pizza crust  gluten free  low carb
#
# Community 27 (1 recipes):
#   1. caveman s spicy swai fish fillets
#
# Community 28 (1 recipes):
#   1. chai tea latte mix
#
# Community 29 (1 recipes):
#   1. charishma s tasty home made nutella
#
# Community 30 (1 recipes):
#   1. cheese plate kebabs
#
# Community 31 (1 recipes):
#   1. cheesy buttery puff
#
# Community 32 (1 recipes):
#   1. cheesy shell taco bites
#
# Community 33 (1 recipes):
#   1. chicken and spinach dip pizza
#
# Community 34 (1 recipes):
#   1. chicken chunk
#
# Community 35 (1 recipes):
#   1. chicken curry casserole
#
# Community 36 (1 recipes):
#   1. chilaquiles casserole
#
# Community 37 (1 recipes):
#   1. chocolate almond fat bombs
#
# Community 38 (1 recipes):
#   1. chucktown sunrise
#
# Community 39 (1 recipes):
#   1. clams in butter garlic herb
#
# Community 40 (1 recipes):
#   1. club med bahama mama
#
# Community 41 (1 recipes):
#   1. collard greens with black beans
#
# Community 42 (1 recipes):
#   1. cracker barrel tartar sauce
#
# Community 43 (1 recipes):
#   1. creamy russian salad
#
# Community 44 (1 recipes):
#   1. crock pot cube steak with gravy
#
# Community 45 (1 recipes):
#   1. crock pot honey garlic chicken
#
# Community 46 (1 recipes):
#   1. crockpot potato soup for weight watchers
#
# Community 47 (1 recipes):
#   1. cypriot pumpkin soup
#
# Community 48 (1 recipes):
#   1. danforth salad
#
# Community 49 (2 recipes):
#   1. syrian thyme mix
#   2. darcey s special dukkah
#
# Community 50 (1 recipes):
#   1. deer mash
#
# Community 51 (1 recipes):
#   1. dr  fuhrman s walnut vinaigrette dressing
#
# Community 52 (1 recipes):
#   1. duba wot
#
# Community 53 (1 recipes):
#   1. duncan hines almond pound cake
#
# Community 54 (1 recipes):
#   1. easiest apple roses
#
# Community 55 (1 recipes):
#   1. easiest creamy cilantro lime ranch salad dressing
#
# Community 56 (1 recipes):
#   1. easy chili rellenos casserole
#
# Community 57 (1 recipes):
#   1. easy nutella chocolate mousse   gluten free
#
# Community 58 (1 recipes):
#   1. emperor norton s ice cream sundae
#
# Community 59 (1 recipes):
#   1. fettuccine with roquefort sauce
#
# Community 60 (1 recipes):
#   1. fiery kickoff wings
#
# Community 61 (1 recipes):
#   1. fig and bourbon fizz
#
# Community 62 (1 recipes):
#   1. flourless banana bread pancakes
#
# Community 63 (1 recipes):
#   1. french green beans almondine
#
# Community 64 (1 recipes):
#   1. fresh peach sweet iced tea
#
# Community 65 (1 recipes):
#   1. frita cheesesteak
#
# Community 66 (1 recipes):
#   1. frozen souffle amaretto  windows on the world
#
# Community 67 (1 recipes):
#   1. fruit loop treats
#
# Community 68 (1 recipes):
#   1. fruity pebbles parfait
#
# Community 69 (1 recipes):
#   1. georgia peach chicken salad
#
# Community 70 (1 recipes):
#   1. gin rocket from the one bottle cocktail
#
# Community 71 (1 recipes):
#   1. glazed wings
#
# Community 72 (1 recipes):
#   1. goats and grapes white pizza  ragu
#
# Community 73 (1 recipes):
#   1. green bean  chicken   stuffing casserole
#
# Community 74 (1 recipes):
#   1. green chocolate smoothie
#
# Community 75 (1 recipes):
#   1. green tea coconut milk ice cream  low gi
#
# Community 76 (1 recipes):
#   1. harissa cauliflower steaks
#
# Community 77 (1 recipes):
#   1. hawaiian cheesecake fruit salad
#
# Community 78 (1 recipes):
#   1. hawaiian pizza pineapples
#
# Community 79 (1 recipes):
#   1. hawaiian style smoked pork   kalua pork cook s country
#
# Community 80 (1 recipes):
#   1. hidden veggie mac and cheese
#
# Community 81 (1 recipes):
#   1. homemade strawberry ice cream recipe
#
# Community 82 (1 recipes):
#   1. hot chocolate concentrate from america s test kitchen
#
# Community 83 (1 recipes):
#   1. hot white chocolate with cardamom
#
# Community 84 (2 recipes):
#   1. island holiday
#   2. police   thieves from the one bottle cocktail
#
# Community 85 (1 recipes):
#   1. jamba juice at home white gummi bear smoothie
#
# Community 86 (1 recipes):
#   1. japanese grilled corn on the cob  yaki tomorokoshi
#
# Community 87 (1 recipes):
#   1. japanese yuzu and ginger cocktail
#
# Community 88 (1 recipes):
#   1. joe holland s hamburgers
#
# Community 89 (1 recipes):
#   1. jordanian herbal tea
#
# Community 90 (1 recipes):
#   1. keto chocolate peanut butter fudge
#
# Community 91 (2 recipes):
#   1. pioneer woman s hot roast beef sandwiches
#   2. kings hawaiian  ham   swiss slider
#
# Community 92 (1 recipes):
#   1. korean style kiolbassa sausage
#
# Community 93 (3 recipes):
#   1. red eye mojito
#   2. strawberry basil mojito
#   3. lemongrass  lime   thai basil mojito
#
# Community 94 (1 recipes):
#   1. lentil pancakes with berries
#
# Community 95 (1 recipes):
#   1. lightened up peanut butter pie
#
# Community 96 (1 recipes):
#   1. loaded cauliflower  as seen on facebook
#
# Community 97 (1 recipes):
#   1. louise s christmas bonbons
#
# Community 98 (1 recipes):
#   1. low carb amish ham casserole
#
# Community 99 (1 recipes):
#   1. low carb raw coconut brownie balls
#
# Community 100 (1 recipes):
#   1. low carb syrup
#
# Community 101 (1 recipes):
#   1. luxury fluffy scrambled eggs
#
# Community 102 (1 recipes):
#   1. mango mint lassi with indian sweet spices
#
# Community 103 (1 recipes):
#   1. mangonada
#
# Community 104 (1 recipes):
#   1. maple pumpkin chocolate chip energy bars
#
# Community 105 (1 recipes):
#   1. marshmallow rice crispy treats ree drummond   pioneer woman
#
# Community 106 (1 recipes):
#   1. masala martini
#
# Community 107 (1 recipes):
#   1. matcha berry swirl smoothie
#
# Community 108 (1 recipes):
#   1. mickey s okinawa taco rice and cheese trc
#
# Community 109 (1 recipes):
#   1. mini hawaiian meatball subs with pineapple coleslaw
#
# Community 110 (1 recipes):
#   1. mint julep margarita
#
# Community 111 (1 recipes):
#   1. miso broiled scallops
#
# Community 112 (1 recipes):
#   1. mississippi baked ham
#
# Community 113 (1 recipes):
#   1. mizerja   polish cucumber salad
#
# Community 114 (1 recipes):
#   1. mocha chocolate mousse
#
# Community 115 (1 recipes):
#   1. mom s egg salad
#
# Community 116 (1 recipes):
#   1. natalia s marinated steak tips
#
# Community 117 (1 recipes):
#   1. neapolitan smoothie
#
# Community 118 (1 recipes):
#   1. no bake chocolate fudge cake
#
# Community 119 (1 recipes):
#   1. no fail bbq baby back ribs  grill
#
# Community 120 (1 recipes):
#   1. no guilt  second helping  slaw
#
# Community 121 (1 recipes):
#   1. no bake key lime cheesecake
#
# Community 122 (1 recipes):
#   1. noah s sausage and pepperoni flatbread pizza
#
# Community 123 (1 recipes):
#   1. nuevos huevos rancheritos
#
# Community 124 (1 recipes):
#   1. nutella ice cream
#
# Community 125 (1 recipes):
#   1. nutella stuffed red velvet cookies
#
# Community 126 (1 recipes):
#   1. oriental style carrot risotto with raisins
#
# Community 127 (1 recipes):
#   1. overnight oatmeal in a jar
#
# Community 128 (1 recipes):
#   1. p f chang s crab wontons
#
# Community 129 (1 recipes):
#   1. pacman punch
#
# Community 130 (1 recipes):
#   1. pan fried brussels sprouts with sriracha  honey and lime
#
# Community 131 (1 recipes):
#   1. pastrami fajitas
#
# Community 132 (1 recipes):
#   1. peach dumplings
#
# Community 133 (1 recipes):
#   1. peach pie moonshine a la mode
#
# Community 134 (1 recipes):
#   1. peanut butter overnight oats
#
# Community 135 (1 recipes):
#   1. perfect fall cheese ball
#
# Community 136 (1 recipes):
#   1. pesto stuffed christmas tree
#
# Community 137 (1 recipes):
#   1. pimiento cheese sandwiches
#
# Community 138 (1 recipes):
#   1. pineapple cannoli cones
#
# Community 139 (1 recipes):
#   1. pink grapefruit fros
#
# Community 140 (1 recipes):
#   1. pizza barbecue monkey bread
#
# Community 141 (1 recipes):
#   1. polenta crusted bacon goat cheese arrotondares con  ragu
#
# Community 142 (1 recipes):
#   1. pomelo spritz
#
# Community 143 (1 recipes):
#   1. pool party ice cream cake
#
# Community 144 (1 recipes):
#   1. pumpkin hand pies
#
# Community 145 (1 recipes):
#   1. pumpkin spice granola
#
# Community 146 (1 recipes):
#   1. quick and easy hot dogs with mashed potatos
#
# Community 147 (1 recipes):
#   1. quick huevos rancheros
#
# Community 148 (1 recipes):
#   1. quick kahlua tiramisu
#
# Community 149 (1 recipes):
#   1. quinoa apple and blueberry salad
#
# Community 150 (1 recipes):
#   1. raspberry and cream frozen yogurt pie
#
# Community 151 (1 recipes):
#   1. recipes by soma sengupta  eton mess
#
# Community 152 (1 recipes):
#   1. reuben bake casserole
#
# Community 153 (1 recipes):
#   1. roasted berry sauce
#
# Community 154 (1 recipes):
#   1. root beer bbq pulled pork
#
# Community 155 (1 recipes):
#   1. rosie o grady s minty lemon iced tea
#
# Community 156 (1 recipes):
#   1. salted caramel holiday treats
#
# Community 157 (1 recipes):
#   1. salty maple buttered cider   a warm fall   winter cocktail
#
# Community 158 (1 recipes):
#   1. sauced crab ball
#
# Community 159 (1 recipes):
#   1. seafood dressing
#
# Community 160 (1 recipes):
#   1. seal the deal pasta from downtime
#
# Community 161 (1 recipes):
#   1. short smoked salmon
#
# Community 162 (1 recipes):
#   1. shrimp with mango and plantians
#
# Community 163 (1 recipes):
#   1. simple ice cream   thermomix
#
# Community 164 (1 recipes):
#   1. simply dirty rice
#
# Community 165 (1 recipes):
#   1. slippery when wet from the one bottle cocktail
#
# Community 166 (1 recipes):
#   1. slow cooker overnight steel cut oats with apples
#
# Community 167 (1 recipes):
#   1. smokey juicy burger patties
#
# Community 168 (1 recipes):
#   1. spicy italian hero crescent ring
#
# Community 169 (1 recipes):
#   1. stacie s ultimate caesar
#
# Community 170 (1 recipes):
#   1. storm s peanut butter and pumpkin dog treats
#
# Community 171 (1 recipes):
#   1. strawberry daiquiri jam
#
# Community 172 (1 recipes):
#   1. strawberry lemonade brownies
#
# Community 173 (1 recipes):
#   1. strawberry margarita spritzers
#
# Community 174 (1 recipes):
#   1. strawberry oatmeal smoothie
#
# Community 175 (1 recipes):
#   1. strawberry shortcake ice cream cake
#
# Community 176 (1 recipes):
#   1. sundried tomato and sweet basil shakshuka  ragu
#
# Community 177 (1 recipes):
#   1. super cheap yogurt pasta
#
# Community 178 (1 recipes):
#   1. sushi bake
#
# Community 179 (1 recipes):
#   1. sweet   sour meatball kabobs with pineapple
#
# Community 180 (1 recipes):
#   1. sweet and savory quinoa salad
#
# Community 181 (1 recipes):
#   1. sweet potato soup with matchstick fries and frizzled leeks
#
# Community 182 (1 recipes):
#   1. sweet potato toast
#
# Community 183 (1 recipes):
#   1. thai almond butter shrimp
#
# Community 184 (1 recipes):
#   1. the healthy elvis shake
#
# Community 185 (1 recipes):
#   1. thyme garlic roasted asparagus
#
# Community 186 (1 recipes):
#   1. totally white white trash casserole
#
# Community 187 (1 recipes):
#   1. tuna tarragon pita
#
# Community 188 (1 recipes):
#   1. tuna tartar
#
# Community 189 (1 recipes):
#   1. veal ribs with fontina cheese
#
# Community 190 (1 recipes):
#   1. venezuelan pepito sandwich   pepito venezolano
#
# Community 191 (1 recipes):
#   1. venezuelan spiced hot chocolate
#
# Community 192 (1 recipes):
#   1. vinegar air and salty crispy potatoes   british larder
#
# Community 193 (1 recipes):
#   1. wasabi ae  broccoli with wasabi sauce
#
# Community 194 (1 recipes):
#   1. watermelon sangria with sriracha
#
# Community 195 (1 recipes):
#   1. whiskey pretzels
#
# Community 196 (1 recipes):
#   1. white chocolate peppermint candies
#
# Community 197 (1 recipes):
#   1. white chocolate rose pudding
#
# Community 198 (1 recipes):
#   1. white russian sorbet
#
# Community 199 (1 recipes):
#   1. wings peanut butter and jelly wings
#
# Community 200 (1 recipes):
#   1. ww brussels sprouts with dried canberries and lemon   3 pts
#
# Community 201 (1 recipes):
#   1. ww soba chicken noodle bowl
#
# Community 202 (1 recipes):
#   1. yogurt fruit bark
#
# Community 203 (1 recipes):
#   1. yuzu cocktail
#
# Total number of communities: 203
# Modularity: 0.3546

# %% [markdown]
# ## Which ingredients act as ”bridges” between different cuisines?

# %%
def analyze_communities(G, communities):
    analysis_results = []

    for i, community in enumerate(communities):
        recipe_names = [G.nodes[node]['name'] for node in community]

        all_ingredients = []
        for node in community:
            all_ingredients.extend(G.nodes[node].get('ingredients', []))

        ingredient_counts = Counter(all_ingredients)
        most_common_ingredients = ingredient_counts.most_common(10) 

        avg_num_ingredients = np.mean([G.nodes[node]['num_ingredients'] for node in community])

        analysis_results.append({
            "community": i + 1,
            "num_recipes": len(community),
            "most_common_ingredients": most_common_ingredients,
            "avg_num_ingredients": avg_num_ingredients,
            "recipe_names": recipe_names
        })

    return analysis_results


def print_community_analysis(results):
    for result in results:
        print("=" * 50)
        print(f"Community {result['community']}")
        print(f"Number of Recipes: {result['num_recipes']}")
        print(f"Average Number of Ingredients: {result['avg_num_ingredients']:.2f}")
        print("\nMost Common Ingredients:")
        for ingredient, count in result['most_common_ingredients']:
            print(f"  - {ingredient} ({count} times)")

        print("\nFirst 20 Recipes:")
        for idx, name in enumerate(result['recipe_names'][:20], start=1):
            print(f"  {idx}. {name}")
        print("=" * 50)

# %%
def find_bridge_ingredients(G, communities):
    node_to_community = {}
    for i, community in enumerate(communities):
        for node in community:
            node_to_community[node] = i

    bridge_ingredients = []
    for u, v in G.edges():
        if node_to_community[u] != node_to_community[v]:
            ingredients_u = set(G.nodes[u].get('ingredients', []))
            ingredients_v = set(G.nodes[v].get('ingredients', []))
            common_ingredients = ingredients_u.intersection(ingredients_v)
            bridge_ingredients.extend(common_ingredients)

    ingredient_counts = Counter(bridge_ingredients)

    return ingredient_counts

# %%
def find_bridge_ingredients_with_details(G, communities):
    node_to_community = {}
    for i, community in enumerate(communities):
        for node in community:
            node_to_community[node] = i + 1  

    bridge_ingredient_details = defaultdict(list)

    for u, v in G.edges():
        community_u = node_to_community[u]
        community_v = node_to_community[v]
        if community_u != community_v:
            ingredients_u = set(G.nodes[u].get('ingredients', []))
            ingredients_v = set(G.nodes[v].get('ingredients', []))
            common_ingredients = ingredients_u.intersection(ingredients_v)
            for ingredient in common_ingredients:
                bridge_ingredient_details[ingredient].append({
                    "recipe_u": G.nodes[u]['name'],
                    "community_u": community_u,
                    "recipe_v": G.nodes[v]['name'],
                    "community_v": community_v
                })

    return bridge_ingredient_details

# %%
greedy_communities = list(greedy_modularity_communities(recipes_graph))
community_analysis_results = analyze_communities(recipes_graph, greedy_communities)
print_community_analysis(community_analysis_results)
# Out:
# ==================================================
# Community 1
# Number of Recipes: 1032
# Average Number of Ingredients: 12.05
#
# Most Common Ingredients:
#   - pepper (853 times)
#   - salt (793 times)
#   - garlic (749 times)
#   - onion (712 times)
#   - olive oil (404 times)
#   - chicken (295 times)
#   - butter (213 times)
#   - oil (213 times)
#   - tomatoes (191 times)
#   - sugar (183 times)
#
# First 20 Recipes:
#   1. chicken and vegetable borscht
#   2. sweet and spicy short ribs
#   3. rainbow rose veggie tart
#   4. sunrabbit s vegan creamy corn chowder
#   5. rice con queso
#   6. lithuanian potato pudding
#   7. barberton hot sauce
#   8. vietnamese caramelized pork  thit ko    instant pot version
#   9. mexican street corn casserole
#   10. roasted pork tenderloin with cajun cornbread stuffing
#   11. slow cooker honey pork roast
#   12. open pit bbq sauce
#   13. alan s vegetarian vegan bean and rice burger mashup
#   14. world s best pasta sauce
#   15. slow cooker whole cauliflower
#   16. border quiche   low carb
#   17. lump crabmeat and avocado crostini
#   18. babette s colossal crockpot chili  ragu
#   19. turkish spice mix
#   20. copycat hamburger helper rice oriental
# ==================================================
# ==================================================
# Community 2
# Number of Recipes: 461
# Average Number of Ingredients: 10.78
#
# Most Common Ingredients:
#   - sugar (523 times)
#   - salt (362 times)
#   - flour (346 times)
#   - butter (288 times)
#   - eggs (197 times)
#   - egg (160 times)
#   - baking (150 times)
#   - Milk (136 times)
#   - cinnamon (131 times)
#   - extract (128 times)
#
# First 20 Recipes:
#   1. cranberry almond  raincoast  crisps
#   2. taralli pugliesi
#   3. cream of wheat buscuits
#   4. warren ohio hot dog shoppe sauce
#   5. faux laminated maple brioche rolls
#   6. tuna noodle broccoli casserole
#   7. coco oatmeal honey cookies
#   8. best ever chewy chocolate chip cookies
#   9. chocolate chip cookie dough pots
#   10. lemon pom pom cake
#   11. nutella banana brunch bake
#   12. gluten free bananas foster pancakes
#   13. great american cookie double fudge cookies
#   14. classic raisin oatmeal cookies
#   15. miracle home made puff pastry
#   16. flourless hazelnut chocolate cake  gluten free
#   17. gluten free  dairy free  corn free pancakes
#   18. galaxy mirror cake
#   19. german cheesecake  mit quark
#   20. milk tart with a baked crust
# ==================================================
# ==================================================
# Community 3
# Number of Recipes: 24
# Average Number of Ingredients: 9.71
#
# Most Common Ingredients:
#   - butter (17 times)
#   - salt (16 times)
#   - pepper (13 times)
#   - flour (10 times)
#   - Milk (9 times)
#   - parmesan (9 times)
#   - cheddar (8 times)
#   - pasta (8 times)
#   - cheese (7 times)
#   - egg (6 times)
#
# First 20 Recipes:
#   1. gwen s old fashioned potato beef casserole  trisha yearwood
#   2. seaside stuffed shells alfredo  ragu
#   3. pastitsio  slow cooker
#   4. everything bagel tortellini
#   5. alton brown s stove top mac n cheese
#   6. spaghetti squash spaghetti  ragu
#   7. julia belle s world famous macaroni and cheese
#   8. buttered noodles with toasted sage
#   9. polenta pasticciata  ragu
#   10. welsh dragon pie
#   11. cory s famous mac and cheese
#   12. olive garden asiago garlic alfredo sauce
#   13. sweet potato   black bean burgers
#   14. basic bechamel  white sauce
#   15. snapper in a poblano chile sauce
#   16. pepperoni and mozzarella stuffed chicken breasts
#   17. skillet mac n cheese
#   18. mini chicken breast sliders
#   19. spaghetti squash boats  ragu
#   20. chicken green chile relleno bake
# ==================================================
# ==================================================
# Community 4
# Number of Recipes: 3
# Average Number of Ingredients: 11.00
#
# Most Common Ingredients:
#   - pepper (4 times)
#   - coriander (3 times)
#   - cinnamon (3 times)
#   - cloves (3 times)
#   - Ginger (2 times)
#   - cardamom (2 times)
#   - turmeric (2 times)
#   - allspice (2 times)
#   - chili (1 times)
#   - Paprika (1 times)
#
# First 20 Recipes:
#   1. berbere spice mix
#   2. eve s addiction   a warm fall and winter cocktail
#   3. japanese curry powder
# ==================================================
# ==================================================
# Community 5
# Number of Recipes: 3
# Average Number of Ingredients: 6.67
#
# Most Common Ingredients:
#   - lime (3 times)
#   - rum (3 times)
#   - soda (3 times)
#   - ice (3 times)
#   - sugar (2 times)
#   - basil (2 times)
#   - cherry (1 times)
#   - mint (1 times)
#   - strawberry (1 times)
#   - lemongrass (1 times)
#
# First 20 Recipes:
#   1. red eye mojito
#   2. strawberry basil mojito
#   3. lemongrass  lime   thai basil mojito
# ==================================================
# ==================================================
# Community 6
# Number of Recipes: 2
# Average Number of Ingredients: 11.00
#
# Most Common Ingredients:
#   - seed (3 times)
#   - pistachio (2 times)
#   - cumin (2 times)
#   - salt (2 times)
#   - fennel (2 times)
#   - thyme (1 times)
#   - sumac (1 times)
#   - chickpea (1 times)
#   - flax (1 times)
#   - coriander (1 times)
#
# First 20 Recipes:
#   1. syrian thyme mix
#   2. darcey s special dukkah
# ==================================================
# ==================================================
# Community 7
# Number of Recipes: 2
# Average Number of Ingredients: 9.00
#
# Most Common Ingredients:
#   - taco (2 times)
#   - rice (2 times)
#   - bean (2 times)
#   - corn (2 times)
#   - Salsa (2 times)
#   - cheddar (2 times)
#   - peppers (1 times)
#   - turkey (1 times)
#   - onion (1 times)
#   - chicken (1 times)
#
# First 20 Recipes:
#   1. salsa stuffed peppers
#   2. easy tex mex burritos
# ==================================================
# ==================================================
# Community 8
# Number of Recipes: 2
# Average Number of Ingredients: 6.50
#
# Most Common Ingredients:
#   - chili (2 times)
#   - cheese (2 times)
#   - eggs (2 times)
#   - salt (2 times)
#   - cheddar (2 times)
#   - cream (1 times)
#   - sour cream (1 times)
#   - corn (1 times)
#
# First 20 Recipes:
#   1. low carb chile relleno casserole
#   2. georgian baked corn casserole
# ==================================================
# ==================================================
# Community 9
# Number of Recipes: 2
# Average Number of Ingredients: 8.50
#
# Most Common Ingredients:
#   - pepper (3 times)
#   - eggs (2 times)
#   - cheese (2 times)
#   - salt (2 times)
#   - cilantro (2 times)
#   - hash (1 times)
#   - salsa (1 times)
#   - Queso (1 times)
#   - bacon (1 times)
#   - crescent (1 times)
#
# First 20 Recipes:
#   1. huevos rancheros potato waffles
#   2. bacon  egg and cheese ring
# ==================================================
# ==================================================
# Community 10
# Number of Recipes: 2
# Average Number of Ingredients: 9.00
#
# Most Common Ingredients:
#   - mayonnaise (3 times)
#   - onion (2 times)
#   - seed (2 times)
#   - mustard (2 times)
#   - Worcestershire (2 times)
#   - buns (1 times)
#   - beef (1 times)
#   - Provolone (1 times)
#   - ham (1 times)
#   - cheese (1 times)
#
# First 20 Recipes:
#   1. pioneer woman s hot roast beef sandwiches
#   2. kings hawaiian  ham   swiss slider
# ==================================================
# ==================================================
# Community 11
# Number of Recipes: 2
# Average Number of Ingredients: 10.50
#
# Most Common Ingredients:
#   - cinnamon (4 times)
#   - water (3 times)
#   - pineapple (3 times)
#   - lime (3 times)
#   - sugar (2 times)
#   - Lime (1 times)
#   - puree (1 times)
#   - rum (1 times)
#   - bitters (1 times)
#   - gin (1 times)
#
# First 20 Recipes:
#   1. island holiday
#   2. police   thieves from the one bottle cocktail
# ==================================================
# ==================================================
# Community 12
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - almond (1 times)
#   - milk (1 times)
#   - baking (1 times)
#   - salt (1 times)
#   - flax (1 times)
#   - cinnamon (1 times)
#
# First 20 Recipes:
#   1. almond pancakes
# ==================================================
# ==================================================
# Community 13
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - sugar (1 times)
#   - water (1 times)
#   - corn (1 times)
#   - syrup (1 times)
#   - peanut (1 times)
#   - marshmallow (1 times)
#
# First 20 Recipes:
#   1. amish peanut butter
# ==================================================
# ==================================================
# Community 14
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - Cointreau (1 times)
#   - limoncello (1 times)
#   - gin (1 times)
#   - Vermouth (1 times)
#   - fruit (1 times)
#   - ice (1 times)
#
# First 20 Recipes:
#   1. angelo azzurro  blue angel  cocktail
# ==================================================
# ==================================================
# Community 15
# Number of Recipes: 1
# Average Number of Ingredients: 12.00
#
# Most Common Ingredients:
#   - onion (2 times)
#   - chicken breast (1 times)
#   - olive oil (1 times)
#   - stir-fry (1 times)
#   - sesame (1 times)
#   - soy (1 times)
#   - teriyaki (1 times)
#   - slaw (1 times)
#   - wrapper (1 times)
#   - oil (1 times)
#
# First 20 Recipes:
#   1. applebee s chicken wonton
# ==================================================
# ==================================================
# Community 16
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - mint (1 times)
#   - lime (1 times)
#   - ice (1 times)
#   - Vodka (1 times)
#   - wine (1 times)
#   - soda (1 times)
#
# First 20 Recipes:
#   1. argentinian tropical tincho
# ==================================================
# ==================================================
# Community 17
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - soy (1 times)
#   - lemon (1 times)
#   - Ginger (1 times)
#   - garlic (1 times)
#   - pork (1 times)
#   - butter (1 times)
#
# First 20 Recipes:
#   1. asian marinated pork chops
# ==================================================
# ==================================================
# Community 18
# Number of Recipes: 1
# Average Number of Ingredients: 9.00
#
# Most Common Ingredients:
#   - lime (2 times)
#   - raspberry (1 times)
#   - avocado (1 times)
#   - cream cheese (1 times)
#   - sugar (1 times)
#   - butter (1 times)
#   - graham cracker (1 times)
#   - coconut (1 times)
#
# First 20 Recipes:
#   1. avocado lime and coconut no bake cheesecake
# ==================================================
# ==================================================
# Community 19
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - bacon (1 times)
#   - pastry (1 times)
#   - eggs (1 times)
#   - cheddar (1 times)
#   - egg (1 times)
#   - water (1 times)
#   - salt (1 times)
#
# First 20 Recipes:
#   1. bacon and egg breakfast stromboli
# ==================================================
# ==================================================
# Community 20
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - butter (1 times)
#   - bacon (1 times)
#   - thyme (1 times)
#   - sage (1 times)
#   - turkey (1 times)
#   - onion (1 times)
#
# First 20 Recipes:
#   1. bacon lattice turkey
# ==================================================
# ==================================================
# Community 21
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - bacon (2 times)
#   - popcorn (1 times)
#   - Peanuts (1 times)
#   - sugar (1 times)
#   - corn (1 times)
#   - water (1 times)
#
# First 20 Recipes:
#   1. bacon peanut caramel corn
# ==================================================
# ==================================================
# Community 22
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - lettuce (1 times)
#   - onion (1 times)
#   - cucumber (1 times)
#   - bacon (1 times)
#   - Provolone (1 times)
#   - ranch (1 times)
#
# First 20 Recipes:
#   1. bacon ranch wedge salad
# ==================================================
# ==================================================
# Community 23
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - pecan (1 times)
#   - apple (1 times)
#   - butter (1 times)
#   - sugar (1 times)
#   - brie (1 times)
#   - maple syrup (1 times)
#
# First 20 Recipes:
#   1. baked brie with maple apples and pecans
# ==================================================
# ==================================================
# Community 24
# Number of Recipes: 1
# Average Number of Ingredients: 9.00
#
# Most Common Ingredients:
#   - banana (1 times)
#   - raisin (1 times)
#   - currant (1 times)
#   - coconut (1 times)
#   - dates (1 times)
#   - peanut (1 times)
#   - walnut (1 times)
#   - carob (1 times)
#   - Stevia (1 times)
#
# First 20 Recipes:
#   1. banana bomb
# ==================================================
# ==================================================
# Community 25
# Number of Recipes: 1
# Average Number of Ingredients: 9.00
#
# Most Common Ingredients:
#   - eggs (1 times)
#   - bacon (1 times)
#   - lettuce (1 times)
#   - tomatoes (1 times)
#   - crouton (1 times)
#   - sour cream (1 times)
#   - buttermilk (1 times)
#   - mustard (1 times)
#   - onion (1 times)
#
# First 20 Recipes:
#   1. belt salad
# ==================================================
# ==================================================
# Community 26
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - chocolate (2 times)
#   - cake (1 times)
#   - baking (1 times)
#   - eggs (1 times)
#   - oil (1 times)
#   - sprinkles (1 times)
#
# First 20 Recipes:
#   1. birthday cake cookies
# ==================================================
# ==================================================
# Community 27
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - cheese (1 times)
#   - eggs (1 times)
#   - bacon (1 times)
#   - onion (1 times)
#   - bread (1 times)
#   - butter (1 times)
#
# First 20 Recipes:
#   1. breakfast grilled cheese mexican style
# ==================================================
# ==================================================
# Community 28
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - ranch (1 times)
#   - hot sauce (1 times)
#   - tomatoes (1 times)
#   - carrot (1 times)
#   - chicken (1 times)
#   - Romaine (1 times)
#   - celery (1 times)
#
# First 20 Recipes:
#   1. buffalo chicken mason jar salad
# ==================================================
# ==================================================
# Community 29
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - beans (1 times)
#   - cream of mushroom (1 times)
#   - Milk (1 times)
#   - cheddar (1 times)
#   - onion (1 times)
#   - biscuit (1 times)
#
# First 20 Recipes:
#   1. campbell s mini green bean casseroles
# ==================================================
# ==================================================
# Community 30
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - apple (1 times)
#   - cake (1 times)
#   - butter (1 times)
#   - caramel (1 times)
#   - cinnamon (1 times)
#   - pecan (1 times)
#
# First 20 Recipes:
#   1. caramel apple dump cake
# ==================================================
# ==================================================
# Community 31
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - coconut oil (1 times)
#   - maple syrup (1 times)
#   - cinnamon (1 times)
#   - salt (1 times)
#   - potato (1 times)
#   - peaches (1 times)
#   - onion (1 times)
#
# First 20 Recipes:
#   1. caramelized sweet potatoes and peaches
# ==================================================
# ==================================================
# Community 32
# Number of Recipes: 1
# Average Number of Ingredients: 8.00
#
# Most Common Ingredients:
#   - pizza (2 times)
#   - tofu (1 times)
#   - cauliflower (1 times)
#   - egg (1 times)
#   - herb (1 times)
#   - salt (1 times)
#   - mozzarella (1 times)
#
# First 20 Recipes:
#   1. cauliflower and tofu pizza crust  gluten free  low carb
# ==================================================
# ==================================================
# Community 33
# Number of Recipes: 1
# Average Number of Ingredients: 9.00
#
# Most Common Ingredients:
#   - pepper (2 times)
#   - spray (1 times)
#   - fillets (1 times)
#   - margarine (1 times)
#   - lemon (1 times)
#   - clove (1 times)
#   - salt (1 times)
#   - ginger (1 times)
#
# First 20 Recipes:
#   1. caveman s spicy swai fish fillets
# ==================================================
# ==================================================
# Community 34
# Number of Recipes: 1
# Average Number of Ingredients: 8.00
#
# Most Common Ingredients:
#   - milk (1 times)
#   - sugar (1 times)
#   - tea (1 times)
#   - creamer (1 times)
#   - ginger (1 times)
#   - cinnamon (1 times)
#   - cardamom (1 times)
#   - clove (1 times)
#
# First 20 Recipes:
#   1. chai tea latte mix
# ==================================================
# ==================================================
# Community 35
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - hazelnut (1 times)
#   - cacao (1 times)
#   - coconut oil (1 times)
#   - Honey (1 times)
#   - salt (1 times)
#   - water (1 times)
#
# First 20 Recipes:
#   1. charishma s tasty home made nutella
# ==================================================
# ==================================================
# Community 36
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - cheese (1 times)
#   - olive (1 times)
#   - salami (1 times)
#   - prosciutto (1 times)
#   - apricot (1 times)
#   - Baguette (1 times)
#   - skewer (1 times)
#
# First 20 Recipes:
#   1. cheese plate kebabs
# ==================================================
# ==================================================
# Community 37
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - crackers (1 times)
#   - Milk (1 times)
#   - Velveeta (1 times)
#   - cream cheese (1 times)
#   - eggs (1 times)
#   - chives (1 times)
#
# First 20 Recipes:
#   1. cheesy buttery puff
# ==================================================
# ==================================================
# Community 38
# Number of Recipes: 1
# Average Number of Ingredients: 8.00
#
# Most Common Ingredients:
#   - cheddar (2 times)
#   - hamburger (1 times)
#   - taco (1 times)
#   - Salsa (1 times)
#   - sour cream (1 times)
#   - avocado (1 times)
#   - cilantro (1 times)
#
# First 20 Recipes:
#   1. cheesy shell taco bites
# ==================================================
# ==================================================
# Community 39
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - crust (1 times)
#   - cornmeal (1 times)
#   - spinach (1 times)
#   - chicken (1 times)
#   - tomatoes (1 times)
#   - mushroom (1 times)
#   - cheese (1 times)
#
# First 20 Recipes:
#   1. chicken and spinach dip pizza
# ==================================================
# ==================================================
# Community 40
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - chicken (1 times)
#   - tomato soup (1 times)
#   - parsley (1 times)
#   - mushroom (1 times)
#   - tomato (1 times)
#   - mozzarella (1 times)
#   - wine (1 times)
#
# First 20 Recipes:
#   1. chicken chunk
# ==================================================
# ==================================================
# Community 41
# Number of Recipes: 1
# Average Number of Ingredients: 10.00
#
# Most Common Ingredients:
#   - chicken (1 times)
#   - soup (1 times)
#   - cream (1 times)
#   - mayonnaise (1 times)
#   - curry (1 times)
#   - lemon (1 times)
#   - broccoli (1 times)
#   - cheddar (1 times)
#   - rice (1 times)
#   - bread (1 times)
#
# First 20 Recipes:
#   1. chicken curry casserole
# ==================================================
# ==================================================
# Community 42
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - tortilla chip (1 times)
#   - eggs (1 times)
#   - chili (1 times)
#   - cheese (1 times)
#   - enchilada (1 times)
#   - corn (1 times)
#   - onion (1 times)
#
# First 20 Recipes:
#   1. chilaquiles casserole
# ==================================================
# ==================================================
# Community 43
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - almond butter (1 times)
#   - coconut oil (1 times)
#   - cocoa (1 times)
#   - cream (1 times)
#   - Truvia (1 times)
#   - vanilla (1 times)
#   - salt (1 times)
#
# First 20 Recipes:
#   1. chocolate almond fat bombs
# ==================================================
# ==================================================
# Community 44
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - lime (2 times)
#   - bourbon (1 times)
#   - ginger (1 times)
#   - grenadine (1 times)
#   - ice (1 times)
#
# First 20 Recipes:
#   1. chucktown sunrise
# ==================================================
# ==================================================
# Community 45
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - pepper (1 times)
#   - lemon (1 times)
#   - garlic (1 times)
#   - butter (1 times)
#   - clam (1 times)
#   - oregano (1 times)
#
# First 20 Recipes:
#   1. clams in butter garlic herb
# ==================================================
# ==================================================
# Community 46
# Number of Recipes: 1
# Average Number of Ingredients: 10.00
#
# Most Common Ingredients:
#   - rum (4 times)
#   - pineapple (1 times)
#   - juice (1 times)
#   - grenadine (1 times)
#   - bitters (1 times)
#   - cherry (1 times)
#   - orange (1 times)
#
# First 20 Recipes:
#   1. club med bahama mama
# ==================================================
# ==================================================
# Community 47
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - greens (1 times)
#   - onion (1 times)
#   - mushroom (1 times)
#   - bean (1 times)
#   - pasta (1 times)
#   - oil (1 times)
#
# First 20 Recipes:
#   1. collard greens with black beans
# ==================================================
# ==================================================
# Community 48
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - mayonnaise (1 times)
#   - dill (1 times)
#   - Parsley (1 times)
#   - lemon (1 times)
#   - onion (1 times)
#   - Worcestershire (1 times)
#
# First 20 Recipes:
#   1. cracker barrel tartar sauce
# ==================================================
# ==================================================
# Community 49
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - cucumber (1 times)
#   - radish (1 times)
#   - onion (1 times)
#   - sour cream (1 times)
#   - dill (1 times)
#   - pepper (1 times)
#
# First 20 Recipes:
#   1. creamy russian salad
# ==================================================
# ==================================================
# Community 50
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - au jus (1 times)
#   - cream (1 times)
#   - soup (1 times)
#   - water (1 times)
#   - gravy (1 times)
#   - steak (1 times)
#
# First 20 Recipes:
#   1. crock pot cube steak with gravy
# ==================================================
# ==================================================
# Community 51
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - chicken (1 times)
#   - garlic (1 times)
#   - basil (1 times)
#   - Honey (1 times)
#   - soy (1 times)
#   - ketchup (1 times)
#
# First 20 Recipes:
#   1. crock pot honey garlic chicken
# ==================================================
# ==================================================
# Community 52
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - hash browns (1 times)
#   - broth (1 times)
#   - cream (1 times)
#   - onion (1 times)
#   - pepper (1 times)
#   - cream cheese (1 times)
#   - milk (1 times)
#
# First 20 Recipes:
#   1. crockpot potato soup for weight watchers
# ==================================================
# ==================================================
# Community 53
# Number of Recipes: 1
# Average Number of Ingredients: 10.00
#
# Most Common Ingredients:
#   - pumpkin (1 times)
#   - almond (1 times)
#   - stock (1 times)
#   - pepper (1 times)
#   - cumin (1 times)
#   - curry (1 times)
#   - edam (1 times)
#   - cream (1 times)
#   - butter (1 times)
#   - olive oil (1 times)
#
# First 20 Recipes:
#   1. cypriot pumpkin soup
# ==================================================
# ==================================================
# Community 54
# Number of Recipes: 1
# Average Number of Ingredients: 8.00
#
# Most Common Ingredients:
#   - cucumber (1 times)
#   - watermelon (1 times)
#   - strawberry (1 times)
#   - feta (1 times)
#   - mint (1 times)
#   - basil (1 times)
#   - lime (1 times)
#   - walnut (1 times)
#
# First 20 Recipes:
#   1. danforth salad
# ==================================================
# ==================================================
# Community 55
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - seasoning (2 times)
#   - carrot (1 times)
#   - onion (1 times)
#   - mushroom (1 times)
#   - rice (1 times)
#   - venison (1 times)
#
# First 20 Recipes:
#   1. deer mash
# ==================================================
# ==================================================
# Community 56
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - raisin (1 times)
#   - vinegar (1 times)
#   - water (1 times)
#   - mustard (1 times)
#   - garlic (1 times)
#   - thyme (1 times)
#   - walnut (1 times)
#
# First 20 Recipes:
#   1. dr  fuhrman s walnut vinaigrette dressing
# ==================================================
# ==================================================
# Community 57
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - squash (1 times)
#   - onion (1 times)
#   - olive oil (1 times)
#   - berbere (1 times)
#   - cumin (1 times)
#   - basil (1 times)
#
# First 20 Recipes:
#   1. duba wot
# ==================================================
# ==================================================
# Community 58
# Number of Recipes: 1
# Average Number of Ingredients: 8.00
#
# Most Common Ingredients:
#   - almond (2 times)
#   - cake (1 times)
#   - pudding (1 times)
#   - eggs (1 times)
#   - water (1 times)
#   - oil (1 times)
#   - sugar (1 times)
#
# First 20 Recipes:
#   1. duncan hines almond pound cake
# ==================================================
# ==================================================
# Community 59
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - butter (1 times)
#   - lemon (1 times)
#   - apples (1 times)
#   - apricot (1 times)
#   - pastry (1 times)
#   - sugar (1 times)
#
# First 20 Recipes:
#   1. easiest apple roses
# ==================================================
# ==================================================
# Community 60
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - ranch (1 times)
#   - Yogurt (1 times)
#   - garlic (1 times)
#   - lime (1 times)
#   - tomatillo (1 times)
#   - cilantro (1 times)
#
# First 20 Recipes:
#   1. easiest creamy cilantro lime ranch salad dressing
# ==================================================
# ==================================================
# Community 61
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - yogurt (1 times)
#   - eggs (1 times)
#   - flour (1 times)
#   - cheddar (1 times)
#   - cheese (1 times)
#   - chili (1 times)
#   - Salsa (1 times)
#
# First 20 Recipes:
#   1. easy chili rellenos casserole
# ==================================================
# ==================================================
# Community 62
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - chocolate (2 times)
#   - cocoa (1 times)
#   - water (1 times)
#   - spread (1 times)
#   - cream (1 times)
#
# First 20 Recipes:
#   1. easy nutella chocolate mousse   gluten free
# ==================================================
# ==================================================
# Community 63
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - walnut (2 times)
#   - banana (1 times)
#   - cherry (1 times)
#   - ice cream (1 times)
#   - fudge (1 times)
#   - cream (1 times)
#
# First 20 Recipes:
#   1. emperor norton s ice cream sundae
# ==================================================
# ==================================================
# Community 64
# Number of Recipes: 1
# Average Number of Ingredients: 10.00
#
# Most Common Ingredients:
#   - pine (1 times)
#   - oil (1 times)
#   - cream (1 times)
#   - Roquefort (1 times)
#   - cream cheese (1 times)
#   - Fettuccine (1 times)
#   - spinach (1 times)
#   - prosciutto (1 times)
#   - parsley (1 times)
#   - salt (1 times)
#
# First 20 Recipes:
#   1. fettuccine with roquefort sauce
# ==================================================
# ==================================================
# Community 65
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - marinade (1 times)
#   - vinegar (1 times)
#   - oil (1 times)
#   - ketchup (1 times)
#   - pepper (1 times)
#   - chicken (1 times)
#
# First 20 Recipes:
#   1. fiery kickoff wings
# ==================================================
# ==================================================
# Community 66
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - mint (2 times)
#   - fig (1 times)
#   - sugar (1 times)
#   - bourbon (1 times)
#   - ice (1 times)
#   - ginger (1 times)
#
# First 20 Recipes:
#   1. fig and bourbon fizz
# ==================================================
# ==================================================
# Community 67
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - banana (1 times)
#   - eggs (1 times)
#   - extract (1 times)
#   - walnut (1 times)
#   - spray (1 times)
#   - almond butter (1 times)
#
# First 20 Recipes:
#   1. flourless banana bread pancakes
# ==================================================
# ==================================================
# Community 68
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - green bean (1 times)
#   - butter (1 times)
#   - lemon (1 times)
#   - mustard (1 times)
#   - almond (1 times)
#   - hazelnut (1 times)
#
# First 20 Recipes:
#   1. french green beans almondine
# ==================================================
# ==================================================
# Community 69
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - tea (1 times)
#   - water (1 times)
#   - peaches (1 times)
#   - syrup (1 times)
#   - lemon (1 times)
#   - ice (1 times)
#
# First 20 Recipes:
#   1. fresh peach sweet iced tea
# ==================================================
# ==================================================
# Community 70
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - cream (1 times)
#   - cheddar (1 times)
#   - bread (1 times)
#   - beef (1 times)
#   - potato (1 times)
#   - onion (1 times)
#
# First 20 Recipes:
#   1. frita cheesesteak
# ==================================================
# ==================================================
# Community 71
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - cream (2 times)
#   - Macaroon (1 times)
#   - egg (1 times)
#   - eggs (1 times)
#   - sugar (1 times)
#   - amaretto (1 times)
#
# First 20 Recipes:
#   1. frozen souffle amaretto  windows on the world
# ==================================================
# ==================================================
# Community 72
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - butter (1 times)
#   - Froot Loops (1 times)
#   - marshmallow (1 times)
#   - salt (1 times)
#   - vanilla (1 times)
#   - Milk (1 times)
#
# First 20 Recipes:
#   1. fruit loop treats
# ==================================================
# ==================================================
# Community 73
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - yogurt (1 times)
#   - cereal (1 times)
#   - banana (1 times)
#   - kiwi (1 times)
#   - strawberry (1 times)
#   - chocolate (1 times)
#
# First 20 Recipes:
#   1. fruity pebbles parfait
# ==================================================
# ==================================================
# Community 74
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - chicken (1 times)
#   - peaches (1 times)
#   - celery (1 times)
#   - pecan (1 times)
#   - tarragon (1 times)
#   - mayonnaise (1 times)
#
# First 20 Recipes:
#   1. georgia peach chicken salad
# ==================================================
# ==================================================
# Community 75
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - lime (2 times)
#   - fennel (1 times)
#   - arugula (1 times)
#   - syrup (1 times)
#   - gin (1 times)
#   - flour (1 times)
#
# First 20 Recipes:
#   1. gin rocket from the one bottle cocktail
# ==================================================
# ==================================================
# Community 76
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - chicken (1 times)
#   - apricot (1 times)
#   - cider (1 times)
#   - soy (1 times)
#   - onion (1 times)
#   - Ginger (1 times)
#
# First 20 Recipes:
#   1. glazed wings
# ==================================================
# ==================================================
# Community 77
# Number of Recipes: 1
# Average Number of Ingredients: 11.00
#
# Most Common Ingredients:
#   - pizza (1 times)
#   - pasta (1 times)
#   - mozzarella (1 times)
#   - Provolone (1 times)
#   - cheese (1 times)
#   - pine (1 times)
#   - grapes (1 times)
#   - arugula (1 times)
#   - rosemary (1 times)
#   - oregano (1 times)
#
# First 20 Recipes:
#   1. goats and grapes white pizza  ragu
# ==================================================
# ==================================================
# Community 78
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - soup (1 times)
#   - Milk (1 times)
#   - stuffing (1 times)
#   - butter (1 times)
#   - chicken (1 times)
#   - bean (1 times)
#
# First 20 Recipes:
#   1. green bean  chicken   stuffing casserole
# ==================================================
# ==================================================
# Community 79
# Number of Recipes: 1
# Average Number of Ingredients: 8.00
#
# Most Common Ingredients:
#   - spinach (1 times)
#   - avocado (1 times)
#   - coconut (1 times)
#   - cocoa (1 times)
#   - cinnamon (1 times)
#   - Honey (1 times)
#   - Stevia (1 times)
#   - ice (1 times)
#
# First 20 Recipes:
#   1. green chocolate smoothie
# ==================================================
# ==================================================
# Community 80
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - coconut (1 times)
#   - eggs (1 times)
#   - erythritol (1 times)
#   - tea (1 times)
#   - extract (1 times)
#   - chocolate (1 times)
#
# First 20 Recipes:
#   1. green tea coconut milk ice cream  low gi
# ==================================================
# ==================================================
# Community 81
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - cauliflower (1 times)
#   - salt (1 times)
#   - coconut oil (1 times)
#   - seasoning (1 times)
#   - pine (1 times)
#   - Lemon (1 times)
#   - mint (1 times)
#
# First 20 Recipes:
#   1. harissa cauliflower steaks
# ==================================================
# ==================================================
# Community 82
# Number of Recipes: 1
# Average Number of Ingredients: 10.00
#
# Most Common Ingredients:
#   - cream cheese (1 times)
#   - pudding (1 times)
#   - coffee creamer (1 times)
#   - strawberry (1 times)
#   - oranges (1 times)
#   - pineapple (1 times)
#   - kiwi (1 times)
#   - mango (1 times)
#   - banana (1 times)
#   - lemon (1 times)
#
# First 20 Recipes:
#   1. hawaiian cheesecake fruit salad
# ==================================================
# ==================================================
# Community 83
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - pizza (1 times)
#   - ricotta (1 times)
#   - seasoning (1 times)
#   - ham (1 times)
#   - pineapple (1 times)
#   - mozzarella (1 times)
#   - scallion (1 times)
#
# First 20 Recipes:
#   1. hawaiian pizza pineapples
# ==================================================
# ==================================================
# Community 84
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - tea (1 times)
#   - salt (1 times)
#   - sugar (1 times)
#   - pepper (1 times)
#   - pork (1 times)
#   - wood chips (1 times)
#
# First 20 Recipes:
#   1. hawaiian style smoked pork   kalua pork cook s country
# ==================================================
# ==================================================
# Community 85
# Number of Recipes: 1
# Average Number of Ingredients: 9.00
#
# Most Common Ingredients:
#   - carrot (1 times)
#   - cauliflower (1 times)
#   - squash (1 times)
#   - milk (1 times)
#   - salt (1 times)
#   - cheddar (1 times)
#   - cream cheese (1 times)
#   - margarine (1 times)
#   - macaroni (1 times)
#
# First 20 Recipes:
#   1. hidden veggie mac and cheese
# ==================================================
# ==================================================
# Community 86
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - strawberry (1 times)
#   - lemon (1 times)
#   - sugar (1 times)
#   - milk (1 times)
#   - cream (1 times)
#   - extract (1 times)
#
# First 20 Recipes:
#   1. homemade strawberry ice cream recipe
# ==================================================
# ==================================================
# Community 87
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - chocolate (2 times)
#   - cream (2 times)
#   - salt (1 times)
#   - Milk (1 times)
#   - marshmallow (1 times)
#
# First 20 Recipes:
#   1. hot chocolate concentrate from america s test kitchen
# ==================================================
# ==================================================
# Community 88
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - white chocolate (1 times)
#   - Milk (1 times)
#   - cream (1 times)
#   - cardamom (1 times)
#   - extract (1 times)
#   - nutmeg (1 times)
#
# First 20 Recipes:
#   1. hot white chocolate with cardamom
# ==================================================
# ==================================================
# Community 89
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - sherbet (2 times)
#   - Peach (1 times)
#   - soymilk (1 times)
#   - pineapple (1 times)
#   - Mango (1 times)
#   - ice (1 times)
#
# First 20 Recipes:
#   1. jamba juice at home white gummi bear smoothie
# ==================================================
# ==================================================
# Community 90
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - corn (1 times)
#   - olive oil (1 times)
#   - salt (1 times)
#   - soy (1 times)
#   - mirin (1 times)
#   - sugar (1 times)
#   - togarashi (1 times)
#
# First 20 Recipes:
#   1. japanese grilled corn on the cob  yaki tomorokoshi
# ==================================================
# ==================================================
# Community 91
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - gin (1 times)
#   - pear (1 times)
#   - syrup (1 times)
#   - Honey (1 times)
#   - water (1 times)
#   - mint (1 times)
#   - ginger (1 times)
#
# First 20 Recipes:
#   1. japanese yuzu and ginger cocktail
# ==================================================
# ==================================================
# Community 92
# Number of Recipes: 1
# Average Number of Ingredients: 8.00
#
# Most Common Ingredients:
#   - buns (1 times)
#   - Old Bay (1 times)
#   - beef (1 times)
#   - pretzels (1 times)
#   - onion (1 times)
#   - thyme (1 times)
#   - oregano (1 times)
#   - egg (1 times)
#
# First 20 Recipes:
#   1. joe holland s hamburgers
# ==================================================
# ==================================================
# Community 93
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - water (1 times)
#   - chamomile (1 times)
#   - anise (1 times)
#   - thyme (1 times)
#   - sage (1 times)
#   - Honey (1 times)
#
# First 20 Recipes:
#   1. jordanian herbal tea
# ==================================================
# ==================================================
# Community 94
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - butter (1 times)
#   - cream cheese (1 times)
#   - peanut (1 times)
#   - cocoa (1 times)
#   - Splenda (1 times)
#   - vanilla (1 times)
#
# First 20 Recipes:
#   1. keto chocolate peanut butter fudge
# ==================================================
# ==================================================
# Community 95
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - onion (2 times)
#   - sausage (1 times)
#   - oil (1 times)
#   - sesame oil (1 times)
#   - red pepper (1 times)
#   - soy (1 times)
#
# First 20 Recipes:
#   1. korean style kiolbassa sausage
# ==================================================
# ==================================================
# Community 96
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - lentils (1 times)
#   - salt (1 times)
#   - water (1 times)
#   - baking (1 times)
#   - oil (1 times)
#   - berry (1 times)
#
# First 20 Recipes:
#   1. lentil pancakes with berries
# ==================================================
# ==================================================
# Community 97
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - cream cheese (1 times)
#   - cool whip (1 times)
#   - graham (1 times)
#   - chocolate (1 times)
#   - sugar (1 times)
#   - peanut butter (1 times)
#   - water (1 times)
#
# First 20 Recipes:
#   1. lightened up peanut butter pie
# ==================================================
# ==================================================
# Community 98
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - cauliflower (1 times)
#   - bacon (1 times)
#   - chives (1 times)
#   - mayonnaise (1 times)
#   - sour cream (1 times)
#   - cheese (1 times)
#   - mushroom (1 times)
#
# First 20 Recipes:
#   1. loaded cauliflower  as seen on facebook
# ==================================================
# ==================================================
# Community 99
# Number of Recipes: 1
# Average Number of Ingredients: 9.00
#
# Most Common Ingredients:
#   - chocolate (2 times)
#   - sugar (1 times)
#   - milk (1 times)
#   - margarine (1 times)
#   - coconut (1 times)
#   - nut (1 times)
#   - salt (1 times)
#   - wax (1 times)
#
# First 20 Recipes:
#   1. louise s christmas bonbons
# ==================================================
# ==================================================
# Community 100
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - ham (1 times)
#   - onion (1 times)
#   - eggs (1 times)
#   - cauliflower (1 times)
#   - cheddar (1 times)
#   - cheese (1 times)
#
# First 20 Recipes:
#   1. low carb amish ham casserole
# ==================================================
# ==================================================
# Community 101
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - walnut (1 times)
#   - Coconut (1 times)
#   - cocoa (1 times)
#   - coconut oil (1 times)
#   - coconut (1 times)
#   - Truvia (1 times)
#   - salt (1 times)
#
# First 20 Recipes:
#   1. low carb raw coconut brownie balls
# ==================================================
# ==================================================
# Community 102
# Number of Recipes: 1
# Average Number of Ingredients: 8.00
#
# Most Common Ingredients:
#   - water (1 times)
#   - erythritol (1 times)
#   - butter (1 times)
#   - coconut oil (1 times)
#   - maple (1 times)
#   - extract (1 times)
#   - gum (1 times)
#   - cinnamon (1 times)
#
# First 20 Recipes:
#   1. low carb syrup
# ==================================================
# ==================================================
# Community 103
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - egg (2 times)
#   - oil (1 times)
#   - Milk (1 times)
#   - baking (1 times)
#   - parmesan (1 times)
#
# First 20 Recipes:
#   1. luxury fluffy scrambled eggs
# ==================================================
# ==================================================
# Community 104
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - Mango (1 times)
#   - sugar (1 times)
#   - mint (1 times)
#   - anise (1 times)
#   - cardamom (1 times)
#   - lime (1 times)
#   - yogurt (1 times)
#
# First 20 Recipes:
#   1. mango mint lassi with indian sweet spices
# ==================================================
# ==================================================
# Community 105
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - Mango (2 times)
#   - mango (1 times)
#   - ice (1 times)
#   - lime (1 times)
#   - chili (1 times)
#   - seasoning (1 times)
#
# First 20 Recipes:
#   1. mangonada
# ==================================================
# ==================================================
# Community 106
# Number of Recipes: 1
# Average Number of Ingredients: 9.00
#
# Most Common Ingredients:
#   - pumpkin (2 times)
#   - bean (1 times)
#   - maple syrup (1 times)
#   - salt (1 times)
#   - oats (1 times)
#   - flour (1 times)
#   - bran (1 times)
#   - chocolate (1 times)
#
# First 20 Recipes:
#   1. maple pumpkin chocolate chip energy bars
# ==================================================
# ==================================================
# Community 107
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - butter (2 times)
#   - marshmallow (1 times)
#   - salt (1 times)
#   - rice (1 times)
#   - sprinkles (1 times)
#
# First 20 Recipes:
#   1. marshmallow rice crispy treats ree drummond   pioneer woman
# ==================================================
# ==================================================
# Community 108
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - gin (1 times)
#   - lime (1 times)
#   - syrup (1 times)
#   - cumin (1 times)
#   - salt (1 times)
#   - lemon (1 times)
#
# First 20 Recipes:
#   1. masala martini
# ==================================================
# ==================================================
# Community 109
# Number of Recipes: 1
# Average Number of Ingredients: 8.00
#
# Most Common Ingredients:
#   - spinach (1 times)
#   - peach (1 times)
#   - pineapple (1 times)
#   - juice (1 times)
#   - banana (1 times)
#   - tea (1 times)
#   - raspberry (1 times)
#   - strawberry (1 times)
#
# First 20 Recipes:
#   1. matcha berry swirl smoothie
# ==================================================
# ==================================================
# Community 110
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - taco (2 times)
#   - ground beef (1 times)
#   - seasoning (1 times)
#   - rice (1 times)
#   - water (1 times)
#   - cheddar (1 times)
#
# First 20 Recipes:
#   1. mickey s okinawa taco rice and cheese trc
# ==================================================
# ==================================================
# Community 111
# Number of Recipes: 1
# Average Number of Ingredients: 10.00
#
# Most Common Ingredients:
#   - pineapple (2 times)
#   - meatball (1 times)
#   - barbecue (1 times)
#   - seasoning (1 times)
#   - roll (1 times)
#   - cheese (1 times)
#   - slaw (1 times)
#   - mayonnaise (1 times)
#   - sugar (1 times)
#
# First 20 Recipes:
#   1. mini hawaiian meatball subs with pineapple coleslaw
# ==================================================
# ==================================================
# Community 112
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - lime (1 times)
#   - sugar (1 times)
#   - mint (1 times)
#   - bourbon (1 times)
#   - liqueur (1 times)
#   - seltzer (1 times)
#
# First 20 Recipes:
#   1. mint julep margarita
# ==================================================
# ==================================================
# Community 113
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - miso (1 times)
#   - mirin (1 times)
#   - onion (1 times)
#   - salt (1 times)
#   - cayenne (1 times)
#   - scallops (1 times)
#   - lime (1 times)
#
# First 20 Recipes:
#   1. miso broiled scallops
# ==================================================
# ==================================================
# Community 114
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - ham (1 times)
# ...
#   - chocolate (1 times)
#   - strawberries (1 times)
#
# First 20 Recipes:
#   1. simple ice cream   thermomix
# ==================================================
# ==================================================
# Community 166
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - beef (1 times)
#   - soup (1 times)
#   - rice (1 times)
#   - sausage (1 times)
#   - onion (1 times)
#   - butter (1 times)
#   - Parsley (1 times)
#
# First 20 Recipes:
#   1. simply dirty rice
# ==================================================
# ==================================================
# Community 167
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - strawberry (2 times)
#   - Honey (1 times)
#   - gin (1 times)
#   - yogurt (1 times)
#   - pepper (1 times)
#
# First 20 Recipes:
#   1. slippery when wet from the one bottle cocktail
# ==================================================
# ==================================================
# Community 168
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - apple (1 times)
#   - milk (1 times)
#   - water (1 times)
#   - maple syrup (1 times)
#   - cinnamon (1 times)
#   - flax (1 times)
#
# First 20 Recipes:
#   1. slow cooker overnight steel cut oats with apples
# ==================================================
# ==================================================
# Community 169
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - ground beef (1 times)
#   - beef (1 times)
#   - veal (1 times)
#   - onion (1 times)
#   - egg (1 times)
#   - essence (1 times)
#
# First 20 Recipes:
#   1. smokey juicy burger patties
# ==================================================
# ==================================================
# Community 170
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - pepper (2 times)
#   - crescent (1 times)
#   - Provolone (1 times)
#   - salami (1 times)
#   - ham (1 times)
#   - capicola (1 times)
#
# First 20 Recipes:
#   1. spicy italian hero crescent ring
# ==================================================
# ==================================================
# Community 171
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - celery (1 times)
#   - lime (1 times)
#   - Vodka (1 times)
#   - Worcestershire (1 times)
#   - frank (1 times)
#   - Pickle (1 times)
#   - Clamato (1 times)
#
# First 20 Recipes:
#   1. stacie s ultimate caesar
# ==================================================
# ==================================================
# Community 172
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - flour (1 times)
#   - eggs (1 times)
#   - pumpkin (1 times)
#   - peanut (1 times)
#   - cinnamon (1 times)
#   - water (1 times)
#
# First 20 Recipes:
#   1. storm s peanut butter and pumpkin dog treats
# ==================================================
# ==================================================
# Community 173
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - strawberry (1 times)
#   - pineapple (1 times)
#   - lime (1 times)
#   - rum (1 times)
#   - sugar (1 times)
#   - butter (1 times)
#   - pectin (1 times)
#
# First 20 Recipes:
#   1. strawberry daiquiri jam
# ==================================================
# ==================================================
# Community 174
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - cake mix (2 times)
#   - eggs (1 times)
#   - oil (1 times)
#   - sugar (1 times)
#   - lemon (1 times)
#
# First 20 Recipes:
#   1. strawberry lemonade brownies
# ==================================================
# ==================================================
# Community 175
# Number of Recipes: 1
# Average Number of Ingredients: 8.00
#
# Most Common Ingredients:
#   - strawberries (2 times)
#   - lime (2 times)
#   - daiquiri (1 times)
#   - tequila (1 times)
#   - liqueur (1 times)
#   - soda (1 times)
#
# First 20 Recipes:
#   1. strawberry margarita spritzers
# ==================================================
# ==================================================
# Community 176
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - oatmeal (1 times)
#   - chia (1 times)
#   - milk (1 times)
#   - yogurt (1 times)
#   - strawberry (1 times)
#   - Truvia (1 times)
#
# First 20 Recipes:
#   1. strawberry oatmeal smoothie
# ==================================================
# ==================================================
# Community 177
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - strawberries (2 times)
#   - cake mix (1 times)
#   - ice cream (1 times)
#   - strawberry (1 times)
#   - wafer (1 times)
#   - icing (1 times)
#
# First 20 Recipes:
#   1. strawberry shortcake ice cream cake
# ==================================================
# ==================================================
# Community 178
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - pasta (1 times)
#   - chickpea (1 times)
#   - eggs (1 times)
#   - olive oil (1 times)
#   - pine (1 times)
#   - Feta (1 times)
#   - bread (1 times)
#
# First 20 Recipes:
#   1. sundried tomato and sweet basil shakshuka  ragu
# ==================================================
# ==================================================
# Community 179
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - pasta (1 times)
#   - yogurt (1 times)
#   - garlic (1 times)
#   - mint (1 times)
#   - salt (1 times)
#   - pepper (1 times)
#
# First 20 Recipes:
#   1. super cheap yogurt pasta
# ==================================================
# ==================================================
# Community 180
# Number of Recipes: 1
# Average Number of Ingredients: 8.00
#
# Most Common Ingredients:
#   - rice (1 times)
#   - mayonnaise (1 times)
#   - sour cream (1 times)
#   - crabmeat (1 times)
#   - shrimp (1 times)
#   - tobiko (1 times)
#   - seasoning (1 times)
#   - nori (1 times)
#
# First 20 Recipes:
#   1. sushi bake
# ==================================================
# ==================================================
# Community 181
# Number of Recipes: 1
# Average Number of Ingredients: 8.00
#
# Most Common Ingredients:
#   - onion (2 times)
#   - skewers (1 times)
#   - meatball (1 times)
#   - peppers (1 times)
#   - pineapple (1 times)
#   - sauce (1 times)
#   - rice (1 times)
#
# First 20 Recipes:
#   1. sweet   sour meatball kabobs with pineapple
# ==================================================
# ==================================================
# Community 182
# Number of Recipes: 1
# Average Number of Ingredients: 8.00
#
# Most Common Ingredients:
#   - water (1 times)
#   - quinoa (1 times)
#   - scallion (1 times)
#   - parsley (1 times)
#   - Feta (1 times)
#   - cranberries (1 times)
#   - corn (1 times)
#   - balsamic (1 times)
#
# First 20 Recipes:
#   1. sweet and savory quinoa salad
# ==================================================
# ==================================================
# Community 183
# Number of Recipes: 1
# Average Number of Ingredients: 10.00
#
# Most Common Ingredients:
#   - potato (3 times)
#   - leek (2 times)
#   - butter (1 times)
#   - stock (1 times)
#   - ginger (1 times)
#   - salt (1 times)
#   - oil (1 times)
#
# First 20 Recipes:
#   1. sweet potato soup with matchstick fries and frizzled leeks
# ==================================================
# ==================================================
# Community 184
# Number of Recipes: 1
# Average Number of Ingredients: 8.00
#
# Most Common Ingredients:
#   - potato (1 times)
#   - avocado (1 times)
#   - egg (1 times)
#   - chili (1 times)
#   - almond butter (1 times)
#   - berry (1 times)
#   - Nutella (1 times)
#   - banana (1 times)
#
# First 20 Recipes:
#   1. sweet potato toast
# ==================================================
# ==================================================
# Community 185
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - coconut (1 times)
#   - almond butter (1 times)
#   - shrimp (1 times)
#   - stock (1 times)
#   - tomato (1 times)
#   - applesauce (1 times)
#
# First 20 Recipes:
#   1. thai almond butter shrimp
# ==================================================
# ==================================================
# Community 186
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - soymilk (1 times)
#   - banana (1 times)
#   - peanut (1 times)
#   - cocoa (1 times)
#   - ice (1 times)
#   - powder (1 times)
#
# First 20 Recipes:
#   1. the healthy elvis shake
# ==================================================
# ==================================================
# Community 187
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - garlic (1 times)
#   - spray (1 times)
#   - asparagus (1 times)
#   - olive oil (1 times)
#   - thyme (1 times)
#   - salt (1 times)
#
# First 20 Recipes:
#   1. thyme garlic roasted asparagus
# ==================================================
# ==================================================
# Community 188
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - ground (1 times)
#   - onion (1 times)
#   - soup (1 times)
#   - cheese (1 times)
#   - tater (1 times)
#   - corn (1 times)
#   - salt (1 times)
#
# First 20 Recipes:
#   1. totally white white trash casserole
# ==================================================
# ==================================================
# Community 189
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - tuna (1 times)
#   - tarragon (1 times)
#   - Feta (1 times)
#   - tomatoes (1 times)
#   - cucumber (1 times)
#   - pita (1 times)
#
# First 20 Recipes:
#   1. tuna tarragon pita
# ==================================================
# ==================================================
# Community 190
# Number of Recipes: 1
# Average Number of Ingredients: 9.00
#
# Most Common Ingredients:
#   - tuna (1 times)
#   - miso (1 times)
#   - wasabi (1 times)
#   - sesame oil (1 times)
#   - sriracha (1 times)
#   - mirin (1 times)
#   - Ponzu (1 times)
#   - soy (1 times)
#   - sesame (1 times)
#
# First 20 Recipes:
#   1. tuna tartar
# ==================================================
# ==================================================
# Community 191
# Number of Recipes: 1
# Average Number of Ingredients: 8.00
#
# Most Common Ingredients:
#   - veal (1 times)
#   - rib (1 times)
#   - eggs (1 times)
#   - olive oil (1 times)
#   - butter (1 times)
#   - garlic (1 times)
#   - fontina (1 times)
#   - truffle (1 times)
#
# First 20 Recipes:
#   1. veal ribs with fontina cheese
# ==================================================
# ==================================================
# Community 192
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - roll (1 times)
#   - steak (1 times)
#   - oil (1 times)
#   - garlic (1 times)
#   - soy (1 times)
#   - Worcestershire (1 times)
#   - salt (1 times)
#
# First 20 Recipes:
#   1. venezuelan pepito sandwich   pepito venezolano
# ==================================================
# ==================================================
# Community 193
# Number of Recipes: 1
# Average Number of Ingredients: 8.00
#
# Most Common Ingredients:
#   - Milk (1 times)
#   - anise (1 times)
#   - cinnamon (1 times)
#   - orange (1 times)
#   - allspice (1 times)
#   - sugar (1 times)
#   - chocolate (1 times)
#   - rum (1 times)
#
# First 20 Recipes:
#   1. venezuelan spiced hot chocolate
# ==================================================
# ==================================================
# Community 194
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - vinegar (1 times)
#   - water (1 times)
#   - gelatin (1 times)
#   - potato (1 times)
#   - salt (1 times)
#   - oil (1 times)
#
# First 20 Recipes:
#   1. vinegar air and salty crispy potatoes   british larder
# ==================================================
# ==================================================
# Community 195
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - broccoli (1 times)
#   - water (1 times)
#   - wasabi (1 times)
#   - soy (1 times)
#   - sake (1 times)
#   - sugar (1 times)
#
# First 20 Recipes:
#   1. wasabi ae  broccoli with wasabi sauce
# ==================================================
# ==================================================
# Community 196
# Number of Recipes: 1
# Average Number of Ingredients: 8.00
#
# Most Common Ingredients:
#   - watermelon (1 times)
#   - wine (1 times)
#   - rum (1 times)
#   - sugar (1 times)
#   - chili (1 times)
#   - lime (1 times)
#   - ginger (1 times)
#   - mint (1 times)
#
# First 20 Recipes:
#   1. watermelon sangria with sriracha
# ==================================================
# ==================================================
# Community 197
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - pretzel (1 times)
#   - butter (1 times)
#   - whiskey (1 times)
#   - sugar (1 times)
#   - garlic (1 times)
#   - pepper (1 times)
#
# First 20 Recipes:
#   1. whiskey pretzels
# ==================================================
# ==================================================
# Community 198
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - spray (1 times)
#   - chocolate (1 times)
#   - cream (1 times)
#   - peppermint (1 times)
#   - food coloring (1 times)
#   - candy (1 times)
#
# First 20 Recipes:
#   1. white chocolate peppermint candies
# ==================================================
# ==================================================
# Community 199
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - Milk (1 times)
#   - cream (1 times)
#   - cornstarch (1 times)
#   - white chocolate (1 times)
#   - essence (1 times)
#   - salt (1 times)
#
# First 20 Recipes:
#   1. white chocolate rose pudding
# ==================================================
# ==================================================
# Community 200
# Number of Recipes: 1
# Average Number of Ingredients: 8.00
#
# Most Common Ingredients:
#   - coffee (2 times)
#   - water (1 times)
#   - sugar (1 times)
#   - espresso (1 times)
#   - syrup (1 times)
#   - cream (1 times)
#   - Vodka (1 times)
#
# First 20 Recipes:
#   1. white russian sorbet
# ==================================================
# ==================================================
# Community 201
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - jelly (1 times)
#   - peanut butter (1 times)
#   - vinegar (1 times)
#   - hot pepper sauce (1 times)
#   - salt (1 times)
#   - chicken (1 times)
#   - cilantro (1 times)
#
# First 20 Recipes:
#   1. wings peanut butter and jelly wings
# ==================================================
# ==================================================
# Community 202
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - Brussels (1 times)
#   - cranberries (1 times)
#   - lemon (1 times)
#   - olive oil (1 times)
#   - salt (1 times)
#   - pepper (1 times)
#
# First 20 Recipes:
#   1. ww brussels sprouts with dried canberries and lemon   3 pts
# ==================================================
# ==================================================
# Community 203
# Number of Recipes: 1
# Average Number of Ingredients: 11.00
#
# Most Common Ingredients:
#   - soba (1 times)
#   - chicken broth (1 times)
#   - water (1 times)
#   - chicken (1 times)
#   - mushroom (1 times)
#   - ginger (1 times)
#   - soy sauce (1 times)
#   - pea (1 times)
#   - peas (1 times)
#   - spinach (1 times)
#
# First 20 Recipes:
#   1. ww soba chicken noodle bowl
# ==================================================
# ==================================================
# Community 204
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - yogurt (1 times)
#   - syrup (1 times)
#   - peach (1 times)
#   - blueberries (1 times)
#   - strawberry (1 times)
#   - granola (1 times)
#
# First 20 Recipes:
#   1. yogurt fruit bark
# ==================================================
# ==================================================
# Community 205
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - rum (1 times)
#   - vodka (1 times)
#   - sec (1 times)
#   - syrup (1 times)
#   - yuzu (1 times)
#   - soda (1 times)
#
# First 20 Recipes:
#   1. yuzu cocktail
# ==================================================

# %%
bridge_ingredient_counts = find_bridge_ingredients(recipes_graph, greedy_communities)

print(f"{'Rank':<5} {'Ingredient':<25} {'Number of Connections'}")
print("=" * 50)
for rank, (ingredient, count) in enumerate(bridge_ingredient_counts.most_common(), start=1):
    print(f"{rank:<5} {ingredient:<25} {count}")
# Out:
# Rank  Ingredient                Number of Connections
# ==================================================
# 1     salt                      4109
# 2     pepper                    2441
# 3     flour                     2363
# 4     garlic                    1918
# 5     onion                     1819
# 6     butter                    1813
# 7     sugar                     1217
# 8     Milk                      998
# 9     water                     775
# 10    egg                       688
# 11    oil                       540
# 12    eggs                      439
# 13    cheese                    409
# 14    chicken                   354
# 15    parmesan                  228
# 16    cheddar                   186
# 17    lemon                     185
# 18    tomatoes                  163
# 19    Paprika                   130
# 20    potato                    128
# 21    cornstarch                118
# 22    carrot                    118
# 23    parsley                   114
# 24    mustard                   106
# 25    cream                     98
# 26    tomato                    97
# 27    soy                       96
# 28    nutmeg                    93
# 29    olive oil                 87
# 30    celery                    85
# 31    cinnamon                  84
# 32    vinegar                   82
# 33    scallion                  78
# 34    ginger                    72
# 35    cream cheese              71
# 36    pasta                     71
# 37    sour cream                70
# 38    baking                    70
# 39    cilantro                  69
# 40    rice                      67
# 41    lime                      60
# 42    macaroni                  57
# 43    yeast                     55
# 44    corn                      49
# 45    sesame oil                43
# 46    chives                    40
# 47    bacon                     40
# 48    oregano                   39
# 49    thyme                     39
# 50    beef                      38
# 51    allspice                  35
# 52    buttermilk                34
# 53    milk                      33
# 54    cloves                    32
# 55    chili                     29
# 56    breadcrumb                28
# 57    ground beef               28
# 58    pork                      26
# 59    hot sauce                 26
# 60    Honey                     26
# 61    wine                      26
# 62    stock                     25
# 63    broth                     25
# 64    cornmeal                  24
# 65    mozzarella                22
# 66    bean                      16
# 67    sausage                   15
# 68    cumin                     15
# 69    lettuce                   14
# 70    Feta                      14
# 71    coriander                 14
# 72    cardamom                  14
# 73    Worcestershire            13
# 74    Ginger                    13
# 75    turmeric                  13
# 76    peanut oil                12
# 77    beef broth                12
# 78    rosemary                  12
# 79    apple                     11
# 80    panko                     11
# 81    mayonnaise                11
# 82    ketchup                   11
# 83    beer                      11
# 84    juice                     9
# 85    zucchini                  8
# 86    pineapple                 8
# 87    orange                    8
# 88    ham                       7
# 89    seed                      7
# 90    almond                    7
# 91    cider                     7
# 92    shrimp                    7
# 93    chipotle                  7
# 94    half-and-half             7
# 95    bread                     6
# 96    walnut                    6
# 97    avocado                   5
# 98    polenta                   5
# 99    hoisin                    5
# 100   leek                      5
# 101   broccoli                  5
# 102   shallot                   5
# 103   dill                      5
# 104   cayenne                   4
# 105   cauliflower               4
# 106   buns                      4
# 107   fish                      4
# 108   pickle                    4
# 109   Gruyere                   3
# 110   pastry                    3
# 111   raisin                    3
# 112   Salsa                     3
# 113   yogurt                    3
# 114   red pepper                3
# 115   squash                    3
# 116   spray                     3
# 117   ricotta                   3
# 118   arugula                   3
# 119   clove                     3
# 120   jam                       2
# 121   salmon                    2
# 122   shortening                2
# 123   sesame                    2
# 124   fennel                    2
# 125   spinach                   2
# 126   seasoning                 2
# 127   chocolate                 2
# 128   spice                     2
# 129   crust                     2
# 130   Pickle                    2
# 131   taco                      2
# 132   mint                      2
# 133   Mango                     1
# 134   paprika                   1
# 135   leaf                      1
# 136   barbecue                  1
# 137   fontina                   1
# 138   pretzels                  1
# 139   fenugreek                 1
# 140   Vodka                     1
# 141   baking soda               1
# 142   crema                     1
# 143   vanilla                   1
# 144   oyster                    1
# 145   coffee                    1
# 146   Velveeta                  1
# 147   turkey                    1
# 148   baguette                  1
# 149   meat                      1
# 150   spaghetti                 1
# 151   mirin                     1
# 152   adobo                     1
# 153   gelatin                   1
# 154   Lard                      1
# 155   powder                    1
# 156   peas                      1

# %%
bridge_ingredient_details = find_bridge_ingredients_with_details(recipes_graph, greedy_communities)

print("=" * 120)
print(f"{'Ingredient':<20} {'Recipe 1 (Community)':<45} {'Recipe 2 (Community)':<45}")
print("=" * 120)

for ingredient, connections in bridge_ingredient_details.items():
    print(f"\nIngredient: {ingredient}")
    for connection in connections[:10]: 
        print(f"  - {connection['recipe_u']} (Community {connection['community_u']}) "
              f"<-> {connection['recipe_v']} (Community {connection['community_v']})")
    print("-" * 120)
# Out:
# ========================================================================================================================
# Ingredient           Recipe 1 (Community)                          Recipe 2 (Community)
# ========================================================================================================================
#
# Ingredient: garlic
#   - lplermagrone (Community 1) <-> cheesy jalapeno corn casserole  slow cooker (Community 2)
#   - lplermagrone (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - lplermagrone (Community 1) <-> everything bagel rugelach (Community 2)
#   - lplermagrone (Community 1) <-> hamburger potpie with homemade crust (Community 2)
#   - lplermagrone (Community 1) <-> julia belle s world famous macaroni and cheese (Community 3)
#   - lplermagrone (Community 1) <-> onion lover s twist (Community 2)
#   - lplermagrone (Community 1) <-> snapper in a poblano chile sauce (Community 3)
#   - lplermagrone (Community 1) <-> traditional style pastitsio  ragu (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> beer cheese stuffed pretzels (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> best general tso s chicken from serious eats (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: salt
#   - lplermagrone (Community 1) <-> cheesy jalapeno corn casserole  slow cooker (Community 2)
#   - lplermagrone (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - lplermagrone (Community 1) <-> decadent a1 swirl corn muffins  a1 (Community 2)
#   - lplermagrone (Community 1) <-> everything bagel rugelach (Community 2)
#   - lplermagrone (Community 1) <-> gwen s old fashioned potato beef casserole  trisha yearwood (Community 3)
#   - lplermagrone (Community 1) <-> ham   spaghetti casserole (Community 2)
#   - lplermagrone (Community 1) <-> hamburger potpie with homemade crust (Community 2)
#   - lplermagrone (Community 1) <-> julia belle s world famous macaroni and cheese (Community 3)
#   - lplermagrone (Community 1) <-> leverpostej   danish liver paste (Community 2)
#   - lplermagrone (Community 1) <-> mac and jack and cheese (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: butter
#   - lplermagrone (Community 1) <-> cheesy jalapeno corn casserole  slow cooker (Community 2)
#   - lplermagrone (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - lplermagrone (Community 1) <-> decadent a1 swirl corn muffins  a1 (Community 2)
#   - lplermagrone (Community 1) <-> everything bagel rugelach (Community 2)
#   - lplermagrone (Community 1) <-> gwen s old fashioned potato beef casserole  trisha yearwood (Community 3)
#   - lplermagrone (Community 1) <-> ham   spaghetti casserole (Community 2)
#   - lplermagrone (Community 1) <-> hamburger potpie with homemade crust (Community 2)
#   - lplermagrone (Community 1) <-> julia belle s world famous macaroni and cheese (Community 3)
#   - lplermagrone (Community 1) <-> leverpostej   danish liver paste (Community 2)
#   - lplermagrone (Community 1) <-> mac and jack and cheese (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: Milk
#   - lplermagrone (Community 1) <-> cheesy jalapeno corn casserole  slow cooker (Community 2)
#   - lplermagrone (Community 1) <-> decadent a1 swirl corn muffins  a1 (Community 2)
#   - lplermagrone (Community 1) <-> gwen s old fashioned potato beef casserole  trisha yearwood (Community 3)
#   - lplermagrone (Community 1) <-> ham   spaghetti casserole (Community 2)
#   - lplermagrone (Community 1) <-> julia belle s world famous macaroni and cheese (Community 3)
#   - lplermagrone (Community 1) <-> leverpostej   danish liver paste (Community 2)
#   - lplermagrone (Community 1) <-> mac and jack and cheese (Community 2)
#   - lplermagrone (Community 1) <-> onion lover s twist (Community 2)
#   - lplermagrone (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - lplermagrone (Community 1) <-> snapper in a poblano chile sauce (Community 3)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: pepper
#   - lplermagrone (Community 1) <-> cheesy jalapeno corn casserole  slow cooker (Community 2)
#   - lplermagrone (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - lplermagrone (Community 1) <-> decadent a1 swirl corn muffins  a1 (Community 2)
#   - lplermagrone (Community 1) <-> everything bagel rugelach (Community 2)
#   - lplermagrone (Community 1) <-> gwen s old fashioned potato beef casserole  trisha yearwood (Community 3)
#   - lplermagrone (Community 1) <-> ham   spaghetti casserole (Community 2)
#   - lplermagrone (Community 1) <-> hamburger potpie with homemade crust (Community 2)
#   - lplermagrone (Community 1) <-> julia belle s world famous macaroni and cheese (Community 3)
#   - lplermagrone (Community 1) <-> leverpostej   danish liver paste (Community 2)
#   - lplermagrone (Community 1) <-> mac and jack and cheese (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: cheese
#   - lplermagrone (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - lplermagrone (Community 1) <-> decadent a1 swirl corn muffins  a1 (Community 2)
#   - lplermagrone (Community 1) <-> ham   spaghetti casserole (Community 2)
#   - lplermagrone (Community 1) <-> julia belle s world famous macaroni and cheese (Community 3)
#   - lplermagrone (Community 1) <-> mac and jack and cheese (Community 2)
#   - lplermagrone (Community 1) <-> snapper in a poblano chile sauce (Community 3)
#   - lplermagrone (Community 1) <-> traditional style pastitsio  ragu (Community 2)
#   - lplermagrone (Community 1) <-> yummy corn cakes (Community 2)
#   - 1 minute breakfast sandwich (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - 1 minute breakfast sandwich (Community 1) <-> decadent a1 swirl corn muffins  a1 (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: onion
#   - lplermagrone (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - lplermagrone (Community 1) <-> everything bagel rugelach (Community 2)
#   - lplermagrone (Community 1) <-> gwen s old fashioned potato beef casserole  trisha yearwood (Community 3)
#   - lplermagrone (Community 1) <-> hamburger potpie with homemade crust (Community 2)
#   - lplermagrone (Community 1) <-> leverpostej   danish liver paste (Community 2)
#   - lplermagrone (Community 1) <-> onion lover s twist (Community 2)
#   - lplermagrone (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - lplermagrone (Community 1) <-> traditional style pastitsio  ragu (Community 2)
#   - lplermagrone (Community 1) <-> yummy corn cakes (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: macaroni
#   - lplermagrone (Community 1) <-> julia belle s world famous macaroni and cheese (Community 3)
#   - lplermagrone (Community 1) <-> mac and jack and cheese (Community 2)
#   - lplermagrone (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - lplermagrone (Community 1) <-> stove top cream cheese and velveeta mac and cheese (Community 2)
#   - lplermagrone (Community 1) <-> traditional style pastitsio  ragu (Community 2)
#   - alton brown s stove top mac n cheese (Community 3) <-> beer bacon mac and cheese (Community 1)
#   - alton brown s stove top mac n cheese (Community 3) <-> collard greens mac   cheese (Community 1)
#   - alton brown s stove top mac n cheese (Community 3) <-> mac and jack and cheese (Community 2)
#   - alton brown s stove top mac n cheese (Community 3) <-> nif s cajun macaroni and cheese (Community 1)
#   - alton brown s stove top mac n cheese (Community 3) <-> stove top cream cheese and velveeta mac and cheese (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: cornstarch
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> apple pie with cheddar crust (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> apple slab pie (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> classic manapua  steamed buns hawaiian style (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> copycat flying saucer beer cheese soup (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> lavender lemon cupcakes (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> lemon meringue pie easy deep dish (Community 2)
#   - 5 minute general tsos chicken (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - apple pie with cheddar crust (Community 2) <-> cheesy chicken parm volcanos (Community 1)
#   - apple pie with cheddar crust (Community 2) <-> chicken helper   chicken enchilada copycat (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: sugar
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> apple pie with cheddar crust (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> apple slab pie (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> beer cheese stuffed pretzels (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> cheesy jalapeno corn casserole  slow cooker (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> chicago style deep dish sausage pizza   real deep dish (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> chili cheese croissant corndogs (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> classic manapua  steamed buns hawaiian style (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> dark   sumptuous chocolate cake (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: flour
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> apple pie with cheddar crust (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> apple slab pie (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> beer cheese stuffed pretzels (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> cheesy jalapeno corn casserole  slow cooker (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> chicago style deep dish sausage pizza   real deep dish (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> chili cheese croissant corndogs (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> classic manapua  steamed buns hawaiian style (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> copycat flying saucer beer cheese soup (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: water
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> apple pie with cheddar crust (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> apple slab pie (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> beer cheese stuffed pretzels (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> chicago style deep dish sausage pizza   real deep dish (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> chili cheese croissant corndogs (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> classic manapua  steamed buns hawaiian style (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> copycat flying saucer beer cheese soup (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> dark   sumptuous chocolate cake (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> hamburger potpie with homemade crust (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> jalapeno bagels (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: vinegar
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> dark   sumptuous chocolate cake (Community 2)
#   - 5 minute general tsos chicken (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - 5 minute healthy sauted red cabbage (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - artichoke pad thai (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - asian vegetable soup with shrimp (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - balsamic chicken wings (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - beef skewers with cilantro chimichurri (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - best general tso s chicken from serious eats (Community 2) <-> blue ribbon coleslaw (Community 1)
#   - best general tso s chicken from serious eats (Community 2) <-> bourbon chicken   jasmine rice (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: tomato
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> chicago style deep dish sausage pizza   real deep dish (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> sweet corn   tomato galette (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> zaatar pita bread (Community 2)
#   - better than a can  homemade sloppy joes (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - a1 marinated top round with bacon parmesan polenta  a1 (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - a1 marinated top round with bacon parmesan polenta  a1 (Community 1) <-> sweet corn   tomato galette (Community 2)
#   - a1 marinated top round with bacon parmesan polenta  a1 (Community 1) <-> zaatar pita bread (Community 2)
#   - amy truong zucchini low carb lasagna (Community 1) <-> chicago style deep dish sausage pizza   real deep dish (Community 2)
#   - amy truong zucchini low carb lasagna (Community 1) <-> pastitsio  slow cooker (Community 3)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: chili
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> chili cheese croissant corndogs (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> jalapeno bagels (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> warren ohio hot dog shoppe sauce (Community 2)
#   - 4 delicious french fry toppers (Community 1) <-> georgian baked corn casserole (Community 8)
#   - 7 layer elote dip (Community 1) <-> georgian baked corn casserole (Community 8)
#   - beefy chipotle cocoa chili (Community 1) <-> warren ohio hot dog shoppe sauce (Community 2)
#   - berbere spice mix (Community 4) <-> chana punjabi  indian chickpea stew (Community 1)
#   - berbere spice mix (Community 4) <-> cheats crock pot indian pakistani chicken curry   semi authentic (Community 1)
#   - berbere spice mix (Community 4) <-> davies  bourbon chili (Community 1)
#   - berbere spice mix (Community 4) <-> slow cooker pho (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: pork
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> classic manapua  steamed buns hawaiian style (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> leverpostej   danish liver paste (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> welsh dragon pie (Community 3)
#   - asian inspired pulled pork shoulder  for tacos or sliders (Community 1) <-> classic manapua  steamed buns hawaiian style (Community 2)
#   - cabbage lasagna (Community 1) <-> leverpostej   danish liver paste (Community 2)
#   - cabbage rolls with mushroom sauce (Community 1) <-> leverpostej   danish liver paste (Community 2)
#   - cabbage rolls with mushroom sauce (Community 1) <-> welsh dragon pie (Community 3)
#   - chinese style glazed  loin of pork (Community 1) <-> classic manapua  steamed buns hawaiian style (Community 2)
#   - classic manapua  steamed buns hawaiian style (Community 2) <-> filipino lumpia  deep fried pork spring rolls (Community 1)
#   - classic manapua  steamed buns hawaiian style (Community 2) <-> p f chang s shrimp with lobster sauce (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: Paprika
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> onion lover s twist (Community 2)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> warren ohio hot dog shoppe sauce (Community 2)
#   - dorito  popcorn seasoning (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - dorito  popcorn seasoning (Community 1) <-> onion lover s twist (Community 2)
#   - west african s finest  mafe (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - 15 bean soup in the instant pot (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - 15 bean soup in the instant pot (Community 1) <-> onion lover s twist (Community 2)
#   - andouille and chicken gumbo with black eyed peas and greens (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - andouille and chicken gumbo with black eyed peas and greens (Community 1) <-> onion lover s twist (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: beef
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - der wiener schnitzel style chili dog sauce (Community 1) <-> warren ohio hot dog shoppe sauce (Community 2)
#   - better than a can  homemade sloppy joes (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - amazing beef stew (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - argentine chili (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - beef   chickpea paprikash (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - beef   chickpea paprikash (Community 1) <-> warren ohio hot dog shoppe sauce (Community 2)
#   - beef and quinoa stuffed bell peppers (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - belizean meat pies (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - big bend texas style chili (Community 1) <-> enchilada burgers (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: oregano
#   - better than a can  homemade sloppy joes (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - amy truong zucchini low carb lasagna (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - argentine chili (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - baja fish taco (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - baked turkey quinoa meatballs (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - beef and quinoa stuffed bell peppers (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - beefy chipotle cocoa chili (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - big bend texas style chili (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - braised brisket tacos (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - breaded fried steak   milanesa (Community 1) <-> pastitsio  slow cooker (Community 3)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: yeast
#   - dorito  popcorn seasoning (Community 1) <-> onion lover s twist (Community 2)
#   - angel biscuits (Community 2) <-> vegan pizza margherita (Community 1)
#   - apple bread abm (Community 2) <-> spicy lamb meatballs (Community 1)
#   - beer cheese stuffed pretzels (Community 2) <-> skillet margarita pizza (Community 1)
#   - beer cheese stuffed pretzels (Community 2) <-> spicy lamb meatballs (Community 1)
#   - beer cheese stuffed pretzels (Community 2) <-> vegan pizza margherita (Community 1)
#   - birthday cake babka (Community 2) <-> spicy lamb meatballs (Community 1)
#   - chicago style deep dish sausage pizza   real deep dish (Community 2) <-> skillet margarita pizza (Community 1)
#   - chicago style deep dish sausage pizza   real deep dish (Community 2) <-> spicy lamb meatballs (Community 1)
#   - chicago style deep dish sausage pizza   real deep dish (Community 2) <-> vegan pizza margherita (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: chives
#   - ham  solo savory cake (Community 2) <-> buffalo cauliflower sandwich (Community 1)
#   - ham  solo savory cake (Community 2) <-> french onion baked potato soup (Community 1)
#   - ham  solo savory cake (Community 2) <-> one pot bacon mac   cheese (Community 3)
#   - beer bacon mac and cheese (Community 1) <-> chili cheese croissant corndogs (Community 2)
#   - beer bacon mac and cheese (Community 1) <-> culinary quest chive corn muffins (Community 2)
#   - beer bacon mac and cheese (Community 1) <-> dees breakfast melt (Community 2)
#   - beer bacon mac and cheese (Community 1) <-> eggs benedict quiche (Community 2)
#   - beer bacon mac and cheese (Community 1) <-> mac   cheese bacon bites (Community 2)
#   - beer bacon mac and cheese (Community 1) <-> one pot bacon mac   cheese (Community 3)
#   - beer bacon mac and cheese (Community 1) <-> three cheese cupcakes (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: cheddar
#   - ham  solo savory cake (Community 2) <-> chicken helper   chicken enchilada copycat (Community 1)
#   - ham  solo savory cake (Community 2) <-> gwen s old fashioned potato beef casserole  trisha yearwood (Community 3)
#   - ham  solo savory cake (Community 2) <-> ham and cheese frittata (Community 1)
#   - ham  solo savory cake (Community 2) <-> instant pot cheesy ham and potato soup (Community 1)
#   - ham  solo savory cake (Community 2) <-> my homemade cheeseburger mac hamburger helper (Community 1)
#   - ham  solo savory cake (Community 2) <-> one pot bacon mac   cheese (Community 3)
#   - ham  solo savory cake (Community 2) <-> severed hand pies (Community 1)
#   - 4 delicious french fry toppers (Community 1) <-> georgian baked corn casserole (Community 8)
#   - 4 delicious french fry toppers (Community 1) <-> julia belle s world famous macaroni and cheese (Community 3)
#   - a1 cowboy up tart  a1 (Community 1) <-> cheesy jalapeno corn casserole  slow cooker (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: egg
#   - ham  solo savory cake (Community 2) <-> creamy turkey soup with homemade noodles (Community 1)
#   - ham  solo savory cake (Community 2) <-> mac n cheese (Community 1)
#   - ham  solo savory cake (Community 2) <-> orange chicken dino nuggets (Community 1)
#   - ham  solo savory cake (Community 2) <-> savory breakfast tart (Community 1)
#   - ham  solo savory cake (Community 2) <-> severed hand pies (Community 1)
#   - 1 minute breakfast sandwich (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - 1 minute breakfast sandwich (Community 1) <-> decadent a1 swirl corn muffins  a1 (Community 2)
#   - 1 minute breakfast sandwich (Community 1) <-> eggs benedict quiche (Community 2)
#   - 1 minute breakfast sandwich (Community 1) <-> ham   spaghetti casserole (Community 2)
#   - 1 minute breakfast sandwich (Community 1) <-> traditional style pastitsio  ragu (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: ham
#   - ham  solo savory cake (Community 2) <-> ham and cheese frittata (Community 1)
#   - ham  solo savory cake (Community 2) <-> instant pot cheesy ham and potato soup (Community 1)
#   - collard greens mac   cheese (Community 1) <-> ham   spaghetti casserole (Community 2)
#   - creamy ham and gnocchi bake (Community 1) <-> ham   spaghetti casserole (Community 2)
#   - creamy ham and gnocchi bake (Community 1) <-> herbed biscuit ham sandwiches (Community 2)
#   - ham   spaghetti casserole (Community 2) <-> instant pot cheesy ham and potato soup (Community 1)
#   - ham   spaghetti casserole (Community 2) <-> sizzler s malibu chicken (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: Gruyere
#   - ham  solo savory cake (Community 2) <-> savory breakfast tart (Community 1)
#   - austrian kaesespaetzle  cheese spaetzle (Community 1) <-> zuppa di cipolla al vino rosso (Community 2)
#   - savory breakfast tart (Community 1) <-> zuppa di cipolla al vino rosso (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: peanut oil
#   - west african s finest  mafe (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - west african s finest  mafe (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - best general tso s chicken from serious eats (Community 2) <-> gulai sayur  collard greens curry indonesian style (Community 1)
#   - best general tso s chicken from serious eats (Community 2) <-> hainanese chicken and rice  instant pot (Community 1)
#   - best general tso s chicken from serious eats (Community 2) <-> p f chang s beef a la sichuan (Community 1)
#   - best general tso s chicken from serious eats (Community 2) <-> p f chang s lo mein (Community 1)
#   - best general tso s chicken from serious eats (Community 2) <-> vietnamese bun cha gio (Community 1)
#   - chicken in red curry and coconut (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - copycat chick fil a spicy deluxe chicken sandwich (Community 2) <-> gulai sayur  collard greens curry indonesian style (Community 1)
#   - copycat chick fil a spicy deluxe chicken sandwich (Community 2) <-> hainanese chicken and rice  instant pot (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: rice
#   - west african s finest  mafe (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - 5 minute general tsos chicken (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - afghan kabuli pulao (Community 1) <-> gluten free dairy free almond poppy seed muffins (Community 2)
#   - andouille and chicken gumbo with black eyed peas and greens (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - artichoke pad thai (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - asian chicken meatball   rice noodle soup (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - beecher s kale and brown rice gratin with smoked cheese (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - beecher s kale and brown rice gratin with smoked cheese (Community 1) <-> pumpkin pancakes  gluten free (Community 2)
#   - best copycat benihana japanese chicken rice (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - best general tso s chicken from serious eats (Community 2) <-> bourbon chicken   jasmine rice (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: potato
#   - west african s finest  mafe (Community 1) <-> hamburger potpie with homemade crust (Community 2)
#   - a 1  slow roasted shredded steak with polenta  a1 (Community 1) <-> gwen s old fashioned potato beef casserole  trisha yearwood (Community 3)
#   - a 1  slow roasted shredded steak with polenta  a1 (Community 1) <-> hamburger potpie with homemade crust (Community 2)
#   - a 1  slow roasted shredded steak with polenta  a1 (Community 1) <-> pioneer woman soul sweet taters (Community 2)
#   - a 1  slow roasted shredded steak with polenta  a1 (Community 1) <-> pumpkin pancakes  gluten free (Community 2)
#   - a 1  slow roasted shredded steak with polenta  a1 (Community 1) <-> the turducken of thanksgiving sides (Community 2)
#   - amazing beef stew (Community 1) <-> gwen s old fashioned potato beef casserole  trisha yearwood (Community 3)
#   - amazing beef stew (Community 1) <-> hamburger potpie with homemade crust (Community 2)
#   - arby s oven baked curly fries (Community 1) <-> gwen s old fashioned potato beef casserole  trisha yearwood (Community 3)
#   - arby s oven baked curly fries (Community 1) <-> hamburger potpie with homemade crust (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: carrot
#   - west african s finest  mafe (Community 1) <-> hamburger potpie with homemade crust (Community 2)
#   - 15 bean soup in the instant pot (Community 1) <-> hamburger potpie with homemade crust (Community 2)
#   - a yummy chicken noodle soup  8 qt  pressure cooker (Community 1) <-> hamburger potpie with homemade crust (Community 2)
#   - amazing beef stew (Community 1) <-> hamburger potpie with homemade crust (Community 2)
#   - asian vegetable soup with shrimp (Community 1) <-> hamburger potpie with homemade crust (Community 2)
#   - beef and barley soup with wils mushrooms (Community 1) <-> hamburger potpie with homemade crust (Community 2)
#   - best copycat benihana japanese chicken rice (Community 1) <-> hamburger potpie with homemade crust (Community 2)
#   - blue ribbon coleslaw (Community 1) <-> hamburger potpie with homemade crust (Community 2)
#   - booyah the soup (Community 1) <-> hamburger potpie with homemade crust (Community 2)
#   - braised brisket tacos (Community 1) <-> hamburger potpie with homemade crust (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: tomatoes
#   - 1 minute breakfast sandwich (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - 1 minute breakfast sandwich (Community 1) <-> decadent a1 swirl corn muffins  a1 (Community 2)
#   - 1 minute breakfast sandwich (Community 1) <-> mac and jack and cheese (Community 2)
#   - a1 cowboy up tart  a1 (Community 1) <-> decadent a1 swirl corn muffins  a1 (Community 2)
#   - amy truong zucchini low carb lasagna (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - amy truong zucchini low carb lasagna (Community 1) <-> sweet corn   tomato galette (Community 2)
#   - argentinian steak sandwiches (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - authentic thai red curry with chicken (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - baked chicken parmigiano (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - baked rice with cheese and tomatoes (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: bacon
#   - 1 minute breakfast sandwich (Community 1) <-> eggs benedict quiche (Community 2)
#   - a1 marinated top round with bacon parmesan polenta  a1 (Community 1) <-> eggs benedict quiche (Community 2)
#   - a1 marinated top round with bacon parmesan polenta  a1 (Community 1) <-> one pot bacon mac   cheese (Community 3)
#   - a1b bacon burger bites on white polenta cakes  a1 (Community 1) <-> one pot bacon mac   cheese (Community 3)
#   - bacon wrapped coconut quiche and coconut popcorn shrimp (Community 2) <-> everything bagel tortellini (Community 3)
#   - bacon wrapped coconut quiche and coconut popcorn shrimp (Community 2) <-> seaside stuffed shells alfredo  ragu (Community 3)
#   - bacon kissed cauliflower dip w  crispy corn tortillas  ragu (Community 1) <-> one pot bacon mac   cheese (Community 3)
#   - bacon kissed cauliflower dip w  crispy corn tortillas  ragu (Community 1) <-> seaside stuffed shells alfredo  ragu (Community 3)
#   - baconfredo (Community 1) <-> one pot bacon mac   cheese (Community 3)
#   - baconfredo (Community 1) <-> seaside stuffed shells alfredo  ragu (Community 3)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: lemon
#   - 15 bean soup in the instant pot (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - 4 delicious french fry toppers (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - a 1  slow roasted shredded steak with polenta  a1 (Community 1) <-> apple pie with cheddar crust (Community 2)
#   - a 1  slow roasted shredded steak with polenta  a1 (Community 1) <-> betty crocker s salmon loaf (Community 2)
#   - a 1  slow roasted shredded steak with polenta  a1 (Community 1) <-> blackberry mini muffins or mini cupcakes   you decide (Community 2)
#   - a 1  slow roasted shredded steak with polenta  a1 (Community 1) <-> blueberry cheesecake crumb cake (Community 2)
#   - a 1  slow roasted shredded steak with polenta  a1 (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - a 1  slow roasted shredded steak with polenta  a1 (Community 1) <-> cornmeal rye waffles (Community 2)
#   - a 1  slow roasted shredded steak with polenta  a1 (Community 1) <-> eggs benedict quiche (Community 2)
#   - a 1  slow roasted shredded steak with polenta  a1 (Community 1) <-> juicy grilled thin cut pork chops (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: olive oil
#   - 15 bean soup in the instant pot (Community 1) <-> rosemary and toasted onion bread  bread machine dough (Community 2)
#   - a 1  pot stickers with chili pineapple dipping sauce  a1 (Community 1) <-> rosemary and toasted onion bread  bread machine dough (Community 2)
#   - a1 marinated top round with bacon parmesan polenta  a1 (Community 1) <-> good seed bread (Community 2)
#   - a1 marinated top round with bacon parmesan polenta  a1 (Community 1) <-> zaatar pita bread (Community 2)
#   - amy truong zucchini low carb lasagna (Community 1) <-> rosemary and toasted onion bread  bread machine dough (Community 2)
#   - andouille and chicken gumbo with black eyed peas and greens (Community 1) <-> rosemary and toasted onion bread  bread machine dough (Community 2)
#   - baked sea bass with vegetables (Community 1) <-> rosemary and toasted onion bread  bread machine dough (Community 2)
#   - beecher s kale and brown rice gratin with smoked cheese (Community 1) <-> rosemary and toasted onion bread  bread machine dough (Community 2)
#   - beef skewers with cilantro chimichurri (Community 1) <-> rosemary and toasted onion bread  bread machine dough (Community 2)
#   - beefy chipotle cocoa chili (Community 1) <-> rosemary and toasted onion bread  bread machine dough (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: oil
#   - 2 minute microwave brownie in a mug (Community 2) <-> beer battered fish tacos with pickled onion and cucumber (Community 1)
#   - 2 minute microwave brownie in a mug (Community 2) <-> orange chicken dino nuggets (Community 1)
#   - 2 minute eggless microwave chocolate cake (Community 2) <-> orange chicken dino nuggets (Community 1)
#   - 2 minute eggless microwave chocolate cake (Community 2) <-> spicy lamb meatballs (Community 1)
#   - a 1 steak puffs with corn and avocado salsa  a1 (Community 1) <-> battered chicken tenders (Community 2)
#   - a 1 steak puffs with corn and avocado salsa  a1 (Community 1) <-> bratwurst wraps with onion sauerkraut filling (Community 2)
#   - a 1 steak puffs with corn and avocado salsa  a1 (Community 1) <-> fingers fried chicken (Community 2)
#   - a 1 steak puffs with corn and avocado salsa  a1 (Community 1) <-> gwen s old fashioned potato beef casserole  trisha yearwood (Community 3)
#   - a 1 steak puffs with corn and avocado salsa  a1 (Community 1) <-> momaphet s cilantro lime cornbread (Community 2)
#   - a 1 steak puffs with corn and avocado salsa  a1 (Community 1) <-> sweet potato   black bean burgers (Community 3)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: cream
#   - 3 layer chocolate cake with chocolate mousse filling  gluten fre (Community 2) <-> chicken friand  tourte au poulet et champignons (Community 1)
#   - 3 layer chocolate cake with chocolate mousse filling  gluten fre (Community 2) <-> creme de volaille  french cream of chicken soup (Community 1)
#   - 3 layer chocolate cake with chocolate mousse filling  gluten fre (Community 2) <-> savory breakfast tart (Community 1)
#   - amish triple butter biscuits (Community 2) <-> chicken friand  tourte au poulet et champignons (Community 1)
#   - amish triple butter biscuits (Community 2) <-> creme de volaille  french cream of chicken soup (Community 1)
#   - amish triple butter biscuits (Community 2) <-> savory breakfast tart (Community 1)
#   - apple pie with cheddar crust (Community 2) <-> blue ribbon coleslaw (Community 1)
#   - apple pie with cheddar crust (Community 2) <-> chicken friand  tourte au poulet et champignons (Community 1)
#   - apple pie with cheddar crust (Community 2) <-> chicken pot pie for two  cook s country (Community 1)
#   - apple pie with cheddar crust (Community 2) <-> creme de volaille  french cream of chicken soup (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: eggs
#   - 3 layer chocolate cake with chocolate mousse filling  gluten fre (Community 2) <-> orange chicken dino nuggets (Community 1)
#   - almond flour blueberry muffins best ever (Community 2) <-> orange chicken dino nuggets (Community 1)
#   - almond flour blueberry muffins best ever (Community 2) <-> oriental chicken salad with honey sesame dressing (Community 1)
#   - almond milk pancakes (Community 2) <-> orange chicken dino nuggets (Community 1)
#   - alton brown s stove top mac n cheese (Community 3) <-> breakfast taquitos (Community 1)
#   - alton brown s stove top mac n cheese (Community 3) <-> cheesy jalapeno corn casserole  slow cooker (Community 2)
#   - alton brown s stove top mac n cheese (Community 3) <-> corned beef hash frittata (Community 1)
#   - alton brown s stove top mac n cheese (Community 3) <-> eggs benedict quiche (Community 2)
#   - alton brown s stove top mac n cheese (Community 3) <-> loaded breakfast potatoes (Community 1)
#   - alton brown s stove top mac n cheese (Community 3) <-> nest egg pie (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: sour cream
#   - 4 delicious french fry toppers (Community 1) <-> georgian baked corn casserole (Community 8)
#   - 7 layer elote dip (Community 1) <-> georgian baked corn casserole (Community 8)
#   - best ever green bean casserole  no canned soup (Community 2) <-> better than del taco chicken soft tacos (Community 1)
#   - best ever green bean casserole  no canned soup (Community 2) <-> buffalo cauliflower chili   crock pot (Community 1)
#   - best ever green bean casserole  no canned soup (Community 2) <-> butternut squash soup with bacon and cheddar (Community 1)
#   - best ever green bean casserole  no canned soup (Community 2) <-> chicken  spinach and cannellini bean quesadillas (Community 1)
#   - best ever green bean casserole  no canned soup (Community 2) <-> curried chicken moghlai (Community 1)
#   - best ever green bean casserole  no canned soup (Community 2) <-> gorky s chicken (Community 1)
#   - best ever green bean casserole  no canned soup (Community 2) <-> gryby w smetanye  mushrooms with sour cream (Community 1)
#   - best ever green bean casserole  no canned soup (Community 2) <-> kick n chunky chicken tortilla soup (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: parmesan
#   - 4 delicious french fry toppers (Community 1) <-> julia belle s world famous macaroni and cheese (Community 3)
#   - 4 delicious french fry toppers (Community 1) <-> traditional style pastitsio  ragu (Community 2)
#   - a 1  slow roasted shredded steak with polenta  a1 (Community 1) <-> julia belle s world famous macaroni and cheese (Community 3)
#   - a 1  slow roasted shredded steak with polenta  a1 (Community 1) <-> onion lover s twist (Community 2)
#   - a 1  slow roasted shredded steak with polenta  a1 (Community 1) <-> polenta pasticciata  ragu (Community 3)
#   - a 1  slow roasted shredded steak with polenta  a1 (Community 1) <-> traditional style pastitsio  ragu (Community 2)
#   - a1 marinated top round with bacon parmesan polenta  a1 (Community 1) <-> julia belle s world famous macaroni and cheese (Community 3)
#   - a1 marinated top round with bacon parmesan polenta  a1 (Community 1) <-> onion lover s twist (Community 2)
#   - a1 marinated top round with bacon parmesan polenta  a1 (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - a1 marinated top round with bacon parmesan polenta  a1 (Community 1) <-> three cheese cupcakes (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: parsley
#   - 4 delicious french fry toppers (Community 1) <-> traditional style pastitsio  ragu (Community 2)
#   - a yummy chicken noodle soup  8 qt  pressure cooker (Community 1) <-> traditional style pastitsio  ragu (Community 2)
#   - apple  honey   caramelized onion flatbread pizza (Community 1) <-> traditional style pastitsio  ragu (Community 2)
#   - austrian kaesespaetzle  cheese spaetzle (Community 1) <-> traditional style pastitsio  ragu (Community 2)
#   - baked sea bass with vegetables (Community 1) <-> traditional style pastitsio  ragu (Community 2)
#   - baked turkey meatballs (Community 1) <-> traditional style pastitsio  ragu (Community 2)
#   - baked turkey quinoa meatballs (Community 1) <-> traditional style pastitsio  ragu (Community 2)
#   - baklava salmon with asparagus (Community 1) <-> herbed biscuit ham sandwiches (Community 2)
#   - bean and bell pepper salad (Community 1) <-> traditional style pastitsio  ragu (Community 2)
#   - beef and barley soup with wils mushrooms (Community 1) <-> traditional style pastitsio  ragu (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: chicken
#   - 5 minute general tsos chicken (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - a yummy chicken noodle soup  8 qt  pressure cooker (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - a yummy chicken noodle soup  8 qt  pressure cooker (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - a yummy chicken noodle soup  8 qt  pressure cooker (Community 1) <-> fingers fried chicken (Community 2)
#   - andouille and chicken gumbo with black eyed peas and greens (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - andouille and chicken gumbo with black eyed peas and greens (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - andouille and chicken gumbo with black eyed peas and greens (Community 1) <-> fingers fried chicken (Community 2)
#   - asian chicken meatball   rice noodle soup (Community 1) <-> battered chicken tenders (Community 2)
#   - asian chicken meatball   rice noodle soup (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - asian chicken meatball   rice noodle soup (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: scallion
#   - 5 minute general tsos chicken (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - a 1  chinese pasta  a1 (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - a1 marinated top round with bacon parmesan polenta  a1 (Community 1) <-> beer cheese stuffed pretzels (Community 2)
#   - a1 marinated top round with bacon parmesan polenta  a1 (Community 1) <-> eggs benedict quiche (Community 2)
#   - a1 marinated top round with bacon parmesan polenta  a1 (Community 1) <-> everything bagel rugelach (Community 2)
#   - asian chicken meatball   rice noodle soup (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - asian chicken meatball   rice noodle soup (Community 1) <-> everything bagel rugelach (Community 2)
#   - beer cheese stuffed pretzels (Community 2) <-> cheesy jalapeo popper pull apart bread (Community 1)
#   - beer cheese stuffed pretzels (Community 2) <-> chicken vol au vent with tomato mango relish  a1 (Community 1)
#   - beer cheese stuffed pretzels (Community 2) <-> lazy days restaurant fish with key lime butter sauce (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: ginger
#   - 5 minute general tsos chicken (Community 1) <-> best general tso s chicken from serious eats (Community 2)
# ...
#
# Ingredient: spinach
#   - butternut squash  spinach   goat cheese pie (Community 1) <-> spaghetti squash boats  ragu (Community 3)
#   - saucy tortellini and meatball soup  a1 (Community 1) <-> spaghetti squash boats  ragu (Community 3)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: pineapple
#   - carrot cake with pineapple (Community 2) <-> coconut shrimp pizza (Community 1)
#   - carrot cake with pineapple (Community 2) <-> pei wei asian diner caramel chicken (Community 1)
#   - carrot cake with pineapple (Community 2) <-> pork chop with sweet potato and pineapple (Community 1)
#   - delicious gluten free carrot cake (Community 2) <-> pork chop with sweet potato and pineapple (Community 1)
#   - dorothy s cranberry bread (Community 2) <-> saucy chickenaloha  a1 (Community 1)
#   - korean bbq chicken thighs  a1 (Community 1) <-> valentines day recipe (Community 2)
#   - pei wei asian diner caramel chicken (Community 1) <-> valentines day recipe (Community 2)
#   - saucy chickenaloha  a1 (Community 1) <-> taiwanese pineapple cakes (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: walnut
#   - carrot cake with pineapple (Community 2) <-> open face bacon jam and egg sandwich  a1 (Community 1)
#   - chocolate peanut butter globs (Community 2) <-> open face bacon jam and egg sandwich  a1 (Community 1)
#   - easy apple dump cake   from scratch (Community 2) <-> open face bacon jam and egg sandwich  a1 (Community 1)
#   - frosted cookie brownies (Community 2) <-> open face bacon jam and egg sandwich  a1 (Community 1)
#   - margarida s broiler cake (Community 2) <-> open face bacon jam and egg sandwich  a1 (Community 1)
#   - old world yugoslavian coffee cake (Community 2) <-> open face bacon jam and egg sandwich  a1 (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: chipotle
#   - cauliflower tacos (Community 1) <-> momaphet s cilantro lime cornbread (Community 2)
#   - coffee chipotle pork chops (Community 1) <-> momaphet s cilantro lime cornbread (Community 2)
#   - lets talk turkey  burgers with chipotle mayo   a1 (Community 1) <-> momaphet s cilantro lime cornbread (Community 2)
#   - momaphet s cilantro lime cornbread (Community 2) <-> paleo chipotle chicken cauliflower bake (Community 1)
#   - momaphet s cilantro lime cornbread (Community 2) <-> smooth smoking spicy salsa (Community 1)
#   - momaphet s cilantro lime cornbread (Community 2) <-> stuffed baby bell peppers (Community 1)
#   - momaphet s cilantro lime cornbread (Community 2) <-> ultimate black bean soup stew with chorizo and braised chicken (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: spray
#   - chicago style deep dish sausage pizza   real deep dish (Community 2) <-> katel s tweaked world s best lasagna (Community 1)
#   - chicago style deep dish sausage pizza   real deep dish (Community 2) <-> taco bell style crunch wrap supreme (Community 1)
#   - royal crown strawberry pie (Community 2) <-> taco bell style crunch wrap supreme (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: rosemary
#   - chicken roast garlic pasta (Community 1) <-> rosemary and toasted onion bread  bread machine dough (Community 2)
#   - creamy vegan tomato sauce (Community 1) <-> rosemary and toasted onion bread  bread machine dough (Community 2)
#   - garlic baked brie spider (Community 1) <-> rosemary and toasted onion bread  bread machine dough (Community 2)
#   - instant pot pork chop (Community 1) <-> rosemary and toasted onion bread  bread machine dough (Community 2)
#   - linguine with honey sauced prawns (Community 1) <-> rosemary and toasted onion bread  bread machine dough (Community 2)
#   - puff pastry chicken pot pie (Community 1) <-> rosemary and toasted onion bread  bread machine dough (Community 2)
#   - roasted pork tenderloin with cajun cornbread stuffing (Community 1) <-> rosemary and toasted onion bread  bread machine dough (Community 2)
#   - rosemary and toasted onion bread  bread machine dough (Community 2) <-> sheet pan chicken dinner (Community 1)
#   - rosemary and toasted onion bread  bread machine dough (Community 2) <-> soma sengupta easter recipes  spring pea soup  a great start to (Community 1)
#   - rosemary and toasted onion bread  bread machine dough (Community 2) <-> stove top pot roast with gravy  potatoes and carrots (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: seasoning
#   - chicken  bacon alfredo bread boat (Community 1) <-> pepperoni pizza football cheese ball (Community 3)
#   - creamy turkey soup with homemade noodles (Community 1) <-> everything bagel tortellini (Community 3)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: buttermilk
#   - chipotle agave chicken wings (Community 1) <-> momaphet s cilantro lime cornbread (Community 2)
#   - chipotle popcorn chicken (Community 1) <-> momaphet s cilantro lime cornbread (Community 2)
#   - cornmeal crusted oven fried chicken (Community 1) <-> lemon rose bundt cake (Community 2)
#   - cornmeal crusted oven fried chicken (Community 1) <-> ma s cornbread re make (Community 2)
#   - cornmeal crusted oven fried chicken (Community 1) <-> panera bread style cobblestone muffins (Community 2)
#   - cornmeal crusted oven fried chicken (Community 1) <-> peach cobbler ice cream cake (Community 2)
#   - cornmeal crusted oven fried chicken (Community 1) <-> pielogen (Community 2)
#   - cornmeal crusted oven fried chicken (Community 1) <-> spicy corn muffins with irish cheddar cheese (Community 2)
#   - cornmeal crusted oven fried chicken (Community 1) <-> yummy corn cakes (Community 2)
#   - flaky layer biscuits (Community 2) <-> melt in your mouth chicken casserole with biscuit topping (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: crema
#   - chipotle agave chicken wings (Community 1) <-> snapper in a poblano chile sauce (Community 3)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: chocolate
#   - choc chilli sauce (Community 1) <-> dark   sumptuous chocolate cake (Community 2)
#   - choc chilli sauce (Community 1) <-> hocus pocus cottage cake (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: vanilla
#   - choc chilli sauce (Community 1) <-> hocus pocus cottage cake (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: ricotta
#   - chocolate eggnog cannoli (Community 2) <-> katel s tweaked world s best lasagna (Community 1)
#   - pepperoni pizza lasagna rolls (Community 1) <-> sweet corn   tomato galette (Community 2)
#   - portuguese baked eggs with chorizo and ricotta (Community 1) <-> sweet corn   tomato galette (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: half-and-half
#   - chris  cinnamon rolls (Community 2) <-> nif s cajun macaroni and cheese (Community 1)
#   - chris  cinnamon rolls (Community 2) <-> pastitsio  slow cooker (Community 3)
#   - copycat flying saucer beer cheese soup (Community 2) <-> nif s cajun macaroni and cheese (Community 1)
#   - cream filled peach cookies (Community 2) <-> nif s cajun macaroni and cheese (Community 1)
#   - creamy chicken and kale tortellini soup (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - nif s cajun macaroni and cheese (Community 1) <-> pastitsio  slow cooker (Community 3)
#   - pastitsio  slow cooker (Community 3) <-> spinach  brie   bacon mini quiche (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: spice
#   - cider   5 spice bundt cake (Community 2) <-> red stripe chicken (Community 1)
#   - corned beef brisket w  veggies   horseradish pressure cooker (Community 1) <-> spiced beets  refrigerater pickles (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: crust
#   - cinnamon roll cream pie (Community 2) <-> severed hand pies (Community 1)
#   - pielogen (Community 2) <-> severed hand pies (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: arugula
#   - circle around sausage minestrone  ragu (Community 1) <-> polenta pasticciata  ragu (Community 3)
#   - polenta pasticciata  ragu (Community 3) <-> roasted shrimp and tomatoes with roasted garlic parmesan  ragu (Community 1)
#   - polenta pasticciata  ragu (Community 3) <-> warm shrimp nest salad  ragu (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: oyster
#   - classic manapua  steamed buns hawaiian style (Community 2) <-> filet mignon (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: coffee
#   - coffee chipotle pork chops (Community 1) <-> pumpkin spice latte cake (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: Pickle
#   - copycat chick fil a spicy deluxe chicken sandwich (Community 2) <-> quick cheeseburger pie  gold medal (Community 1)
#   - quaker steak and lube pick up pickles (Community 2) <-> quick cheeseburger pie  gold medal (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: Velveeta
#   - copycat flying saucer beer cheese soup (Community 2) <-> incredible cheesy broccoli soup   weight watchers (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: fish
#   - crawfish or shrimp bisque (Community 1) <-> snapper in a poblano chile sauce (Community 3)
#   - lazy days restaurant fish with key lime butter sauce (Community 1) <-> snapper in a poblano chile sauce (Community 3)
#   - pei wei asian diner caramel chicken (Community 1) <-> snapper in a poblano chile sauce (Community 3)
#   - snapper in a poblano chile sauce (Community 3) <-> vietnamese chicken liver pate (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: clove
#   - creme de volaille  french cream of chicken soup (Community 1) <-> leverpostej   danish liver paste (Community 2)
#   - creme de volaille  french cream of chicken soup (Community 1) <-> pumpkin pancakes  gluten free (Community 2)
#   - pumpkin pancakes  gluten free (Community 2) <-> slow cooker pho (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: taco
#   - doritos taco casserole (Community 1) <-> salsa stuffed peppers (Community 7)
#   - one pot taco pasta (Community 1) <-> salsa stuffed peppers (Community 7)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: turkey
#   - doritos taco casserole (Community 1) <-> salsa stuffed peppers (Community 7)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: orange
#   - dorothy s cranberry bread (Community 2) <-> orange chicken dino nuggets (Community 1)
#   - giant cinnamon roll with blood orange glaze (Community 2) <-> orange chicken dino nuggets (Community 1)
#   - giant cinnamon roll with blood orange glaze (Community 2) <-> persian rice with cinnamon  pistachios and golden raisins (Community 1)
#   - habanero and orange chocolate chip cookies (Community 2) <-> orange chicken dino nuggets (Community 1)
#   - orange chicken dino nuggets (Community 1) <-> orange french toast (Community 2)
#   - orange chicken dino nuggets (Community 1) <-> swans down orange coconut cake (Community 2)
#   - orange chicken dino nuggets (Community 1) <-> three cheese cupcakes (Community 2)
#   - orange chicken dino nuggets (Community 1) <-> valentines day recipe (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: baguette
#   - french onion soup ii (Community 1) <-> zuppa di cipolla al vino rosso (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: pickle
#   - fried chicken sandwich with hot honey (Community 1) <-> herbed biscuit ham sandwiches (Community 2)
#   - fried chicken sandwich with hot honey (Community 1) <-> mini chicken breast sliders (Community 3)
#   - fried chicken sandwich with hot honey (Community 1) <-> quaker steak and lube pick up pickles (Community 2)
#   - quaker steak and lube pick up pickles (Community 2) <-> quick cheeseburger pie  gold medal (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: meat
#   - gheyme (Community 1) <-> hamburger potpie with homemade crust (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: spaghetti
#   - ham   spaghetti casserole (Community 2) <-> spaghetti and turkey meatballs (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: mirin
#   - home style sushi over rice  chirashizushi (Community 1) <-> valentines day recipe (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: adobo
#   - instant pot turkey chili (Community 1) <-> sweet potato   black bean burgers (Community 3)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: gelatin
#   - milk   cookie cups (Community 2) <-> welsh dragon pie (Community 3)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: mint
#   - moroccan carrots (Community 2) <-> quinoa with winter squash and carrot stew (Community 1)
#   - pei wei asian diner caramel chicken (Community 1) <-> valentines day recipe (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: Lard
#   - pork carnitas (Community 1) <-> welsh dragon pie (Community 3)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: powder
#   - quaker steak and lube pick up pickles (Community 2) <-> taco bell style crunch wrap supreme (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: peas
#   - quick chicken and dumplings (Community 1) <-> tuna noodle broccoli casserole (Community 2)
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## What are the most versatile or influential recipes based on their graph connectivity?

# %%
def compute_centralities(graph):
    degree_centrality = nx.degree_centrality(graph)
    betweenness_centrality = nx.betweenness_centrality(graph)
    closeness_centrality = nx.closeness_centrality(graph)
    eigenvector_centrality = nx.eigenvector_centrality(graph)
    
    return {
        'degree': degree_centrality,
        'betweenness': betweenness_centrality,
        'closeness': closeness_centrality,
        'eigenvector': eigenvector_centrality
    }

def get_top_recipes(graph, centralities, centrality_type='degree', top_n=10):
    if centrality_type not in centralities:
        raise ValueError("Invalid centrality type. Choose from ['degree', 'betweenness', 'closeness', 'eigenvector']")
    
    sorted_centralities = sorted(centralities[centrality_type].items(), key=lambda x: x[1], reverse=True)
    sorted_centralities = [(graph.nodes[node]['name'], centrality) for node, centrality in sorted_centralities]
    return sorted_centralities[:top_n] 



def get_top_recipes_by_frequency(graph, centralities, top_n=5):
    all_top_recipes = []
    
    for centrality_type in ['degree', 'betweenness', 'closeness', 'eigenvector']:
        top_recipes = get_top_recipes(graph, centralities, centrality_type=centrality_type, top_n=top_n)
        all_top_recipes.extend([recipe[0] for recipe in top_recipes]) 
    
    recipe_counts = Counter(all_top_recipes)
    
    top_recipes_by_frequency = recipe_counts.most_common(top_n)
    
    return top_recipes_by_frequency

# %%
def centralities_info(graph, graph_name):
    
    centralities = compute_centralities(graph)
    print(f"Centralities for {graph_name}: {centralities}")

    top_recipes_by_frequency = get_top_recipes_by_frequency(graph, centralities, top_n=5)
    print(f"Top Recipes by Frequency across Centralities in {graph_name}:")
    for recipe, count in top_recipes_by_frequency:
        print(f"{recipe}: {count} times")

# %%
centralities_info(recipes_graph, "Recipe network with min. 5 common ingredients")
# Out:
# Centralities for Recipe network with min. 5 common ingredients: {'degree': {'522861': 0.06018518518518518, '523359': 0.21006944444444442, '513531': 0.08738425925925926, '535020': 0.003472222222222222, '519068': 0.07349537037037036, '535431': 0.03298611111111111, '532472': 0.14872685185185183, '533190': 0.016203703703703703, '531143': 0.004050925925925926, '525649': 0.2228009259259259, '531148': 0.013888888888888888, '517511': 0.03298611111111111, '513216': 0.04398148148148148, '516214': 0.03009259259259259, '520809': 0.14525462962962962, '531161': 0.034722222222222224, '513291': 0.06886574074074074, '531144': 0.04050925925925926, '514206': 0.08159722222222222, '535021': 0.08391203703703703, '516267': 0.21354166666666666, '518146': 0.001736111111111111, '517683': 0.08969907407407407, '518176': 0.07233796296296297, '518068': 0.02025462962962963, '517702': 0.011574074074074073, '518151': 0.17592592592592593, '518145': 0.15104166666666666, '518143': 0.009259259259259259, '518234': 0.078125, '518192': 0.01099537037037037, '518230': 0.004050925925925926, '517863': 0.03009259259259259, '532656': 0.015046296296296295, '526265': 0.010416666666666666, '512943': 0.011574074074074073, '524790': 0.0005787037037037037, '530305': 0.012152777777777776, '517847': 0.028935185185185182, '522117': 0.04398148148148148, '516687': 0.003472222222222222, '535371': 0.07233796296296297, '519547': 0.01273148148148148, '511753': 0.001736111111111111, '526984': 0.06770833333333333, '515787': 0.0, '512375': 0.004050925925925926, '522989': 0.010416666666666666, '521731': 0.016782407407407406, '512051': 0.09606481481481481, '534722': 0.02372685185185185, '515019': 0.011574074074074073, '512939': 0.011574074074074073, '526764': 0.019675925925925923, '536322': 0.0, '518120': 0.08738425925925926, '536384': 0.10706018518518517, '521585': 0.1892361111111111, '512771': 0.19849537037037035, '517082': 0.05092592592592592, '517983': 0.0, '513805': 0.0005787037037037037, '512207': 0.06712962962962962, '512016': 0.018518518518518517, '528546': 0.021412037037037035, '512109': 0.004629629629629629, '534000': 0.10648148148148148, '517371': 0.01909722222222222, '528058': 0.09780092592592592, '518669': 0.04398148148148148, '521251': 0.004629629629629629, '524289': 0.0005787037037037037, '512773': 0.0, '532924': 0.0011574074074074073, '520120': 0.017361111111111112, '529216': 0.0011574074074074073, '514145': 0.07870370370370369, '536318': 0.13425925925925924, '517347': 0.0011574074074074073, '536401': 0.1105324074074074, '536044': 0.0, '512720': 0.07696759259259259, '528358': 0.10011574074074074, '520016': 0.10821759259259259, '515833': 0.09259259259259259, '516981': 0.008101851851851851, '518223': 0.0, '512372': 0.001736111111111111, '520940': 0.07060185185185185, '512747': 0.05150462962962963, '516015': 0.03587962962962963, '513298': 0.02488425925925926, '532422': 0.057291666666666664, '523334': 0.02546296296296296, '512041': 0.05555555555555555, '530683': 0.0005787037037037037, '529506': 0.0, '515352': 0.008680555555555556, '517715': 0.016203703703703703, '525001': 0.046296296296296294, '536583': 0.0, '533950': 0.0, '527202': 0.0, '523538': 0.005787037037037037, '512716': 0.0, '536564': 0.004629629629629629, '513221': 0.001736111111111111, '516718': 0.0011574074074074073, '524716': 0.11342592592592592, '513094': 0.08333333333333333, '530386': 0.02546296296296296, '514211': 0.10763888888888888, '516897': 0.02662037037037037, '535581': 0.10532407407407407, '520110': 0.1273148148148148, '533718': 0.08738425925925926, '513817': 0.024305555555555552, '533649': 0.0, '518070': 0.061921296296296294, '513941': 0.15335648148148148, '515852': 0.023148148148148147, '530364': 0.017939814814814815, '528861': 0.009837962962962962, '522710': 0.09027777777777778, '529772': 0.057291666666666664, '512106': 0.03356481481481481, '524817': 0.020833333333333332, '532486': 0.19328703703703703, '537076': 0.023148148148148147, '520337': 0.017361111111111112, '515814': 0.11516203703703703, '517798': ...
# Top Recipes by Frequency across Centralities in Recipe network with min. 5 common ingredients:
# spicy lamb meatballs: 4 times
# orange chicken dino nuggets: 4 times
# copycat chick fil a spicy deluxe chicken sandwich: 3 times
# kick n chunky chicken tortilla soup: 2 times
# mix   match chicken soup: 2 times

# %%
def plot_centrality_distributions(df, graph_name):
    centrality_types = ['degree', 'closeness', 'betweenness', 'eigenvector']
    titles = [
        'Degree Centrality',
        'Closeness Centrality',
        'Betweenness Centrality',
        'Eigenvector Centrality'
    ]

    fig, axes = plt.subplots(1, 4, figsize=(20, 5))

    for ax, centrality_type, title in zip(axes, centrality_types, titles):
        ax.hist(df[centrality_type], bins=30, edgecolor='black')
        ax.set_title(f'Distribution of {title}')
        ax.set_xlabel(f'{title} Value')
        ax.set_ylabel('Frequency')

    plt.suptitle(f'Distribution of Centralities for {graph_name}', fontsize=16)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95]) 
    plt.show()

# %%
centralities = compute_centralities(recipes_graph)
df = pd.DataFrame(centralities)
plot_centrality_distributions(df, recipes_graph)

# %% [markdown]
# ## Extra calculations

# %%
def compute_correlation(df, col1, col2):
    pearson_corr, _ = pearsonr(df[col1], df[col2])
    spearman_corr, _ = spearmanr(df[col1], df[col2])
    kendall_corr, _ = kendalltau(df[col1], df[col2])
    return pearson_corr, spearman_corr, kendall_corr

def plot_centrality_scatter_plots(df, graph_name):
    centrality_columns = [
        'degree',
        'closeness',
        'betweenness',
        'eigenvector'
    ]
    
    fig, axes = plt.subplots(2, 3, figsize=(20, 10))
    axes = axes.flatten()  
    
    plot_index = 0
    for i in range(len(centrality_columns)):
        for j in range(i + 1, len(centrality_columns)):
            col1 = centrality_columns[i]
            col2 = centrality_columns[j]
            
            pearson_corr, spearman_corr, kendall_corr = compute_correlation(df, col1, col2)
            
            axes[plot_index].scatter(df[col1], df[col2], alpha=0.7)
            axes[plot_index].set_title(f'Scatter Plot: {col1} vs {col2}')
            axes[plot_index].set_xlabel(col1)
            axes[plot_index].set_ylabel(col2)
            
            axes[plot_index].text(0.05, 0.95, f'Pearson: {pearson_corr:.2f}\nSpearman: {spearman_corr:.2f}\nKendall: {kendall_corr:.2f}', 
                                   transform=axes[plot_index].transAxes, fontsize=12, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.5))
            
            plot_index += 1

    plt.tight_layout()
    plt.suptitle(f'Centrality Correlations for {graph_name}', fontsize=16, y=1.02)
    plt.show()

# %%
centralities = compute_centralities(recipes_graph)
df = pd.DataFrame(centralities)
plot_centrality_scatter_plots(df, "Recipe network with min. 5 common ingredients")

# %%
def compute_pearson(df1, df2, col):
    return pearsonr(df1[col], df2[col])[0]

def plot_centrality_comparisons(df_original, df_randomized, graph_name):
    centrality_types = ['degree', 'closeness', 'betweenness', 'eigenvector']
    
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    axes = axes.flatten()

    for i, centrality in enumerate(centrality_types):
        pearson_corr = compute_pearson(df_original, df_randomized, centrality)
        
        axes[i].scatter(df_original[centrality], df_randomized[centrality], alpha=0.7, label=f'Pearson: {pearson_corr:.2f}')
        axes[i].set_title(f'Original vs Randomized: {centrality.capitalize()}', fontsize=14)
        axes[i].set_xlabel(f'Original {centrality.capitalize()}', fontsize=12)
        axes[i].set_ylabel(f'Randomized {centrality.capitalize()}', fontsize=12)
        axes[i].legend()
    
    plt.tight_layout()
    plt.suptitle(f'Centrality Comparisons: Original vs Randomized ({graph_name})', fontsize=16, y=1.02)
    plt.show()

# %%
centralities = compute_centralities(recipes_graph)
df = pd.DataFrame(centralities)
    
randomized_graph = randomize_graph(recipes_graph)
randomized_centralities = compute_centralities(randomized_graph)
df_randomized = pd.DataFrame(randomized_centralities)
    
plot_centrality_comparisons(df, df_randomized, "Recipe network with min. 5 common ingredients")

# %% [markdown]
# ### Observations
#
# We can see on the plots that the Degree Centrality remains unchanged in the randomized graphs, because the degree distribution is preserved by the randomization. In case of Closeness and Betweenness Centrality we can see a lower correlation because randomization disrupts the shortest-path and flow structures. The Eigenvector Centrality also shows lower correlations but the difference is smaller, depending on how connected the nodes are in the random graph versus the original.

# %% [markdown]
#
# #### 1. Degree Centrality
# Degree centrality measures the number of direct connections a node has within the network. A recipe with high degree centrality is one that shares a significant number of ingredients with many other recipes. These recipes likely use common ingredients and might represent versatile or foundational recipes that connect to many others.
#
# During the randomization the edges are randomly rewired, but the node degrees remain unchanged, so the degree distribution remains the same, and therefore, the Degree Centrality remains unchanged, as the total number of connections for each node remained constant. Thats why it has 1.0 correlation.
#
# #### 2. Closeness Centrality
# Closeness centrality reflects how quickly a node can access other nodes in the network, measured by the average shortest path from that node to all others. A recipe with high closeness centrality can quickly "reach" or is closely connected to other recipes in the network. These recipes might be versatile in the sense that they use a set of ingredients that frequently appear in other recipes, making them central to the graph.
#
# Closeness Centrality shows lower correlation because overall the shortest paths are disrupted because of the randomization.
#
# #### 3. Betweenness Centrality
# Betweenness centrality measures the extent to which a node serves as a bridge along the shortest paths between other nodes. Nodes with high betweenness centrality are critical for information flow or connectivity, acting as intermediaries. A recipe with high betweenness centrality acts as a "bridge" between clusters of recipes. These recipes likely share ingredients with multiple distinct groups of recipes and could play a crucial role in connecting different cuisines or cooking styles.
#
# The Betweenness Centrality is also affected by the randomization because when the network is randomized shortest paths are removed or altered, and the nodes that served as intermediaries may no longer fulfill this role. This highlights the sensitivity of betweenness centrality to network structure.
#
# #### 4. Eigenvector Centrality
# Eigenvector centrality evaluates a node's influence based not just on the number of connections but also on the quality and influence of its neighbors. A node connected to other well-connected nodes scores higher. A recipe with high eigenvector centrality is connected to other influential recipes. These recipes are central to the overall structure of the graph and might represent dishes with ingredients that are foundational to many popular or versatile recipes.
#
# With the Eigenvector Centrality the correlation is affected less by the randomization,because it depends on how well the randomization maintains the overall connectivity and flow of importance across nodes. While randomization may disrupt connections, eigenvector centrality continues to reflect the influence of nodes based on their connections to other significant nodes.
#
# #### Observed Differences and Similarities
#
# Degree centrality remained stable in all cases, while closeness, betweenness, and eigenvector centralities were significantly affected by randomization, showcasing how the specific structure of the network influences the sensitivity of different centrality measures.

# %%
def plot_fit(G):
    degrees = [degree for _, degree in G.degree()]

    degrees = [d for d in degrees if d > 0]

    if len(degrees) == 0:
        print("No degrees greater than zero in the graph.")
        return

    fit = powerlaw.Fit(degrees, discrete=True)
    alpha = fit.alpha
    xmin = fit.xmin

    alpha_error = fit.sigma

    print(f"Alpha Error: {alpha_error}")
    print(f"Fitted alpha: {alpha}")

    lam = np.mean(degrees)

    hist, bin_edges = np.histogram(
        degrees,
        bins=np.logspace(np.log10(min(degrees)), np.log10(max(degrees)), num=40),
        density=True
    )
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

    if np.any(np.isnan(hist)):
        print("Histogram contains NaN values. Check degree distribution.")
        return

    degree_values = np.arange(1, max(degrees) + 1)
    poisson_prob = (lam ** degree_values * np.exp(-lam)) / factorial(degree_values)
    exponential_prob = (1 / lam) * np.exp(-degree_values / lam)

    plt.figure(figsize=(7, 5))

    plt.loglog(bin_centers, hist, 'o', color='blue', markersize=5, label="Empirical Data")
    fit.power_law.plot_pdf(color='red', label=f"Power-Law Fit (α={alpha:.2f})")
    plt.loglog(degree_values, poisson_prob, 'g-', label=f'Poisson Fit (λ = {lam:.2f})')
    plt.loglog(degree_values, exponential_prob, 'm-', label=f'Exponential Fit (λ = {lam:.2f})')

    plt.xlabel("Degree (k)", fontsize=12)
    plt.ylabel("Probability (p(k))", fontsize=12)
    plt.title("Empirical Degree Distribution with Power-Law, Poisson, and Exponential Fits", fontsize=14)
    plt.legend()

    max_empirical_prob = np.nanmax(hist) 
    if max_empirical_prob > 0:
        plt.ylim(1e-6, max_empirical_prob * 1.1)
    else:
        print("Maximum empirical probability is zero or invalid.")
        return

    plt.show()

# %%
plot_fit(recipes_graph)
# Out:
# Calculating best minimal value for power law fit
# Alpha Error: 0.28773721979648403
# Fitted alpha: 4.762652390164675
# /var/folders/2j/w5gyp6sx2xqdbzcqb6l19dvr0000gn/T/ipykernel_70779/3553165567.py:33: RuntimeWarning: overflow encountered in power
#   poisson_prob = (lam ** degree_values * np.exp(-lam)) / factorial(degree_values)
# /var/folders/2j/w5gyp6sx2xqdbzcqb6l19dvr0000gn/T/ipykernel_70779/3553165567.py:33: RuntimeWarning: invalid value encountered in divide
#   poisson_prob = (lam ** degree_values * np.exp(-lam)) / factorial(degree_values)
