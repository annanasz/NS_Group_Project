# %%
import os
import networkx as nx
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from networkx.algorithms.community import greedy_modularity_communities, label_propagation_communities, modularity
from collections import Counter, defaultdict, Counter
from scipy.stats import pearsonr, spearmanr, kendalltau, poisson, expon
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import factorial
import powerlaw


recipes_graph = nx.read_gml("final_recipe_graph_min_common_3.gml")

# %%
for node in recipes_graph.nodes(data=True):
    print(node)
# Out:
# ('522861', {'name': 'lplermagrone', 'num_ingredients': 8, 'ingredients': ['Milk', 'salt', 'macaroni', 'cheese', 'pepper', 'butter', 'onion', 'garlic']})
# ('523359', {'name': 'der wiener schnitzel style chili dog sauce', 'num_ingredients': 14, 'ingredients': ['beef', 'pork', 'water', 'cornstarch', 'flour', 'tomato', 'chili', 'Paprika', 'vinegar', 'salt', 'onion', 'sugar', 'garlic', 'pepper']})
# ('513531', {'name': 'better than a can  homemade sloppy joes', 'num_ingredients': 18, 'ingredients': ['olive oil', 'onion', 'pepper', 'pepper', 'celery', 'garlic', 'tomato', 'tomato', 'ketchup', 'vinegar', 'Molasses', 'Worcestershire', 'mushroom', 'tomato', 'oregano', 'beef', 'pepper', 'buns']})
# ('535020', {'name': 'buffalo wing  mushrooms', 'num_ingredients': 8, 'ingredients': ['mushroom', 'cornstarch', 'flour', 'salt', 'pepper', 'seltzer', 'panko', 'oil']})
# ('519068', {'name': 'dorito  popcorn seasoning', 'num_ingredients': 8, 'ingredients': ['yeast', 'garlic', 'onion', 'cumin', 'Paprika', 'chili', 'pepper', 'salt']})
# ('535431', {'name': 'ham  solo savory cake', 'num_ingredients': 12, 'ingredients': ['cheddar', 'spray', 'Bisquick', 'Milk', 'sugar', 'egg', 'salt', 'Gruyere', 'onion', 'ham', 'chives', 'butter']})
# ('532472', {'name': 'west african s finest  mafe', 'num_ingredients': 16, 'ingredients': ['peanut oil', 'carrot', 'garlic', 'potato', 'potato', 'onion', 'tomato', 'Paprika', 'pepper', 'cumin', 'thyme', 'chickpea', 'salt', 'stock', 'peanut butter', 'rice']})
# ('533190', {'name': '1 minute breakfast sandwich', 'num_ingredients': 12, 'ingredients': ['egg', 'Milk', 'salt', 'pepper', 'spray', 'English muffin', 'cheese', 'bacon', 'tomatoes', 'basil', 'avocado', 'pepper']})
# ('531143', {'name': '10 minute shrimp pad thai', 'num_ingredients': 13, 'ingredients': ['rice noodles', 'Peanut butter', 'sambal oelek', 'lime', 'fish', 'sugar', 'oil', 'shrimp', 'tomatoes', 'bean', 'cilantro', 'peanut', 'lime']})
# ('525649', {'name': '15 bean soup in the instant pot', 'num_ingredients': 17, 'ingredients': ['bean', 'water', 'onion', 'carrot', 'garlic', 'olive oil', 'ham', 'lemon', 'tomato soup', 'Paprika', 'paprika', 'chili', 'pepper', 'pepper', 'oregano', 'thyme', 'salt']})
# ('531148', {'name': '15 minute shrimp stir fry', 'num_ingredients': 11, 'ingredients': ['olive oil', 'shrimp', 'salt', 'onion', 'corn', 'tomatoes', 'zucchini', 'pea', 'Lemon', 'butter', 'herb']})
# ('517511', {'name': '2 minute microwave brownie in a mug', 'num_ingredients': 7, 'ingredients': ['oil', 'water', 'flour', 'salt', 'sugar', 'cocoa', 'extract']})
# ('513216', {'name': '2 minute eggless microwave chocolate cake', 'num_ingredients': 8, 'ingredients': ['flour', 'cocoa', 'oil', 'Milk', 'sugar', 'sugar', 'baking', 'salt']})
# ('516214', {'name': '2014 memorial day buttermilk french toast', 'num_ingredients': 9, 'ingredients': ['bread', 'eggs', 'sugar', 'buttermilk', 'Milk', 'vanilla', 'nutmeg', 'cinnamon', 'butter']})
# ('520809', {'name': '3 layer chocolate cake with chocolate mousse filling  gluten fre', 'num_ingredients': 19, 'ingredients': ['flour', 'tapioca', 'flour', 'cocoa', 'chocolate', 'baking soda', 'cream', 'gum', 'butter', 'salt', 'sugar', 'sugar', 'eggs', 'egg', 'vanilla', 'coconut', 'butter', 'cream', 'extract']})
# ('531161', {'name': '3 ingredient carnitas', 'num_ingredients': 13, 'ingredients': ['pork', 'water', 'salt', 'cumin', 'cloves', 'cayenne', 'tortilla', 'cabbage', 'sour cream', 'onion', 'cilantro', 'avocado', 'chili']})
# ('513291', {'name': '4 delicious french fry toppers', 'num_ingredients': 16, 'ingredients': ['Salsa', 'cheddar', 'onion', 'parsley', 'parmesan', 'caper', 'lemon', 'salt', 'garlic', 'mayonnaise', 'lemon', 'paprika', 'chili', 'onion', 'sour cream', 'cheese']})
# ('531144', {'name': '5 minute general tsos chicken', 'num_ingredients': 14, 'ingredients': ['chicken', 'broccoli', 'salt', 'cornstarch', 'vinegar', 'soy', 'Honey', 'chili', 'sesame oil', 'garlic', 'ginger', 'rice', 'scallion', 'sesame']})
# ('514206', {'name': '5 minute healthy sauted red cabbage', 'num_ingredients': 12, 'ingredients': ['cabbage', 'lemon', 'stock', 'olive oil', 'garlic', 'salt', 'pepper', 'ginger', 'seed', 'soy', 'cilantro', 'vinegar']})
# ('535021', {'name': '7 layer elote dip', 'num_ingredients': 15, 'ingredients': ['avocado', 'olive oil', 'lime', 'salt', 'corn', 'sour cream', 'corn', 'cilantro', 'cheese', 'onion', 'salt', 'chili', 'garlic', 'seasoning', 'tortilla']})
# ('516267', {'name': 'a yummy chicken noodle soup  8 qt  pressure cooker', 'num_ingredients': 16, 'ingredients': ['salt', 'pepper', 'carrot', 'celery', 'onion', 'bay', 'thyme', 'parsley', 'ginger', 'garlic', 'chicken', 'water', 'noodles', 'butter', 'mushroom', 'sherry']})
# ('518146', {'name': 'a 1 black cherry brie   chocolate walnut tartlet  a1', 'num_ingredients': 11, 'ingredients': ['cherries', 'sugar', 'zest', 'sauce', 'cornstarch', 'walnut', 'chocolate', 'cheese', 'pastry', 'orange', 'cherry']})
# ('517683', {'name': 'a 1 butter deconstructed pinwheel steak with avocado sauce  a1', 'num_ingredients': 13, 'ingredients': ['steak', 'salt', 'pepper', 'butter', 'cilantro', 'sauce', 'olive oil', 'garlic', 'salt', 'spinach', 'avocado', 'tomato', 'lime']})
# ('518176', {'name': 'a 1 steak puffs with corn and avocado salsa  a1', 'num_ingredients': 14, 'ingredients': ['steak', 'oil', 'onion', 'flour', 'pastry', 'egg', 'beef broth', 'sauce', 'cheese', 'avocado', 'corn', 'lime', 'salt', 'pepper']})
# ('518068', {'name': 'a 1  cherry cobbler tart   a1', 'num_ingredients': 10, 'ingredients': ['cherry', 'mascarpone', 'sugar', 'extract', 'pastry', 'flour', 'butter', 'chocolate', 'sauce', 'cream']})
# ('517702', {'name': 'a 1  chinese pasta  a1', 'num_ingredients': 12, 'ingredients': ['garlic', 'scallion', 'mushroom', 'pasta', 'sauce', 'hoisin', 'soy', 'sugar', 'pepper', 'sesame', 'mayonnaise', 'turkey']})
# ('518151', {'name': 'a 1  pot stickers with chili pineapple dipping sauce  a1', 'num_ingredients': 15, 'ingredients': ['wrapper', 'olive oil', 'spinach', 'onion', 'salt', 'pepper', 'turkey', 'garlic', 'ginger', 'sauce', 'pepper', 'sugar', 'water', 'cilantro', 'onion']})
# ('518145', {'name': 'a 1  slow roasted shredded steak with polenta  a1', 'num_ingredients': 18, 'ingredients': ['oil', 'steak', 'salt', 'pepper', 'sauce', 'jam', 'water', 'garlic', 'mustard', 'sugar', 'lemon', 'lemon', 'potato', 'Milk', 'garlic', 'polenta', 'parmesan', 'butter']})
# ('518143', {'name': 'a1 cowboy up tart  a1', 'num_ingredients': 11, 'ingredients': ['pastry', 'cream cheese', 'sour cream', 'sauce', 'steak', 'potato', 'tomatoes', 'corn', 'pepper', 'cheddar', 'salt']})
# ('518234', {'name': 'a1 marinated top round with bacon parmesan polenta  a1', 'num_ingredients': 19, 'ingredients': ['tomato', 'shallot', 'scallion', 'olive oil', 'salt', 'pepper', 'Milk', 'water', 'cornmeal', 'parmesan', 'butter', 'bacon', 'sauce', 'sugar', 'agave', 'scallion', 'tarragon', 'hot sauce', 'steak']})
# ('518192', {'name': 'a1 zesty potatoes  a1', 'num_ingredients': 9, 'ingredients': ['bacon', 'potato', 'onion', 'walnut', 'mayonnaise', 'cheese', 'sauce', 'mustard', 'salt']})
# ('518230', {'name': 'a1 derful grilled chicken  a1', 'num_ingredients': 8, 'ingredients': ['sauce', 'chicken', 'pineapple', 'cheese', 'spinach', 'salt', 'pepper', 'pineapple']})
# ('517863', {'name': 'a1b bacon burger bites on white polenta cakes  a1', 'num_ingredients': 13, 'ingredients': ['Milk', 'water', 'pepper', 'salt', 'polenta', 'cheese', 'olive oil', 'bacon', 'sugar', 'turkey', 'sauce', 'pepper', 'cheddar']})
# ('532656', {'name': 'acili biskuvi  spicy biscuits', 'num_ingredients': 8, 'ingredients': ['flour', 'butter', 'cheese', 'egg', 'salt', 'pepper', 'egg', 'seed']})
# ('526265', {'name': 'afghan kabuli pulao', 'num_ingredients': 10, 'ingredients': ['rice', 'onion', 'pistachio', 'almond', 'carrot', 'raisin', 'sugar', 'oil', 'olive oil', 'salt']})
# ('512943', {'name': 'aha herb mix', 'num_ingredients': 10, 'ingredients': ['pepper', 'garlic', 'basil', 'thyme', 'Parsley', 'marjoram', 'Mace', 'onion', 'pepper', 'sage']})
# ('524790', {'name': 'aip bbq sauce', 'num_ingredients': 10, 'ingredients': ['pumpkin', 'cider', 'vinegar', 'coconut oil', 'Molasses', 'syrup', 'garlic', 'salt', 'aminos', 'ginger']})
# ('530305', {'name': 'air fried onion rings', 'num_ingredients': 7, 'ingredients': ['breadcrumb', 'salt', 'pepper', 'parmesan', 'onion', 'egg', 'spray']})
# ('517847', {'name': 'aji criollo   green aji salsa', 'num_ingredients': 7, 'ingredients': ['cilantro', 'onion', 'lime', 'Vinegar', 'pepper', 'olive oil', 'salt']})
# ('522117', {'name': 'alan s vegetarian vegan bean and rice burger mashup', 'num_ingredients': 12, 'ingredients': ['bean', 'bean', 'rice', 'breadcrumb', 'picante', 'chili', 'cumin', 'oregano', 'salt', 'pepper', 'garlic', 'pepper']})
# ('516687', {'name': 'alea s corned beef and cabbage soup', 'num_ingredients': 6, 'ingredients': ['beef broth', 'potato', 'onion', 'garlic', 'beef', 'cabbage']})
# ('535371', {'name': 'almond flour blueberry muffins best ever', 'num_ingredients': 11, 'ingredients': ['flour', 'baking soda', 'salt', 'nutmeg', 'sugar', 'eggs', 'oil', 'Honey', 'almond', 'extract', 'blueberries']})
# ('519547', {'name': 'almond flour stevia cookies', 'num_ingredients': 6, 'ingredients': ['butter', 'flour', 'Stevia', 'salt', 'extract', 'egg']})
# ('511753', {'name': 'almond milk hot chocolate   martha stewart', 'num_ingredients': 6, 'ingredients': ['milk', 'cinnamon', 'sugar', 'cocoa', 'chocolate', 'salt']})
# ('526984', {'name': 'almond milk pancakes', 'num_ingredients': 8, 'ingredients': ['flour', 'baking', 'sugar', 'salt', 'almond milk', 'oil', 'vanilla', 'eggs']})
# ('515787', {'name': 'almond pancakes', 'num_ingredients': 6, 'ingredients': ['almond', 'milk', 'baking', 'salt', 'flax', 'cinnamon']})
# ('512375', {'name': 'almond chive salmon', 'num_ingredients': 10, 'ingredients': ['almond', 'chives', 'parsley', 'lemon', 'bread', 'salt', 'salmon', 'pepper', 'spray', 'Lemon']})
# ('522989', {'name': 'alton brown s stove top mac n cheese', 'num_ingredients': 9, 'ingredients': ['macaroni', 'butter', 'eggs', 'milk', 'hot sauce', 'salt', 'pepper', 'mustard', 'cheddar']})
# ('521731', {'name': 'amazing baked chicken breasts    you must try   easy to make', 'num_ingredients': 10, 'ingredients': ['chicken', 'Feta', 'tomatoes', 'garlic', 'basil', 'parsley', 'chives', 'olive', 'cheddar', 'salt']})
# ('512051', {'name': 'amazing beef stew', 'num_ingredients': 13, 'ingredients': ['beef', 'flour', 'salt', 'pepper', 'olive oil', 'onion', 'celery', 'Parsley', 'thyme', 'beef broth', 'carrot', 'potato', 'peas']})
# ('534722', {'name': 'amazing buttermilk biscuits', 'num_ingredients': 6, 'ingredients': ['flour', 'buttermilk', 'butter', 'baking', 'salt', 'baking soda']})
# ('515019', {'name': 'amazingly easy grain free biscuits rolls', 'num_ingredients': 7, 'ingredients': ['flour', 'starch', 'baking', 'salt', 'sugar', 'milk', 'olive oil']})
# ('512939', {'name': 'american sandwich bread   abm or oven', 'num_ingredients': 8, 'ingredients': ['water', 'milk', 'butter', 'Honey', 'flour', 'flour', 'salt', 'yeast']})
# ('526764', {'name': 'amish funeral cookies', 'num_ingredients': 8, 'ingredients': ['butter', 'Milk', 'sugar', 'cocoa', 'peanut butter', 'vanilla', 'salt', 'oats']})
# ('536322', {'name': 'amish peanut butter', 'num_ingredients': 6, 'ingredients': ['sugar', 'water', 'corn', 'syrup', 'peanut', 'marshmallow']})
# ('518120', {'name': 'amish sourdough bread starter', 'num_ingredients': 11, 'ingredients': ['Yeast', 'water', 'flour', 'sugar', 'Milk', 'Honey', 'salt', 'oil', 'eggs', 'flour', 'egg']})
# ('536384', {'name': 'amish triple butter biscuits', 'num_ingredients': 8, 'ingredients': ['flour', 'salt', 'cream', 'sugar', 'baking', 'butter', 'egg', 'Milk']})
# ('521585', {'name': 'amy truong zucchini low carb lasagna', 'num_ingredients': 19, 'ingredients': ['ground', 'onion', 'tomatoes', 'tomato', 'garlic', 'oregano', 'basil', 'thyme', 'water', 'pepper', 'eggs', 'cheese', 'red pepper', 'sriracha', 'mozzarella', 'flour', 'zucchini', 'parmesan', 'olive oil']})
# ('512771', {'name': 'andouille and chicken gumbo with black eyed peas and greens', 'num_ingredients': 23, 'ingredients': ['sausage', 'chicken', 'salt', 'pepper', 'Paprika', 'pepper', 'olive oil', 'flour', 'onion', 'onion', 'celery', 'garlic', 'pepper', 'pepper', 'chicken', 'leaf', 'thyme', 'pea', 'greens', 'okra', 'gumbo', 'rice', 'hot pepper sauce']})
# ('517082', {'name': 'angel biscuits', 'num_ingredients': 11, 'ingredients': ['flour', 'baking', 'salt', 'baking soda', 'sugar', 'yeast', 'water', 'buttermilk', 'shortening', 'biscuit', 'flour']})
# ('517983', {'name': 'angelo azzurro  blue angel  cocktail', 'num_ingredients': 6, 'ingredients': ['Cointreau', 'limoncello', 'gin', 'Vermouth', 'fruit', 'ice']})
# ('513805', {'name': 'apple bok choy salad', 'num_ingredients': 9, 'ingredients': ['bok choy', 'cashews', 'milk', 'vinegar', 'raisin', 'mustard', 'apple', 'carrot', 'onion']})
# ('512207', {'name': 'apple bread abm', 'num_ingredients': 9, 'ingredients': ['sugar', 'cinnamon', 'apple', 'juice', 'flour', 'yeast', 'salt', 'butter', 'egg']})
# ('512016', {'name': 'apple mango chutney', 'num_ingredients': 14, 'ingredients': ['apple', 'Mango', 'onion', 'ginger', 'juice', 'lemon', 'cider', 'sugar', 'raisin', 'cayenne', 'cinnamon', 'nutmeg', 'salt', 'thyme']})
# ('528546', {'name': 'apple pie breakfast quinoa', 'num_ingredients': 12, 'ingredients': ['quinoa', 'milk', 'apple', 'sugar', 'cinnamon', 'allspice', 'clove', 'nutmeg', 'extract', 'salt', 'pecan', 'syrup']})
# ('512109', {'name': 'apple pie egg roll', 'num_ingredients': 7, 'ingredients': ['apple', 'sugar', 'flour', 'cinnamon', 'lemon', 'wraps', 'oil']})
# ('534000', {'name': 'apple pie with cheddar crust', 'num_ingredients': 15, 'ingredients': ['flour', 'salt', 'butter', 'cheddar', 'water', 'apple', 'lemon', 'sugar', 'cornstarch', 'cinnamon', 'salt', 'egg', 'cream', 'sugar', 'cream']})
# ('517371', {'name': 'apple sharlotka', 'num_ingredients': 9, 'ingredients': ['apples', 'eggs', 'sugar', 'extract', 'flour', 'cinnamon', 'sugar', 'cream', 'sour cream']})
# ('528058', {'name': 'apple slab pie', 'num_ingredients': 14, 'ingredients': ['flour', 'sugar', 'salt', 'butter', 'water', 'apple', 'cornstarch', 'cinnamon', 'nutmeg', 'allspice', 'cream', 'glaze', 'sugar', 'Milk']})
# ('518669', {'name': 'apple  honey   caramelized onion flatbread pizza', 'num_ingredients': 13, 'ingredients': ['crust', 'olive oil', 'onion', 'rosemary', 'salt', 'pepper', 'cornmeal', 'apple', 'brie', 'mozzarella', 'parmesan', 'Honey', 'parsley']})
# ('521251', {'name': 'apple cinnamon mug cake', 'num_ingredients': 7, 'ingredients': ['oatmeal', 'sugar', 'cinnamon', 'baking', 'apple', 'Milk', 'oil']})
# ('524289', {'name': 'apple glazed stuffed pork chops', 'num_ingredients': 9, 'ingredients': ['bacon', 'leek', 'wine', 'thyme', 'salt', 'pepper', 'jelly', 'mustard', 'pork']})
# ('512773', {'name': 'applebee s chicken wonton', 'num_ingredients': 12, 'ingredients': ['chicken breast', 'olive oil', 'stir-fry', 'sesame', 'soy', 'teriyaki', 'slaw', 'wrapper', 'oil', 'onion', 'cilantro', 'onion']})
# ('532924', {'name': 'apricot almond cake with rosewater   cardamom', 'num_ingredients': 13, 'ingredients': ['apricot', 'water', 'cardamom', 'almonds', 'polenta', 'baking', 'sugar', 'eggs', 'lemon', 'rose water', 'spray', 'rose', 'pistachio']})
# ('520120', {'name': 'apricot cranberry kugel', 'num_ingredients': 11, 'ingredients': ['noodles', 'sour cream', 'cream cheese', 'apricot', 'salt', 'extract', 'cinnamon', 'cranberries', 'eggs', 'butter', 'cereal']})
# ('529216', {'name': 'arancini  italian rice balls', 'num_ingredients': 8, 'ingredients': ['rice', 'chicken', 'butter', 'eggs', 'parmesan', 'mozzarella', 'breadcrumb', 'oil']})
# ('514145', {'name': 'arby s oven baked curly fries', 'num_ingredients': 9, 'ingredients': ['potato', 'Paprika', 'salt', 'garlic', 'onion', 'pepper', 'flour', 'egg', 'milk']})
# ('536318', {'name': 'argentine chili', 'num_ingredients': 12, 'ingredients': ['olive oil', 'ground sirloin', 'chorizo', 'onion', 'garlic', 'pepper', 'salt', 'oregano', 'paprika', 'chile', 'tomato', 'beef']})
# ('517347', {'name': 'argentine grilled flank steak', 'num_ingredients': 6, 'ingredients': ['steak', 'pepper', 'olive oil', 'lime', 'soy', 'garlic']})
# ('536401', {'name': 'argentinian steak sandwiches', 'num_ingredients': 15, 'ingredients': ['beef', 'olive oil', 'salt', 'Baguette', 'mayonnaise', 'lettuce', 'avocado', 'vinegar', 'shallot', 'tomatoes', 'garlic', 'parsley', 'oregano', 'pepper', 'salt']})
# ('536044', {'name': 'argentinian tropical tincho', 'num_ingredients': 6, 'ingredients': ['mint', 'lime', 'ice', 'Vodka', 'wine', 'soda']})
# ('512720', {'name': 'artichoke heart frittata', 'num_ingredients': 13, 'ingredients': ['artichoke', 'zucchini', 'onion', 'pepper', 'garlic', 'oil', 'eggs', 'Milk', 'salt', 'pepper', 'bread', 'cream cheese', 'cheddar']})
# ('528358', {'name': 'artichoke pad thai', 'num_ingredients': 19, 'ingredients': ['rice', 'onion', 'garlic', 'ginger', 'tamarind', 'Honey', 'peanut', 'vinegar', 'fish', 'vinegar', 'sesame oil', 'olive oil', 'pepper', 'pepper', 'artichoke', 'bean', 'egg', 'cilantro', 'lime']})
# ('520016', {'name': 'asian chicken meatball   rice noodle soup', 'num_ingredients': 20, 'ingredients': ['scallion', 'garlic', 'ginger', 'egg', 'soy', 'oil', 'spice', 'salt', 'pepper', 'chicken', 'pork', 'breadcrumb', 'stock', 'garlic', 'Ginger', 'anise', 'mushroom', 'carrot', 'bok choy', 'rice']})
# ('515833', {'name': 'asian inspired pulled pork shoulder  for tacos or sliders', 'num_ingredients': 15, 'ingredients': ['pork', 'pepper', 'salt', 'onion', 'water', 'hoisin', 'Honey', 'soy', 'sesame oil', 'mirin', 'wine', 'lemongrass', 'ginger', 'garlic', 'spice']})
# ('516981', {'name': 'asian inspired zucchini', 'num_ingredients': 8, 'ingredients': ['zucchini', 'onion', 'garlic', 'sesame oil', 'olive oil', 'soy', 'ginger', 'seed']})
# ('518223', {'name': 'asian marinated pork chops', 'num_ingredients': 6, 'ingredients': ['soy', 'lemon', 'Ginger', 'garlic', 'pork', 'butter']})
# ('512372', {'name': 'asian noodle bowl with sesame salmon', 'num_ingredients': 11, 'ingredients': ['salmon', 'teriyaki', 'seed', 'Vermicelli', 'vinegar', 'onion', 'onion', 'tomatoes', 'cucumber', 'carrot', 'cilantro']})
# ('520940', {'name': 'asian vegetable soup with shrimp', 'num_ingredients': 15, 'ingredients': ['coconut oil', 'leek', 'celery', 'ginger', 'garlic', 'pepper', 'pepper', 'carrot', 'cabbage', 'vinegar', 'soy', 'stock', 'water', 'shrimp', 'salt']})
# ('512747', {'name': 'aunt carrie s indian pudding', 'num_ingredients': 11, 'ingredients': ['Milk', 'water', 'cornmeal', 'butter', 'Molasses', 'flour', 'cinnamon', 'Ginger', 'salt', 'egg', 'ice cream']})
# ('516015', {'name': 'austin chicken fajitas', 'num_ingredients': 10, 'ingredients': ['chicken', 'oil', 'juice', 'sauce', 'onion', 'garlic', 'pepper', 'celery', 'jalapeno', 'zest']})
# ('513298', {'name': 'australian crash hot potatoes', 'num_ingredients': 7, 'ingredients': ['potato', 'olive oil', 'garlic', 'salt', 'pepper', 'herb', 'parmesan']})
# ('532422', {'name': 'austrian kaesespaetzle  cheese spaetzle', 'num_ingredients': 10, 'ingredients': ['flour', 'eggs', 'Milk', 'Gruyere', 'edam', 'onion', 'olive oil', 'salt', 'pepper', 'parsley']})
# ('523334', {'name': 'authentic eggplant parmesan', 'num_ingredients': 13, 'ingredients': ['olive oil', 'garlic', 'onion', 'tomato', 'tomato', 'wine', 'seasoning', 'eggplant', 'eggs', 'Milk', 'breadcrumbs', 'mozzarella', 'cheese']})
# ('512041', {'name': 'authentic thai red curry with chicken', 'num_ingredients': 17, 'ingredients': ['chicken', 'curry', 'coconut', 'oil', 'stock', 'bouillon', 'onion', 'pepper', 'carrot', 'eggplant', 'sugar', 'lemon', 'fish', 'basil', 'basil', 'tomatoes', 'rice']})
# ('530683', {'name': 'avocado cream cheese toast', 'num_ingredients': 7, 'ingredients': ['bread', 'cream cheese', 'olive oil', 'avocado', 'salt', 'pepper', 'hot sauce']})
# ('529506', {'name': 'avocado lime and coconut no bake cheesecake', 'num_ingredients': 9, 'ingredients': ['raspberry', 'lime', 'avocado', 'cream cheese', 'lime', 'sugar', 'butter', 'graham cracker', 'coconut']})
# ('515352', {'name': 'avocado white bean hummus', 'num_ingredients': 7, 'ingredients': ['bean', 'avocado', 'lemon', 'tahini', 'garlic', 'salt', 'olive oil']})
# ('517715', {'name': 'avocado tomatillo taco truck sauce', 'num_ingredients': 8, 'ingredients': ['tomatillo', 'chili', 'cilantro', 'onion', 'water', 'avocado', 'lime', 'salt']})
# ('525001', {'name': 'babette s colossal crockpot chili  ragu', 'num_ingredients': 11, 'ingredients': ['pasta', 'tomato', 'sausage', 'onion', 'garlic', 'pasta', 'bean', 'pepper', 'water', 'chili', 'Feta']})
# ('536583', {'name': 'bacon and egg breakfast stromboli', 'num_ingredients': 7, 'ingredients': ['bacon', 'pastry', 'eggs', 'cheddar', 'egg', 'water', 'salt']})
# ('533950', {'name': 'bacon lattice turkey', 'num_ingredients': 6, 'ingredients': ['butter', 'bacon', 'thyme', 'sage', 'turkey', 'onion']})
# ('527202', {'name': 'bacon peanut caramel corn', 'num_ingredients': 7, 'ingredients': ['bacon', 'popcorn', 'bacon', 'Peanuts', 'sugar', 'corn', 'water']})
# ('523538', {'name': 'bacon potato cheddar tart', 'num_ingredients': 7, 'ingredients': ['bacon', 'potato', 'cheddar', 'paper', 'pepper', 'onion', 'garlic']})
# ('512716', {'name': 'bacon ranch wedge salad', 'num_ingredients': 6, 'ingredients': ['lettuce', 'onion', 'cucumber', 'bacon', 'Provolone', 'ranch']})
# ('536564', {'name': 'bacon wrapped coconut quiche and coconut popcorn shrimp', 'num_ingredients': 17, 'ingredients': ['coconut', 'eggs', 'corn', 'parmesan', 'bacon', 'shrimp', 'flour', 'egg', 'cornmeal', 'panko', 'coconut oil', 'Coconut', 'ketchup', 'Worcestershire', 'lemon', 'soy', 'tabasco']})
# ('513221', {'name': 'bacon wrapped steak', 'num_ingredients': 7, 'ingredients': ['beef', 'bacon', 'butter', 'rosemary', 'garlic', 'olive oil', 'wine']})
# ('516718', {'name': 'bacon  egg and cheese ring', 'num_ingredients': 8, 'ingredients': ['bacon', 'eggs', 'salt', 'pepper', 'crescent', 'cheese', 'cilantro', 'Salsa']})
# ('524716', {'name': 'bacon kissed cauliflower dip w  crispy corn tortillas  ragu', 'num_ingredients': 12, 'ingredients': ['oil', 'tortillas', 'salt', 'bacon', 'butter', 'onion', 'cauliflower', 'garlic', 'pepper', 'cheese', 'pasta', 'panko']})
# ('513094', {'name': 'bacon wrapped sonoran hot dogs', 'num_ingredients': 15, 'ingredients': ['bun', 'bacon', 'hot dog', 'bean', 'onion', 'tomato', 'mayonnaise', 'mustard', 'Salsa', 'garlic', 'olive oil', 'peppers', 'lime', 'oregano', 'salt']})
# ('530386', {'name': 'baconfredo', 'num_ingredients': 8, 'ingredients': ['bacon', 'onion', 'butter', 'cream', 'parmesan', 'pepper', 'salt', 'pasta']})
# ('514211', {'name': 'baileys irish cream pancakes', 'num_ingredients': 10, 'ingredients': ['butter', 'sugar', 'salt', 'egg', 'Milk', 'cream', 'flour', 'baking', 'butter', 'syrup']})
# ('516897', {'name': 'baja citrus marinade  chicken or pork chops', 'num_ingredients': 10, 'ingredients': ['chicken', 'beverage', 'juice', 'Vinegar', 'soy', 'oil', 'onion', 'garlic', 'salt', 'cayenne']})
# ('535581', {'name': 'baja fish taco', 'num_ingredients': 12, 'ingredients': ['salt', 'pepper', 'chicken', 'oregano', 'mustard', 'water', 'flour', 'tomato', 'onion', 'jalapeno', 'lemon', 'cilantro']})
# ('520110', {'name': 'bake a chocolate cake', 'num_ingredients': 13, 'ingredients': ['cocoa', 'sugar', 'baking soda', 'flour', 'salt', 'eggs', 'butter', 'water', 'vanilla', 'butter', 'Milk', 'cocoa', 'sugar']})
# ('533718', {'name': 'baked apple cider donuts', 'num_ingredients': 15, 'ingredients': ['cider', 'oil', 'applesauce', 'sugar', 'eggs', 'extract', 'flour', 'cinnamon', 'baking', 'salt', 'sugar', 'food', 'doughnut', 'licorice', 'apple']})
# ('513817', {'name': 'baked barley with mushrooms', 'num_ingredients': 11, 'ingredients': ['tomato', 'olive oil', 'carrot', 'shallot', 'mushroom', 'thyme', 'broth', 'barley', 'salt', 'pepper', 'mozzarella']})
# ('533649', {'name': 'baked brie with maple apples and pecans', 'num_ingredients': 6, 'ingredients': ['pecan', 'apple', 'butter', 'sugar', 'brie', 'maple syrup']})
# ('518070', {'name': 'baked chicken parmigiano', 'num_ingredients': 10, 'ingredients': ['yogurt', 'garlic', 'oregano', 'salt', 'pepper', 'chicken', 'parmesan', 'tomatoes', 'basil', 'bocconcini']})
# ('513941', {'name': 'baked mango sriracha cauliflower wings', 'num_ingredients': 16, 'ingredients': ['cauliflower', 'water', 'flour', 'salt', 'garlic', 'onion', 'paprika', 'chili', 'cayenne', 'pepper', 'oil', 'Mango', 'sriracha', 'hot sauce', 'juice', 'ginger']})
# ('515852', {'name': 'baked mexican pie', 'num_ingredients': 13, 'ingredients': ['beef', 'taco', 'beef broth', 'butter', 'onion', 'garlic', 'onion', 'chili', 'soup', 'enchilada', 'bean', 'flour', 'cheese']})
# ('530364', {'name': 'baked penne', 'num_ingredients': 13, 'ingredients': ['beef', 'sausage', 'pasta', 'pasta', 'onion', 'pepper', 'pepper', 'mushroom', 'carrot', 'spinach', 'tomatoes', 'cheddar', 'parmesan']})
# ('528861', {'name': 'baked potato volcano', 'num_ingredients': 10, 'ingredients': ['potato', 'bacon', 'cream cheese', 'cheddar', 'mozzarella', 'onion', 'chili', 'salt', 'cheddar', 'parsley']})
# ('522710', {'name': 'baked rice with cheese and tomatoes', 'num_ingredients': 11, 'ingredients': ['butter', 'onion', 'garlic', 'tomatoes', 'rice', 'salt', 'thyme', 'leaf', 'chicken', 'cheese', 'parmesan']})
# ('529772', {'name': 'baked salmon with garlic and dijon', 'num_ingredients': 9, 'ingredients': ['salmon', 'parsley', 'garlic', 'mustard', 'salt', 'pepper', 'olive oil', 'lemon', 'lemon']})
# ('512106', {'name': 'baked salmon with lemon and capers', 'num_ingredients': 10, 'ingredients': ['salmon', 'olive oil', 'salt', 'pepper', 'garlic', 'lemon', 'lemon', 'wine', 'caper', 'foil']})
# ('524817', {'name': 'baked sausage and garbanzo bean rollups  ragu', 'num_ingredients': 12, 'ingredients': ['flour', 'water', 'lemon', 'salt', 'oil', 'sausage', 'bean', 'pasta', 'breadcrumb', 'cilantro', 'pine', 'olive oil']})
# ('532486', {'name': 'baked sea bass with vegetables', 'num_ingredients': 12, 'ingredients': ['sea bass', 'onion', 'garlic', 'tomatoes', 'potato', 'lemon', 'water', 'olive oil', 'pepper', 'salt', 'parsley', 'Lemon']})
# ('537076', {'name': 'baked shrimp and orzo with chickpeas  lemon  and dill', 'num_ingredients': 15, 'ingredients': ['shrimp', 'salt', 'olive oil', 'fennel', 'garlic', 'red pepper', 'orzo', 'chickpea', 'tomatoes', 'olive', 'dill', 'Lemon', 'wine', 'broth', 'feta']})
# ('520337', {'name': 'baked turkey meatballs', 'num_ingredients': 9, 'ingredients': ['turkey', 'breadcrumbs', 'cheese', 'parsley', 'egg', 'garlic', 'salt', 'pepper', 'pepper']})
# ('515814', {'name': 'baked turkey quinoa meatballs', 'num_ingredients': 11, 'ingredients': ['turkey', 'quinoa', 'garlic', 'egg', 'onion', 'pepper', 'parsley', 'basil', 'oregano', 'tomato', 'salt']})
# ('517798', {'name': 'baked zucchini balls  gluten free', 'num_ingredients': 8, 'ingredients': ['zucchini', 'parmesan', 'breadcrumb', 'basil', 'egg', 'salt', 'flour', 'olive oil']})
# ('536474', {'name': 'baklava salmon with asparagus', 'num_ingredients': 14, 'ingredients': ['butter', 'mustard', 'Honey', 'pistachio', 'panko', 'parsley', 'olive oil', 'salmon', 'asparagus', 'tomatoes', 'thyme', 'lemon', 'salt', 'pepper']})
# ('532338', {'name': 'balsamic chicken wings', 'num_ingredients': 9, 'ingredients': ['chicken', 'Honey', 'sugar', 'vinegar', 'ginger', 'garlic', 'Lemon', 'salt', 'lemon']})
# ('529948', {'name': 'banana bomb', 'num_ingredients': 9, 'ingredients': ['banana', 'raisin', 'currant', 'coconut', 'dates', 'peanut', 'walnut', 'carob', 'Stevia']})
# ('536568', {'name': 'banana coffee cake', 'num_ingredients': 12, 'ingredients': ['butter', 'sugar', 'flour', 'cinnamon', 'salt', 'vanilla', 'cake', 'baking', 'banana', 'eggs', 'yogurt', 'sugar']})
# ('519167', {'name': 'banana date bread', 'num_ingredients': 12, 'ingredients': ['oil', 'sugar', 'egg', 'flour', 'baking', 'baking soda', 'salt', 'banana', 'water', 'extract', 'date', 'nut']})
# ('517744', {'name': 'banana muffins', 'num_ingredients': 10, 'ingredients': ['sugar', 'margarine', 'eggs', 'banana', 'water', 'flour', 'baking soda', 'salt', 'baking', 'chocolate']})
# ('525729', {'name': 'banana mug cake', 'num_ingredients': 8, 'ingredients': ['banana', 'syrup', 'oil', 'extract', 'flour', 'salt', 'cinnamon', 'sugar']})
# ('513434', {'name': 'banana pecan buttermilk pancakes', 'num_ingredients': 13, 'ingredients': ['pecan', 'flour', 'flour', 'sugar', 'baking', 'salt', 'flax', 'eggs', 'butter', 'milk', 'buttermilk', 'vanilla', 'banana']})
# ('535830', {'name': 'banana pudding beach icebox cake', 'num_ingredients': 10, 'ingredients': ['cream cheese', 'sugar', 'Milk', 'extract', 'cream', 'pudding', 'sugar', 'wafer', 'banana', 'cream']})
# ('522498', {'name': 'banana walnut pancake  paleo compliant', 'num_ingredients': 11, 'ingredients': ['banana', 'walnut', 'eggs', 'flour', 'baking', 'extract', 'baking soda', 'cinnamon', 'coconut', 'butter', 'Honey']})
# ('521481', {'name': 'bang bang shrimp pasta', 'num_ingredients': 11, 'ingredients': ['spaghetti', 'shrimp', 'coconut oil', 'garlic', 'Paprika', 'Parsley', 'pepper', 'mayonnaise', 'chili', 'lime', 'red pepper']})
# ('527864', {'name': 'barberton hot sauce', 'num_ingredients': 11, 'ingredients': ['Crisco', 'onion', 'celery', 'pepper', 'tomatoes', 'tomato', 'pepper', 'sugar', 'salt', 'pepper', 'rice']})
# ('514038', {'name': 'basic bechamel  white sauce', 'num_ingredients': 7, 'ingredients': ['butter', 'flour', 'Paprika', 'nutmeg', 'leaf', 'Milk', 'pepper']})
# ('516838', {'name': 'basil   mint orzo salad', 'num_ingredients': 12, 'ingredients': ['chicken', 'orzo', 'vinegar', 'lemon', 'Honey', 'salt', 'pepper', 'olive oil', 'tomatoes', 'onion', 'basil', 'mint']})
# ('520864', {'name': 'battered chicken tenders', 'num_ingredients': 11, 'ingredients': ['chicken', 'flour', 'baking', 'salt', 'pepper', 'egg', 'water', 'oil', 'mayonnaise', 'mustard', 'Honey']})
# ('519260', {'name': 'bbq chicken tenders', 'num_ingredients': 10, 'ingredients': ['barbecue', 'mustard', 'Honey', 'chicken', 'flour', 'salt', 'pepper', 'eggs', 'breadcrumb', 'olive oil']})
# ('512390', {'name': 'bean and bell pepper salad', 'num_ingredients': 12, 'ingredients': ['bean', 'bean', 'pepper', 'pepper', 'bell pepper', 'pepper', 'onion', 'garlic', 'parsley', 'lemon', 'olive oil', 'salt']})
# ('517603', {'name': 'beecher s kale and brown rice gratin with smoked cheese', 'num_ingredients': 13, 'ingredients': ['chicken', 'rice', 'olive oil', 'onion', 'garlic', 'kale', 'salt', 'pepper', 'butter', 'flour', 'Milk', 'fontina', 'gouda']})
# ('516391', {'name': 'beef   bean    oven tacos', 'num_ingredients': 8, 'ingredients': ['beef', 'onion', 'bean', 'taco', 'tomatoes', 'shell', 'cheese', 'corn']})
# ('513565', {'name': 'beef   chickpea paprikash', 'num_ingredients': 16, 'ingredients': ['beef', 'flour', 'salt', 'pepper', 'butter', 'onion', 'garlic', 'stock', 'Paprika', 'sugar', 'pepper', 'mustard', 'ketchup', 'Worcestershire', 'chickpea', 'yogurt']})
# ('518912', {'name': 'beef and barley soup with wils mushrooms', 'num_ingredients': 16, 'ingredients': ['beef', 'water', 'mushroom', 'barley', 'onion', 'celery', 'carrot', 'salt', 'pepper', 'thyme', 'leaf', 'garlic', 'parsley', 'mushroom', 'tomatoes', 'beef broth']})
# ('512873', {'name': 'beef and black bean taco dip', 'num_ingredients': 7, 'ingredients': ['ground beef', 'taco', 'garlic', 'tomatoes', 'bean', 'cheese', 'scallion']})
# ('518104', {'name': 'beef and quinoa stuffed bell peppers', 'num_ingredients': 11, 'ingredients': ['quinoa', 'water', 'beef', 'pepper', 'olive oil', 'onion', 'oregano', 'basil', 'salt', 'pepper', 'tomato']})
# ('515568', {'name': 'beef skewers with cilantro chimichurri', 'num_ingredients': 12, 'ingredients': ['cider', 'sugar', 'salt', 'onion', 'cilantro', 'steak', 'garlic', 'vinegar', 'lemon', 'pepper', 'olive oil', 'pepper']})
# ('512458', {'name': 'beefy chipotle cocoa chili', 'num_ingredients': 23, 'ingredients': ['olive oil', 'ground beef', 'chili', 'Paprika', 'garlic', 'onion', 'oregano', 'cumin', 'cocoa', 'sugar', 'salt', 'pepper', 'pepper', 'tomato', 'bean', 'corn', 'tomatoes', 'onion', 'peppers', 'water', 'squash', 'cilantro', 'epazote']})
# ('535570', {'name': 'beer bacon mac and cheese', 'num_ingredients': 15, 'ingredients': ['macaroni', 'bacon', 'butter', 'flour', 'garlic', 'chile', 'paprika', 'salt', 'pepper', 'beer', 'chicken', 'milk', 'Worcestershire', 'cheddar', 'chives']})
# ('511925', {'name': 'beer battered fish tacos with pickled onion and cucumber', 'num_ingredients': 18, 'ingredients': ['oil', 'flour', 'cumin', 'pepper', 'salt', 'beer', 'tilapia', 'flour', 'cucumber', 'cider', 'sugar', 'water', 'onion', 'onion', 'cucumber', 'pepper', 'tomato', 'cilantro']})
# ('534898', {'name': 'beer cheese stuffed pretzels', 'num_ingredients': 18, 'ingredients': ['water', 'sugar', 'yeast', 'beer', 'butter', 'salt', 'flour', 'pretzels', 'pretzel', 'egg', 'salt', 'cheddar', 'cheese', 'garlic', 'mustard', 'Worcestershire', 'cream', 'scallion']})
# ('527535', {'name': 'beery chorizo queso fundido', 'num_ingredients': 13, 'ingredients': ['butter', 'onion', 'jalapeno', 'garlic', 'chorizo', 'flour', 'chili', 'cumin', 'beer', 'milk', 'cheese', 'cilantro', 'chip']})
# ('532442', {'name': 'belizean meat pies', 'num_ingredients': 14, 'ingredients': ['beef', 'pepper', 'onion', 'pepper', 'thyme', 'tomato', 'cumin', 'Worcestershire', 'pepper', 'flour', 'baking', 'salt', 'shortening', 'water']})
# ('512898', {'name': 'belt salad', 'num_ingredients': 9, 'ingredients': ['eggs', 'bacon', 'lettuce', 'tomatoes', 'crouton', 'sour cream', 'buttermilk', 'mustard', 'onion']})
# ('532427', {'name': 'berbere spice mix', 'num_ingredients': 12, 'ingredients': ['chili', 'Paprika', 'Ginger', 'cardamom', 'turmeric', 'coriander', 'fenugreek', 'cinnamon', 'nutmeg', 'allspice', 'cloves', 'pepper']})
# ('514982', {'name': 'best copycat benihana japanese chicken rice', 'num_ingredients': 14, 'ingredients': ['rice', 'butter', 'garlic', 'sesame oil', 'eggs', 'chicken', 'peas', 'carrot', 'onion', 'onion', 'salt', 'pepper', 'soy', 'sesame']})
# ('529697', {'name': 'best ever cornbread', 'num_ingredients': 8, 'ingredients': ['butter', 'eggs', 'Milk', 'sugar', 'baking', 'salt', 'flour', 'cornmeal']})
# ('511622', {'name': 'best ever green bean casserole  no canned soup', 'num_ingredients': 9, 'ingredients': ['butter', 'flour', 'salt', 'sugar', 'onion', 'sour cream', 'bean', 'onion', 'cheddar']})
# ('532179', {'name': 'best ever pecan pie bars', 'num_ingredients': 11, 'ingredients': ['butter', 'sugar', 'eggs', 'vanilla', 'flour', 'baking', 'salt', 'corn syrup', 'sugar', 'cream', 'pecan']})
# ('515446', {'name': 'best general tso s chicken from serious eats', 'num_ingredients': 20, 'ingredients': ['egg', 'soy', 'wine', 'Vodka', 'baking soda', 'cornstarch', 'chicken', 'flour', 'baking', 'salt', 'vinegar', 'broth', 'sugar', 'sesame oil', 'peanut oil', 'garlic', 'ginger', 'scallion', 'pepper', 'rice']})
# ('511837', {'name': 'best paleo pancakes', 'num_ingredients': 10, 'ingredients': ['eggs', 'Milk', 'flour', 'almond', 'banana', 'baking soda', 'gelatin', 'vanilla', 'cider', 'salt']})
# ('512954', {'name': 'best vegan blueberry muffins ever', 'num_ingredients': 10, 'ingredients': ['flour', 'sugar', 'sugar', 'sugar', 'salt', 'baking', 'banana', 'oil', 'coconut', 'blueberries']})
# ('522478', {'name': 'best ever chewy chocolate chip cookies', 'num_ingredients': 10, 'ingredients': ['butter', 'sugar', 'sugar', 'egg', 'extract', 'flour', 'cornstarch', 'baking soda', 'salt', 'chocolate']})
# ('536834', {'name': 'better than del taco chicken soft tacos', 'num_ingredients': 15, 'ingredients': ['chicken', 'lime', 'garlic', 'taco', 'oil', 'sugar', 'ranch', 'sour cream', 'lime', 'garlic', 'salt', 'lettuce', 'tomatoes', 'cheddar', 'flour']})
# ('521101', {'name': 'better than takeout chicken fried rice from rachel schultz', 'num_ingredients': 8, 'ingredients': ['rice', 'chicken breast', 'peas', 'onion', 'garlic', 'eggs', 'sesame oil', 'soy']})
# ('519383', {'name': 'betty crocker s baking powder biscuits  light  flaky and tender', 'num_ingredients': 6, 'ingredients': ['flour', 'sugar', 'baking', 'salt', 'shortening', 'Milk']})
# ('520030', {'name': 'betty crocker s salmon loaf', 'num_ingredients': 11, 'ingredients': ['salmon', 'margarine', 'flour', 'salt', 'pepper', 'Milk', 'bread', 'eggs', 'lemon', 'soup', 'water']})
# ('513249', {'name': 'betty fords buttermilk pancakes', 'num_ingredients': 7, 'ingredients': ['flour', 'baking', 'baking soda', 'salt', 'sugar', 'eggs', 'buttermilk']})
# ('522745', {'name': 'big bend texas style chili', 'num_ingredients': 17, 'ingredients': ['olive oil', 'garlic', 'onion', 'beef', 'salt', 'pepper', 'chili', 'tomatoes', 'tomato', 'beef', 'beer', 'vinegar', 'cumin', 'oregano', 'parsley', 'bean', 'cheese']})
# ('529766', {'name': 'birthday cake babka', 'num_ingredients': 12, 'ingredients': ['milk', 'yeast', 'sugar', 'flour', 'salt', 'eggs', 'vanilla', 'butter', 'sprinkles', 'extract', 'butter', 'chocolate']})
# ('530370', {'name': 'birthday cake cookies', 'num_ingredients': 7, 'ingredients': ['cake', 'baking', 'eggs', 'oil', 'chocolate', 'chocolate', 'sprinkles']})
# ('524062', {'name': 'bisquick crepes', 'num_ingredients': 7, 'ingredients': ['eggs', 'Bisquick', 'Milk', 'butter', 'cream cheese', 'sugar', 'extract']})
# ('513680', {'name': 'bistec argentino al chimichurri  steak with chimichurri sauce', 'num_ingredients': 11, 'ingredients': ['cilantro', 'vinegar', 'olive oil', 'garlic', 'adobo', 'oregano', 'pepper', 'chili', 'steak', 'herb', 'butter']})
# ('515641', {'name': 'black bean and sweet potato burritos light', 'num_ingredients': 8, 'ingredients': ['bean', 'onion', 'potato', 'peppers', 'garlic', 'cumin', 'oil', 'flour']})
# ('516662', {'name': 'black bean chocolate cake', 'num_ingredients': 9, 'ingredients': ['bean', 'eggs', 'vanilla', 'salt', 'coconut oil', 'Honey', 'cocoa', 'baking', 'baking soda']})
# ('527442', {'name': 'black bean donuts', 'num_ingredients': 15, 'ingredients': ['bean', 'milk', 'baking', 'baking soda', 'cider', 'vanilla', 'cocoa', 'salt', 'sweetener', 'oat', 'egg', 'applesauce', 'peanut', 'sugar', 'Milk']})
# ('516952', {'name': 'black bean quinoa soup', 'num_ingredients': 14, 'ingredients': ['onion', 'pepper', 'garlic', 'carrot', 'tomatoes', 'cumin', 'chili', 'cilantro', 'red pepper', 'bean', 'quinoa', 'broth', 'spinach', 'lime']})
# ('516447', {'name': 'blackberry mini muffins or mini cupcakes   you decide', 'num_ingredients': 11, 'ingredients': ['butter', 'sugar', 'eggs', 'extract', 'Milk', 'flour', 'baking soda', 'salt', 'blackberry', 'lemon', 'sugar']})
# ('514889', {'name': 'blackened cod with mango salsa', 'num_ingredients': 15, 'ingredients': ['chili', 'Paprika', 'cumin', 'garlic', 'salt', 'sugar', 'oil', 'Mango', 'onion', 'pepper', 'jalapeno', 'lime', 'salt', 'cilantro', 'cod']})
# ('520307', {'name': 'blackened pork ribs', 'num_ingredients': 11, 'ingredients': ['pork', 'salt', 'cumin', 'fennel', 'Paprika', 'clove', 'garlic', 'lime', 'ketchup', 'tabasco', 'vinegar']})
# ('531172', {'name': 'blender chocolate mousse', 'num_ingredients': 7, 'ingredients': ['chocolate', 'cream', 'butter', 'eggs', 'extract', 'salt', 'raspberries']})
# ('515629', {'name': 'bloody marys by ree drummond', 'num_ingredients': 9, 'ingredients': ['Vodka', 'lime', 'steak', 'Worcestershire', 'pepper', 'tomato', 'salt', 'pepper', 'celery']})
# ('514370', {'name': 'blue ribbon chicken pasta with prosciutto', 'num_ingredients': 13, 'ingredients': ['steak', 'pepper', 'chicken', 'olive oil', 'garlic', 'tomatoes', 'prosciutto', 'butter', 'basil', 'linguine', 'Parmesan', 'chiles', 'peppers']})
# ('522349', {'name': 'blue ribbon coleslaw', 'num_ingredients': 13, 'ingredients': ['slaw', 'onion', 'carrot', 'pepper', 'apple', 'mayonnaise', 'cream', 'vinegar', 'lemon', 'sugar', 'garlic', 'salt', 'pepper']})
# ('512753', {'name': 'blueberry and lemon ricotta cheesecake  gluten free', 'num_ingredients': 9, 'ingredients': ['oats', 'almond', 'sugar', 'butter', 'eggs', 'almond', 'ricotta', 'lemon', 'blueberries']})
# ('535644', {'name': 'blueberry cheesecake crumb cake', 'num_ingredients': 16, 'ingredients': ['flour', 'baking', 'salt', 'butter', 'lemon', 'sugar', 'sugar', 'eggs', 'vanilla', 'Mascarpone', 'cream cheese', 'sugar', 'cornstarch', 'blueberries', 'sugar', 'Milk']})
# ('519945', {'name': 'blueberry coffee cake', 'num_ingredients': 13, 'ingredients': ['butter', 'sugar', 'eggs', 'sour cream', 'extract', 'flour', 'baking', 'salt', 'blueberries', 'sugar', 'cinnamon', 'pecan', 'sugar']})
# ('536305', {'name': 'blueberry lemon oreo cheesecake bars', 'num_ingredients': 11, 'ingredients': ['butter', 'Oreo', 'blueberries', 'sugar', 'water', 'lemon', 'cornstarch', 'cream cheese', 'sour cream', 'extract', 'egg']})
# ('527141', {'name': 'bob s sloppy joes for 6', 'num_ingredients': 10, 'ingredients': ['ground beef', 'onion', 'pepper', 'pepper', 'garlic', 'mustard', 'ketchup', 'sugar', 'salt', 'pepper']})
# ('524301', {'name': 'bob s taco soup with pasta', 'num_ingredients': 11, 'ingredients': ['beef', 'onion', 'tomatoes', 'bean', 'taco', 'corn', 'chili', 'jalapeno', 'ranch', 'pasta', 'sour cream']})
# ('513973', {'name': 'bobotie  south african curry meat loaf', 'num_ingredients': 17, 'ingredients': ['tea', 'raisin', 'apricot', 'oil', 'garlic', 'onion', 'turmeric', 'coriander', 'pepper', 'cumin', 'fenugreek', 'pepper', 'fennel', 'salt', 'cider', 'ground beef', 'almond']})
# ('520015', {'name': 'boiled pig feet', 'num_ingredients': 10, 'ingredients': ['salt', 'onion', 'garlic', 'pepper', 'onion', 'cider', 'bay', 'parsley', 'seasoning', 'pepper']})
# ('518243', {'name': 'bok choy in cream sauce', 'num_ingredients': 9, 'ingredients': ['cabbage', 'oil', 'salt', 'sugar', 'stock', 'cornstarch', 'water', 'Milk', 'pepper']})
# ('533432', {'name': 'booyah the soup', 'num_ingredients': 21, 'ingredients': ['chicken', 'beef', 'flour', 'kielbasa', 'olive oil', 'onion', 'pepper', 'celery', 'carrot', 'turnip', 'potato', 'barley', 'corn', 'pea', 'seasoning', 'pepper', 'salt', 'pepper', 'tomatoes', 'chicken', 'beer']})
# ('513641', {'name': 'border quiche   low carb', 'num_ingredients': 11, 'ingredients': ['butter', 'eggs', 'cream', 'hot pepper sauce', 'salt', 'pepper', 'chili', 'chorizo', 'Muenster', 'cilantro', 'scallion']})
# ('520055', {'name': 'bourbon chicken   jasmine rice', 'num_ingredients': 13, 'ingredients': ['sesame oil', 'chicken', 'garlic', 'ginger', 'pepper', 'apple', 'sugar', 'ketchup', 'vinegar', 'bourbon', 'soy', 'rice', 'scallion']})
# ('534558', {'name': 'braciole', 'num_ingredients': 12, 'ingredients': ['beef', 'garlic', 'cheese', 'parsley', 'salt', 'prosciutto', 'olive oil', 'garlic', 'wine', 'tomato', 'basil', 'ziti']})
# ('535724', {'name': 'braised brisket tacos', 'num_ingredients': 29, 'ingredients': ['beef', 'salt', 'olive oil', 'carrot', 'onion', 'celery', 'pepper', 'garlic', 'coriander', 'cumin', 'Paprika', 'pepper', 'oregano', 'tomato', 'tomato', 'beef broth', 'avocado', 'Lemon', 'basil', 'cheese', 'apple', 'pear', 'cabbage', 'cider', 'tortilla', 'cilantro', 'Lime', 'Yogurt', 'hot sauce']})
# ('534393', {'name': 'braised cauliflower with bacon', 'num_ingredients': 8, 'ingredients': ['cauliflower', 'olive oil', 'garlic', 'Bacon', 'onion', 'tomatoes', 'red pepper', 'salt']})
# ('513820', {'name': 'bratwurst wraps with onion sauerkraut filling', 'num_ingredients': 11, 'ingredients': ['bratwurst', 'beer', 'onion', 'oil', 'sauerkraut', 'sugar', 'salt', 'red pepper', 'flour', 'mustard', 'cheese']})
# ('513812', {'name': 'brazilian chicken and rice with olives', 'num_ingredients': 10, 'ingredients': ['chicken', 'olive oil', 'garlic', 'zest', 'water', 'juice', 'rice', 'olive', 'cilantro', 'orange']})
# ('517907', {'name': 'brazilian shrimp stew', 'num_ingredients': 13, 'ingredients': ['shrimp', 'salt', 'pepper', 'garlic', 'lemon', 'tomatoes', 'onion', 'pepper', 'oil', 'cayenne', 'cilantro', 'coconut', 'oil']})
# ('517531', {'name': 'breaded fried steak   milanesa', 'num_ingredients': 9, 'ingredients': ['beef', 'breadcrumb', 'oregano', 'flour', 'salt', 'pepper', 'eggs', 'oil', 'salt']})
# ('529787', {'name': 'breakfast egg muffins', 'num_ingredients': 11, 'ingredients': ['olive oil', 'ground beef', 'salt', 'thyme', 'garlic', 'paprika', 'pepper', 'pepper', 'pepper', 'eggs', 'parsley']})
# ('513821', {'name': 'breakfast grilled cheese mexican style', 'num_ingredients': 6, 'ingredients': ['cheese', 'eggs', 'bacon', 'onion', 'bread', 'butter']})
# ('532077', {'name': 'breakfast muffins to go', 'num_ingredients': 15, 'ingredients': ['olive oil', 'garlic', 'onion', 'zucchini', 'chives', 'cheese', 'flour', 'baking', 'salt', 'eggs', 'avocado', 'chip', 'Honey', 'lemon', 'sriracha']})
# ('533171', {'name': 'breakfast taquitos', 'num_ingredients': 11, 'ingredients': ['sausage', 'eggs', 'salt', 'pepper', 'spray', 'cheddar', 'cilantro', 'tortillas', 'Salsa', 'hot sauce', 'sour cream']})
# ('516279', {'name': 'bright and fresh thai beef salad', 'num_ingredients': 15, 'ingredients': ['Anaheim', 'tomatoes', 'lemongrass', 'fish', 'lime', 'mint', 'Honey', 'garlic', 'chili', 'olive oil', 'beef', 'pepper', 'Lettuce', 'radicchio', 'arugula']})
# ('511612', {'name': 'broccoli and bean soup', 'num_ingredients': 6, 'ingredients': ['onion', 'garlic', 'broth', 'broccoli', 'bean', 'pepper']})
# ('534509', {'name': 'broccoli cauliflower mac and cheese', 'num_ingredients': 10, 'ingredients': ['pasta', 'butter', 'flour', 'shallot', 'Milk', 'salt', 'cheddar', 'cheese', 'broccoli', 'cauliflower']})
# ('520442', {'name': 'broccoli cheddar latkes', 'num_ingredients': 12, 'ingredients': ['broccoli', 'potato', 'onion', 'panko', 'eggs', 'pepper', 'salt', 'pepper', 'flour', 'cheddar', 'oil', 'oil']})
# ('513724', {'name': 'broiled halibut steaks with cranberry compote', 'num_ingredients': 11, 'ingredients': ['halibut', 'oil', 'onion', 'cranberries', 'pear', 'sugar', 'water', 'cloves', 'salt', 'pepper', 'walnut']})
# ('520577', {'name': 'broiled honey lime salmon', 'num_ingredients': 8, 'ingredients': ['salmon', 'pepper', 'olive oil', 'Honey', 'lime', 'lime', 'soy', 'cilantro']})
# ('514825', {'name': 'brown sugar carmel pound cake', 'num_ingredients': 13, 'ingredients': ['butter', 'sugar', 'sugar', 'eggs', 'flour', 'baking', 'salt', 'milk', 'toffee', 'pecan', 'milk', 'sugar', 'extract']})
# ('534954', {'name': 'brownie baklava', 'num_ingredients': 11, 'ingredients': ['butter', 'chocolate', 'sugar', 'eggs', 'vanilla', 'flour', 'cinnamon', 'walnut', 'pistachio', 'phyllo', 'Honey']})
# ('535690', {'name': 'brownie terrarium', 'num_ingredients': 19, 'ingredients': ['mix', 'candy', 'Graham', 'brownie', 'egg', 'sugar', 'salt', 'cream', 'chocolate', 'extract', 'coconut oil', 'chocolate', 'flour', 'baking powder', 'salt', 'cocoa', 'eggs', 'Coconut', 'food']})
# ('532637', {'name': 'bruschetta grilled chicken zoodle bowl', 'num_ingredients': 13, 'ingredients': ['olive oil', 'vinegar', 'salt', 'pepper', 'garlic', 'basil', 'chicken', 'tomatoes', 'onion', 'olive oil', 'salt', 'parmesan', 'zucchini']})
# ('513874', {'name': 'budget bytes  italian wonderpot', 'num_ingredients': 12, 'ingredients': ['broth', 'olive oil', 'Fettuccine', 'spinach', 'tomatoes', 'onion', 'garlic', 'basil', 'oregano', 'pepper', 'pepper', 'Feta']})
# ('512719', {'name': 'buffalo cauliflower chili   crock pot', 'num_ingredients': 15, 'ingredients': ['cauliflower', 'onion', 'bean', 'tomatoes', 'chili', 'hot sauce', 'sugar', 'chili', 'cumin', 'pepper', 'salt', 'blue cheese', 'celery', 'onion', 'sour cream']})
# ('522824', {'name': 'buffalo cauliflower sandwich', 'num_ingredients': 18, 'ingredients': ['cauliflower', 'Milk', 'water', 'flour', 'garlic', 'onion', 'cumin', 'Paprika', 'salt', 'pepper', 'butter', 'hot sauce', 'mayonnaise', 'cider', 'dill', 'parsley', 'chives', 'salt']})
# ('530729', {'name': 'buffalo cauliflower tots', 'num_ingredients': 10, 'ingredients': ['olive oil', 'onion', 'cauliflower', 'flour', 'eggs', 'hot sauce', 'salt', 'pepper', 'rice', 'ranch']})
# ('523551', {'name': 'buffalo chicken fritos pie', 'num_ingredients': 11, 'ingredients': ['chicken', 'chicken', 'salt', 'hot sauce', 'cream', 'butter', 'cheese', 'Fritos', 'ranch', 'tomatoes', 'onion']})
# ...
# ('537089', {'name': 'vampire s kiss cake', 'num_ingredients': 18, 'ingredients': ['egg', 'eggs', 'milk', 'vanilla', 'flour', 'sugar', 'baking', 'salt', 'butter', 'frosting', 'lemon', 'almond', 'corn', 'cornstarch', 'food coloring', 'food', 'food coloring', 'sprinkles']})
# ('515188', {'name': 'vanilla cornmeal griddle cakes with pears', 'num_ingredients': 15, 'ingredients': ['butter', 'flour', 'cornflour', 'sugar', 'baking', 'salt', 'nutmeg', 'buttermilk', 'grits', 'egg', 'juice', 'extract', 'pear', 'butter', 'syrup']})
# ('517394', {'name': 'vanilla custards with roasted berries', 'num_ingredients': 8, 'ingredients': ['milk', 'vanilla', 'egg', 'sugar', 'flour', 'butter', 'blueberries', 'lemon']})
# ('529309', {'name': 'veal ribs with fontina cheese', 'num_ingredients': 8, 'ingredients': ['veal', 'rib', 'eggs', 'olive oil', 'butter', 'garlic', 'fontina', 'truffle']})
# ('516828', {'name': 'vegan banana chocolate cake', 'num_ingredients': 12, 'ingredients': ['oil', 'chocolate', 'sugar', 'banana', 'flour', 'baking', 'salt', 'cinnamon', 'nutmeg', 'cloves', 'nuts', 'raisin']})
# ('524458', {'name': 'vegan collard greens', 'num_ingredients': 10, 'ingredients': ['greens', 'bouillon', 'onion', 'garlic', 'tomatoes', 'jalapeno', 'vinegar', 'water', 'olive oil', 'salt']})
# ('528506', {'name': 'vegan fried cauliflower', 'num_ingredients': 9, 'ingredients': ['flour', 'paprika', 'garlic', 'seasoning', 'salt', 'water', 'oil', 'coconut oil', 'cauliflower']})
# ('511625', {'name': 'vegan graham crackers', 'num_ingredients': 9, 'ingredients': ['flour', 'sugar', 'baking soda', 'cinnamon', 'salt', 'oil', 'syrup', 'extract', 'water']})
# ('530722', {'name': 'vegan oatmeal pancakes with banana', 'num_ingredients': 9, 'ingredients': ['oat', 'water', 'baking', 'flax', 'cinnamon', 'vanilla', 'Honey', 'banana', 'salt']})
# ('530409', {'name': 'vegan pizza margherita', 'num_ingredients': 12, 'ingredients': ['sugar', 'yeast', 'water', 'flour', 'salt', 'olive oil', 'cornmeal', 'tomato', 'garlic', 'basil', 'chili', 'cheese']})
# ('513113', {'name': 'vegan spelt buns or rolls', 'num_ingredients': 9, 'ingredients': ['water', 'coconut oil', 'Yeast', 'sugar', 'water', 'flax', 'salt', 'flour', 'poppy']})
# ('519882', {'name': 'vegetable broth base', 'num_ingredients': 8, 'ingredients': ['leek', 'carrot', 'root', 'parsley', 'onion', 'salt', 'tomato', 'soy']})
# ('519394', {'name': 'vegetarian african peanut soup', 'num_ingredients': 11, 'ingredients': ['broth', 'onion', 'ginger', 'garlic', 'salt', 'greens', 'peanut', 'tomato', 'hot sauce', 'peanut', 'rice']})
# ('529568', {'name': 'vegetarian french dip sandwiches', 'num_ingredients': 12, 'ingredients': ['onion', 'mushroom', 'butter', 'salt', 'thyme', 'oregano', 'broth', 'soy', 'sugar', 'garlic', 'bread', 'Provolone']})
# ('517857', {'name': 'vegetarian lomo saltado', 'num_ingredients': 14, 'ingredients': ['mushroom', 'tofu', 'oil', 'onion', 'garlic', 'pepper', 'tomatoes', 'soy', 'oregano', 'cumin', 'vinegar', 'salt', 'fries', 'rice']})
# ('517530', {'name': 'venezuelan pepito sandwich   pepito venezolano', 'num_ingredients': 7, 'ingredients': ['roll', 'steak', 'oil', 'garlic', 'soy', 'Worcestershire', 'salt']})
# ('514024', {'name': 'venezuelan spiced hot chocolate', 'num_ingredients': 8, 'ingredients': ['Milk', 'anise', 'cinnamon', 'orange', 'allspice', 'sugar', 'chocolate', 'rum']})
# ('513187', {'name': 'vermont whole wheat oatmeal honey bread', 'num_ingredients': 10, 'ingredients': ['water', 'oats', 'sugar', 'Honey', 'butter', 'salt', 'cinnamon', 'yeast', 'flour', 'flour']})
# ('514161', {'name': 'vietnamese beef marinade', 'num_ingredients': 11, 'ingredients': ['onion', 'ginger', 'garlic', 'pepper', 'pear', 'soy', 'sugar', 'sugar', 'sesame oil', 'oil', 'onion']})
# ('520663', {'name': 'vietnamese bun cha gio', 'num_ingredients': 19, 'ingredients': ['pork', 'ginger', 'garlic', 'fish', 'soy', 'sugar', 'peanut oil', 'water', 'vinegar', 'chili-garlic', 'salt', 'carrot', 'Vermicelli', 'mung', 'cucumber', 'cilantro', 'peanut', 'onion', 'roll']})
# ('535341', {'name': 'vietnamese caramelized pork  thit ko    instant pot version', 'num_ingredients': 13, 'ingredients': ['pork', 'eggs', 'sugar', 'garlic', 'shallot', 'anise', 'pepper', 'salt', 'soy', 'msg', 'coconut', 'water', 'fish']})
# ('535389', {'name': 'vietnamese chicken', 'num_ingredients': 11, 'ingredients': ['chicken', 'onion', 'garlic', 'Ginger', 'salt', 'pepper', 'chili', 'olive oil', 'sugar', 'water', 'Soya']})
# ('516702', {'name': 'vietnamese chicken liver pate', 'num_ingredients': 9, 'ingredients': ['liver', 'Milk', 'wine', 'onion', 'garlic', 'fish', 'salt', 'pepper', 'butter']})
# ('514721', {'name': 'vietnamese lemongrass pork', 'num_ingredients': 9, 'ingredients': ['pork', 'sugar', 'garlic', 'shallot', 'lemongrass', 'pepper', 'soy sauce', 'fish', 'oil']})
# ('523426', {'name': 'vietnamese style caramel chicken with broccoli', 'num_ingredients': 9, 'ingredients': ['baking soda', 'chicken', 'sugar', 'fish', 'ginger', 'broccoli', 'cornstarch', 'pepper', 'cilantro']})
# ('511623', {'name': 'vinegar air and salty crispy potatoes   british larder', 'num_ingredients': 6, 'ingredients': ['vinegar', 'water', 'gelatin', 'potato', 'salt', 'oil']})
# ('523306', {'name': 'vinegar dill coleslaw', 'num_ingredients': 11, 'ingredients': ['cabbage', 'carrot', 'cabbage', 'onion', 'sugar', 'oil', 'vinegar', 'mustard', 'dill', 'celery', 'salt']})
# ('518198', {'name': 'walnut crusted cherry chicken  a1', 'num_ingredients': 17, 'ingredients': ['walnut', 'pepper', 'sugar', 'paprika', 'salt', 'rosemary', 'sage', 'chicken', 'olive oil', 'cherry', 'sugar', 'sauce', 'mustard', 'agave', 'jelly', 'jelly', 'mint']})
# ('527823', {'name': 'walnut rolls', 'num_ingredients': 8, 'ingredients': ['walnut', 'cinnamon', 'cloves', 'sugar', 'phyllo', 'butter', 'water', 'lemon']})
# ('526150', {'name': 'warm roasted vegetable farro salad', 'num_ingredients': 14, 'ingredients': ['eggplant', 'salt', 'tomatoes', 'zucchini', 'mushroom', 'garlic', 'onion', 'olive oil', 'farro', 'milk', 'vinegar', 'cilantro', 'salt', 'pepper']})
# ('524868', {'name': 'warm shrimp nest salad  ragu', 'num_ingredients': 12, 'ingredients': ['pasta', 'squash', 'parmesan', 'eggs', 'shrimp', 'garlic', 'arugula', 'vinegar', 'cheese', 'butter', 'salt', 'pepper']})
# ('513395', {'name': 'warm sweet potato salad with chorizo', 'num_ingredients': 10, 'ingredients': ['potato', 'olive oil', 'juice', 'sugar', 'salt', 'pepper', 'chorizo', 'pepper', 'onion', 'cilantro']})
# ('520788', {'name': 'warren ohio hot dog shoppe sauce', 'num_ingredients': 10, 'ingredients': ['beef', 'salt', 'sugar', 'chili', 'clove', 'nutmeg', 'Paprika', 'ketchup', 'water', 'flour']})
# ('522871', {'name': 'wasabi ae  broccoli with wasabi sauce', 'num_ingredients': 6, 'ingredients': ['broccoli', 'water', 'wasabi', 'soy', 'sake', 'sugar']})
# ('516296', {'name': 'watermelon sangria with sriracha', 'num_ingredients': 8, 'ingredients': ['watermelon', 'wine', 'rum', 'sugar', 'chili', 'lime', 'ginger', 'mint']})
# ('520322', {'name': 'weight watchers classic lasagna', 'num_ingredients': 20, 'ingredients': ['olive oil', 'onion', 'carrot', 'celery', 'garlic', 'ground beef', 'wine', 'tomatoes', 'tomato', 'oregano', 'salt', 'pepper', 'pepper', 'basil', 'Ricotta', 'egg', 'parmesan', 'parsley', 'lasagna', 'mozzarella']})
# ('519141', {'name': 'weight watchers italian sausage and pepper pasta', 'num_ingredients': 10, 'ingredients': ['sausage', 'olive oil', 'pepper', 'wine', 'garlic', 'tomato', 'red pepper', 'salt', 'fusilli', 'basil']})
# ('512242', {'name': 'weight watchers parmesan crusted chicken schnitzels', 'num_ingredients': 7, 'ingredients': ['chicken', 'breadcrumb', 'parmesan', 'garlic', 'oregano', 'salt', 'oil']})
# ('533134', {'name': 'welsh dragon pie', 'num_ingredients': 12, 'ingredients': ['pork', 'leek', 'butter', 'cumin', 'pepper', 'salt', 'flour', 'Lard', 'water', 'salt', 'stock', 'gelatin']})
# ('521673', {'name': 'west african chili', 'num_ingredients': 18, 'ingredients': ['ham', 'bay', 'chilies', 'pepper', 'garlic', 'cumin', 'salt', 'water', 'olive oil', 'onion', 'tomatoes', 'curry', 'cumin', 'paprika', 'chili', 'cauliflower', 'carrot', 'chard']})
# ('511737', {'name': 'whiskey pretzels', 'num_ingredients': 6, 'ingredients': ['pretzel', 'butter', 'whiskey', 'sugar', 'garlic', 'pepper']})
# ('534786', {'name': 'white bean and chicken chili', 'num_ingredients': 11, 'ingredients': ['chicken', 'onion', 'garlic', 'bean', 'chicken', 'chili', 'soup', 'cumin', 'pepper', 'olive oil', 'cheese']})
# ('513918', {'name': 'white bean green chili with ground pork', 'num_ingredients': 12, 'ingredients': ['bean', 'pork', 'chili', 'garlic', 'onion', 'chicken', 'cumin', 'garlic', 'chili', 'Paprika', 'pepper', 'salt']})
# ('516610', {'name': 'white castle turkey stuffing', 'num_ingredients': 6, 'ingredients': ['hamburger', 'celery', 'thyme', 'sage', 'pepper', 'chicken']})
# ('535874', {'name': 'white chocolate grasshopper pie', 'num_ingredients': 18, 'ingredients': ['flour', 'baking soda', 'baking', 'shortening', 'sugar', 'egg', 'food', 'chocolate', 'gelatin', 'water', 'marshmallow', 'half-and-half', 'creme de menthe', 'cream', 'water', 'gelatin', 'white chocolate', 'corn']})
# ('534956', {'name': 'white chocolate mousse mirror cake', 'num_ingredients': 10, 'ingredients': ['strawberry', 'gelatin', 'sugar', 'chocolate', 'water', 'cream', 'cake', 'sugar', 'glucose', 'milk']})
# ('534266', {'name': 'white chocolate peppermint candies', 'num_ingredients': 6, 'ingredients': ['spray', 'chocolate', 'cream', 'peppermint', 'food coloring', 'candy']})
# ('516142', {'name': 'white chocolate raspberry pancakes', 'num_ingredients': 8, 'ingredients': ['flour', 'baking soda', 'salt', 'egg', 'sour cream', 'Milk', 'raspberries', 'white chocolate']})
# ('518114', {'name': 'white chocolate rose pudding', 'num_ingredients': 6, 'ingredients': ['Milk', 'cream', 'cornstarch', 'white chocolate', 'essence', 'salt']})
# ('517641', {'name': 'white russian sorbet', 'num_ingredients': 8, 'ingredients': ['water', 'sugar', 'espresso', 'syrup', 'cream', 'Vodka', 'coffee', 'coffee']})
# ('530037', {'name': 'whole 30 hibachi chicken', 'num_ingredients': 8, 'ingredients': ['aminos', 'garlic', 'pineapple', 'ginger', 'onion', 'cilantro', 'pepper', 'chicken']})
# ('520769', {'name': 'whole lemon roasted chicken', 'num_ingredients': 7, 'ingredients': ['lemon', 'butter', 'thyme', 'salt', 'chicken', 'pepper', 'garlic']})
# ('531446', {'name': 'whole wheat spaghetti bolognese', 'num_ingredients': 16, 'ingredients': ['carrot', 'root', 'parsley', 'onion', 'garlic', 'olive oil', 'beef', 'bacon', 'tomato', 'wine', 'beef', 'bay', 'thyme', 'pepper', 'spaghetti', 'Grana Padano']})
# ('520313', {'name': 'wholly huli pulled pork', 'num_ingredients': 12, 'ingredients': ['pork', 'oil', 'sesame oil', 'soy', 'pineapple', 'sugar', 'ginger', 'sake', 'onion', 'garlic', 'pepper', 'onion']})
# ('536066', {'name': 'widow s soup', 'num_ingredients': 16, 'ingredients': ['butter', 'olive oil', 'onion', 'garlic', 'parsley', 'potato', 'carrot', 'kohlrabi', 'celery', 'bean', 'pea', 'cauliflower', 'tomato', 'stock', 'salt', 'cheese']})
# ('511932', {'name': 'wild rice and ham soup   lower fat', 'num_ingredients': 11, 'ingredients': ['butter', 'onion', 'flour', 'broth', 'rice', 'mushroom', 'carrot', 'ham', 'almond', 'milk', 'wine']})
# ('512536', {'name': 'wings peanut butter and jelly wings', 'num_ingredients': 7, 'ingredients': ['jelly', 'peanut butter', 'vinegar', 'hot pepper sauce', 'salt', 'chicken', 'cilantro']})
# ('521748', {'name': 'world s best pasta sauce', 'num_ingredients': 14, 'ingredients': ['sausage', 'ground beef', 'onion', 'garlic', 'tomato', 'tomato', 'tomato', 'water', 'sugar', 'basil', 'fennel', 'seasoning', 'salt', 'pepper']})
# ('514626', {'name': 'ww broccoli with spicy honey sesame sauce', 'num_ingredients': 6, 'ingredients': ['broccoli', 'soy sauce', 'Honey', 'seed', 'sesame oil', 'pepper']})
# ('513171', {'name': 'ww brussels sprouts with dried canberries and lemon   3 pts', 'num_ingredients': 6, 'ingredients': ['Brussels', 'cranberries', 'lemon', 'olive oil', 'salt', 'pepper']})
# ('514750', {'name': 'ww soba chicken noodle bowl', 'num_ingredients': 11, 'ingredients': ['soba', 'chicken broth', 'water', 'chicken', 'mushroom', 'ginger', 'soy sauce', 'pea', 'peas', 'spinach', 'scallion']})
# ('527467', {'name': 'yakitori chicken', 'num_ingredients': 12, 'ingredients': ['sake', 'mirin', 'garlic', 'ginger', 'red pepper', 'sugar', 'soy sauce', 'soy', 'chicken', 'scallion', 'pepper', 'pear']})
# ('527351', {'name': 'yellow butter cake', 'num_ingredients': 12, 'ingredients': ['cake mix', 'butter', 'eggs', 'cream cheese', 'sugar', 'extract', 'chocolate', 'white chocolate', 'flour', 'Milk', 'sugar', 'vanilla']})
# ('523043', {'name': 'yellow squash and corn saute', 'num_ingredients': 7, 'ingredients': ['corn', 'squash', 'water', 'butter', 'parsley', 'salt', 'pepper']})
# ('512528', {'name': 'yemeni lentil soup', 'num_ingredients': 13, 'ingredients': ['lentils', 'oil', 'tomatoes', 'onion', 'garlic', 'cumin', 'coriander', 'turmeric', 'salt', 'water', 'pepper', 'pepper', 'pepper']})
# ('517455', {'name': 'yogurt and dill  crack  sauce', 'num_ingredients': 6, 'ingredients': ['yogurt', 'mayonnaise', 'lemon', 'dill', 'garlic', 'salt']})
# ('533161', {'name': 'yogurt fruit bark', 'num_ingredients': 6, 'ingredients': ['yogurt', 'syrup', 'peach', 'blueberries', 'strawberry', 'granola']})
# ('516278', {'name': 'yummy corn cakes', 'num_ingredients': 13, 'ingredients': ['cornmeal', 'flour', 'salt', 'baking soda', 'pepper', 'sugar', 'butter', 'egg', 'buttermilk', 'corn', 'onion', 'pepper', 'cheese']})
# ('522942', {'name': 'yuzu cocktail', 'num_ingredients': 6, 'ingredients': ['rum', 'vodka', 'sec', 'syrup', 'yuzu', 'soda']})
# ('532829', {'name': 'zaatar pita bread', 'num_ingredients': 11, 'ingredients': ["Za'atar", 'olive oil', 'bread', 'labneh', 'tomato', 'olive', 'flour', 'yeast', 'salt', 'sugar', 'water']})
# ('516905', {'name': 'zero carb bread', 'num_ingredients': 8, 'ingredients': ['flax', 'egg', 'eggs', 'flax seed', 'baking', 'salt', 'water', 'Stevia']})
# ('524487', {'name': 'zesty chicken and black bean salad   starbucks copycat', 'num_ingredients': 15, 'ingredients': ['tomato', 'vinegar', 'olive oil', 'mustard', 'garlic', 'basil', 'salt', 'quinoa', 'salad', 'tomatoes', 'bean', 'corn', 'jicama', 'Feta', 'chicken']})
# ('517517', {'name': 'zharenaya kartoshka fried potatoes russian style', 'num_ingredients': 7, 'ingredients': ['potato', 'onion', 'garlic', 'mushroom', 'water', 'oil', 'onion']})
# ('511888', {'name': 'zippy meatloaf   2 5 qt  pressure cooker', 'num_ingredients': 14, 'ingredients': ['salt', 'pepper', 'oatmeal', 'Worcestershire', 'parsley', 'onion', 'celery', 'garlic', 'pepper', 'sirloin', 'pork', 'oil', 'ketchup', 'tomato sauce']})
# ('531003', {'name': 'zucchini and sweet corn chowder', 'num_ingredients': 13, 'ingredients': ['zucchini', 'zucchini', 'onion', 'garlic', 'celery', 'corn', 'epazote', 'half-and-half', 'pepper', 'turmeric', 'water', 'oil', 'salt']})
# ('522243', {'name': 'zucchini fritters  low carb', 'num_ingredients': 12, 'ingredients': ['zucchini', 'scallion', 'eggs', 'cream cheese', 'parmesan', 'garlic', 'basil', 'salt', 'pepper', 'powder', 'butter', 'olive oil']})
# ('517690', {'name': 'zucchini lemon poppyseed bread', 'num_ingredients': 14, 'ingredients': ['sugar', 'eggs', 'vanilla', 'oil', 'Milk', 'lemon', 'salt', 'baking soda', 'baking', 'flour', 'flour', 'cinnamon', 'poppy', 'zucchini']})
# ('528086', {'name': 'zucchini tater tots', 'num_ingredients': 11, 'ingredients': ['zucchini', 'shallot', 'mozzarella', 'parmesan', 'panko', 'egg', 'seasoning', 'garlic', 'salt', 'olive oil', 'marinara']})
# ('515473', {'name': 'zucchini  kale  and tomato saute', 'num_ingredients': 10, 'ingredients': ['olive oil', 'onion', 'garlic', 'zucchini', 'tomatoes', 'basil', 'oregano', 'red pepper', 'salt', 'kale']})
# ('529308', {'name': 'zuppa di cipolla al vino rosso', 'num_ingredients': 10, 'ingredients': ['beef broth', 'butter', 'onion', 'flour', 'oil', 'pepper', 'salt', 'sugar', 'Gruyere', 'baguette']})

# %% [markdown]
# ## Do recipes from the same cuisine form distinct communities within the graph?

# %%
def randomize_graph(graph):
    randomized_graph = nx.algorithms.smallworld.random_reference(graph, connectivity=False)
    return randomized_graph

# %%
def print_total_communities_and_modularity(G, method, communities):
    total_communities = len(communities)
    modularity_value = modularity(G, communities)
    print(f"{method} - Total Communities: {total_communities}, Modularity: {modularity_value:.4f}")

def communities_greedy_label_summary(G, dataset_name):
    greedy_communities = list(greedy_modularity_communities(G))
    print_total_communities_and_modularity(G, "Greedy Modularity", greedy_communities)

    label_communities = list(label_propagation_communities(G))
    print_total_communities_and_modularity(G, "Label Propagation", label_communities)

print("\n=== Greedy and Label ===")
communities_greedy_label_summary(recipes_graph, 'Graph 3 Common Ingredients')

print("\n=== Randomized ===")
recipes_randomized = randomize_graph(recipes_graph)
communities_greedy_label_summary(recipes_randomized, 'Graph 3 Common Ingredients Randomized')
# Out:
# === Greedy and Label ===
# Greedy Modularity - Total Communities: 16, Modularity: 0.2566
# Label Propagation - Total Communities: 13, Modularity: 0.0000
#
# === Randomized ===
# Greedy Modularity - Total Communities: 15, Modularity: 0.0169
# Label Propagation - Total Communities: 13, Modularity: 0.0000

# %%
def print_communities_by_name(G, method, communities):
    print(f"\n{method}:")
    for i, community in enumerate(communities):
        node_names = [G.nodes[node]['name'] for node in community]
        print(f"\nCommunity {i+1} ({len(node_names)} recipes):")
        for idx, name in enumerate(node_names, start=1):
            print(f"  {idx}. {name}")
    print(f"\nTotal number of communities: {len(communities)}")
    print(f"Modularity: {modularity(G, communities):.4f}")

def communities_greedy_label(G, dataset_name):
    greedy_communities = list(greedy_modularity_communities(G))
    print_communities_by_name(G, "Greedy Modularity", greedy_communities)

    label_communities = list(label_propagation_communities(G))
    print_communities_by_name(G, "Label Propagation", label_communities)

# %%
communities_greedy_label(recipes_graph, 'Graph 3 Common Ingredients')
# Out:
# Greedy Modularity:
#
# Community 1 (1041 recipes):
#   1. hot spicey tomato oil for dipping
#   2. low carb amish ham casserole
#   3. a 1  chinese pasta  a1
#   4. mexican tomato soup with toasted pasta
#   5. sausage stuffed ragu mushrooms  ragu
#   6. basil   mint orzo salad
#   7. cayenne cherry chocolate steak sauce  a1
#   8. crunchy lentil walnut salad
#   9. spice rubbed tilapia with tomatillo  black bean and mango salad
#   10. one pan no peek chicken and rice
#   11. maltese stuffed eggplant  brungiel mimli
#   12. alan s vegetarian vegan bean and rice burger mashup
#   13. pasta and burnt butter sauce
#   14. janet s kfc seasoned fried chicken
#   15. creole oven fried chicken and rice
#   16. spicy shrimp tacos with garlic cilantro lime slaw
#   17. easy  delicious   low carb taco soup
#   18. greek style watermelon salad
#   19. creamy beef   rice casserole
#   20. chicken adobo   steamy kitchen
#   21. huevos rancheros potato waffles
#   22. fig and bourbon fizz
#   23. unrolled cabbage rolls
#   24. crispy baked tofu with pineapple  avocado   corn salad  a1
#   25. bourbon chicken   jasmine rice
#   26. bacon potato cheddar tart
#   27. sweet and savory chicken rice bowl
#   28. seared ahi tuna
#   29. lump crabmeat and avocado crostini
#   30. fear the reaper bbq sauce
#   31. slow cooker pho
#   32. dal bhat  red lentils with rice
#   33. alea s corned beef and cabbage soup
#   34. black bean and sweet potato burritos light
#   35. clams in butter garlic herb
#   36. navy bean  ham and potato soup
#   37. panda express eggplant tofu
#   38. stuffing butter
#   39. light thai coconut soup
#   40. mel s brown pizza sauce
#   572. shrimp scampi garlic bread
#   573. portuguese macaroni   bean soup
#   574. aji criollo   green aji salsa
#   575. smooth smoking spicy salsa
#   576. caesar dressing
#   577. slow cooker chicken burrito bowls
#   578. shrimp and crab meat with rice
#   579. roasted potatoes  leeks and cabbage
#   580. crockpot venison roast
#   581. creamy sriracha dressing
#   582. kfc kentucky fried chicken with 11 special seasonings
#   583. calico slaw with poppyseed dressing
#   584. lemon chicken and spaghetti squash
#   585. creamy vegan tomato sauce
#   586. satisfying tomato soup
#   587. spice rubbed pork with quinoa
#   588. lentil  bean   parsley salad
#   589. chipotle agave chicken wings
#   590. kick n chunky chicken tortilla soup
#   591. food works parmesan roasted broccoli
#   592. rainbow trout  tilapia  baked
#   593. breakfast egg muffins
#   594. warm roasted vegetable farro salad
#   595. slow cooker quinoa chicken chili
#   596. cheesy potato zucchini casserole
#   597. caldo verde
#   598. mashup mexican lasagna
#   599. fresh cucumber condiment   tang kwah ah jad
#   600. red wine braised short ribs with fingerlings potatoes
#   601. bacon wrapped steak
#   602. honey lemon glazed cauliflower
#   603. paleo chipotle chicken cauliflower bake
#   604. bistec argentino al chimichurri  steak with chimichurri sauce
#   605. pureed beets with yogurt   zaatar
#   606. weight watchers parmesan crusted chicken schnitzels
#   607. jordanian herbal tea
#   608. quick cheeseburger pie  gold medal
#   609. saarlndischer dippelappes  or kartoffel charles  po
#   610. cheesy chicken parm volcanos
#   611. rigatoni pasta bake
#   612. purple gnocchi with shiitake mushrooms
#   613. dee s italian green bean salad
#   614. lplermagrone
#   615. roasted cauliflower potato leek and garlic soup
#   616. smoky salmon spread
#   617. shrimp tortellini pasta toss
#   618. easy avocado   feta cheese dip
#   619. flounder  or other white fish  stuffed with shrimp
#   620. quick huevos rancheros
#   621. fermented giardiniera
#   622. creamy russian salad
#   623. p f chang s pepper steak
#   624. phena s asian chicken kabobs  a1
#   625. joe holland s hamburgers
#   626. green goddess pizza
#   627. omlet
#   628. chicken helper   chicken enchilada copycat
#   629. bobotie  south african curry meat loaf
#   630. linda s low carb italian casserole
#   631. french onion baked potato soup
#   632. instant pot turkey chili
#   633. mexican tabbouleh
#   634. tasty green bean casserole cups
#   635. modern moussaka  a1
#   636. stuffed papaya
#   637. buffalo chicken monkey bread
#   638. no carb   chicken stuffed green peppers
#   639. harissa cauliflower steaks
#   640. hawaiian poke bowl
#   641. kfc inspired chicken  slow cooker
#   642. solar starninja s twisted green bean casserole
#   643. yakitori chicken
#   644. cajun jambalaya soup
#   645. parmesan french toast
#   646. pork ribs perfection
#   647. better than a can  homemade sloppy joes
#   648. grilled jerk pork tenderloin
#   649. beecher s kale and brown rice gratin with smoked cheese
#   650. grilled pork tenderloin with peach barbecue sauce
#   651. goats and grapes white pizza  ragu
#   652. oven fried chicken sliders
#   653. pan seared shrimp and bacon 3 cheese truffles  ragu
#   654. danforth salad
#   655. amy truong zucchini low carb lasagna
#   656. aha herb mix
#   657. lemongrass  lime   thai basil mojito
#   658. crock pot white chicken chili
#   659. pan fried quinoa cakes
#   1672. scallops marinara with spinach linguine
#   1673. classic raisin oatmeal cookies
#   1674. chicken pot pie  using rotisserie chicken
#   1675. chucktown sunrise
#   1676. chorizo   quinoa stuffed poblano peppers with adobo chile  t
#   1677. epic egg brunch
#   1678. honey dijon chicken from tiphero com
#   1679. panko crusted salmon
#   1680. grilled roadside chicken with knob onions
#   1681. churro ice cream cones
#   1682. steak tacos with charred salsa
#   1683. beer cheese stuffed pretzels
#   1684. touchdown turkey chili
#   1685. zucchini  kale  and tomato saute
#   1686. qunoa and black bean salad
#   1687. spicy mini pork kabobs
#   1688. duff s good ass fudge
#   1689. chicken poppy seed salad
#   1690. apple  honey   caramelized onion flatbread pizza
#   1691. blueberry coffee cake
#   1692. chocolate chip cookie slab pie
#   1693. lasagna soup with sausage
#   1694. nordic  stone age  nut and seed bread
#   1695. pineapple cannoli cones
#   1696. duba wot
#   1697. pumpkin spice granola
#   1698. cauliflower mac   cheese
#   1699. old world yugoslavian coffee cake
#   1700. green bean and carrot soup  vegan  gluten free
#   1701. austin chicken fajitas
#   1702. french green beans almondine
#   1703. cider   5 spice bundt cake
#   1704. brazilian chicken and rice with olives
#   1705. herb garden grilled hamburgers
#   1706. ketchup   from fresh garden tomatoes
#   1707. pan fried chicken with garlic and lemon
#   1708. tacos de bistec with lime sauce  mexican street tacos
#   1709. instant pot pork chop
#   1710. buscuits
#   1711. spaghetti squash casserole with sweet sausage   peppers
#   1712. portuguese chicken and rice
#   1713. roasted red potatoes in the crock pot
#   1714. rice con queso
#   1715. cranberry walnut chickpea salad sandwich
#   1716. creamy crockpot tortellini soup
#   1717. lime grilled chicken and polenta with a 1  mole sauce  a1
#
# Community 2 (1 recipes):
#   1. angelo azzurro  blue angel  cocktail
#
# Community 3 (1 recipes):
#   1. jamba juice at home white gummi bear smoothie
#
# Community 4 (1 recipes):
#   1. mississippi baked ham
#
# Community 5 (1 recipes):
#   1. pomelo spritz
#
# Community 6 (1 recipes):
#   1. slippery when wet from the one bottle cocktail
#
# Community 7 (1 recipes):
#   1. strawberry margarita spritzers
#
# Community 8 (1 recipes):
#   1. strawberry oatmeal smoothie
#
# Community 9 (1 recipes):
#   1. strawberry shortcake ice cream cake
#
# Community 10 (1 recipes):
#   1. thai almond butter shrimp
#
# Community 11 (1 recipes):
#   1. the healthy elvis shake
#
# Community 12 (1 recipes):
#   1. yogurt fruit bark
#
# Community 13 (1 recipes):
#   1. yuzu cocktail
#
# Total number of communities: 13
# Modularity: 0.0000

# %% [markdown]
# ## Which ingredients act as ”bridges” between different cuisines?

# %%
def analyze_communities(G, communities):
    analysis_results = []

    for i, community in enumerate(communities):
        recipe_names = [G.nodes[node]['name'] for node in community]

        all_ingredients = []
        for node in community:
            all_ingredients.extend(G.nodes[node].get('ingredients', []))

        ingredient_counts = Counter(all_ingredients)
        most_common_ingredients = ingredient_counts.most_common(10) 

        avg_num_ingredients = np.mean([G.nodes[node]['num_ingredients'] for node in community])

        analysis_results.append({
            "community": i + 1,
            "num_recipes": len(community),
            "most_common_ingredients": most_common_ingredients,
            "avg_num_ingredients": avg_num_ingredients,
            "recipe_names": recipe_names
        })

    return analysis_results


def print_community_analysis(results):
    for result in results:
        print("=" * 50)
        print(f"Community {result['community']}")
        print(f"Number of Recipes: {result['num_recipes']}")
        print(f"Average Number of Ingredients: {result['avg_num_ingredients']:.2f}")
        print("\nMost Common Ingredients:")
        for ingredient, count in result['most_common_ingredients']:
            print(f"  - {ingredient} ({count} times)")

        print("\nFirst 20 Recipes:")
        for idx, name in enumerate(result['recipe_names'][:20], start=1):
            print(f"  {idx}. {name}")
        print("=" * 50)

# %%
def find_bridge_ingredients(G, communities):
    node_to_community = {}
    for i, community in enumerate(communities):
        for node in community:
            node_to_community[node] = i

    bridge_ingredients = []
    for u, v in G.edges():
        if node_to_community[u] != node_to_community[v]:
            ingredients_u = set(G.nodes[u].get('ingredients', []))
            ingredients_v = set(G.nodes[v].get('ingredients', []))
            common_ingredients = ingredients_u.intersection(ingredients_v)
            bridge_ingredients.extend(common_ingredients)

    ingredient_counts = Counter(bridge_ingredients)

    return ingredient_counts

# %%
def find_bridge_ingredients_with_details(G, communities):
    node_to_community = {}
    for i, community in enumerate(communities):
        for node in community:
            node_to_community[node] = i + 1  

    bridge_ingredient_details = defaultdict(list)

    for u, v in G.edges():
        community_u = node_to_community[u]
        community_v = node_to_community[v]
        if community_u != community_v:
            ingredients_u = set(G.nodes[u].get('ingredients', []))
            ingredients_v = set(G.nodes[v].get('ingredients', []))
            common_ingredients = ingredients_u.intersection(ingredients_v)
            for ingredient in common_ingredients:
                bridge_ingredient_details[ingredient].append({
                    "recipe_u": G.nodes[u]['name'],
                    "community_u": community_u,
                    "recipe_v": G.nodes[v]['name'],
                    "community_v": community_v
                })

    return bridge_ingredient_details

# %%
greedy_communities = list(greedy_modularity_communities(recipes_graph))
community_analysis_results = analyze_communities(recipes_graph, greedy_communities)
print_community_analysis(community_analysis_results)
# Out:
# ==================================================
# Community 1
# Number of Recipes: 1041
# Average Number of Ingredients: 11.46
#
# Most Common Ingredients:
#   - pepper (803 times)
#   - garlic (725 times)
#   - salt (723 times)
#   - onion (701 times)
#   - olive oil (393 times)
#   - chicken (263 times)
#   - tomatoes (191 times)
#   - oil (187 times)
#   - lemon (177 times)
#   - butter (169 times)
#
# First 20 Recipes:
#   1. hot spicey tomato oil for dipping
#   2. low carb amish ham casserole
#   3. a 1  chinese pasta  a1
#   4. mexican tomato soup with toasted pasta
#   5. sausage stuffed ragu mushrooms  ragu
#   6. basil   mint orzo salad
#   7. cayenne cherry chocolate steak sauce  a1
#   8. crunchy lentil walnut salad
#   9. spice rubbed tilapia with tomatillo  black bean and mango salad
#   10. one pan no peek chicken and rice
#   11. maltese stuffed eggplant  brungiel mimli
#   12. alan s vegetarian vegan bean and rice burger mashup
#   13. pasta and burnt butter sauce
#   14. janet s kfc seasoned fried chicken
#   15. creole oven fried chicken and rice
#   16. spicy shrimp tacos with garlic cilantro lime slaw
#   17. easy  delicious   low carb taco soup
#   18. greek style watermelon salad
#   19. creamy beef   rice casserole
#   20. chicken adobo   steamy kitchen
# ==================================================
# ==================================================
# Community 2
# Number of Recipes: 668
# Average Number of Ingredients: 10.61
#
# Most Common Ingredients:
#   - sugar (596 times)
#   - salt (492 times)
#   - flour (435 times)
#   - butter (375 times)
#   - eggs (243 times)
#   - egg (191 times)
#   - water (178 times)
#   - Milk (177 times)
#   - baking (159 times)
#   - cinnamon (149 times)
#
# First 20 Recipes:
#   1. faux laminated maple brioche rolls
#   2. jumbo chocolate chip cookies
#   3. salvadoran sweet cheese bread
#   4. bacon and egg breakfast stromboli
#   5. marshmallow fluff sponge cake
#   6. sweet   saucy chicken
#   7. creamy ham and gnocchi bake
#   8. lightened up peanut butter pie
#   9. fannie farmer sugar cookies
#   10. mrs  o callaghan s soda bread
#   11. light   fluffy coconut macaroons
#   12. walnut rolls
#   13. polenta crusted bacon goat cheese arrotondares con  ragu
#   14. one pot bacon mac   cheese
#   15. john f kennedy waffles
#   16. kitchenaid kneaded basic white bread
#   17. johnny cakes   journey cakes
#   18. forevermama s old time pancakes
#   19. pineapple habanero pepper jelly
#   20. swans down orange coconut cake
# ==================================================
# ==================================================
# Community 3
# Number of Recipes: 5
# Average Number of Ingredients: 8.80
#
# Most Common Ingredients:
#   - soy (5 times)
#   - sugar (4 times)
#   - salt (3 times)
#   - mirin (3 times)
#   - wasabi (3 times)
#   - water (2 times)
#   - pork (1 times)
#   - eggs (1 times)
#   - garlic (1 times)
#   - shallot (1 times)
#
# First 20 Recipes:
#   1. vietnamese caramelized pork  thit ko    instant pot version
#   2. hiyashi somen   cold noodles with dipping sauce mark bittman
#   3. japanese grilled corn on the cob  yaki tomorokoshi
#   4. tuna tartar
#   5. wasabi ae  broccoli with wasabi sauce
# ==================================================
# ==================================================
# Community 4
# Number of Recipes: 3
# Average Number of Ingredients: 11.33
#
# Most Common Ingredients:
#   - pepper (4 times)
#   - butter (3 times)
#   - soup (2 times)
#   - Milk (2 times)
#   - chicken (2 times)
#   - potato (2 times)
#   - mushroom (2 times)
#   - onion (2 times)
#   - sour cream (2 times)
#   - stuffing (1 times)
#
# First 20 Recipes:
#   1. green bean  chicken   stuffing casserole
#   2. loaded breakfast potatoes
#   3. creamy chicken casserole with fingerling potatoes
# ==================================================
# ==================================================
# Community 5
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - Cointreau (1 times)
#   - limoncello (1 times)
#   - gin (1 times)
#   - Vermouth (1 times)
#   - fruit (1 times)
#   - ice (1 times)
#
# First 20 Recipes:
#   1. angelo azzurro  blue angel  cocktail
# ==================================================
# ==================================================
# Community 6
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - sherbet (2 times)
#   - Peach (1 times)
#   - soymilk (1 times)
#   - pineapple (1 times)
#   - Mango (1 times)
#   - ice (1 times)
#
# First 20 Recipes:
#   1. jamba juice at home white gummi bear smoothie
# ==================================================
# ==================================================
# Community 7
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - ham (1 times)
#   - clove (1 times)
#   - Coca-Cola (1 times)
#   - Pineapple (1 times)
#   - sugar (1 times)
#   - cherries (1 times)
#
# First 20 Recipes:
#   1. mississippi baked ham
# ==================================================
# ==================================================
# Community 8
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - tequila (1 times)
#   - liqueur (1 times)
#   - juice (1 times)
#   - lemon (1 times)
#   - syrup (1 times)
#   - wine (1 times)
#
# First 20 Recipes:
#   1. pomelo spritz
# ==================================================
# ==================================================
# Community 9
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - strawberry (2 times)
#   - Honey (1 times)
#   - gin (1 times)
#   - yogurt (1 times)
#   - pepper (1 times)
#
# First 20 Recipes:
#   1. slippery when wet from the one bottle cocktail
# ==================================================
# ==================================================
# Community 10
# Number of Recipes: 1
# Average Number of Ingredients: 8.00
#
# Most Common Ingredients:
#   - strawberries (2 times)
#   - lime (2 times)
#   - daiquiri (1 times)
#   - tequila (1 times)
#   - liqueur (1 times)
#   - soda (1 times)
#
# First 20 Recipes:
#   1. strawberry margarita spritzers
# ==================================================
# ==================================================
# Community 11
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - oatmeal (1 times)
#   - chia (1 times)
#   - milk (1 times)
#   - yogurt (1 times)
#   - strawberry (1 times)
#   - Truvia (1 times)
#
# First 20 Recipes:
#   1. strawberry oatmeal smoothie
# ==================================================
# ==================================================
# Community 12
# Number of Recipes: 1
# Average Number of Ingredients: 7.00
#
# Most Common Ingredients:
#   - strawberries (2 times)
#   - cake mix (1 times)
#   - ice cream (1 times)
#   - strawberry (1 times)
#   - wafer (1 times)
#   - icing (1 times)
#
# First 20 Recipes:
#   1. strawberry shortcake ice cream cake
# ==================================================
# ==================================================
# Community 13
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - coconut (1 times)
#   - almond butter (1 times)
#   - shrimp (1 times)
#   - stock (1 times)
#   - tomato (1 times)
#   - applesauce (1 times)
#
# First 20 Recipes:
#   1. thai almond butter shrimp
# ==================================================
# ==================================================
# Community 14
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - soymilk (1 times)
#   - banana (1 times)
#   - peanut (1 times)
#   - cocoa (1 times)
#   - ice (1 times)
#   - powder (1 times)
#
# First 20 Recipes:
#   1. the healthy elvis shake
# ==================================================
# ==================================================
# Community 15
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - yogurt (1 times)
#   - syrup (1 times)
#   - peach (1 times)
#   - blueberries (1 times)
#   - strawberry (1 times)
#   - granola (1 times)
#
# First 20 Recipes:
#   1. yogurt fruit bark
# ==================================================
# ==================================================
# Community 16
# Number of Recipes: 1
# Average Number of Ingredients: 6.00
#
# Most Common Ingredients:
#   - rum (1 times)
#   - vodka (1 times)
#   - sec (1 times)
#   - syrup (1 times)
#   - yuzu (1 times)
#   - soda (1 times)
#
# First 20 Recipes:
#   1. yuzu cocktail
# ==================================================

# %%
bridge_ingredient_counts = find_bridge_ingredients(recipes_graph, greedy_communities)

print(f"{'Rank':<5} {'Ingredient':<25} {'Number of Connections'}")
print("=" * 50)
for rank, (ingredient, count) in enumerate(bridge_ingredient_counts.most_common(), start=1):
    print(f"{rank:<5} {ingredient:<25} {count}")
# Out:
# Rank  Ingredient                Number of Connections
# ==================================================
# 1     salt                      70272
# 2     pepper                    37551
# 3     onion                     27096
# 4     garlic                    25531
# 5     butter                    18019
# 6     sugar                     12739
# 7     flour                     12145
# 8     oil                       8906
# 9     water                     8717
# 10    olive oil                 7098
# 11    chicken                   6559
# 12    eggs                      5912
# 13    egg                       3899
# 14    Milk                      3424
# 15    lemon                     3148
# 16    cheese                    2815
# 17    parsley                   2091
# 18    tomato                    1891
# 19    potato                    1891
# 20    parmesan                  1778
# 21    vinegar                   1587
# 22    carrot                    1550
# 23    cream                     1435
# 24    tomatoes                  1431
# 25    chili                     1358
# 26    mustard                   1261
# 27    cheddar                   1257
# 28    Paprika                   1080
# 29    cinnamon                  1059
# 30    cornstarch                1046
# 31    cilantro                  997
# 32    mushroom                  991
# 33    soy                       954
# 34    sour cream                948
# 35    thyme                     933
# 36    celery                    928
# 37    bacon                     847
# 38    ginger                    793
# 39    rice                      786
# 40    cumin                     746
# 41    lime                      702
# 42    bean                      634
# 43    basil                     613
# 44    beef                      610
# 45    scallion                  549
# 46    corn                      540
# 47    cream cheese              431
# 48    Honey                     421
# 49    breadcrumb                413
# 50    seasoning                 377
# 51    oregano                   375
# 52    pasta                     371
# 53    pork                      348
# 54    wine                      348
# 55    stock                     326
# 56    Worcestershire            303
# 57    milk                      289
# 58    nutmeg                    259
# 59    sauce                     253
# 60    shallot                   245
# 61    chives                    213
# 62    shrimp                    198
# 63    mayonnaise                196
# 64    cloves                    187
# 65    spinach                   186
# 66    broth                     186
# 67    mozzarella                180
# 68    hot sauce                 179
# 69    panko                     178
# 70    ketchup                   153
# 71    baking                    144
# 72    sesame oil                139
# 73    cider                     127
# 74    sausage                   127
# 75    Ginger                    127
# 76    coriander                 126
# 77    cauliflower               120
# 78    yeast                     115
# 79    broccoli                  111
# 80    allspice                  111
# 81    buttermilk                110
# 82    fish                      105
# 83    zucchini                  104
# 84    coconut                   102
# 85    ham                       101
# 86    avocado                   96
# 87    walnut                    96
# 88    paprika                   94
# 89    dill                      93
# 90    bread                     91
# 91    cabbage                   90
# 92    pineapple                 90
# 93    beef broth                87
# 94    rosemary                  87
# 95    leaf                      86
# 96    turkey                    84
# 97    coconut oil               84
# 98    raisin                    83
# 99    steak                     81
# 100   ground beef               81
# 101   turmeric                  79
# 102   apple                     78
# 103   macaroni                  73
# 104   cucumber                  72
# 105   mint                      67
# 106   beer                      67
# 107   spray                     64
# 108   seed                      62
# 109   almond                    61
# 110   red pepper                61
# 111   jalapeno                  60
# 112   squash                    60
# 113   lettuce                   59
# 114   Parsley                   57
# 115   cayenne                   54
# 116   juice                     54
# 117   clove                     50
# 118   leek                      47
# 119   pastry                    46
# 120   baking soda               45
# 121   yogurt                    43
# 122   cardamom                  43
# 123   cocoa                     40
# 124   pecan                     40
# 125   peas                      36
# 126   cornmeal                  33
# 127   chile                     33
# 128   polenta                   31
# 129   sage                      31
# 130   Molasses                  31
# 131   mirin                     31
# 132   sesame                    30
# 133   syrup                     30
# 134   Feta                      30
# 135   pickle                    30
# 136   Vinegar                   29
# 137   pine                      29
# 138   bay                       28
# 139   half-and-half             28
# 140   pea                       27
# 141   peanut oil                26
# 142   pumpkin                   25
# 143   Salsa                     22
# 144   soy sauce                 22
# 145   chorizo                   21
# 146   soup                      21
# 147   ricotta                   21
# 148   oats                      20
# 149   taco                      20
# 150   salmon                    19
# 151   orange                    19
# 152   arugula                   19
# 153   shortening                18
# 154   chocolate                 17
# 155   tarragon                  17
# 156   olive                     17
# 157   chickpea                  16
# 158   sriracha                  15
# 159   pizza                     15
# 160   margarine                 13
# 161   rum                       13
# 162   quinoa                    11
# 163   tortilla                  11
# 164   bourbon                   11
# 165   cranberries               10
# 166   chipotle                  10
# 167   pepperoni                 10
# 168   hoisin                    9
# 169   bouillon                  9
# 170   tabasco                   9
# 171   sake                      9
# 172   buns                      8
# 173   cherry                    8
# 174   spice                     8
# 175   ranch                     8
# 176   garam masala              8
# 177   saffron                   8
# 178   agave                     7
# 179   blueberries               7
# 180   anise                     7
# 181   barbecue                  7
# 182   peppers                   7
# 183   pear                      7
# 184   blue cheese               7
# 185   peaches                   7
# 186   maple syrup               7
# 187   Pork                      7
# 188   caraway                   7
# 189   peanut                    6
# 190   sherry                    6
# 191   cherries                  6
# 192   jam                       6
# 193   hot pepper sauce          6
# 194   greens                    6
# 195   applesauce                6
# 196   adobo                     6
# 197   Romaine                   6
# 198   powder                    6
# 199   cornbread                 6
# 200   ribs                      6
# 201   pistachio                 5
# 202   Coconut                   5
# 203   chicken breast            5
# 204   Queso                     5
# 205   Pickle                    5
# 206   flax                      5
# 207   spaghetti                 5
# 208   lentils                   5
# 209   strawberry                5
# 210   strawberries              5
# 211   roll                      5
# 212   noodle                    5
# 213   peanut butter             4
# 214   herb                      4
# 215   Mango                     4
# 216   artichoke                 4
# 217   tahini                    4
# 218   orzo                      4
# 219   cod                       4
# 220   pie                       4
# 221   wasabi                    4
# 222   Lemon                     3
# 223   noodles                   3
# 224   fontina                   3
# 225   tilapia                   3
# 226   fenugreek                 3
# 227   Vodka                     3
# 228   phyllo                    3
# 229   wheat                     3
# 230   beets                     3
# 231   Herbes                    3
# 232   oyster                    3
# 233   coffee                    3
# 234   scallops                  3
# 235   baguette                  3
# 236   bun                       3
# 237   Bisquick                  2
# 238   almond milk               2
# 239   crust                     2
# 240   almonds                   2
# 241   breadcrumbs               2
# 242   gouda                     2
# 243   pretzel                   2
# 244   sauerkraut                2
# 245   bratwurst                 2
# 246   zest                      2
# 247   crackers                  2
# 248   pico                      2
# 249   tea                       2
# 250   Provolone                 2
# 251   Naan                      2
# 252   vegetables                2
# 253   crema                     2
# 254   Rotel                     2
# 255   cracker                   2
# 256   crabmeat                  2
# 257   pomegranate               2
# 258   hamburger                 2
# 259   Yogurt                    2
# 260   ice                       2
# 261   peppercorn                2
# 262   stuffing                  2
# 263   fruit                     2
# 264   msg                       2
# 265   sambal                    2
# 266   whiskey                   2
# 267   potatoes                  2
# 268   chicken broth             2
# 269   mascarpone                1
# 270   apricot                   1
# 271   edam                      1
# 272   bocconcini                1
# 273   Crisco                    1
# 274   pretzels                  1
# 275   Muenster                  1
# 276   egg noodles               1
# 277   lima beans                1
# 278   peach                     1
# 279   sec                       1
# 280   tequila                   1
# 281   Asiago                    1
# 282   poppy                     1
# 283   Cashew                    1
# 284   gingerroot                1
# 285   Lime                      1
# 286   vegetable                 1
# 287   hash browns               1
# 288   rose                      1
# 289   Toast                     1
# 290   cranberry                 1
# 291   meat                      1
# 292   brioche                   1
# 293   nori                      1
# 294   pita                      1
# 295   orange juice              1
# 296   trout                     1
# 297   tapioca                   1
# 298   miso                      1
# 299   Lard                      1
# 300   Za'atar                   1
# 301   grits                     1
# 302   goat cheese               1
# 303   tuna                      1

# %%
bridge_ingredient_details = find_bridge_ingredients_with_details(recipes_graph, greedy_communities)

print("=" * 120)
print(f"{'Ingredient':<20} {'Recipe 1 (Community)':<45} {'Recipe 2 (Community)':<45}")
print("=" * 120)

for ingredient, connections in bridge_ingredient_details.items():
    print(f"\nIngredient: {ingredient}")
    for connection in connections[:10]: 
        print(f"  - {connection['recipe_u']} (Community {connection['community_u']}) "
              f"<-> {connection['recipe_v']} (Community {connection['community_v']})")
    print("-" * 120)
# Out:
# ========================================================================================================================
# Ingredient           Recipe 1 (Community)                          Recipe 2 (Community)
# ========================================================================================================================
#
# Ingredient: pepper
#   - lplermagrone (Community 1) <-> der wiener schnitzel style chili dog sauce (Community 2)
#   - lplermagrone (Community 1) <-> a 1 steak puffs with corn and avocado salsa  a1 (Community 2)
#   - lplermagrone (Community 1) <-> a 1  slow roasted shredded steak with polenta  a1 (Community 2)
#   - lplermagrone (Community 1) <-> a1 marinated top round with bacon parmesan polenta  a1 (Community 2)
#   - lplermagrone (Community 1) <-> a1b bacon burger bites on white polenta cakes  a1 (Community 2)
#   - lplermagrone (Community 1) <-> acili biskuvi  spicy biscuits (Community 2)
#   - lplermagrone (Community 1) <-> alton brown s stove top mac n cheese (Community 2)
#   - lplermagrone (Community 1) <-> austrian kaesespaetzle  cheese spaetzle (Community 2)
#   - lplermagrone (Community 1) <-> basic bechamel  white sauce (Community 2)
#   - lplermagrone (Community 1) <-> beef   chickpea paprikash (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: garlic
#   - lplermagrone (Community 1) <-> der wiener schnitzel style chili dog sauce (Community 2)
#   - lplermagrone (Community 1) <-> a 1  slow roasted shredded steak with polenta  a1 (Community 2)
#   - lplermagrone (Community 1) <-> beef   chickpea paprikash (Community 2)
#   - lplermagrone (Community 1) <-> beer bacon mac and cheese (Community 2)
#   - lplermagrone (Community 1) <-> beer cheese stuffed pretzels (Community 2)
#   - lplermagrone (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - lplermagrone (Community 1) <-> buffalo cauliflower sandwich (Community 2)
#   - lplermagrone (Community 1) <-> charquican   chilean beef stew (Community 2)
#   - lplermagrone (Community 1) <-> cheddar cheese biscuits like ruby tuesday s (Community 2)
#   - lplermagrone (Community 1) <-> cheesy jalapeno corn casserole  slow cooker (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: salt
#   - lplermagrone (Community 1) <-> der wiener schnitzel style chili dog sauce (Community 2)
#   - lplermagrone (Community 1) <-> ham  solo savory cake (Community 2)
#   - lplermagrone (Community 1) <-> a 1 steak puffs with corn and avocado salsa  a1 (Community 2)
#   - lplermagrone (Community 1) <-> a 1  slow roasted shredded steak with polenta  a1 (Community 2)
#   - lplermagrone (Community 1) <-> a1 marinated top round with bacon parmesan polenta  a1 (Community 2)
#   - lplermagrone (Community 1) <-> a1b bacon burger bites on white polenta cakes  a1 (Community 2)
#   - lplermagrone (Community 1) <-> acili biskuvi  spicy biscuits (Community 2)
#   - lplermagrone (Community 1) <-> alton brown s stove top mac n cheese (Community 2)
#   - lplermagrone (Community 1) <-> amish funeral cookies (Community 2)
#   - lplermagrone (Community 1) <-> amish triple butter biscuits (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: onion
#   - lplermagrone (Community 1) <-> der wiener schnitzel style chili dog sauce (Community 2)
#   - lplermagrone (Community 1) <-> ham  solo savory cake (Community 2)
#   - lplermagrone (Community 1) <-> a 1 steak puffs with corn and avocado salsa  a1 (Community 2)
#   - lplermagrone (Community 1) <-> austrian kaesespaetzle  cheese spaetzle (Community 2)
#   - lplermagrone (Community 1) <-> beef   chickpea paprikash (Community 2)
#   - lplermagrone (Community 1) <-> beer battered fish tacos with pickled onion and cucumber (Community 2)
#   - lplermagrone (Community 1) <-> belizean meat pies (Community 2)
#   - lplermagrone (Community 1) <-> best ever green bean casserole  no canned soup (Community 2)
#   - lplermagrone (Community 1) <-> bratwurst wraps with onion sauerkraut filling (Community 2)
#   - lplermagrone (Community 1) <-> broccoli cheddar latkes (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: Milk
#   - lplermagrone (Community 1) <-> ham  solo savory cake (Community 2)
#   - lplermagrone (Community 1) <-> a 1  slow roasted shredded steak with polenta  a1 (Community 2)
#   - lplermagrone (Community 1) <-> a1 marinated top round with bacon parmesan polenta  a1 (Community 2)
#   - lplermagrone (Community 1) <-> a1b bacon burger bites on white polenta cakes  a1 (Community 2)
#   - lplermagrone (Community 1) <-> amish funeral cookies (Community 2)
#   - lplermagrone (Community 1) <-> amish triple butter biscuits (Community 2)
#   - lplermagrone (Community 1) <-> apple slab pie (Community 2)
#   - lplermagrone (Community 1) <-> aunt carrie s indian pudding (Community 2)
#   - lplermagrone (Community 1) <-> austrian kaesespaetzle  cheese spaetzle (Community 2)
#   - lplermagrone (Community 1) <-> baileys irish cream pancakes (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: butter
#   - lplermagrone (Community 1) <-> ham  solo savory cake (Community 2)
#   - lplermagrone (Community 1) <-> a 1  slow roasted shredded steak with polenta  a1 (Community 2)
#   - lplermagrone (Community 1) <-> a1 marinated top round with bacon parmesan polenta  a1 (Community 2)
#   - lplermagrone (Community 1) <-> acili biskuvi  spicy biscuits (Community 2)
#   - lplermagrone (Community 1) <-> alton brown s stove top mac n cheese (Community 2)
#   - lplermagrone (Community 1) <-> amish funeral cookies (Community 2)
#   - lplermagrone (Community 1) <-> amish triple butter biscuits (Community 2)
#   - lplermagrone (Community 1) <-> apple slab pie (Community 2)
#   - lplermagrone (Community 1) <-> aunt carrie s indian pudding (Community 2)
#   - lplermagrone (Community 1) <-> baileys irish cream pancakes (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: cheese
#   - lplermagrone (Community 1) <-> a 1 steak puffs with corn and avocado salsa  a1 (Community 2)
#   - lplermagrone (Community 1) <-> a1b bacon burger bites on white polenta cakes  a1 (Community 2)
#   - lplermagrone (Community 1) <-> acili biskuvi  spicy biscuits (Community 2)
#   - lplermagrone (Community 1) <-> beer cheese stuffed pretzels (Community 2)
#   - lplermagrone (Community 1) <-> bratwurst wraps with onion sauerkraut filling (Community 2)
#   - lplermagrone (Community 1) <-> broccoli cauliflower mac and cheese (Community 2)
#   - lplermagrone (Community 1) <-> chicken green chile relleno bake (Community 2)
#   - lplermagrone (Community 1) <-> chorizo   black bean breakfast burritos  oamc (Community 2)
#   - lplermagrone (Community 1) <-> collard greens mac   cheese (Community 2)
#   - lplermagrone (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient
Community 2)
#   - better than a can  homemade sloppy joes (Community 1) <-> spicy lamb meatballs (Community 2)
#   - 15 bean soup in the instant pot (Community 1) <-> breaded fried steak   milanesa (Community 2)
#   - 15 bean soup in the instant pot (Community 1) <-> orange chicken dino nuggets (Community 2)
#   - 15 bean soup in the instant pot (Community 1) <-> pastitsio  slow cooker (Community 2)
#   - 15 bean soup in the instant pot (Community 1) <-> spicy lamb meatballs (Community 2)
#   - alan s vegetarian vegan bean and rice burger mashup (Community 1) <-> breaded fried steak   milanesa (Community 2)
#   - alan s vegetarian vegan bean and rice burger mashup (Community 1) <-> orange chicken dino nuggets (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: mushroom
#   - better than a can  homemade sloppy joes (Community 1) <-> cajun glazed mushrooms (Community 2)
#   - better than a can  homemade sloppy joes (Community 1) <-> chicken cutlets with mushrooms and pearl onions (Community 2)
#   - better than a can  homemade sloppy joes (Community 1) <-> chicken frangelico (Community 2)
#   - better than a can  homemade sloppy joes (Community 1) <-> chicken friand  tourte au poulet et champignons (Community 2)
#   - better than a can  homemade sloppy joes (Community 1) <-> chicken pot pie  using rotisserie chicken (Community 2)
#   - better than a can  homemade sloppy joes (Community 1) <-> creamy chicken casserole with fingerling potatoes (Community 4)
#   - better than a can  homemade sloppy joes (Community 1) <-> dungeness   mushroom chowder (Community 2)
#   - better than a can  homemade sloppy joes (Community 1) <-> francos sea scallops in white wine sauce (Community 2)
#   - better than a can  homemade sloppy joes (Community 1) <-> gryby w smetanye  mushrooms with sour cream (Community 2)
#   - better than a can  homemade sloppy joes (Community 1) <-> instant pot vegetarian stew (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: buns
#   - better than a can  homemade sloppy joes (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - buffalo turkey burgers with blue cheese (Community 2) <-> herb garden grilled hamburgers (Community 1)
#   - buffalo turkey burgers with blue cheese (Community 2) <-> lets talk turkey  burgers with chipotle mayo   a1 (Community 1)
#   - copycat chick fil a spicy deluxe chicken sandwich (Community 2) <-> enchilada burgers (Community 1)
#   - copycat chick fil a spicy deluxe chicken sandwich (Community 2) <-> herb garden grilled hamburgers (Community 1)
#   - copycat chick fil a spicy deluxe chicken sandwich (Community 2) <-> joe holland s hamburgers (Community 1)
#   - copycat chick fil a spicy deluxe chicken sandwich (Community 2) <-> lets talk turkey  burgers with chipotle mayo   a1 (Community 1)
#   - lets talk turkey  burgers with chipotle mayo   a1 (Community 1) <-> sweet potato   black bean burgers (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: celery
#   - better than a can  homemade sloppy joes (Community 1) <-> creamy chicken casserole with fingerling potatoes (Community 4)
#   - better than a can  homemade sloppy joes (Community 1) <-> creamy turkey soup with homemade noodles (Community 2)
#   - better than a can  homemade sloppy joes (Community 1) <-> creme de volaille  french cream of chicken soup (Community 2)
#   - better than a can  homemade sloppy joes (Community 1) <-> hamburger potpie with homemade crust (Community 2)
#   - better than a can  homemade sloppy joes (Community 1) <-> i forgot about the broccoli soup (Community 2)
#   - better than a can  homemade sloppy joes (Community 1) <-> instant pot vegetarian stew (Community 2)
#   - better than a can  homemade sloppy joes (Community 1) <-> spicy lamb meatballs (Community 2)
#   - a yummy chicken noodle soup  8 qt  pressure cooker (Community 1) <-> creamy chicken casserole with fingerling potatoes (Community 4)
#   - a yummy chicken noodle soup  8 qt  pressure cooker (Community 1) <-> creamy turkey soup with homemade noodles (Community 2)
#   - a yummy chicken noodle soup  8 qt  pressure cooker (Community 1) <-> creme de volaille  french cream of chicken soup (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: oil
#   - buffalo wing  mushrooms (Community 2) <-> artichoke heart frittata (Community 1)
#   - buffalo wing  mushrooms (Community 2) <-> asian chicken meatball   rice noodle soup (Community 1)
#   - buffalo wing  mushrooms (Community 2) <-> bacon kissed cauliflower dip w  crispy corn tortillas  ragu (Community 1)
#   - buffalo wing  mushrooms (Community 2) <-> baked mango sriracha cauliflower wings (Community 1)
#   - buffalo wing  mushrooms (Community 2) <-> blackened cod with mango salsa (Community 1)
#   - buffalo wing  mushrooms (Community 2) <-> bobotie  south african curry meat loaf (Community 1)
#   - buffalo wing  mushrooms (Community 2) <-> brazilian shrimp stew (Community 1)
#   - buffalo wing  mushrooms (Community 2) <-> broiled halibut steaks with cranberry compote (Community 1)
#   - buffalo wing  mushrooms (Community 2) <-> burnt garlic whole wheat or gluten free noodles (Community 1)
#   - buffalo wing  mushrooms (Community 2) <-> cajun french fries  lowfat (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: panko
#   - buffalo wing  mushrooms (Community 2) <-> bacon kissed cauliflower dip w  crispy corn tortillas  ragu (Community 1)
#   - buffalo wing  mushrooms (Community 2) <-> baklava salmon with asparagus (Community 1)
#   - buffalo wing  mushrooms (Community 2) <-> cheesesteak stuffed onion rings (Community 1)
#   - buffalo wing  mushrooms (Community 2) <-> cheesy potato zucchini casserole (Community 1)
#   - buffalo wing  mushrooms (Community 2) <-> chicken and mushroom patties  kotlety or katleti (Community 1)
#   - buffalo wing  mushrooms (Community 2) <-> coconut shrimp pizza (Community 1)
#   - buffalo wing  mushrooms (Community 2) <-> crispy chicken thighs in convection oven (Community 1)
#   - buffalo wing  mushrooms (Community 2) <-> lettuce wrap fish tacos (Community 1)
#   - buffalo wing  mushrooms (Community 2) <-> oven fried chicken sliders (Community 1)
#   - buffalo wing  mushrooms (Community 2) <-> sizzler s malibu chicken (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: cumin
#   - dorito  popcorn seasoning (Community 1) <-> beer battered fish tacos with pickled onion and cucumber (Community 2)
#   - dorito  popcorn seasoning (Community 1) <-> belizean meat pies (Community 2)
#   - dorito  popcorn seasoning (Community 1) <-> buffalo cauliflower sandwich (Community 2)
#   - dorito  popcorn seasoning (Community 1) <-> curried chicken moghlai (Community 2)
#   - dorito  popcorn seasoning (Community 1) <-> taco bell style crunch wrap supreme (Community 2)
#   - dorito  popcorn seasoning (Community 1) <-> welsh dragon pie (Community 2)
#   - west african s finest  mafe (Community 1) <-> beer battered fish tacos with pickled onion and cucumber (Community 2)
#   - west african s finest  mafe (Community 1) <-> belizean meat pies (Community 2)
#   - west african s finest  mafe (Community 1) <-> buffalo cauliflower sandwich (Community 2)
#   - west african s finest  mafe (Community 1) <-> curried chicken moghlai (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: yeast
#   - dorito  popcorn seasoning (Community 1) <-> beer cheese stuffed pretzels (Community 2)
#   - dorito  popcorn seasoning (Community 1) <-> chili cheese croissant corndogs (Community 2)
#   - dorito  popcorn seasoning (Community 1) <-> jalapeno bagels (Community 2)
#   - dorito  popcorn seasoning (Community 1) <-> onion lover s twist (Community 2)
#   - dorito  popcorn seasoning (Community 1) <-> onion rye loaf  bread machine (Community 2)
#   - dorito  popcorn seasoning (Community 1) <-> rosemary and toasted onion bread  bread machine dough (Community 2)
#   - dorito  popcorn seasoning (Community 1) <-> spicy lamb meatballs (Community 2)
#   - dorito  popcorn seasoning (Community 1) <-> vegan pizza margherita (Community 2)
#   - american sandwich bread   abm or oven (Community 2) <-> creamy vegan potato soup (Community 1)
#   - american sandwich bread   abm or oven (Community 2) <-> skillet margarita pizza (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: spray
#   - ham  solo savory cake (Community 2) <-> 1 minute breakfast sandwich (Community 1)
#   - ham  solo savory cake (Community 2) <-> air fried onion rings (Community 1)
#   - ham  solo savory cake (Community 2) <-> almond chive salmon (Community 1)
#   - ham  solo savory cake (Community 2) <-> breakfast taquitos (Community 1)
#   - ham  solo savory cake (Community 2) <-> cauliflower tots (Community 1)
#   - ham  solo savory cake (Community 2) <-> chicken  spinach and cannellini bean quesadillas (Community 1)
#   - ham  solo savory cake (Community 2) <-> katel s tweaked world s best lasagna (Community 1)
#   - ham  solo savory cake (Community 2) <-> lets talk turkey  burgers with chipotle mayo   a1 (Community 1)
#   - ham  solo savory cake (Community 2) <-> omelet bites (Community 1)
#   - ham  solo savory cake (Community 2) <-> skillet mac n cheese (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: egg
#   - ham  solo savory cake (Community 2) <-> 1 minute breakfast sandwich (Community 1)
#   - ham  solo savory cake (Community 2) <-> air fried onion rings (Community 1)
#   - ham  solo savory cake (Community 2) <-> arby s oven baked curly fries (Community 1)
#   - ham  solo savory cake (Community 2) <-> baked turkey quinoa meatballs (Community 1)
#   - ham  solo savory cake (Community 2) <-> butternut squash  spinach   goat cheese pie (Community 1)
#   - ham  solo savory cake (Community 2) <-> cauliflower tots (Community 1)
#   - ham  solo savory cake (Community 2) <-> cheesesteak stuffed onion rings (Community 1)
#   - ham  solo savory cake (Community 2) <-> cheesy chicken parm volcanos (Community 1)
#   - ham  solo savory cake (Community 2) <-> chicken and pepper (Community 1)
#   - ham  solo savory cake (Community 2) <-> chicken meatball tikka masala (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: ham
#   - ham  solo savory cake (Community 2) <-> 15 bean soup in the instant pot (Community 1)
#   - ham  solo savory cake (Community 2) <-> crock pot lentil   ham soup (Community 1)
#   - ham  solo savory cake (Community 2) <-> crockpot pinto beans and ham (Community 1)
#   - ham  solo savory cake (Community 2) <-> ellen s potato soup (Community 1)
#   - ham  solo savory cake (Community 2) <-> ham and cheese frittata (Community 1)
#   - ham  solo savory cake (Community 2) <-> instant pot cheesy ham and potato soup (Community 1)
#   - ham  solo savory cake (Community 2) <-> kings hawaiian  ham   swiss slider (Community 1)
#   - ham  solo savory cake (Community 2) <-> low carb amish ham casserole (Community 1)
#   - ham  solo savory cake (Community 2) <-> mamaw s ham   dumplings (Community 1)
#   - ham  solo savory cake (Community 2) <-> nassau peas and rice (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: cheddar
#   - ham  solo savory cake (Community 2) <-> 4 delicious french fry toppers (Community 1)
#   - ham  solo savory cake (Community 2) <-> amazing baked chicken breasts    you must try   easy to make (Community 1)
#   - ham  solo savory cake (Community 2) <-> artichoke heart frittata (Community 1)
#   - ham  solo savory cake (Community 2) <-> baked potato volcano (Community 1)
#   - ham  solo savory cake (Community 2) <-> breakfast taquitos (Community 1)
#   - ham  solo savory cake (Community 2) <-> campbell s mini green bean casseroles (Community 1)
#   - ham  solo savory cake (Community 2) <-> cheesy buffalo chicken skulls (Community 1)
#   - ham  solo savory cake (Community 2) <-> chicken helper   chicken enchilada copycat (Community 1)
#   - ham  solo savory cake (Community 2) <-> cornbread squash casserole (Community 1)
#   - ham  solo savory cake (Community 2) <-> creamy spaghetti with beef and veggies (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: chives
#   - ham  solo savory cake (Community 2) <-> almond chive salmon (Community 1)
#   - ham  solo savory cake (Community 2) <-> amazing baked chicken breasts    you must try   easy to make (Community 1)
#   - ham  solo savory cake (Community 2) <-> breakfast muffins to go (Community 1)
#   - ham  solo savory cake (Community 2) <-> cast iron steaks with herb butter (Community 1)
#   - ham  solo savory cake (Community 2) <-> cheeseboard supper potatoes (Community 1)
#   - ham  solo savory cake (Community 2) <-> crab cake stuffed mushrooms (Community 1)
#   - ham  solo savory cake (Community 2) <-> crawfish or shrimp bisque (Community 1)
#   - ham  solo savory cake (Community 2) <-> french onion baked potato soup (Community 1)
#   - ham  solo savory cake (Community 2) <-> garlic and herb mashed potatoes (Community 1)
#   - ham  solo savory cake (Community 2) <-> hungarian chicken breasts (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: Bisquick
#   - ham  solo savory cake (Community 2) <-> instant pot chicken and dumplings (Community 1)
#   - bisquick crepes (Community 2) <-> instant pot chicken and dumplings (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: potato
#   - west african s finest  mafe (Community 1) <-> a 1  slow roasted shredded steak with polenta  a1 (Community 2)
#   - west african s finest  mafe (Community 1) <-> broccoli cheddar latkes (Community 2)
#   - west african s finest  mafe (Community 1) <-> charquican   chilean beef stew (Community 2)
#   - west african s finest  mafe (Community 1) <-> chicken pot pie  using rotisserie chicken (Community 2)
#   - west african s finest  mafe (Community 1) <-> deruny   ukrainian potato pancakes (Community 2)
#   - west african s finest  mafe (Community 1) <-> dhaba style aloo paratha (Community 2)
#   - west african s finest  mafe (Community 1) <-> dungeness   mushroom chowder (Community 2)
#   - west african s finest  mafe (Community 1) <-> easy potato latkes (Community 2)
#   - west african s finest  mafe (Community 1) <-> gwen s old fashioned potato beef casserole  trisha yearwood (Community 2)
#   - west african s finest  mafe (Community 1) <-> hamburger hash brown casserole (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: thyme
#   - west african s finest  mafe (Community 1) <-> apple mango chutney (Community 2)
#   - west african s finest  mafe (Community 1) <-> belizean meat pies (Community 2)
#   - west african s finest  mafe (Community 1) <-> chicken cutlets with mushrooms and pearl onions (Community 2)
#   - west african s finest  mafe (Community 1) <-> chicken pot pie  using rotisserie chicken (Community 2)
#   - west african s finest  mafe (Community 1) <-> cornmeal crusted oven fried chicken (Community 2)
#   - west african s finest  mafe (Community 1) <-> creamy ham and gnocchi bake (Community 2)
#   - west african s finest  mafe (Community 1) <-> dungeness   mushroom chowder (Community 2)
#   - west african s finest  mafe (Community 1) <-> fingers fried chicken (Community 2)
#   - west african s finest  mafe (Community 1) <-> i forgot about the broccoli soup (Community 2)
#   - west african s finest  mafe (Community 1) <-> prime rib with garlic herb butter (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: stock
#   - west african s finest  mafe (Community 1) <-> beef   chickpea paprikash (Community 2)
#   - west african s finest  mafe (Community 1) <-> bok choy in cream sauce (Community 2)
#   - west african s finest  mafe (Community 1) <-> butternut squash soup with bacon and cheddar (Community 2)
#   - west african s finest  mafe (Community 1) <-> chicken frangelico (Community 2)
#   - west african s finest  mafe (Community 1) <-> curried chicken moghlai (Community 2)
#   - west african s finest  mafe (Community 1) <-> julia belle s world famous macaroni and cheese (Community 2)
#   - west african s finest  mafe (Community 1) <-> pork chop with sweet potato and pineapple (Community 2)
#   - west african s finest  mafe (Community 1) <-> sweet potato soup with matchstick fries and frizzled leeks (Community 2)
#   - west african s finest  mafe (Community 1) <-> welsh dragon pie (Community 2)
#   - 5 minute healthy sauted red cabbage (Community 1) <-> beef   chickpea paprikash (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: chickpea
#   - west african s finest  mafe (Community 1) <-> beef   chickpea paprikash (Community 2)
#   - baked shrimp and orzo with chickpeas  lemon  and dill (Community 1) <-> beef   chickpea paprikash (Community 2)
#   - beef   chickpea paprikash (Community 2) <-> chana masala in the slow cooker (Community 1)
#   - beef   chickpea paprikash (Community 2) <-> chana punjabi  indian chickpea stew (Community 1)
#   - beef   chickpea paprikash (Community 2) <-> chickpea pilaf (Community 1)
#   - beef   chickpea paprikash (Community 2) <-> chicpea salad sandwiches (Community 1)
#   - beef   chickpea paprikash (Community 2) <-> dees bell pepper salad (Community 1)
#   - beef   chickpea paprikash (Community 2) <-> harira soup (Community 1)
#   - beef   chickpea paprikash (Community 2) <-> mintea couscous  vegan (Community 1)
#   - beef   chickpea paprikash (Community 2) <-> moroccan cauliflower couscous salad (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: rice
#   - west african s finest  mafe (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - west african s finest  mafe (Community 1) <-> chicken margarita   saffron yellow rice (Community 2)
#   - west african s finest  mafe (Community 1) <-> chicken teriyaki meatballs (Community 2)
#   - west african s finest  mafe (Community 1) <-> orange chicken dino nuggets (Community 2)
#   - west african s finest  mafe (Community 1) <-> perfect gluten free pie crust (Community 2)
#   - west african s finest  mafe (Community 1) <-> pumpkin pancakes  gluten free (Community 2)
#   - west african s finest  mafe (Community 1) <-> spinach rice pot (Community 2)
#   - west african s finest  mafe (Community 1) <-> thai peanut coconut chicken (Community 2)
#   - west african s finest  mafe (Community 1) <-> wild rice and ham soup   lower fat (Community 2)
#   - 5 minute general tsos chicken (Community 1) <-> best general tso s chicken from serious eats (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: peanut oil
#   - west african s finest  mafe (Community 1) <-> best general tso s chicken from serious eats (Community 2)
#   - west african s finest  mafe (Community 1) <-> copycat chick fil a spicy deluxe chicken sandwich (Community 2)
#   - west african s finest  mafe (Community 1) <-> quick golden crispy latkes (Community 2)
#   - best general tso s chicken from serious eats (Community 2) <-> chicken in red curry and coconut (Community 1)
#   - best general tso s chicken from serious eats (Community 2) <-> gulai sayur  collard greens curry indonesian style (Community 1)
#   - best general tso s chicken from serious eats (Community 2) <-> hainanese chicken and rice  instant pot (Community 1)
#   - best general tso s chicken from serious eats (Community 2) <-> p f chang s beef a la sichuan (Community 1)
#   - best general tso s chicken from serious eats (Community 2) <-> p f chang s lo mein (Community 1)
#   - best general tso s chicken from serious eats (Community 2) <-> spicy fried ginger beef (Community 1)
#   - best general tso s chicken from serious eats (Community 2) <-> spicy thai basil beef (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: carrot
#   - west african s finest  mafe (Community 1) <-> charquican   chilean beef stew (Community 2)
#   - west african s finest  mafe (Community 1) <-> creamy turkey soup with homemade noodles (Community 2)
#   - west african s finest  mafe (Community 1) <-> creme de volaille  french cream of chicken soup (Community 2)
#   - west african s finest  mafe (Community 1) <-> hamburger potpie with homemade crust (Community 2)
#   - west african s finest  mafe (Community 1) <-> incredible cheesy broccoli soup   weight watchers (Community 2)
#   - west african s finest  mafe (Community 1) <-> instant pot vegetarian stew (Community 2)
#   - west african s finest  mafe (Community 1) <-> klotski  potato dumplings in chicken broth (Community 2)
#   - west african s finest  mafe (Community 1) <-> memes meal (Community 2)
#   - west african s finest  mafe (Community 1) <-> moroccan carrots (Community 2)
#   - west african s finest  mafe (Community 1) <-> oriental chicken salad with honey sesame dressing (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: peanut butter
#   - west african s finest  mafe (Community 1) <-> thai peanut coconut chicken (Community 2)
#   - peanut noodles with pork (Community 1) <-> thai peanut coconut chicken (Community 2)
#   - thai peanut coconut chicken (Community 2) <-> turkey meatballs and peanut sauce (Community 1)
#   - thai peanut coconut chicken (Community 2) <-> wings peanut butter and jelly wings (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: avocado
#   - 1 minute breakfast sandwich (Community 1) <-> a 1 steak puffs with corn and avocado salsa  a1 (Community 2)
#   - 1 minute breakfast sandwich (Community 1) <-> sweet potato   black bean burgers (Community 2)
#   - 3 ingredient carnitas (Community 1) <-> a 1 steak puffs with corn and avocado salsa  a1 (Community 2)
#   - 7 layer elote dip (Community 1) <-> a 1 steak puffs with corn and avocado salsa  a1 (Community 2)
# ...
#   - island holiday (Community 2) <-> watermelon sangria with sriracha (Community 1)
#   - lemongrass  lime   thai basil mojito (Community 1) <-> strawberry daiquiri jam (Community 2)
#   - pina colada pineapple cakes (Community 2) <-> pina colada shrimp (Community 1)
#   - pina colada shrimp (Community 1) <-> strawberry daiquiri jam (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: caraway
#   - curried chicken moghlai (Community 2) <-> paprika pork chops (Community 1)
#   - curried chicken moghlai (Community 2) <-> roasted potatoes  leeks and cabbage (Community 1)
#   - curried chicken moghlai (Community 2) <-> umami bomb (Community 1)
#   - mrs  o callaghan s soda bread (Community 2) <-> paprika pork chops (Community 1)
#   - paprika pork chops (Community 1) <-> schinkenfleckerln    ham noodle casserole (Community 2)
#   - roasted potatoes  leeks and cabbage (Community 1) <-> schinkenfleckerln    ham noodle casserole (Community 2)
#   - schinkenfleckerln    ham noodle casserole (Community 2) <-> umami bomb (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: rose
#   - darcey s special dukkah (Community 1) <-> dark   sumptuous chocolate cake (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: Toast
#   - dees breakfast melt (Community 2) <-> smoked salmon   avocado baked eggs (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: cranberry
#   - dorothy s cranberry bread (Community 2) <-> thanksgiving turkey meatloaf (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: Yogurt
#   - easy bagel dogs weight watchers friendly (Community 2) <-> spicy beef flatbread with yogurt   cucumbers (Community 1)
#   - easy bagel dogs weight watchers friendly (Community 2) <-> turkish green bean salad (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: ice
#   - fig and bourbon fizz (Community 1) <-> rosie o grady s minty lemon iced tea (Community 2)
#   - red eye mojito (Community 1) <-> rosie o grady s minty lemon iced tea (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: scallops
#   - francos sea scallops in white wine sauce (Community 2) <-> lemon butter scallops (Community 1)
#   - francos sea scallops in white wine sauce (Community 2) <-> miso broiled scallops (Community 1)
#   - francos sea scallops in white wine sauce (Community 2) <-> scallops marinara with spinach linguine (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: baguette
#   - french onion soup ii (Community 1) <-> zuppa di cipolla al vino rosso (Community 2)
#   - lump crabmeat and avocado crostini (Community 1) <-> zuppa di cipolla al vino rosso (Community 2)
#   - sheet pan shrimp scampi (Community 1) <-> zuppa di cipolla al vino rosso (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: strawberry
#   - french toast roll ups (Community 2) <-> strawberry mint quinoa salad with lemon vinaigrette featuring ve (Community 1)
#   - fresh strawberry cake with white chocolate chips (Community 2) <-> strawberry mint quinoa salad with lemon vinaigrette featuring ve (Community 1)
#   - strawberry basil mojito (Community 1) <-> strawberry daiquiri jam (Community 2)
#   - strawberry blessed snow with custard sauce (Community 2) <-> strawberry mint quinoa salad with lemon vinaigrette featuring ve (Community 1)
#   - strawberry mint quinoa salad with lemon vinaigrette featuring ve (Community 1) <-> twice baked jumbo mini cheesecakes (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: peppercorn
#   - garlic pepper sausage linguine pasta (Community 1) <-> klotski  potato dumplings in chicken broth (Community 2)
#   - grilled pork tenderloin with peach barbecue sauce (Community 1) <-> klotski  potato dumplings in chicken broth (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: pepperoni
#   - gastric sleeve white bean soup with extra protein and bone broth (Community 1) <-> mac   cheese stuffed crust pizza (Community 2)
#   - mac   cheese stuffed crust pizza (Community 2) <-> pepperoni pizza lasagna rolls (Community 1)
#   - mac   cheese stuffed crust pizza (Community 2) <-> pizza skulls (Community 1)
#   - mac   cheese stuffed crust pizza (Community 2) <-> portobello pizzas (Community 1)
#   - mac   cheese stuffed crust pizza (Community 2) <-> pull apart pepperoni pizza bread  monkey pizza (Community 1)
#   - mac   cheese stuffed crust pizza (Community 2) <-> rigatoni pizza pie (Community 1)
#   - mini pepperoni calzones (Community 1) <-> pepperoni and mozzarella stuffed chicken breasts (Community 2)
#   - pepperoni and mozzarella stuffed chicken breasts (Community 2) <-> pepperoni pizza lasagna rolls (Community 1)
#   - pepperoni and mozzarella stuffed chicken breasts (Community 2) <-> pizza lasagna (Community 1)
#   - pepperoni and mozzarella stuffed chicken breasts (Community 2) <-> portobello pizzas (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: meat
#   - gheyme (Community 1) <-> hamburger potpie with homemade crust (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: strawberries
#   - glazed strawberry galette (Community 2) <-> irish scrambler and irish bangers (Community 1)
#   - irish scrambler and irish bangers (Community 1) <-> not your grandmothers fruitcake (Community 2)
#   - irish scrambler and irish bangers (Community 1) <-> old fashioned triple lemon cake (Community 2)
#   - irish scrambler and irish bangers (Community 1) <-> red  white and blueberry trifle (Community 2)
#   - irish scrambler and irish bangers (Community 1) <-> valentines day recipe (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: brioche
#   - gouda grilled cheese with tahini black bean hummus (Community 1) <-> open face bacon jam and egg sandwich  a1 (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: stuffing
#   - green bean  chicken   stuffing casserole (Community 4) <-> the turducken of thanksgiving sides (Community 2)
#   - thanksgiving turkey meatloaf (Community 1) <-> the turducken of thanksgiving sides (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: sake
#   - grilled chicken wings   japanese style (Community 1) <-> home style sushi over rice  chirashizushi (Community 2)
#   - home style sushi over rice  chirashizushi (Community 2) <-> shrimp in chili sauce  ebi no chili sauce (Community 1)
#   - home style sushi over rice  chirashizushi (Community 2) <-> steak teriyaki (Community 1)
#   - home style sushi over rice  chirashizushi (Community 2) <-> wasabi ae  broccoli with wasabi sauce (Community 3)
#   - home style sushi over rice  chirashizushi (Community 2) <-> wholly huli pulled pork (Community 1)
#   - home style sushi over rice  chirashizushi (Community 2) <-> yakitori chicken (Community 1)
#   - shrimp in chili sauce  ebi no chili sauce (Community 1) <-> wasabi ae  broccoli with wasabi sauce (Community 3)
#   - wasabi ae  broccoli with wasabi sauce (Community 3) <-> wholly huli pulled pork (Community 1)
#   - wasabi ae  broccoli with wasabi sauce (Community 3) <-> yakitori chicken (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: fruit
#   - ham and cheese frittata (Community 1) <-> pumpkin spice french toast bake (Community 2)
#   - ham and cheese frittata (Community 1) <-> super creamy scrambled eggs (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: msg
#   - hemingway s favorite burger (Community 1) <-> vietnamese caramelized pork  thit ko    instant pot version (Community 3)
#   - killer voodoo gumbo (Community 1) <-> vietnamese caramelized pork  thit ko    instant pot version (Community 3)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: wasabi
#   - hiyashi somen   cold noodles with dipping sauce mark bittman (Community 3) <-> home style sushi over rice  chirashizushi (Community 2)
#   - home style sushi over rice  chirashizushi (Community 2) <-> jk wasabi dip  public (Community 1)
#   - home style sushi over rice  chirashizushi (Community 2) <-> tuna tartar (Community 3)
#   - home style sushi over rice  chirashizushi (Community 2) <-> wasabi ae  broccoli with wasabi sauce (Community 3)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: nori
#   - home style sushi over rice  chirashizushi (Community 2) <-> sushi bake (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: roll
#   - honey poppy seed roll   bread (Community 2) <-> mexican tabbouleh (Community 1)
#   - honey poppy seed roll   bread (Community 2) <-> oven fried chicken sliders (Community 1)
#   - honey poppy seed roll   bread (Community 2) <-> peppered sliders (Community 1)
#   - honey poppy seed roll   bread (Community 2) <-> vietnamese bun cha gio (Community 1)
#   - royal crown strawberry pie (Community 2) <-> vietnamese bun cha gio (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: sambal
#   - indonesian malaysian street noodles (Community 1) <-> spicy lamb meatballs (Community 2)
#   - spicy daal (Community 1) <-> spicy lamb meatballs (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: pita
#   - instant pot beef shawarma (Community 1) <-> sugared pita with fried apples (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: orange juice
#   - instant pot or slow cooker pork carnitas (Community 1) <-> moroccan carrots (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: whiskey
#   - irish bread pudding with whiskey caramel sauce (Community 2) <-> whiskey pretzels (Community 1)
#   - pielogen (Community 2) <-> whiskey pretzels (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: potatoes
#   - kartoffelpuffer  german potato pancakes   sp5 (Community 2) <-> red wine braised short ribs with fingerlings potatoes (Community 1)
#   - kartoffelpuffer  german potato pancakes   sp5 (Community 2) <-> sheet pan breakfast bake (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: bun
#   - kenji s better big mac (Community 1) <-> mini chicken breast sliders (Community 2)
#   - mini chicken breast sliders (Community 2) <-> root beer bbq pulled pork (Community 1)
#   - mini chicken breast sliders (Community 2) <-> spicy tuna sandwich (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: ribs
#   - kenji s better big mac (Community 1) <-> sweet and spicy short ribs (Community 2)
#   - peruvian breakfast sandwich (Community 1) <-> sweet and spicy short ribs (Community 2)
#   - pork ribs perfection (Community 1) <-> sweet and spicy short ribs (Community 2)
#   - red wine braised short ribs with fingerlings potatoes (Community 1) <-> sweet and spicy short ribs (Community 2)
#   - sweet and spicy short ribs (Community 2) <-> sweet dry rub baby back ribs   6 qt electric pressure cooker (Community 1)
#   - sweet and spicy short ribs (Community 2) <-> sweet tea baby back ribs (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: noodle
#   - neopolitan nachos  ragu (Community 1) <-> oriental chicken salad with honey sesame dressing (Community 2)
#   - oriental chicken salad with honey sesame dressing (Community 2) <-> p f chang s lo mein (Community 1)
#   - oriental chicken salad with honey sesame dressing (Community 2) <-> peanut noodles with pork (Community 1)
#   - oriental chicken salad with honey sesame dressing (Community 2) <-> pork belly ramen (Community 1)
#   - oriental chicken salad with honey sesame dressing (Community 2) <-> skinny beef and broccoli (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: trout
#   - pan fried rainbow trout (Community 2) <-> rainbow trout  tilapia  baked (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: chicken broth
#   - pei wei asian diner caramel chicken (Community 2) <-> spicy szechuan orange chicken   ww (Community 1)
#   - pei wei asian diner caramel chicken (Community 2) <-> ww soba chicken noodle bowl (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: tapioca
#   - perfect gluten free pie crust (Community 2) <-> stove top pot roast with gravy  potatoes and carrots (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: miso
#   - pork belly ramen (Community 1) <-> tuna tartar (Community 3)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: Lard
#   - pork carnitas (Community 1) <-> welsh dragon pie (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: Za'atar
#   - pureed beets with yogurt   zaatar (Community 1) <-> zaatar pita bread (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: grits
#   - smothered pork chops and grits (Community 1) <-> vanilla cornmeal griddle cakes with pears (Community 2)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: goat cheese
#   - spicy lamb meatballs (Community 2) <-> stuffed banana peppers (Community 1)
# ------------------------------------------------------------------------------------------------------------------------
#
# Ingredient: tuna
#   - spicy tuna sandwich (Community 1) <-> tuna noodle broccoli casserole (Community 2)
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## What are the most versatile or influential recipes based on their graph connectivity?

# %%
def compute_centralities(graph):
    degree_centrality = nx.degree_centrality(graph)
    betweenness_centrality = nx.betweenness_centrality(graph)
    closeness_centrality = nx.closeness_centrality(graph)
    eigenvector_centrality = nx.eigenvector_centrality(graph)
    
    return {
        'degree': degree_centrality,
        'betweenness': betweenness_centrality,
        'closeness': closeness_centrality,
        'eigenvector': eigenvector_centrality
    }

def get_top_recipes(graph, centralities, centrality_type='degree', top_n=10):
    if centrality_type not in centralities:
        raise ValueError("Invalid centrality type. Choose from ['degree', 'betweenness', 'closeness', 'eigenvector']")
    
    sorted_centralities = sorted(centralities[centrality_type].items(), key=lambda x: x[1], reverse=True)
    sorted_centralities = [(graph.nodes[node]['name'], centrality) for node, centrality in sorted_centralities]
    return sorted_centralities[:top_n] 



def get_top_recipes_by_frequency(graph, centralities, top_n=5):
    all_top_recipes = []
    
    for centrality_type in ['degree', 'betweenness', 'closeness', 'eigenvector']:
        top_recipes = get_top_recipes(graph, centralities, centrality_type=centrality_type, top_n=top_n)
        all_top_recipes.extend([recipe[0] for recipe in top_recipes]) 
    
    recipe_counts = Counter(all_top_recipes)
    
    top_recipes_by_frequency = recipe_counts.most_common(top_n)
    
    return top_recipes_by_frequency

# %%
def centralities_info(graph, graph_name):
    
    centralities = compute_centralities(graph)
    print(f"Centralities for {graph_name}: {centralities}")

    top_recipes_by_frequency = get_top_recipes_by_frequency(graph, centralities, top_n=5)
    print(f"Top Recipes by Frequency across Centralities in {graph_name}:")
512716': 0.001736111111111111, '536564': 0.10069444444444443, '513221': 0.08564814814814814, '516718': 0.14699074074074073, '524716': 0.5179398148148148, '513094': 0.4265046296296296, '530386': 0.3472222222222222, '514211': 0.31307870370370366, '516897': 0.3333333333333333, '535581': 0.49479166666666663, '520110': 0.3483796296296296, '533718': 0.29050925925925924, '513817': 0.2725694444444444, '533649': 0.02199074074074074, '518070': 0.36689814814814814, '513941': 0.5543981481481481, '515852': 0.22800925925925924, '530364': 0.21238425925925924, '528861': 0.1736111111111111, '522710': 0.4288194444444444, '529772': 0.3680555555555555, '512106': 0.34432870370370366, '524817': 0.3263888888888889, '532486': 0.5196759259259259, '537076': 0.2361111111111111, '520337': 0.30092592592592593, '515814': 0.445 ...
# Top Recipes by Frequency across Centralities in Recipe network with min. 3 common ingredients:
# spicy lamb meatballs: 4 times
# orange chicken dino nuggets: 4 times
# copycat chick fil a spicy deluxe chicken sandwich: 4 times
# traditional style pastitsio  ragu: 3 times
# curried chicken moghlai: 3 times

# %%
def plot_centrality_distributions(df, graph_name):
    centrality_types = ['degree', 'closeness', 'betweenness', 'eigenvector']
    titles = [
        'Degree Centrality',
        'Closeness Centrality',
        'Betweenness Centrality',
        'Eigenvector Centrality'
    ]

    fig, axes = plt.subplots(1, 4, figsize=(20, 5))

    for ax, centrality_type, title in zip(axes, centrality_types, titles):
        ax.hist(df[centrality_type], bins=30, edgecolor='black')
        ax.set_title(f'Distribution of {title}')
        ax.set_xlabel(f'{title} Value')
        ax.set_ylabel('Frequency')

    plt.suptitle(f'Distribution of Centralities for {graph_name}', fontsize=16)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95]) 
    plt.show()

# %%
centralities = compute_centralities(recipes_graph)
df = pd.DataFrame(centralities)
plot_centrality_distributions(df, recipes_graph)

# %% [markdown]
# ## Extra calculations

# %%
def compute_correlation(df, col1, col2):
    pearson_corr, _ = pearsonr(df[col1], df[col2])
    spearman_corr, _ = spearmanr(df[col1], df[col2])
    kendall_corr, _ = kendalltau(df[col1], df[col2])
    return pearson_corr, spearman_corr, kendall_corr

def plot_centrality_scatter_plots(df, graph_name):
    centrality_columns = [
        'degree',
        'closeness',
        'betweenness',
        'eigenvector'
    ]
    
    fig, axes = plt.subplots(2, 3, figsize=(20, 10))
    axes = axes.flatten()  
    
    plot_index = 0
    for i in range(len(centrality_columns)):
        for j in range(i + 1, len(centrality_columns)):
            col1 = centrality_columns[i]
            col2 = centrality_columns[j]
            
            pearson_corr, spearman_corr, kendall_corr = compute_correlation(df, col1, col2)
            
            axes[plot_index].scatter(df[col1], df[col2], alpha=0.7)
            axes[plot_index].set_title(f'Scatter Plot: {col1} vs {col2}')
            axes[plot_index].set_xlabel(col1)
            axes[plot_index].set_ylabel(col2)
            
            axes[plot_index].text(0.05, 0.95, f'Pearson: {pearson_corr:.2f}\nSpearman: {spearman_corr:.2f}\nKendall: {kendall_corr:.2f}', 
                                   transform=axes[plot_index].transAxes, fontsize=12, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.5))
            
            plot_index += 1

    plt.tight_layout()
    plt.suptitle(f'Centrality Correlations for {graph_name}', fontsize=16, y=1.02)
    plt.show()

# %%
centralities = compute_centralities(recipes_graph)
df = pd.DataFrame(centralities)
plot_centrality_scatter_plots(df, "Recipe network with min. 3 common ingredients")

# %%
def compute_pearson(df1, df2, col):
    return pearsonr(df1[col], df2[col])[0]

def plot_centrality_comparisons(df_original, df_randomized, graph_name):
    centrality_types = ['degree', 'closeness', 'betweenness', 'eigenvector']
    
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    axes = axes.flatten()

    for i, centrality in enumerate(centrality_types):
        pearson_corr = compute_pearson(df_original, df_randomized, centrality)
        
        axes[i].scatter(df_original[centrality], df_randomized[centrality], alpha=0.7, label=f'Pearson: {pearson_corr:.2f}')
        axes[i].set_title(f'Original vs Randomized: {centrality.capitalize()}', fontsize=14)
        axes[i].set_xlabel(f'Original {centrality.capitalize()}', fontsize=12)
        axes[i].set_ylabel(f'Randomized {centrality.capitalize()}', fontsize=12)
        axes[i].legend()
    
    plt.tight_layout()
    plt.suptitle(f'Centrality Comparisons: Original vs Randomized ({graph_name})', fontsize=16, y=1.02)
    plt.show()

# %%
centralities = compute_centralities(recipes_graph)
df = pd.DataFrame(centralities)
    
randomized_graph = randomize_graph(recipes_graph)
randomized_centralities = compute_centralities(randomized_graph)
df_randomized = pd.DataFrame(randomized_centralities)
    
plot_centrality_comparisons(df, df_randomized, "Recipe network with min. 5 common ingredients")

# %% [markdown]
# ### Observations
#
# We can see on the plots that the Degree Centrality remains unchanged in the randomized graphs, because the degree distribution is preserved by the randomization. In case of Closeness and Betweenness Centrality we can see a lower correlation because randomization disrupts the shortest-path and flow structures. The Eigenvector Centrality also shows lower correlations but the difference is smaller, depending on how connected the nodes are in the random graph versus the original.

# %% [markdown]
#
# #### 1. Degree Centrality
# Degree centrality measures the number of direct connections a node has within the network. A recipe with high degree centrality is one that shares a significant number of ingredients with many other recipes. These recipes likely use common ingredients and might represent versatile or foundational recipes that connect to many others.
#
# During the randomization the edges are randomly rewired, but the node degrees remain unchanged, so the degree distribution remains the same, and therefore, the Degree Centrality remains unchanged, as the total number of connections for each node remained constant. Thats why it has 1.0 correlation.
#
# #### 2. Closeness Centrality
# Closeness centrality reflects how quickly a node can access other nodes in the network, measured by the average shortest path from that node to all others. A recipe with high closeness centrality can quickly "reach" or is closely connected to other recipes in the network. These recipes might be versatile in the sense that they use a set of ingredients that frequently appear in other recipes, making them central to the graph.
#
# Closeness Centrality shows lower correlation because overall the shortest paths are disrupted because of the randomization.
#
# #### 3. Betweenness Centrality
# Betweenness centrality measures the extent to which a node serves as a bridge along the shortest paths between other nodes. Nodes with high betweenness centrality are critical for information flow or connectivity, acting as intermediaries. A recipe with high betweenness centrality acts as a "bridge" between clusters of recipes. These recipes likely share ingredients with multiple distinct groups of recipes and could play a crucial role in connecting different cuisines or cooking styles.
#
# The Betweenness Centrality is also affected by the randomization because when the network is randomized shortest paths are removed or altered, and the nodes that served as intermediaries may no longer fulfill this role. This highlights the sensitivity of betweenness centrality to network structure.
#
# #### 4. Eigenvector Centrality
# Eigenvector centrality evaluates a node's influence based not just on the number of connections but also on the quality and influence of its neighbors. A node connected to other well-connected nodes scores higher. A recipe with high eigenvector centrality is connected to other influential recipes. These recipes are central to the overall structure of the graph and might represent dishes with ingredients that are foundational to many popular or versatile recipes.
#
# With the Eigenvector Centrality the correlation is affected less by the randomization,because it depends on how well the randomization maintains the overall connectivity and flow of importance across nodes. While randomization may disrupt connections, eigenvector centrality continues to reflect the influence of nodes based on their connections to other significant nodes.
#
# #### Observed Differences and Similarities
#
# Degree centrality remained stable in all cases, while closeness, betweenness, and eigenvector centralities were significantly affected by randomization, showcasing how the specific structure of the network influences the sensitivity of different centrality measures.

# %%
def plot_fit(G):
    degrees = [degree for _, degree in G.degree()]

    degrees = [d for d in degrees if d > 0]

    if len(degrees) == 0:
        print("No degrees greater than zero in the graph.")
        return

    fit = powerlaw.Fit(degrees, discrete=True)
    alpha = fit.alpha
    xmin = fit.xmin

    alpha_error = fit.sigma

    print(f"Alpha Error: {alpha_error}")
    print(f"Fitted alpha: {alpha}")

    lam = np.mean(degrees)

    hist, bin_edges = np.histogram(
        degrees,
        bins=np.logspace(np.log10(min(degrees)), np.log10(max(degrees)), num=40),
        density=True
    )
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

    if np.any(np.isnan(hist)):
        print("Histogram contains NaN values. Check degree distribution.")
        return

    degree_values = np.arange(1, max(degrees) + 1)
    poisson_prob = (lam ** degree_values * np.exp(-lam)) / factorial(degree_values)
    exponential_prob = (1 / lam) * np.exp(-degree_values / lam)

    plt.figure(figsize=(7, 5))

    plt.loglog(bin_centers, hist, 'o', color='blue', markersize=5, label="Empirical Data")
    fit.power_law.plot_pdf(color='red', label=f"Power-Law Fit (α={alpha:.2f})")
    plt.loglog(degree_values, poisson_prob, 'g-', label=f'Poisson Fit (λ = {lam:.2f})')
    plt.loglog(degree_values, exponential_prob, 'm-', label=f'Exponential Fit (λ = {lam:.2f})')

    plt.xlabel("Degree (k)", fontsize=12)
    plt.ylabel("Probability (p(k))", fontsize=12)
    plt.title("Empirical Degree Distribution with Power-Law, Poisson, and Exponential Fits", fontsize=14)
    plt.legend()

    max_empirical_prob = np.nanmax(hist) 
    if max_empirical_prob > 0:
        plt.ylim(1e-6, max_empirical_prob * 1.1)
    else:
        print("Maximum empirical probability is zero or invalid.")
        return

    plt.show()

# %%
plot_fit(recipes_graph)
# Out:
# Calculating best minimal value for power law fit
# Alpha Error: 0.10791224308678828
# Fitted alpha: 3.972977400837208
# /var/folders/2j/w5gyp6sx2xqdbzcqb6l19dvr0000gn/T/ipykernel_68462/3553165567.py:33: RuntimeWarning: overflow encountered in power
#   poisson_prob = (lam ** degree_values * np.exp(-lam)) / factorial(degree_values)
# /var/folders/2j/w5gyp6sx2xqdbzcqb6l19dvr0000gn/T/ipykernel_68462/3553165567.py:33: RuntimeWarning: invalid value encountered in divide
#   poisson_prob = (lam ** degree_values * np.exp(-lam)) / factorial(degree_values)
